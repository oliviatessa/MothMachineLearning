# %% [markdown]
# # Callin Switzer
# ### 6 June 2019
# ___
# ### - Train Dense, Feedforward Neural Network with Keras
# ### - Train with fully actuated system

# %% [markdown]
# ___

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.ticker import ScalarFormatter
import matplotlib.colors as colors
import os
import pandas as pd
import time
from datetime import datetime
import sys
import seaborn as sns
import scipy.io
import subprocess
import winsound
import pickle
import glob
import sqlite3

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
print("TensorFlow successfully installed.")
if tf.test.is_built_with_cuda():
    print("The installed version of TensorFlow includes GPU support.")
print(sys.version, "\n")
now = datetime.now()
print("last run on " + str(now))

# define directories
baseDir = os.getcwd()
dataDir = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\PythonGeneratedData_twoTorque'
figDir = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\Figs'
dataOutput = r'D:/Dropbox/AcademiaDropbox/mothMachineLearning_dataAndFigs/DataOutput_twoTorque'
savedModels = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels'
if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
if not os.path.exists(savedModels):
    os.mkdir(savedModels)
# Out:
# C:\Users\calli\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2019-06-12 08:46:30.565206

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Make training and test set

# %% [raw]
# # import data

# %%
# get table names in database
con1 = sqlite3.connect(os.path.join(dataDir, "twoTorqueData.db"))
cursorObj = con1.cursor()
res = cursorObj.execute("SELECT name FROM sqlite_master WHERE type='table';")
tableNames = [name[0] for name in res]
con1.close()
print(tableNames)
# Out:
# ['test', 'train']

# %%
con1 = sqlite3.connect(os.path.join(dataDir, "twoTorqueData.db"))
trainDF = pd.read_sql_query("SELECT * FROM train", con1)
testDF = pd.read_sql_query("SELECT * FROM test", con1)
con1.close()

# %%
trainDF.head()
# Out:
#    x_0         xd_0  y_0        yd_0   theta_0   thetad_0     phi_0  \
# 0  0.0  1147.407904  0.0 -238.429602  1.123847  23.498330  4.482445
# 1  0.0 -1152.043723  0.0  369.845453  4.645359   5.927584  3.398032
# 2  0.0  -592.993151  0.0 -525.687613  5.220594   6.983077  4.307985
# 3  0.0  1338.965230  0.0   61.191760  3.628833 -17.119889  2.109267
# 4  0.0 -1361.776972  0.0  664.606866  1.468084   8.355107  0.008353
#
#       phid_0        x_f         xd_f        y_f        yd_f    theta_f  \
# 0  12.691013  18.723606   691.882850  -4.739545 -293.363224   4.014081
# 1 -19.816137 -23.448395  -706.563802   8.272804  684.314462  14.631620
# 2 -23.696882  -4.641471  -608.960470  -5.348081  430.757954   9.520878
# 3 -11.436424  26.318800   623.841539   0.005384  863.443021  16.589887
# 4   8.528276 -27.521247 -1473.234824  14.165396  774.628129   3.269968
#
#       thetad_f      phi_f       phid_f             F     alpha           tau0  \
# 0   308.066760   8.139222   345.558353  30853.584922  1.797866 -546297.092872
# 1   851.354510  11.946214   778.225185  31872.475362  2.658456  961528.396769
# 2   942.874265   8.779522   955.717081  21305.283236  2.463747 -313643.967698
# 3  1316.282852  15.180057  1307.874474  19428.750439  0.374967 -203911.489339
# 4   165.211558   1.712961   160.158577   8084.383659  1.102396   63102.747684
#
#           tau_w
# 0  10262.953817
# 1  36965.947717
# 2  45809.941477
# 3  47599.081146
# 4   6365.517419

# %%
testDF.head()
# Out:
#    x_0         xd_0  y_0         yd_0   theta_0   thetad_0     phi_0  \
# 0  0.0  1290.475733  0.0  1031.459220  5.901014   9.348979  3.643856
# 1  0.0  -643.287407  0.0  -812.471891  0.923325   5.317080  3.764966
# 2  0.0   817.563373  0.0 -1295.713095  3.073726   4.217052  0.532687
# 3  0.0  -818.423313  0.0  1230.998812  0.037942 -24.356912  1.783597
# 4  0.0 -1240.409449  0.0 -1375.065310  3.503992   9.262691  2.659674
#
#       phid_0        x_f         xd_f        y_f         yd_f    theta_f  \
# 0  17.157149  26.235253  1137.037978  20.847415   289.689136  18.537756
# 1 -24.582937  -9.018544 -1514.026571 -11.076141 -1014.695373 -10.546085
# 2  -4.945442  13.080550  -325.919134 -23.274466  -817.967701  17.014216
# 3  17.914569 -13.849188 -1982.346897  19.697223  1963.656391 -11.793649
# 4  -6.227951 -10.039456 -1427.009664  -9.628598 -1844.939378   5.908790
#
#       thetad_f      phi_f       phid_f             F     alpha           tau0  \
# 0  1221.875359  15.098098  1167.837706  10507.464077  0.559591  799932.656919
# 1 -1478.783791  -6.871128 -1435.593398  34686.690435  1.063056 -737949.278098
# 2  1687.486984  14.956286  1693.827720  27441.473272  0.549398 -575984.856139
# 3 -1541.793049 -10.608393 -1556.139800   4053.551364  3.837047  617346.567027
# 4   590.782422   4.559646   516.295982  17916.938852  1.558088  967963.511996
#
#           tau_w
# 0  61301.505115
# 1 -97316.403803
# 2  87908.705311
# 3 -53108.537683
# 4  52430.831318

# %%
# double check for repeats!
np.sum(trainDF.iloc[:, [16,17,18]].duplicated()) # 0 means no repeats
# Out:
# 0

# %%
print(trainDF.shape)
trainDF.head()
# Out:
# (10000000, 20)
#    x_0         xd_0  y_0        yd_0   theta_0   thetad_0     phi_0  \
# 0  0.0  1147.407904  0.0 -238.429602  1.123847  23.498330  4.482445
# 1  0.0 -1152.043723  0.0  369.845453  4.645359   5.927584  3.398032
# 2  0.0  -592.993151  0.0 -525.687613  5.220594   6.983077  4.307985
# 3  0.0  1338.965230  0.0   61.191760  3.628833 -17.119889  2.109267
# 4  0.0 -1361.776972  0.0  664.606866  1.468084   8.355107  0.008353
#
#       phid_0        x_f         xd_f        y_f        yd_f    theta_f  \
# 0  12.691013  18.723606   691.882850  -4.739545 -293.363224   4.014081
# 1 -19.816137 -23.448395  -706.563802   8.272804  684.314462  14.631620
# 2 -23.696882  -4.641471  -608.960470  -5.348081  430.757954   9.520878
# 3 -11.436424  26.318800   623.841539   0.005384  863.443021  16.589887
# 4   8.528276 -27.521247 -1473.234824  14.165396  774.628129   3.269968
#
#       thetad_f      phi_f       phid_f             F     alpha           tau0  \
# 0   308.066760   8.139222   345.558353  30853.584922  1.797866 -546297.092872
# 1   851.354510  11.946214   778.225185  31872.475362  2.658456  961528.396769
# 2   942.874265   8.779522   955.717081  21305.283236  2.463747 -313643.967698
# 3  1316.282852  15.180057  1307.874474  19428.750439  0.374967 -203911.489339
# 4   165.211558   1.712961   160.158577   8084.383659  1.102396   63102.747684
#
#           tau_w
# 0  10262.953817
# 1  36965.947717
# 2  45809.941477
# 3  47599.081146
# 4   6365.517419

# %%
# rename columns to be consistent with other code
columnMapping = {"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "x_f" : "x_99", "y_f" : "y_99", "phi_f" : "phi_99", "theta_f" : "theta_99", 
                        "xd_0" : "x_dot_0", "yd_0" : "y_dot_0", "phid_0" : "phi_dot_0", "thetad_0": "theta_dot_0", 
                        "xd_f" : "x_dot_99", "yd_f": "y_dot_99", "phid_f": "phi_dot_99", "thetad_f": "theta_dot_99", 
                        "tau0" : "tau"}

# rename columns
trainDF.rename(columns=columnMapping, inplace=True)
testDF.rename(columns=columnMapping, inplace=True)


trainDF.head()
testDF.head()
# Out:
#    x_0      x_dot_0  y_0      y_dot_0   theta_0  theta_dot_0     phi_0  \
# 0  0.0  1290.475733  0.0  1031.459220  5.901014     9.348979  3.643856
# 1  0.0  -643.287407  0.0  -812.471891  0.923325     5.317080  3.764966
# 2  0.0   817.563373  0.0 -1295.713095  3.073726     4.217052  0.532687
# 3  0.0  -818.423313  0.0  1230.998812  0.037942   -24.356912  1.783597
# 4  0.0 -1240.409449  0.0 -1375.065310  3.503992     9.262691  2.659674
#
#    phi_dot_0       x_99     x_dot_99       y_99     y_dot_99   theta_99  \
# 0  17.157149  26.235253  1137.037978  20.847415   289.689136  18.537756
# 1 -24.582937  -9.018544 -1514.026571 -11.076141 -1014.695373 -10.546085
# 2  -4.945442  13.080550  -325.919134 -23.274466  -817.967701  17.014216
# 3  17.914569 -13.849188 -1982.346897  19.697223  1963.656391 -11.793649
# 4  -6.227951 -10.039456 -1427.009664  -9.628598 -1844.939378   5.908790
#
#    theta_dot_99     phi_99   phi_dot_99             F     alpha  \
# 0   1221.875359  15.098098  1167.837706  10507.464077  0.559591
# 1  -1478.783791  -6.871128 -1435.593398  34686.690435  1.063056
# 2   1687.486984  14.956286  1693.827720  27441.473272  0.549398
# 3  -1541.793049 -10.608393 -1556.139800   4053.551364  3.837047
# 4    590.782422   4.559646   516.295982  17916.938852  1.558088
#
#              tau         tau_w
# 0  799932.656919  61301.505115
# 1 -737949.278098 -97316.403803
# 2 -575984.856139  87908.705311
# 3  617346.567027 -53108.537683
# 4  967963.511996  52430.831318

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

# convert to fx and fy
testDF["Fx"] = testDF.F * np.cos(testDF.alpha)
testDF["Fy"] = testDF.F * np.sin(testDF.alpha)

# %%
# make dataset
Xtrain = trainDF.loc[:, [ "phi_0", "theta_0", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0",
                   "x_99", "y_99", "phi_99", "theta_99"]]

Ytrain = trainDF.loc[:, ["Fx", "Fy", "tau", "tau_w", "x_dot_99", "y_dot_99", "phi_dot_99", "theta_dot_99",] ]

# make dataset
Xtest = testDF.loc[:, Xtrain.columns]

Ytest = testDF.loc[:, Ytrain.columns ]

# %%
Xtrain.head()
# Out:
#       phi_0   theta_0      x_dot_0     y_dot_0  phi_dot_0  theta_dot_0  \
# 0  4.482445  1.123847  1147.407904 -238.429602  12.691013    23.498330
# 1  3.398032  4.645359 -1152.043723  369.845453 -19.816137     5.927584
# 2  4.307985  5.220594  -592.993151 -525.687613 -23.696882     6.983077
# 3  2.109267  3.628833  1338.965230   61.191760 -11.436424   -17.119889
# 4  0.008353  1.468084 -1361.776972  664.606866   8.528276     8.355107
#
#         x_99       y_99     phi_99   theta_99
# 0  18.723606  -4.739545   8.139222   4.014081
# 1 -23.448395   8.272804  11.946214  14.631620
# 2  -4.641471  -5.348081   8.779522   9.520878
# 3  26.318800   0.005384  15.180057  16.589887
# 4 -27.521247  14.165396   1.712961   3.269968

# %%
Ytrain.head()
# Out:
#              Fx            Fy            tau         tau_w     x_dot_99  \
# 0  -6945.877556  30061.578261 -546297.092872  10262.953817   691.882850
# 1 -28224.423763  14806.640027  961528.396769  36965.947717  -706.563802
# 2 -16595.229877  13360.892152 -313643.967698  45809.941477  -608.960470
# 3  18078.833179   7115.626082 -203911.489339  47599.081146   623.841539
# 4   3649.772460   7213.627391   63102.747684   6365.517419 -1473.234824
#
#      y_dot_99   phi_dot_99  theta_dot_99
# 0 -293.363224   345.558353    308.066760
# 1  684.314462   778.225185    851.354510
# 2  430.757954   955.717081    942.874265
# 3  863.443021  1307.874474   1316.282852
# 4  774.628129   160.158577    165.211558

# %%
# scale data 
scalerX = MinMaxScaler([-0.5, 0.5])  
scalerY = MinMaxScaler([-0.5, 0.5])  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xtest_scaled = scalerX.transform(Xtest)
Ytest_scaled = scalerY.transform(Ytest)

# %%
pd.DataFrame(Xtrain_scaled, columns = Xtrain.columns).head()
# Out:
#       phi_0   theta_0   x_dot_0   y_dot_0  phi_dot_0  theta_dot_0      x_99      y_99    phi_99  theta_99
# 0  0.213403 -0.321134  0.382469 -0.079477   0.253820     0.469967  0.243012 -0.059803  0.100510  0.011596
# 1  0.040814  0.239332 -0.384015  0.123282  -0.396323     0.118552 -0.305912  0.109870  0.177605  0.232007
# 2  0.185637  0.330883 -0.197664 -0.175229  -0.473938     0.139662 -0.061115 -0.067737  0.113476  0.125913
# 3 -0.164300  0.077547  0.446322  0.020397  -0.228728    -0.342398  0.341873  0.002068  0.243093  0.272659
# 4 -0.498671 -0.266347 -0.453926  0.221536   0.170566     0.167102 -0.358925  0.186705 -0.029628 -0.003851

# %%
pd.DataFrame(Ytrain_scaled, columns = Ytrain.columns).head()
# Out:
#          Fx        Fy       tau     tau_w  x_dot_99  y_dot_99  phi_dot_99  theta_dot_99
# 0 -0.078394  0.339311 -0.273149  0.051315  0.080022 -0.035045    0.056173      0.055090
# 1 -0.318573  0.167129  0.480764  0.184830 -0.085016  0.079136    0.131251      0.148198
# 2 -0.187310  0.150811 -0.156822  0.229050 -0.073498  0.049523    0.162050      0.163883
# 3  0.204068  0.080321 -0.101956  0.237995  0.071992  0.100055    0.223158      0.227877
# 4  0.041202  0.081427  0.031551  0.031827 -0.175495  0.089683    0.024001      0.030608

# %%
# # save scalers, to be used on test set
# scalerfileX = 'scalerX_fullact.pkl'
# pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

# scalerfileY = 'scalerY_fullact.pkl'
# pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %% [markdown]
# # Keras models

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
K.clear_session()

# %%
# refref: start with small network and then build up
# refref: start with large network and prune

# %%
# create network
def create_network(optimizer = 'rmsprop', 
                    numUnits = [32, 32, 32, 32], 
                    weightRegularization = 0.0, 
                    dropout_rate=0.1):
    
    '''
    Create a feed forward network.  Assumes Xtrain & Ytrain have been created and scaled
    
    Params: 
    optimizer (str): choice of optimizer
    numUnits (list): number of units in each hidden
    weightRegularization (float): between 0 and 1
    dropout_rate (float): between 0 and 1
    
    '''
    K.clear_session()
    inputs = Input(shape=(Xtrain_scaled.shape[1],))    
    
    # add layers
    for ii in np.arange(0, len(numUnits)):
        if ii >= 1: 
            x = Dense(numUnits[ii], activation='tanh', 
                      kernel_regularizer=regularizers.l1(weightRegularization))(x)

        else: 
            x = Dense(numUnits[ii], activation='tanh')(inputs)


        # add dropout
        if dropout_rate > 0: 
            x = Dropout(dropout_rate)(x)
    
    predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

    # create model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(loss="mean_squared_error", optimizer = optimizer, metrics = ['mse'])

    return(model)

# %%
modelParams = {"optimizer": "rmsprop", 
              "dropout_rate" : 0, 
               "numUnits": [400, 400, 400, 16],
               "weightRegularization": 0
              }


model = create_network(**modelParams)

modelName = ''.join('{}_{}__'.format(key[0:3].capitalize(), val) for  key, val in modelParams.items()).\
                            replace("[", "").replace("]", "").replace(", ", "_")[0:-2] + "_" + datetime.now().strftime("%Y_%m_%d__%I_%M_%S")
print(modelName)

model.summary()
# Out:
# Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2019_06_12__10_41_43
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               4400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                6416
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 136
# =================================================================
# Total params: 331,752
# Trainable params: 331,752
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.get_config()
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=100, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
# start training
historyDict = {"mean_squared_error": [], 
               "val_mean_squared_error": []}

# %%
# # fit model without regularization
stt = time.time()
history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 1000, verbose = 2, 
                        batch_size=2**14, callbacks=[earlystop], validation_split = 0.3)
winsound.PlaySound("*", winsound.SND_ALIAS)
endd = time.time() - stt
print(endd)
# Out:
# Train on 7000000 samples, validate on 3000000 samples
# Epoch 1/1000
#  - 9s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 2/1000
#  - 9s - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 3/1000
#  - 9s - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 4/1000
#  - 9s - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 5/1000
#  - 9s - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 6/1000
#  - 9s - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 7/1000
#  - 9s - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0104 - val_mean_squared_error: 0.0104
# Epoch 8/1000
#  - 9s - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 9/1000
#  - 9s - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 10/1000
#  - 9s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 11/1000
#  - 9s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 12/1000
#  - 9s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 13/1000
#  - 9s - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 14/1000
#  - 9s - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 15/1000
#  - 9s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 16/1000
#  - 9s - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 17/1000
#  - 9s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 18/1000
#  - 9s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0088 - val_mean_squared_error: 0.0088
# Epoch 19/1000
#  - 9s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 20/1000
#  - 9s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 21/1000
#  - 9s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 22/1000
#  - 9s - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 23/1000
#  - 9s - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 24/1000
#  - 9s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 25/1000
#  - 9s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 26/1000
#  - 9s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 27/1000
#  - 9s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 28/1000
#  - 9s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 29/1000
#  - 9s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 30/1000
#  - 9s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 31/1000
#  - 9s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 32/1000
#  - 9s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 33/1000
#  - 9s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 34/1000
#  - 9s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 35/1000
#  - 9s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 36/1000
#  - 9s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 37/1000
#  - 9s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 38/1000
#  - 9s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 39/1000
#  - 9s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 40/1000
#  - 9s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 41/1000
#  - 9s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 42/1000
#  - 9s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 43/1000
#  - 9s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 44/1000
#  - 9s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 45/1000
#  - 9s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 46/1000
#  - 9s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 47/1000
#  - 9s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 48/1000
#  - 9s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 49/1000
#  - 9s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 50/1000
#  - 9s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 51/1000
#  - 9s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 52/1000
#  - 9s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 53/1000
#  - 9s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 54/1000
#  - 9s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 55/1000
#  - 9s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 56/1000
#  - 9s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 57/1000
#  - 9s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 58/1000
#  - 9s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 59/1000
#  - 9s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 60/1000
#  - 9s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 61/1000
#  - 9s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 62/1000
#  - 9s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 63/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 64/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 65/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 66/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 67/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 68/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 69/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 70/1000
#  - 9s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 71/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 72/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 73/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 74/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 75/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 76/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 77/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 78/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 79/1000
#  - 9s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 80/1000
#  - 9s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 81/1000
#  - 9s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 82/1000
#  - 9s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 83/1000
#  - 9s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 84/1000
#  - 9s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 85/1000
#  - 9s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 86/1000
#  - 9s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 87/1000
#  - 9s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 88/1000
#  - 9s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 89/1000
#  - 9s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 90/1000
#  - 9s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 91/1000
#  - 9s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 92/1000
#  - 9s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 93/1000
#  - 9s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 94/1000
#  - 9s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 95/1000
#  - 9s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 96/1000
#  - 9s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 97/1000
#  - 9s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 98/1000
#  - 9s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 99/1000
#  - 9s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 100/1000
#  - 9s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 101/1000
#  - 9s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 102/1000
#  - 9s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 103/1000
#  - 9s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 104/1000
#  - 9s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 105/1000
#  - 9s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 106/1000
#  - 9s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 107/1000
#  - 9s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 108/1000
#  - 9s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 109/1000
#  - 9s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 110/1000
#  - 9s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 111/1000
#  - 9s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 112/1000
#  - 9s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 113/1000
#  - 9s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 114/1000
#  - 9s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 115/1000
#  - 9s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 116/1000
#  - 9s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 117/1000
#  - 9s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 118/1000
#  - 9s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 119/1000
#  - 9s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 120/1000
#  - 9s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 121/1000
#  - 9s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 122/1000
#  - 9s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 123/1000
#  - 9s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 124/1000
#  - 9s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 125/1000
#  - 9s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 126/1000
#  - 9s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 127/1000
#  - 9s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 128/1000
#  - 9s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 129/1000
#  - 9s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 130/1000
#  - 9s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 131/1000
#  - 9s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 132/1000
#  - 9s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 133/1000
#  - 9s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 134/1000
#  - 9s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 135/1000
#  - 9s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 136/1000
#  - 9s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 137/1000
#  - 9s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 138/1000
#  - 9s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 139/1000
#  - 9s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 140/1000
#  - 9s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 141/1000
#  - 9s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 142/1000
#  - 9s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 143/1000
#  - 9s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 144/1000
#  - 9s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 145/1000
#  - 9s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 146/1000
#  - 9s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 147/1000
#  - 9s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 148/1000
#  - 9s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 149/1000
#  - 9s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 150/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 151/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 152/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 153/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 154/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 155/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 156/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 157/1000
#  - 9s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 158/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 159/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 160/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 161/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 162/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 163/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 164/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 165/1000
#  - 9s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 166/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 167/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 168/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 169/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 170/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 171/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 172/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 173/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 174/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 175/1000
#  - 9s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 176/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 177/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 178/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 179/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 180/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 181/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 182/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 183/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 184/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 185/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 186/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 187/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 188/1000
#  - 9s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 189/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 190/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 191/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 192/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 193/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 194/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 195/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 196/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 197/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 198/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 199/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 200/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 201/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 202/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 203/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 204/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 205/1000
#  - 9s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 206/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 207/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 208/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 209/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 210/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 211/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 212/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 213/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 214/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 215/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 216/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 217/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 218/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 219/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 220/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 221/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 222/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 223/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 224/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 225/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 226/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 227/1000
#  - 9s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 228/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 229/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 230/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 231/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 232/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 233/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 234/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 235/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 236/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 237/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 238/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 239/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 240/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 241/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 242/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 243/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 244/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 245/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 246/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 247/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 248/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 249/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 250/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 251/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 252/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 253/1000
#  - 9s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 254/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 255/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 256/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 257/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 258/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 259/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 260/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 261/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 262/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 263/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 264/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 265/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 266/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 267/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 268/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 269/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 270/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 271/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 272/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 273/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 274/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 275/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 276/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 277/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 278/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 279/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 280/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 281/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 282/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 283/1000
#  - 9s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 284/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 285/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 286/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 287/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 288/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 289/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 290/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 291/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 292/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 293/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 294/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 295/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 296/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 297/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 298/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 299/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 300/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 301/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 302/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 303/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 304/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 305/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 306/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 307/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 308/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 309/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 310/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 311/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 312/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 313/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 314/1000
#  - 9s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 315/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 316/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 317/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 318/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 319/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 320/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 321/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 322/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 323/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 324/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 325/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 326/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 327/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 328/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 329/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 330/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 331/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 332/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 333/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 334/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 335/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 336/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 337/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 338/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 339/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 340/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 341/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 342/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 343/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 344/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 345/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 346/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 347/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 348/1000
#  - 9s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 349/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 350/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 351/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 352/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 353/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 354/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 355/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 356/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 357/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 358/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 359/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 360/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 361/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 362/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 363/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 364/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 365/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 366/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 367/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 368/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 369/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 370/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 371/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 372/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 373/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 374/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 375/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 376/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 377/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 378/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 379/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 380/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 381/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 382/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 383/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 384/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 385/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 386/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 387/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 388/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 389/1000
#  - 9s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 390/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 391/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 392/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 393/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 394/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 395/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 396/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 397/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 398/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 399/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 400/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 401/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 402/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 403/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 404/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 405/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 406/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 407/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 408/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 409/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 410/1000
#  - 9s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 411/1000
# ...
# Epoch 823/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 824/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 825/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 826/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 827/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 828/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 829/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 830/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 831/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 832/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 833/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 834/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 835/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 836/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 837/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 838/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 839/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 840/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 841/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 842/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 843/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 844/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 845/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 846/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 847/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 848/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 849/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 850/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 851/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 852/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 853/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 854/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 855/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 856/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 857/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 858/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 859/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 860/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 861/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 862/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 863/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 864/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 865/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 866/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 867/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 868/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 869/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 870/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 871/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 872/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 873/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 874/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 875/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 876/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 877/1000
#  - 9s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 878/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 879/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 880/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 881/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 882/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 883/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 884/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 885/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 886/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 887/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 888/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 889/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 890/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 891/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 892/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 893/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 894/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 895/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 896/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 897/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 898/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 899/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 900/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 901/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 902/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 903/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 904/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 905/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 906/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 907/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 908/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 909/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 910/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 911/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 912/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 913/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 914/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 915/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 916/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 917/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 918/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 919/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 920/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 921/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 922/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 923/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 924/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 925/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 926/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 927/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 928/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 929/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 930/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 931/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 932/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 933/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 934/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 935/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 936/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 937/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 938/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 939/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 940/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 941/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 942/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 943/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 944/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 945/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 946/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 947/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 948/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 949/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 950/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 951/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 952/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 953/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 954/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 955/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 956/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 957/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 958/1000
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 00958: early stopping
# 8323.906490802765

# %%
historyDict["mean_squared_error"].extend(history.history["mean_squared_error"])
historyDict["val_mean_squared_error"].extend(history.history["val_mean_squared_error"])

# %%
# save model and history
model.save(os.path.join(savedModels,  modelName + "_fullActuated" + '.h5'))
pickle.dump(historyDict, open(os.path.join(dataOutput, modelName + "history.pkl"), "wb"))

# %%
fig, axs = plt.subplots(1,1,figsize=(10,5))
# summarize history for accuracy
axs.plot(historyDict["val_mean_squared_error"], label = "val", color = "C1")
axs.plot(historyDict["mean_squared_error"], label = "train", color = "C0")

axs.set_title('Model MSE = '+ str((historyDict['val_mean_squared_error'][-1]))[:8])
axs.set_ylabel('Mean squared error')
axs.set_xlabel('Epoch')
axs.legend( loc='best')
plt.yscale('log') #logarithmic scale for y axis
fig.savefig(os.path.join(figDir, modelName + '_training.png'))

# %% [markdown]
# ___

# %% [markdown]
# ## Evaluate accuracy on test data

# %% [markdown]
# ___

# %%
from keras.models import load_model

modelPath = os.path.join(savedModels, "Opt_rmsprop__Dro_0__Num_512_512_512_16__Wei_0_2019_06_11__11_27_06_fullActuated.h5")

model = load_model(modelPath)

# %%
# load scalers
scalerX = pickle.load(open("D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput_twoTorque\scalerX_fullact.pkl", "rb"))
scalerY = pickle.load(open("D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput_twoTorque\scalerY_fullact.pkl", "rb"))

# %%
# predict
Ytest_pred = model.predict(Xtest_scaled)


# make data frames
XtestDF = pd.DataFrame(scalerX.inverse_transform(Xtest_scaled), columns = Xtrain.columns)
YtestDF = pd.DataFrame(scalerY.inverse_transform(Ytest_scaled), columns = Ytrain.columns)
YpredDF = pd.DataFrame(scalerY.inverse_transform(Ytest_pred), columns = Ytrain.columns+ "_pred")

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

df_c = pd.concat([YtestDF.reset_index(drop=True), YpredDF], axis=1)
df_c.head()
# Out:
#              Fx            Fy            tau         tau_w     x_dot_99     y_dot_99   phi_dot_99  theta_dot_99       Fx_pred       Fy_pred     tau_pred    tau_w_pred  x_dot_99_pred  y_dot_99_pred  phi_dot_99_pred  theta_dot_99_pred
# 0   8904.784685   5577.778325  799932.656919  61301.505115  1137.037978   289.689136  1167.837706   1221.875359   9574.181641   -421.608215  807317.2500  58429.609375     891.107239     170.097595      1233.637695        1287.005737
# 1  16864.812183  30310.800111 -737949.278098 -97316.403803 -1514.026571 -1014.695373 -1435.593398  -1478.783791   6807.492676  26852.830078 -696389.6875 -96242.882812   -1917.313721   -1311.362427     -1583.363525       -1632.851440
# 2  23403.157090  14329.225157 -575984.856139  87908.705311  -325.919134  -817.967701  1693.827720   1687.486984  26502.578125  -5210.011230 -558230.0000  83538.765625    -682.908508    -864.819336      1685.520386        1651.075806
# 3  -3112.164797  -2597.250264  617346.567027 -53108.537683 -1982.346897  1963.656391 -1556.139800  -1541.793049    650.742615  -1645.336792  672178.2500 -54041.820312   -1725.103271    1720.187988     -1680.968018       -1638.137817
# 4    227.692545  17915.492009  967963.511996  52430.831318 -1427.009664 -1844.939378   516.295982    590.782422   1306.761475   8066.011230  899994.3125  52369.867188   -1367.816895   -1594.149414       451.140289         512.950623

# %%
# # predict on training data
# Ytest_pred = model.predict(Xtrain_scaled)


# # make data frames
# XtestDF = pd.DataFrame(scalerX.inverse_transform(Xtrain_scaled), columns = Xtrain.columns)
# YtestDF = pd.DataFrame(scalerY.inverse_transform(Xtrain_scaled), columns = Ytrain.columns)
# YpredDF = pd.DataFrame(scalerY.inverse_transform(Ytrain_scaled), columns = Ytrain.columns+ "_pred")

# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)

# df_c = pd.concat([YtestDF.reset_index(drop=True), YpredDF], axis=1)
# df_c.head()

# %%
df_c = df_c.iloc[:1000, :]

# %%
# make plots
from sklearn.metrics import r2_score
from matplotlib import ticker

M = 3
yticks = ticker.MaxNLocator(M)

plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array([25, 9]), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.2, wspace=0.7)
#fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel("C")

ylabs = [r"g*cm/$s^2$", r"g*cm/$s^2$", r"g*$cm^2$/$s^2$", r"g*$cm^2$/$s^2$", "cm/s", "cm/s", "rad/s", "rad/s"]

# replace lightest colors with white
import matplotlib.colors

cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

# Plot y = actual, x = predicted
for ii in np.arange(0, df_c.shape[1] //2):
    axs[ii].hexbin(y = df_c.loc[:,YtestDF.columns[ii]],
                   x = df_c.loc[:,YpredDF.columns[ii]], 
                   gridsize = 50, cmap = cmap)
    axs[ii].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[ii].yaxis.set_major_locator(ticker.MaxNLocator(5))

    if(ii == 0):
        axs[ii].set_ylabel("Actual Value\n" + ylabs[ii])
    else:
        axs[ii].set_ylabel(ylabs[ii])

    axs[ii].set_title(YtestDF.columns[ii])
    axs[ii].plot(df_c.loc[:,YtestDF.columns[ii]], 
                 df_c.loc[:,YtestDF.columns[ii]], 
                 'grey', linewidth = 1, linestyle  = "--")

    # annotate with R^2
    axs[ii].text(np.max(df_c.loc[:,YtestDF.columns[ii]])*-0.2, 
                 np.min(df_c.loc[:,YtestDF.columns[ii]])*0.9, 
                 r'$r^2$ =' + 
                 str(np.round((r2_score(df_c.loc[:,YtestDF.columns[ii]],  
                                        df_c.loc[:,YpredDF.columns[ii]])), 3)))
    axs[ii].set_xlim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]])), 
                      np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]]))])

# # residual plots x = predicted, y = actual - predicted
# jj is column in dataset, plotNum is plot position
for jj, plotNum in enumerate(np.arange(8, df_c.shape[1])):

    axs[plotNum].hexbin(y = df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]],
                   x = df_c.loc[:,YpredDF.columns[jj]], 
                   gridsize = 50, cmap = cmap) 
    axs[plotNum].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[plotNum].yaxis.set_major_locator(ticker.MaxNLocator(5))
    axs[plotNum].set_xlabel("Predicted Value\n" + ylabs[jj])

    if(jj == 0):
        axs[plotNum].set_ylabel("Actual - Predicted\n" + ylabs[jj])
    else:
        axs[plotNum].set_ylabel(ylabs[jj])

    axs[plotNum].hlines(y = 0, xmin = np.min( df_c.loc[:,YpredDF.columns[jj]]), 
                   xmax = np.max( df_c.loc[:,YpredDF.columns[jj]]), 
                   linestyle =  "--", linewidth = 1)
    axs[plotNum].set_ylim([-np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]])), 
                      np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]]- df_c.loc[:,YpredDF.columns[jj]]))])


fig.savefig(os.path.join(figDir, "PredVActual_fullAct" + modelName + ".png"), dpi = 500, bbox_inches='tight')
plt.show()
# plt.close()
