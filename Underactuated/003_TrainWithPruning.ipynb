# %% [markdown]
# # Callin Switzer
# ___
#
# ### 16 Jan 2020
# ### - Train without pruning
# ### - Then prune a Dense, Feedforward Neural Network with Keras
# ### - Use data that was generated in Python

# %% [markdown]
# ___

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rc('font',family='Times New Roman')
from matplotlib.ticker import ScalarFormatter
import os
import pandas as pd
import time
from datetime import datetime
import sys
import seaborn as sns
import scipy.io
import subprocess
import winsound
import pickle
import glob
import sqlite3

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
print("TensorFlow successfully installed.")
if tf.test.is_built_with_cuda():
    print("The installed version of TensorFlow includes GPU support.")
print(sys.version, "\n")
now = datetime.now()
print("last run on " + str(now))

# define directories
baseDir = os.getcwd()
dataDir = r'D:\MothSimulations\11c-AggressiveManeuver\Qstore\hws_am_con'
figDir = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\Figs'
dataOutput = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput'
savedModels = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels'
dataDir = r'D:/Dropbox/AcademiaDropbox/mothMachineLearning_dataAndFigs/PythonGeneratedData_oneTorque/'
if not os.path.exists(figDir):
    os.mkdir(figDir)

if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
if not os.path.exists(savedModels):
    os.mkdir(savedModels)
# Out:
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2020-01-22 08:39:02.148086

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Make training and test set

# %%
# get table names in database
con1 = sqlite3.connect(os.path.join(dataDir, "oneTorqueData.db"))
cursorObj = con1.cursor()
res = cursorObj.execute("SELECT name FROM sqlite_master WHERE type='table';")
tableNames = [name[0] for name in res]
con1.close()
print(tableNames)
# Out:
# ['test', 'train']

# %%
con1 = sqlite3.connect(os.path.join(dataDir, "oneTorqueData.db"))
trainDF = pd.read_sql_query("SELECT * FROM train", con1)
testDF = pd.read_sql_query("SELECT * FROM test", con1)
con1.close()

# %%
# double check for repeats!
np.sum(trainDF.iloc[:, [16,17,18]].duplicated()) # 0 means no repeats
# Out:
# 0

# %%
print(trainDF.shape)
trainDF.head()
# Out:
# (10000000, 19)
#    x_0         xd_0  y_0         yd_0   theta_0   thetad_0     phi_0  \
# 0  0.0  1127.569064  0.0   765.895323  1.075898  11.962440  3.427385
# 1  0.0   979.651081  0.0  -625.561275  0.306688  -5.637037  2.576453
# 2  0.0  1111.257777  0.0 -1406.672066  5.094943  16.102668  1.775724
# 3  0.0 -1438.730397  0.0   690.882986  5.034187  -3.375327  5.534301
# 4  0.0  1370.322727  0.0  -216.459775  4.186927 -16.500337  3.194818
#
#       phid_0        x_f         xd_f        y_f         yd_f   theta_f  \
# 0  18.462602  18.803451   757.917346  15.029585   590.721265  2.594171
# 1  19.788635  18.720572   891.140764 -13.653612  -722.829360  0.118141
# 2  -9.188076  19.273656  1013.752111 -25.658272 -1063.047803  2.975486
# 3  -9.669100 -30.983146 -1503.728256  10.869231   358.062499  6.320129
# 4  -0.385905  27.316158  1362.785459  -4.558381  -239.943312  3.971987
#
#      thetad_f     phi_f      phid_f             F     alpha          tau0
# 0  140.850390  5.057473  146.997624  41181.992912  1.987846 -63216.237665
# 1  -31.877751  2.388198  -31.855755   9062.020340  3.567122  19108.940596
# 2 -203.455066 -0.207493 -196.647522  42727.993224  4.104033  49781.327507
# 3  140.234874  6.796193  139.485057  28953.145279  4.698031  92261.347215
# 4  -11.139903  3.168960   -1.854711    371.601599  0.668810 -40259.257246

# %%
# rename columns to be consistent with other code
trainDF.rename(columns={"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "x_f" : "x_99", "y_f" : "y_99", "phi_f" : "phi_99", "theta_f" : "theta_99", 
                        "xd_0" : "x_dot_0", "yd_0" : "y_dot_0", "phid_0" : "phi_dot_0", "thetad_0": "theta_dot_0", 
                        "xd_f" : "x_dot_99", "yd_f": "y_dot_99", "phid_f": "phi_dot_99", "thetad_f": "theta_dot_99", 
                        "tau0" : "tau"}, inplace=True)

# rename columns to be consistent with other code
testDF.rename(columns={"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "x_f" : "x_99", "y_f" : "y_99", "phi_f" : "phi_99", "theta_f" : "theta_99", 
                        "xd_0" : "x_dot_0", "yd_0" : "y_dot_0", "phid_0" : "phi_dot_0", "thetad_0": "theta_dot_0", 
                        "xd_f" : "x_dot_99", "yd_f": "y_dot_99", "phid_f": "phi_dot_99", "thetad_f": "theta_dot_99", 
                        "tau0" : "tau"}, inplace=True)

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

testDF["Fx"] = testDF.F * np.cos(testDF.alpha)
testDF["Fy"] = testDF.F * np.sin(testDF.alpha)

# %%
# make dataset
X = trainDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

# make dataset
Xtest = testDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Ytest = testDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

# %%
X.head()
# Out:
#       phi_0   theta_0       x_99       y_99    phi_99  theta_99      x_dot_0  \
# 0  3.427385  1.075898  18.803451  15.029585  5.057473  2.594171  1127.569064
# 1  2.576453  0.306688  18.720572 -13.653612  2.388198  0.118141   979.651081
# 2  1.775724  5.094943  19.273656 -25.658272 -0.207493  2.975486  1111.257777
# 3  5.534301  5.034187 -30.983146  10.869231  6.796193  6.320129 -1438.730397
# 4  3.194818  4.186927  27.316158  -4.558381  3.168960  3.971987  1370.322727
#
#        y_dot_0  phi_dot_0  theta_dot_0
# 0   765.895323  18.462602    11.962440
# 1  -625.561275  19.788635    -5.637037
# 2 -1406.672066  -9.188076    16.102668
# 3   690.882986  -9.669100    -3.375327
# 4  -216.459775  -0.385905   -16.500337

# %%
Y.head()
# Out:
#              Fx            Fy           tau     x_dot_99     y_dot_99  \
# 0 -16681.383440  37652.197635 -63216.237665   757.917346   590.721265
# 1  -8253.874132  -3740.825371  19108.940596   891.140764  -722.829360
# 2 -24419.876370 -35062.102662  49781.327507  1013.752111 -1063.047803
# 3   -415.702991 -28950.160838  92261.347215 -1503.728256   358.062499
# 4    291.543841    230.412537 -40259.257246  1362.785459  -239.943312
#
#    phi_dot_99  theta_dot_99
# 0  146.997624    140.850390
# 1  -31.855755    -31.877751
# 2 -196.647522   -203.455066
# 3  139.485057    140.234874
# 4   -1.854711    -11.139903

# %%
# val train split
Xtrain, Xval, Ytrain, Yval = train_test_split(X, Y, test_size=0.2, random_state = 123)

# %%
# scale data 
scalerX = MinMaxScaler([-0.5, 0.5])  
scalerY = MinMaxScaler([-0.5, 0.5])  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xval_scaled = scalerX.transform(Xval)
Yval_scaled = scalerY.transform(Yval)


# final test data
Xtest_scaled = scalerX.transform(Xtest)

# %%
pd.DataFrame(Xtrain_scaled, columns = X.columns).head()
# Out:
#       phi_0   theta_0      x_99      y_99    phi_99  theta_99   x_dot_0  \
# 0  0.440808 -0.497541 -0.377795 -0.093499  0.283923 -0.123559 -0.413733
# 1  0.002656  0.450960  0.235487  0.307672 -0.026624  0.181926  0.276074
# 2  0.302116  0.217276  0.365577 -0.177635 -0.010400 -0.051983  0.385703
# 3 -0.471247  0.121804  0.070307  0.309669 -0.312522 -0.057033  0.103501
# 4 -0.350056 -0.349031  0.316691  0.163576 -0.090551 -0.091089  0.350805
#
#     y_dot_0  phi_dot_0  theta_dot_0
# 0 -0.087276   0.151751    -0.419563
# 1  0.383212   0.227138     0.094672
# 2 -0.188919  -0.266187    -0.202705
# 3  0.332100  -0.227711     0.447327
# 4  0.216431   0.136925     0.270457

# %% [markdown]
# # Keras models

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K

K.clear_session()

# %%
# create network
def create_network(optimizer = 'rmsprop', 
                    numUnits = [400, 16], 
                    weightRegularization = 0.0, 
                    dropout_rate=0.1):
    
    '''
    Create a feed forward network.  Assumes Xtrain & Ytrain have been created and scaled
    
    Params: 
    optimizer (str): choice of optimizer
    numUnits (list): number of units in each hidden
    weightRegularization (float): between 0 and 1
    dropout_rate (float): between 0 and 1
    
    '''
    K.clear_session()
    inputs = Input(shape=(Xtrain_scaled.shape[1],))    
    
    # add layers
    for ii in np.arange(0, len(numUnits)):
        if ii >= 1: 
            x = Dense(numUnits[ii], activation='tanh', 
                      kernel_regularizer=regularizers.l1(weightRegularization))(x)

        else: 
            x = Dense(numUnits[ii], activation='tanh')(inputs)


        # add dropout
        if dropout_rate > 0: 
            x = Dropout(dropout_rate)(x)
    
    predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

    # create model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(loss="mean_squared_error", optimizer = optimizer, metrics = ['mse'])

    return(model)

# %%
def format_e(n):
    a = '%E' % n
    return a.split('E')[0].rstrip('0').rstrip('.') + 'E' + a.split('E')[1]


earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=150, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
np.arange(0,len(history.history['val_mean_squared_error']), 50),
# Out:
# (array([  0,  50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550]),)

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE = '+ str(format_e(model_history.history['val_mean_squared_error'][-1])))
    axs.set_ylabel('Mean squared error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(0,len(model_history.history['val_mean_squared_error']), 50), 50)
    axs.legend(['train', 'validation'], loc='best')
    plt.yscale('log') #logarithmic scale for y axis
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_" + modelName + ".pdf"), dpi = 500, bbox_inches='tight')
    
    plt.show()

    
def plot_model_history_fromDict(model_history_dictionary, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history_dictionary['mean_squared_error'])+1),
             model_history_dictionary['mean_squared_error'])
    axs.plot(range(1,len(model_history_dictionary['val_mean_squared_error'])+1),
             model_history_dictionary['val_mean_squared_error'])
    axs.set_title('Model MSE = '+ str(format_e(model_history_dictionary['val_mean_squared_error'][-1])) + "\n" +  str(nzwts) + " non-zero weights")
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history_dictionary['val_mean_squared_error'])+1),
                   len(model_history_dictionary['val_mean_squared_error'])/10)
    axs.legend(['train', 'validation'], loc='best')
    plt.yscale('log') #logarithmic scale for y axis
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned.png"), dpi = 120, bbox_inches='tight')
        print(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned.png"))
    plt.show()

# %% [markdown]
# ___

# %%
# train and trim weights

# %%
K.clear_session()

modelParams = {"optimizer": "rmsprop", 
              "dropout_rate" : 0, 
               "numUnits": [400, 400, 400, 16],
               "weightRegularization": 0
              }


model = create_network(**modelParams)

modeltimestamp = datetime.now().strftime("%Y_%m_%d__%I_%M_%S")
modelName = ''.join('{}_{}__'.format(key[0:3].capitalize(), val) for  key, val in modelParams.items()).\
                            replace("[", "").replace("]", "").replace(", ", "_")[0:-2] + "_" + modeltimestamp
print(modelName)

model.summary()
# Out:
# Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2020_01_21__03_07_03
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               4400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                6416
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 331,735
# Trainable params: 331,735
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # save scalers, to be used on test set
scalerfileX = 'scalerX_fullact_' + modeltimestamp + '.pkl'
pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

scalerfileY = 'scalerY_fullact_' + modeltimestamp + '.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %%
# start training
historyDict = {"mean_squared_error": [], 
               "val_mean_squared_error": []}

# %%
# train without pruning
history = model.fit(Xtrain_scaled, Ytrain_scaled, 
                    validation_data=(Xval_scaled, Yval_scaled), 
                    callbacks = [earlystop],
                    verbose = 2, batch_size=2**12, epochs = 1000)
# Out:
# Train on 8000000 samples, validate on 2000000 samples
# Epoch 1/1000
#  - 15s - loss: 7.9810e-04 - mean_squared_error: 7.9810e-04 - val_loss: 5.7408e-04 - val_mean_squared_error: 5.7408e-04
# Epoch 2/1000
#  - 15s - loss: 7.8755e-04 - mean_squared_error: 7.8755e-04 - val_loss: 8.6297e-04 - val_mean_squared_error: 8.6297e-04
# Epoch 3/1000
#  - 15s - loss: 7.7944e-04 - mean_squared_error: 7.7944e-04 - val_loss: 9.4926e-04 - val_mean_squared_error: 9.4926e-04
# Epoch 4/1000
#  - 14s - loss: 7.6992e-04 - mean_squared_error: 7.6992e-04 - val_loss: 6.5870e-04 - val_mean_squared_error: 6.5870e-04
# Epoch 5/1000
#  - 14s - loss: 7.6134e-04 - mean_squared_error: 7.6134e-04 - val_loss: 9.1353e-04 - val_mean_squared_error: 9.1353e-04
# Epoch 6/1000
#  - 15s - loss: 7.5308e-04 - mean_squared_error: 7.5308e-04 - val_loss: 8.0672e-04 - val_mean_squared_error: 8.0672e-04
# Epoch 7/1000
#  - 15s - loss: 7.4531e-04 - mean_squared_error: 7.4531e-04 - val_loss: 7.1936e-04 - val_mean_squared_error: 7.1936e-04
# Epoch 8/1000
#  - 14s - loss: 7.3849e-04 - mean_squared_error: 7.3849e-04 - val_loss: 6.5864e-04 - val_mean_squared_error: 6.5864e-04
# Epoch 9/1000
#  - 15s - loss: 7.2999e-04 - mean_squared_error: 7.2999e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 10/1000
#  - 16s - loss: 7.2194e-04 - mean_squared_error: 7.2194e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 11/1000
#  - 15s - loss: 7.1743e-04 - mean_squared_error: 7.1743e-04 - val_loss: 7.4757e-04 - val_mean_squared_error: 7.4757e-04
# Epoch 12/1000
#  - 15s - loss: 7.1009e-04 - mean_squared_error: 7.1009e-04 - val_loss: 6.1463e-04 - val_mean_squared_error: 6.1463e-04
# Epoch 13/1000
#  - 15s - loss: 7.0408e-04 - mean_squared_error: 7.0408e-04 - val_loss: 5.5587e-04 - val_mean_squared_error: 5.5587e-04
# Epoch 14/1000
#  - 15s - loss: 6.9801e-04 - mean_squared_error: 6.9801e-04 - val_loss: 6.5531e-04 - val_mean_squared_error: 6.5531e-04
# Epoch 15/1000
#  - 15s - loss: 6.9253e-04 - mean_squared_error: 6.9253e-04 - val_loss: 6.5982e-04 - val_mean_squared_error: 6.5982e-04
# Epoch 16/1000
#  - 15s - loss: 6.8619e-04 - mean_squared_error: 6.8619e-04 - val_loss: 6.3594e-04 - val_mean_squared_error: 6.3594e-04
# Epoch 17/1000
#  - 14s - loss: 6.8045e-04 - mean_squared_error: 6.8045e-04 - val_loss: 6.2600e-04 - val_mean_squared_error: 6.2600e-04
# Epoch 18/1000
#  - 14s - loss: 6.7616e-04 - mean_squared_error: 6.7616e-04 - val_loss: 7.6073e-04 - val_mean_squared_error: 7.6073e-04
# Epoch 19/1000
#  - 15s - loss: 6.7072e-04 - mean_squared_error: 6.7072e-04 - val_loss: 4.6761e-04 - val_mean_squared_error: 4.6761e-04
# Epoch 20/1000
#  - 14s - loss: 6.6425e-04 - mean_squared_error: 6.6425e-04 - val_loss: 7.9848e-04 - val_mean_squared_error: 7.9848e-04
# Epoch 21/1000
#  - 15s - loss: 6.6039e-04 - mean_squared_error: 6.6039e-04 - val_loss: 7.0891e-04 - val_mean_squared_error: 7.0891e-04
# Epoch 22/1000
#  - 16s - loss: 6.5570e-04 - mean_squared_error: 6.5570e-04 - val_loss: 7.1345e-04 - val_mean_squared_error: 7.1345e-04
# Epoch 23/1000
#  - 16s - loss: 6.5109e-04 - mean_squared_error: 6.5109e-04 - val_loss: 6.1136e-04 - val_mean_squared_error: 6.1136e-04
# Epoch 24/1000
#  - 15s - loss: 6.4698e-04 - mean_squared_error: 6.4698e-04 - val_loss: 7.8172e-04 - val_mean_squared_error: 7.8172e-04
# Epoch 25/1000
#  - 15s - loss: 6.4194e-04 - mean_squared_error: 6.4194e-04 - val_loss: 5.6238e-04 - val_mean_squared_error: 5.6238e-04
# Epoch 26/1000
#  - 15s - loss: 6.3819e-04 - mean_squared_error: 6.3819e-04 - val_loss: 7.1025e-04 - val_mean_squared_error: 7.1025e-04
# Epoch 27/1000
#  - 15s - loss: 6.3399e-04 - mean_squared_error: 6.3399e-04 - val_loss: 8.7958e-04 - val_mean_squared_error: 8.7958e-04
# Epoch 28/1000
#  - 14s - loss: 6.2819e-04 - mean_squared_error: 6.2819e-04 - val_loss: 7.0034e-04 - val_mean_squared_error: 7.0034e-04
# Epoch 29/1000
#  - 16s - loss: 6.2487e-04 - mean_squared_error: 6.2487e-04 - val_loss: 6.3505e-04 - val_mean_squared_error: 6.3505e-04
# Epoch 30/1000
#  - 15s - loss: 6.2191e-04 - mean_squared_error: 6.2191e-04 - val_loss: 6.6055e-04 - val_mean_squared_error: 6.6055e-04
# Epoch 31/1000
#  - 14s - loss: 6.1686e-04 - mean_squared_error: 6.1686e-04 - val_loss: 5.7352e-04 - val_mean_squared_error: 5.7352e-04
# Epoch 32/1000
#  - 16s - loss: 6.1275e-04 - mean_squared_error: 6.1275e-04 - val_loss: 5.7897e-04 - val_mean_squared_error: 5.7897e-04
# Epoch 33/1000
#  - 15s - loss: 6.1048e-04 - mean_squared_error: 6.1048e-04 - val_loss: 5.3452e-04 - val_mean_squared_error: 5.3452e-04
# Epoch 34/1000
#  - 15s - loss: 6.0618e-04 - mean_squared_error: 6.0618e-04 - val_loss: 5.0826e-04 - val_mean_squared_error: 5.0826e-04
# Epoch 35/1000
#  - 15s - loss: 6.0223e-04 - mean_squared_error: 6.0223e-04 - val_loss: 6.4793e-04 - val_mean_squared_error: 6.4793e-04
# Epoch 36/1000
#  - 15s - loss: 5.9811e-04 - mean_squared_error: 5.9811e-04 - val_loss: 6.1421e-04 - val_mean_squared_error: 6.1421e-04
# Epoch 37/1000
#  - 15s - loss: 5.9600e-04 - mean_squared_error: 5.9600e-04 - val_loss: 4.9263e-04 - val_mean_squared_error: 4.9263e-04
# Epoch 38/1000
#  - 15s - loss: 5.9245e-04 - mean_squared_error: 5.9245e-04 - val_loss: 6.3490e-04 - val_mean_squared_error: 6.3490e-04
# Epoch 39/1000
#  - 16s - loss: 5.8889e-04 - mean_squared_error: 5.8889e-04 - val_loss: 7.4058e-04 - val_mean_squared_error: 7.4058e-04
# Epoch 40/1000
#  - 15s - loss: 5.8596e-04 - mean_squared_error: 5.8596e-04 - val_loss: 5.2295e-04 - val_mean_squared_error: 5.2295e-04
# Epoch 41/1000
#  - 15s - loss: 5.8379e-04 - mean_squared_error: 5.8379e-04 - val_loss: 5.4051e-04 - val_mean_squared_error: 5.4051e-04
# Epoch 42/1000
#  - 15s - loss: 5.7917e-04 - mean_squared_error: 5.7917e-04 - val_loss: 5.1026e-04 - val_mean_squared_error: 5.1026e-04
# Epoch 43/1000
#  - 15s - loss: 5.7777e-04 - mean_squared_error: 5.7777e-04 - val_loss: 7.0786e-04 - val_mean_squared_error: 7.0786e-04
# Epoch 44/1000
#  - 15s - loss: 5.7355e-04 - mean_squared_error: 5.7355e-04 - val_loss: 6.5909e-04 - val_mean_squared_error: 6.5909e-04
# Epoch 45/1000
#  - 15s - loss: 5.7064e-04 - mean_squared_error: 5.7064e-04 - val_loss: 6.6403e-04 - val_mean_squared_error: 6.6403e-04
# Epoch 46/1000
#  - 15s - loss: 5.6853e-04 - mean_squared_error: 5.6853e-04 - val_loss: 6.5008e-04 - val_mean_squared_error: 6.5008e-04
# Epoch 47/1000
#  - 15s - loss: 5.6468e-04 - mean_squared_error: 5.6468e-04 - val_loss: 4.4832e-04 - val_mean_squared_error: 4.4832e-04
# Epoch 48/1000
#  - 15s - loss: 5.6198e-04 - mean_squared_error: 5.6198e-04 - val_loss: 4.5689e-04 - val_mean_squared_error: 4.5689e-04
# Epoch 49/1000
#  - 15s - loss: 5.5943e-04 - mean_squared_error: 5.5943e-04 - val_loss: 5.9687e-04 - val_mean_squared_error: 5.9687e-04
# Epoch 50/1000
#  - 15s - loss: 5.5588e-04 - mean_squared_error: 5.5588e-04 - val_loss: 8.4538e-04 - val_mean_squared_error: 8.4538e-04
# Epoch 51/1000
#  - 15s - loss: 5.5386e-04 - mean_squared_error: 5.5386e-04 - val_loss: 6.3898e-04 - val_mean_squared_error: 6.3898e-04
# Epoch 52/1000
#  - 15s - loss: 5.5122e-04 - mean_squared_error: 5.5122e-04 - val_loss: 7.6509e-04 - val_mean_squared_error: 7.6509e-04
# Epoch 53/1000
#  - 15s - loss: 5.4840e-04 - mean_squared_error: 5.4840e-04 - val_loss: 5.6417e-04 - val_mean_squared_error: 5.6417e-04
# Epoch 54/1000
#  - 15s - loss: 5.4586e-04 - mean_squared_error: 5.4586e-04 - val_loss: 6.1083e-04 - val_mean_squared_error: 6.1083e-04
# Epoch 55/1000
#  - 15s - loss: 5.4431e-04 - mean_squared_error: 5.4431e-04 - val_loss: 4.4179e-04 - val_mean_squared_error: 4.4179e-04
# Epoch 56/1000
#  - 15s - loss: 5.4105e-04 - mean_squared_error: 5.4105e-04 - val_loss: 7.2863e-04 - val_mean_squared_error: 7.2863e-04
# Epoch 57/1000
#  - 15s - loss: 5.3794e-04 - mean_squared_error: 5.3794e-04 - val_loss: 6.7012e-04 - val_mean_squared_error: 6.7012e-04
# Epoch 58/1000
#  - 16s - loss: 5.3659e-04 - mean_squared_error: 5.3659e-04 - val_loss: 6.1665e-04 - val_mean_squared_error: 6.1665e-04
# Epoch 59/1000
#  - 15s - loss: 5.3373e-04 - mean_squared_error: 5.3373e-04 - val_loss: 4.4745e-04 - val_mean_squared_error: 4.4745e-04
# Epoch 60/1000
#  - 15s - loss: 5.3198e-04 - mean_squared_error: 5.3198e-04 - val_loss: 5.6862e-04 - val_mean_squared_error: 5.6862e-04
# Epoch 61/1000
#  - 15s - loss: 5.2977e-04 - mean_squared_error: 5.2977e-04 - val_loss: 5.6022e-04 - val_mean_squared_error: 5.6022e-04
# Epoch 62/1000
#  - 15s - loss: 5.2750e-04 - mean_squared_error: 5.2750e-04 - val_loss: 6.0835e-04 - val_mean_squared_error: 6.0835e-04
# Epoch 63/1000
#  - 15s - loss: 5.2495e-04 - mean_squared_error: 5.2495e-04 - val_loss: 6.8879e-04 - val_mean_squared_error: 6.8879e-04
# Epoch 64/1000
#  - 15s - loss: 5.2293e-04 - mean_squared_error: 5.2293e-04 - val_loss: 5.2406e-04 - val_mean_squared_error: 5.2406e-04
# Epoch 65/1000
#  - 15s - loss: 5.2035e-04 - mean_squared_error: 5.2035e-04 - val_loss: 7.9015e-04 - val_mean_squared_error: 7.9015e-04
# Epoch 66/1000
#  - 15s - loss: 5.1862e-04 - mean_squared_error: 5.1862e-04 - val_loss: 4.6401e-04 - val_mean_squared_error: 4.6401e-04
# Epoch 67/1000
#  - 15s - loss: 5.1693e-04 - mean_squared_error: 5.1693e-04 - val_loss: 4.5781e-04 - val_mean_squared_error: 4.5781e-04
# Epoch 68/1000
#  - 15s - loss: 5.1489e-04 - mean_squared_error: 5.1489e-04 - val_loss: 7.4425e-04 - val_mean_squared_error: 7.4425e-04
# Epoch 69/1000
#  - 15s - loss: 5.1270e-04 - mean_squared_error: 5.1270e-04 - val_loss: 4.4548e-04 - val_mean_squared_error: 4.4548e-04
# Epoch 70/1000
#  - 15s - loss: 5.1061e-04 - mean_squared_error: 5.1061e-04 - val_loss: 6.2356e-04 - val_mean_squared_error: 6.2356e-04
# Epoch 71/1000
#  - 15s - loss: 5.0786e-04 - mean_squared_error: 5.0786e-04 - val_loss: 6.5100e-04 - val_mean_squared_error: 6.5100e-04
# Epoch 72/1000
#  - 15s - loss: 5.0576e-04 - mean_squared_error: 5.0576e-04 - val_loss: 4.8186e-04 - val_mean_squared_error: 4.8186e-04
# Epoch 73/1000
#  - 15s - loss: 5.0409e-04 - mean_squared_error: 5.0409e-04 - val_loss: 5.4019e-04 - val_mean_squared_error: 5.4019e-04
# Epoch 74/1000
#  - 15s - loss: 5.0126e-04 - mean_squared_error: 5.0126e-04 - val_loss: 5.5326e-04 - val_mean_squared_error: 5.5326e-04
# Epoch 75/1000
#  - 15s - loss: 4.9997e-04 - mean_squared_error: 4.9997e-04 - val_loss: 4.7552e-04 - val_mean_squared_error: 4.7552e-04
# Epoch 76/1000
#  - 15s - loss: 4.9654e-04 - mean_squared_error: 4.9654e-04 - val_loss: 5.9009e-04 - val_mean_squared_error: 5.9009e-04
# Epoch 77/1000
#  - 15s - loss: 4.9329e-04 - mean_squared_error: 4.9329e-04 - val_loss: 3.5606e-04 - val_mean_squared_error: 3.5606e-04
# Epoch 78/1000
#  - 15s - loss: 4.9132e-04 - mean_squared_error: 4.9132e-04 - val_loss: 4.8467e-04 - val_mean_squared_error: 4.8467e-04
# Epoch 79/1000
#  - 15s - loss: 4.8885e-04 - mean_squared_error: 4.8885e-04 - val_loss: 3.4545e-04 - val_mean_squared_error: 3.4545e-04
# Epoch 80/1000
#  - 15s - loss: 4.8723e-04 - mean_squared_error: 4.8723e-04 - val_loss: 3.8966e-04 - val_mean_squared_error: 3.8966e-04
# Epoch 81/1000
#  - 15s - loss: 4.8459e-04 - mean_squared_error: 4.8459e-04 - val_loss: 6.5483e-04 - val_mean_squared_error: 6.5483e-04
# Epoch 82/1000
#  - 15s - loss: 4.8156e-04 - mean_squared_error: 4.8156e-04 - val_loss: 4.2046e-04 - val_mean_squared_error: 4.2046e-04
# Epoch 83/1000
#  - 15s - loss: 4.7939e-04 - mean_squared_error: 4.7939e-04 - val_loss: 5.0777e-04 - val_mean_squared_error: 5.0777e-04
# Epoch 84/1000
#  - 15s - loss: 4.7648e-04 - mean_squared_error: 4.7648e-04 - val_loss: 5.0674e-04 - val_mean_squared_error: 5.0674e-04
# Epoch 85/1000
#  - 15s - loss: 4.7444e-04 - mean_squared_error: 4.7444e-04 - val_loss: 5.2320e-04 - val_mean_squared_error: 5.2320e-04
# Epoch 86/1000
#  - 15s - loss: 4.7226e-04 - mean_squared_error: 4.7226e-04 - val_loss: 5.2079e-04 - val_mean_squared_error: 5.2079e-04
# Epoch 87/1000
#  - 15s - loss: 4.7000e-04 - mean_squared_error: 4.7000e-04 - val_loss: 4.6809e-04 - val_mean_squared_error: 4.6809e-04
# Epoch 88/1000
#  - 15s - loss: 4.6796e-04 - mean_squared_error: 4.6796e-04 - val_loss: 4.0161e-04 - val_mean_squared_error: 4.0161e-04
# Epoch 89/1000
#  - 15s - loss: 4.6554e-04 - mean_squared_error: 4.6554e-04 - val_loss: 4.9359e-04 - val_mean_squared_error: 4.9359e-04
# Epoch 90/1000
#  - 15s - loss: 4.6437e-04 - mean_squared_error: 4.6437e-04 - val_loss: 4.0252e-04 - val_mean_squared_error: 4.0252e-04
# Epoch 91/1000
#  - 15s - loss: 4.6186e-04 - mean_squared_error: 4.6186e-04 - val_loss: 4.8275e-04 - val_mean_squared_error: 4.8275e-04
# Epoch 92/1000
#  - 15s - loss: 4.6021e-04 - mean_squared_error: 4.6021e-04 - val_loss: 4.2518e-04 - val_mean_squared_error: 4.2518e-04
# Epoch 93/1000
#  - 16s - loss: 4.5868e-04 - mean_squared_error: 4.5868e-04 - val_loss: 4.5345e-04 - val_mean_squared_error: 4.5345e-04
# Epoch 94/1000
#  - 15s - loss: 4.5670e-04 - mean_squared_error: 4.5670e-04 - val_loss: 5.3311e-04 - val_mean_squared_error: 5.3311e-04
# Epoch 95/1000
#  - 15s - loss: 4.5472e-04 - mean_squared_error: 4.5472e-04 - val_loss: 5.0310e-04 - val_mean_squared_error: 5.0310e-04
# Epoch 96/1000
#  - 15s - loss: 4.5321e-04 - mean_squared_error: 4.5321e-04 - val_loss: 4.3349e-04 - val_mean_squared_error: 4.3349e-04
# Epoch 97/1000
#  - 15s - loss: 4.5216e-04 - mean_squared_error: 4.5216e-04 - val_loss: 3.1862e-04 - val_mean_squared_error: 3.1862e-04
# Epoch 98/1000
#  - 15s - loss: 4.4989e-04 - mean_squared_error: 4.4989e-04 - val_loss: 4.6867e-04 - val_mean_squared_error: 4.6867e-04
# Epoch 99/1000
#  - 15s - loss: 4.4779e-04 - mean_squared_error: 4.4779e-04 - val_loss: 4.2172e-04 - val_mean_squared_error: 4.2172e-04
# Epoch 100/1000
#  - 15s - loss: 4.4632e-04 - mean_squared_error: 4.4632e-04 - val_loss: 4.3066e-04 - val_mean_squared_error: 4.3066e-04
# Epoch 101/1000
#  - 15s - loss: 4.4524e-04 - mean_squared_error: 4.4524e-04 - val_loss: 5.2887e-04 - val_mean_squared_error: 5.2887e-04
# Epoch 102/1000
#  - 15s - loss: 4.4381e-04 - mean_squared_error: 4.4381e-04 - val_loss: 4.1207e-04 - val_mean_squared_error: 4.1207e-04
# Epoch 103/1000
#  - 15s - loss: 4.4263e-04 - mean_squared_error: 4.4263e-04 - val_loss: 4.0694e-04 - val_mean_squared_error: 4.0694e-04
# Epoch 104/1000
#  - 15s - loss: 4.4117e-04 - mean_squared_error: 4.4117e-04 - val_loss: 4.8612e-04 - val_mean_squared_error: 4.8612e-04
# Epoch 105/1000
#  - 15s - loss: 4.3922e-04 - mean_squared_error: 4.3922e-04 - val_loss: 4.8589e-04 - val_mean_squared_error: 4.8589e-04
# Epoch 106/1000
#  - 15s - loss: 4.3775e-04 - mean_squared_error: 4.3775e-04 - val_loss: 5.2090e-04 - val_mean_squared_error: 5.2090e-04
# Epoch 107/1000
#  - 15s - loss: 4.3715e-04 - mean_squared_error: 4.3715e-04 - val_loss: 5.2198e-04 - val_mean_squared_error: 5.2198e-04
# Epoch 108/1000
#  - 15s - loss: 4.3625e-04 - mean_squared_error: 4.3625e-04 - val_loss: 6.0498e-04 - val_mean_squared_error: 6.0498e-04
# Epoch 109/1000
#  - 15s - loss: 4.3376e-04 - mean_squared_error: 4.3376e-04 - val_loss: 4.0617e-04 - val_mean_squared_error: 4.0617e-04
# Epoch 110/1000
#  - 16s - loss: 4.3336e-04 - mean_squared_error: 4.3336e-04 - val_loss: 4.5618e-04 - val_mean_squared_error: 4.5618e-04
# Epoch 111/1000
#  - 15s - loss: 4.3235e-04 - mean_squared_error: 4.3235e-04 - val_loss: 5.0732e-04 - val_mean_squared_error: 5.0732e-04
# Epoch 112/1000
#  - 15s - loss: 4.3047e-04 - mean_squared_error: 4.3047e-04 - val_loss: 4.2483e-04 - val_mean_squared_error: 4.2483e-04
# Epoch 113/1000
#  - 15s - loss: 4.2992e-04 - mean_squared_error: 4.2992e-04 - val_loss: 3.8459e-04 - val_mean_squared_error: 3.8459e-04
# Epoch 114/1000
#  - 15s - loss: 4.2858e-04 - mean_squared_error: 4.2858e-04 - val_loss: 4.1391e-04 - val_mean_squared_error: 4.1391e-04
# Epoch 115/1000
#  - 15s - loss: 4.2725e-04 - mean_squared_error: 4.2725e-04 - val_loss: 4.1723e-04 - val_mean_squared_error: 4.1723e-04
# Epoch 116/1000
#  - 15s - loss: 4.2630e-04 - mean_squared_error: 4.2630e-04 - val_loss: 4.7904e-04 - val_mean_squared_error: 4.7904e-04
# Epoch 117/1000
#  - 15s - loss: 4.2483e-04 - mean_squared_error: 4.2483e-04 - val_loss: 5.1851e-04 - val_mean_squared_error: 5.1851e-04
# Epoch 118/1000
#  - 15s - loss: 4.2365e-04 - mean_squared_error: 4.2365e-04 - val_loss: 3.2934e-04 - val_mean_squared_error: 3.2934e-04
# Epoch 119/1000
#  - 15s - loss: 4.2245e-04 - mean_squared_error: 4.2245e-04 - val_loss: 4.4768e-04 - val_mean_squared_error: 4.4768e-04
# Epoch 120/1000
#  - 16s - loss: 4.2148e-04 - mean_squared_error: 4.2148e-04 - val_loss: 5.1810e-04 - val_mean_squared_error: 5.1810e-04
# Epoch 121/1000
#  - 15s - loss: 4.2118e-04 - mean_squared_error: 4.2118e-04 - val_loss: 4.3874e-04 - val_mean_squared_error: 4.3874e-04
# Epoch 122/1000
#  - 15s - loss: 4.1936e-04 - mean_squared_error: 4.1936e-04 - val_loss: 3.4552e-04 - val_mean_squared_error: 3.4552e-04
# Epoch 123/1000
#  - 14s - loss: 4.1855e-04 - mean_squared_error: 4.1855e-04 - val_loss: 5.2548e-04 - val_mean_squared_error: 5.2548e-04
# Epoch 124/1000
#  - 15s - loss: 4.1760e-04 - mean_squared_error: 4.1760e-04 - val_loss: 5.5825e-04 - val_mean_squared_error: 5.5825e-04
# Epoch 125/1000
#  - 15s - loss: 4.1635e-04 - mean_squared_error: 4.1635e-04 - val_loss: 8.1758e-04 - val_mean_squared_error: 8.1758e-04
# Epoch 126/1000
#  - 15s - loss: 4.1568e-04 - mean_squared_error: 4.1568e-04 - val_loss: 4.7316e-04 - val_mean_squared_error: 4.7316e-04
# Epoch 127/1000
#  - 15s - loss: 4.1419e-04 - mean_squared_error: 4.1419e-04 - val_loss: 5.6716e-04 - val_mean_squared_error: 5.6716e-04
# Epoch 128/1000
#  - 16s - loss: 4.1349e-04 - mean_squared_error: 4.1349e-04 - val_loss: 3.8377e-04 - val_mean_squared_error: 3.8377e-04
# Epoch 129/1000
#  - 15s - loss: 4.1246e-04 - mean_squared_error: 4.1246e-04 - val_loss: 3.0693e-04 - val_mean_squared_error: 3.0693e-04
# Epoch 130/1000
#  - 15s - loss: 4.1138e-04 - mean_squared_error: 4.1138e-04 - val_loss: 3.5844e-04 - val_mean_squared_error: 3.5844e-04
# Epoch 131/1000
#  - 15s - loss: 4.1050e-04 - mean_squared_error: 4.1050e-04 - val_loss: 4.7370e-04 - val_mean_squared_error: 4.7370e-04
# Epoch 132/1000
#  - 15s - loss: 4.0941e-04 - mean_squared_error: 4.0941e-04 - val_loss: 3.0698e-04 - val_mean_squared_error: 3.0698e-04
# Epoch 133/1000
#  - 15s - loss: 4.0840e-04 - mean_squared_error: 4.0840e-04 - val_loss: 3.7946e-04 - val_mean_squared_error: 3.7946e-04
# Epoch 134/1000
#  - 15s - loss: 4.0750e-04 - mean_squared_error: 4.0750e-04 - val_loss: 3.0934e-04 - val_mean_squared_error: 3.0934e-04
# Epoch 135/1000
#  - 15s - loss: 4.0654e-04 - mean_squared_error: 4.0654e-04 - val_loss: 4.0913e-04 - val_mean_squared_error: 4.0913e-04
# Epoch 136/1000
#  - 16s - loss: 4.0616e-04 - mean_squared_error: 4.0616e-04 - val_loss: 5.2168e-04 - val_mean_squared_error: 5.2168e-04
# Epoch 137/1000
#  - 16s - loss: 4.0463e-04 - mean_squared_error: 4.0463e-04 - val_loss: 4.3359e-04 - val_mean_squared_error: 4.3359e-04
# Epoch 138/1000
#  - 17s - loss: 4.0462e-04 - mean_squared_error: 4.0462e-04 - val_loss: 4.7584e-04 - val_mean_squared_error: 4.7584e-04
# Epoch 139/1000
#  - 15s - loss: 4.0342e-04 - mean_squared_error: 4.0342e-04 - val_loss: 3.7815e-04 - val_mean_squared_error: 3.7815e-04
# Epoch 140/1000
#  - 16s - loss: 4.0327e-04 - mean_squared_error: 4.0327e-04 - val_loss: 3.3596e-04 - val_mean_squared_error: 3.3596e-04
# Epoch 141/1000
#  - 15s - loss: 4.0133e-04 - mean_squared_error: 4.0133e-04 - val_loss: 4.4130e-04 - val_mean_squared_error: 4.4130e-04
# Epoch 142/1000
#  - 15s - loss: 4.0108e-04 - mean_squared_error: 4.0108e-04 - val_loss: 3.9591e-04 - val_mean_squared_error: 3.9591e-04
# Epoch 143/1000
#  - 15s - loss: 3.9971e-04 - mean_squared_error: 3.9971e-04 - val_loss: 3.1789e-04 - val_mean_squared_error: 3.1789e-04
# Epoch 144/1000
#  - 15s - loss: 3.9947e-04 - mean_squared_error: 3.9947e-04 - val_loss: 3.5948e-04 - val_mean_squared_error: 3.5948e-04
# Epoch 145/1000
#  - 16s - loss: 3.9871e-04 - mean_squared_error: 3.9871e-04 - val_loss: 3.9355e-04 - val_mean_squared_error: 3.9355e-04
# Epoch 146/1000
#  - 16s - loss: 3.9783e-04 - mean_squared_error: 3.9783e-04 - val_loss: 2.5167e-04 - val_mean_squared_error: 2.5167e-04
# Epoch 147/1000
#  - 16s - loss: 3.9701e-04 - mean_squared_error: 3.9701e-04 - val_loss: 5.1521e-04 - val_mean_squared_error: 5.1521e-04
# Epoch 148/1000
#  - 16s - loss: 3.9604e-04 - mean_squared_error: 3.9604e-04 - val_loss: 3.9570e-04 - val_mean_squared_error: 3.9570e-04
# Epoch 149/1000
#  - 16s - loss: 3.9527e-04 - mean_squared_error: 3.9527e-04 - val_loss: 3.4671e-04 - val_mean_squared_error: 3.4671e-04
# Epoch 150/1000
#  - 16s - loss: 3.9490e-04 - mean_squared_error: 3.9490e-04 - val_loss: 3.2801e-04 - val_mean_squared_error: 3.2801e-04
# Epoch 151/1000
#  - 16s - loss: 3.9430e-04 - mean_squared_error: 3.9430e-04 - val_loss: 5.6859e-04 - val_mean_squared_error: 5.6859e-04
# Epoch 152/1000
#  - 15s - loss: 3.9357e-04 - mean_squared_error: 3.9357e-04 - val_loss: 4.7891e-04 - val_mean_squared_error: 4.7891e-04
# Epoch 153/1000
#  - 15s - loss: 3.9286e-04 - mean_squared_error: 3.9286e-04 - val_loss: 4.3318e-04 - val_mean_squared_error: 4.3318e-04
# Epoch 154/1000
#  - 17s - loss: 3.9189e-04 - mean_squared_error: 3.9189e-04 - val_loss: 3.5496e-04 - val_mean_squared_error: 3.5496e-04
# Epoch 155/1000
#  - 16s - loss: 3.9074e-04 - mean_squared_error: 3.9074e-04 - val_loss: 2.9611e-04 - val_mean_squared_error: 2.9611e-04
# Epoch 156/1000
#  - 16s - loss: 3.9006e-04 - mean_squared_error: 3.9006e-04 - val_loss: 3.5760e-04 - val_mean_squared_error: 3.5760e-04
# Epoch 157/1000
#  - 16s - loss: 3.9003e-04 - mean_squared_error: 3.9003e-04 - val_loss: 4.0143e-04 - val_mean_squared_error: 4.0143e-04
# Epoch 158/1000
#  - 16s - loss: 3.8912e-04 - mean_squared_error: 3.8912e-04 - val_loss: 3.4595e-04 - val_mean_squared_error: 3.4595e-04
# Epoch 159/1000
#  - 15s - loss: 3.8794e-04 - mean_squared_error: 3.8794e-04 - val_loss: 3.9320e-04 - val_mean_squared_error: 3.9320e-04
# Epoch 160/1000
#  - 16s - loss: 3.8753e-04 - mean_squared_error: 3.8753e-04 - val_loss: 4.1037e-04 - val_mean_squared_error: 4.1037e-04
# Epoch 161/1000
#  - 15s - loss: 3.8700e-04 - mean_squared_error: 3.8700e-04 - val_loss: 4.8583e-04 - val_mean_squared_error: 4.8583e-04
# Epoch 162/1000
#  - 16s - loss: 3.8623e-04 - mean_squared_error: 3.8623e-04 - val_loss: 5.3974e-04 - val_mean_squared_error: 5.3974e-04
# Epoch 163/1000
#  - 16s - loss: 3.8605e-04 - mean_squared_error: 3.8605e-04 - val_loss: 4.9692e-04 - val_mean_squared_error: 4.9692e-04
# Epoch 164/1000
#  - 16s - loss: 3.8581e-04 - mean_squared_error: 3.8581e-04 - val_loss: 2.5208e-04 - val_mean_squared_error: 2.5208e-04
# Epoch 165/1000
#  - 15s - loss: 3.8421e-04 - mean_squared_error: 3.8421e-04 - val_loss: 4.9068e-04 - val_mean_squared_error: 4.9068e-04
# Epoch 166/1000
#  - 15s - loss: 3.8391e-04 - mean_squared_error: 3.8391e-04 - val_loss: 4.2363e-04 - val_mean_squared_error: 4.2363e-04
# Epoch 167/1000
#  - 15s - loss: 3.8396e-04 - mean_squared_error: 3.8396e-04 - val_loss: 3.1768e-04 - val_mean_squared_error: 3.1768e-04
# Epoch 168/1000
#  - 16s - loss: 3.8206e-04 - mean_squared_error: 3.8206e-04 - val_loss: 3.9816e-04 - val_mean_squared_error: 3.9816e-04
# Epoch 169/1000
#  - 15s - loss: 3.8236e-04 - mean_squared_error: 3.8236e-04 - val_loss: 2.9045e-04 - val_mean_squared_error: 2.9045e-04
# Epoch 170/1000
#  - 15s - loss: 3.8104e-04 - mean_squared_error: 3.8104e-04 - val_loss: 4.4334e-04 - val_mean_squared_error: 4.4334e-04
# Epoch 171/1000
#  - 16s - loss: 3.8111e-04 - mean_squared_error: 3.8111e-04 - val_loss: 2.9164e-04 - val_mean_squared_error: 2.9164e-04
# Epoch 172/1000
#  - 15s - loss: 3.7989e-04 - mean_squared_error: 3.7989e-04 - val_loss: 5.2150e-04 - val_mean_squared_error: 5.2150e-04
# Epoch 173/1000
#  - 16s - loss: 3.7898e-04 - mean_squared_error: 3.7898e-04 - val_loss: 4.2959e-04 - val_mean_squared_error: 4.2959e-04
# Epoch 174/1000
#  - 16s - loss: 3.7876e-04 - mean_squared_error: 3.7876e-04 - val_loss: 4.8742e-04 - val_mean_squared_error: 4.8742e-04
# Epoch 175/1000
#  - 15s - loss: 3.7793e-04 - mean_squared_error: 3.7793e-04 - val_loss: 3.5604e-04 - val_mean_squared_error: 3.5604e-04
# Epoch 176/1000
#  - 15s - loss: 3.7819e-04 - mean_squared_error: 3.7819e-04 - val_loss: 4.3897e-04 - val_mean_squared_error: 4.3897e-04
# Epoch 177/1000
#  - 15s - loss: 3.7690e-04 - mean_squared_error: 3.7690e-04 - val_loss: 3.9007e-04 - val_mean_squared_error: 3.9007e-04
# Epoch 178/1000
#  - 15s - loss: 3.7540e-04 - mean_squared_error: 3.7540e-04 - val_loss: 4.5297e-04 - val_mean_squared_error: 4.5297e-04
# Epoch 179/1000
#  - 15s - loss: 3.7586e-04 - mean_squared_error: 3.7586e-04 - val_loss: 2.4487e-04 - val_mean_squared_error: 2.4487e-04
# Epoch 180/1000
#  - 16s - loss: 3.7502e-04 - mean_squared_error: 3.7502e-04 - val_loss: 3.2882e-04 - val_mean_squared_error: 3.2882e-04
# Epoch 181/1000
#  - 16s - loss: 3.7431e-04 - mean_squared_error: 3.7431e-04 - val_loss: 3.0493e-04 - val_mean_squared_error: 3.0493e-04
# Epoch 182/1000
#  - 16s - loss: 3.7419e-04 - mean_squared_error: 3.7419e-04 - val_loss: 3.3033e-04 - val_mean_squared_error: 3.3033e-04
# Epoch 183/1000
#  - 15s - loss: 3.7324e-04 - mean_squared_error: 3.7324e-04 - val_loss: 5.1271e-04 - val_mean_squared_error: 5.1271e-04
# Epoch 184/1000
#  - 15s - loss: 3.7296e-04 - mean_squared_error: 3.7296e-04 - val_loss: 4.2962e-04 - val_mean_squared_error: 4.2962e-04
# Epoch 185/1000
#  - 16s - loss: 3.7215e-04 - mean_squared_error: 3.7215e-04 - val_loss: 6.7109e-04 - val_mean_squared_error: 6.7109e-04
# Epoch 186/1000
#  - 16s - loss: 3.7129e-04 - mean_squared_error: 3.7129e-04 - val_loss: 3.9488e-04 - val_mean_squared_error: 3.9488e-04
# Epoch 187/1000
#  - 16s - loss: 3.7164e-04 - mean_squared_error: 3.7164e-04 - val_loss: 2.4925e-04 - val_mean_squared_error: 2.4925e-04
# Epoch 188/1000
#  - 15s - loss: 3.6985e-04 - mean_squared_error: 3.6985e-04 - val_loss: 7.2934e-04 - val_mean_squared_error: 7.2934e-04
# Epoch 189/1000
#  - 15s - loss: 3.6989e-04 - mean_squared_error: 3.6989e-04 - val_loss: 3.6895e-04 - val_mean_squared_error: 3.6895e-04
# Epoch 190/1000
#  - 15s - loss: 3.6946e-04 - mean_squared_error: 3.6946e-04 - val_loss: 3.9212e-04 - val_mean_squared_error: 3.9212e-04
# Epoch 191/1000
#  - 15s - loss: 3.6809e-04 - mean_squared_error: 3.6809e-04 - val_loss: 3.5770e-04 - val_mean_squared_error: 3.5770e-04
# Epoch 192/1000
#  - 14s - loss: 3.6868e-04 - mean_squared_error: 3.6868e-04 - val_loss: 3.4619e-04 - val_mean_squared_error: 3.4619e-04
# Epoch 193/1000
#  - 15s - loss: 3.6749e-04 - mean_squared_error: 3.6749e-04 - val_loss: 4.9128e-04 - val_mean_squared_error: 4.9128e-04
# Epoch 194/1000
#  - 15s - loss: 3.6710e-04 - mean_squared_error: 3.6710e-04 - val_loss: 4.1756e-04 - val_mean_squared_error: 4.1756e-04
# Epoch 195/1000
#  - 15s - loss: 3.6739e-04 - mean_squared_error: 3.6739e-04 - val_loss: 4.4092e-04 - val_mean_squared_error: 4.4092e-04
# Epoch 196/1000
#  - 15s - loss: 3.6609e-04 - mean_squared_error: 3.6609e-04 - val_loss: 3.1699e-04 - val_mean_squared_error: 3.1699e-04
# Epoch 197/1000
#  - 15s - loss: 3.6572e-04 - mean_squared_error: 3.6572e-04 - val_loss: 3.4043e-04 - val_mean_squared_error: 3.4043e-04
# Epoch 198/1000
#  - 15s - loss: 3.6519e-04 - mean_squared_error: 3.6519e-04 - val_loss: 4.0742e-04 - val_mean_squared_error: 4.0742e-04
# Epoch 199/1000
#  - 15s - loss: 3.6515e-04 - mean_squared_error: 3.6515e-04 - val_loss: 2.7393e-04 - val_mean_squared_error: 2.7393e-04
# Epoch 200/1000
#  - 15s - loss: 3.6421e-04 - mean_squared_error: 3.6421e-04 - val_loss: 5.5974e-04 - val_mean_squared_error: 5.5974e-04
# Epoch 201/1000
#  - 15s - loss: 3.6420e-04 - mean_squared_error: 3.6420e-04 - val_loss: 3.1068e-04 - val_mean_squared_error: 3.1068e-04
# Epoch 202/1000
#  - 16s - loss: 3.6318e-04 - mean_squared_error: 3.6318e-04 - val_loss: 4.9294e-04 - val_mean_squared_error: 4.9294e-04
# Epoch 203/1000
#  - 15s - loss: 3.6265e-04 - mean_squared_error: 3.6265e-04 - val_loss: 3.9023e-04 - val_mean_squared_error: 3.9023e-04
# Epoch 204/1000
#  - 15s - loss: 3.6253e-04 - mean_squared_error: 3.6253e-04 - val_loss: 4.2120e-04 - val_mean_squared_error: 4.2120e-04
# Epoch 205/1000
#  - 15s - loss: 3.6208e-04 - mean_squared_error: 3.6208e-04 - val_loss: 3.9573e-04 - val_mean_squared_error: 3.9573e-04
# Epoch 206/1000
#  - 15s - loss: 3.6170e-04 - mean_squared_error: 3.6170e-04 - val_loss: 3.1457e-04 - val_mean_squared_error: 3.1457e-04
# Epoch 207/1000
#  - 15s - loss: 3.6045e-04 - mean_squared_error: 3.6045e-04 - val_loss: 5.1444e-04 - val_mean_squared_error: 5.1444e-04
# Epoch 208/1000
#  - 16s - loss: 3.6049e-04 - mean_squared_error: 3.6049e-04 - val_loss: 3.0084e-04 - val_mean_squared_error: 3.0084e-04
# Epoch 209/1000
#  - 16s - loss: 3.5948e-04 - mean_squared_error: 3.5948e-04 - val_loss: 3.3818e-04 - val_mean_squared_error: 3.3818e-04
# Epoch 210/1000
#  - 14s - loss: 3.5925e-04 - mean_squared_error: 3.5925e-04 - val_loss: 4.6464e-04 - val_mean_squared_error: 4.6464e-04
# Epoch 211/1000
#  - 14s - loss: 3.5857e-04 - mean_squared_error: 3.5857e-04 - val_loss: 3.0953e-04 - val_mean_squared_error: 3.0953e-04
# Epoch 212/1000
#  - 15s - loss: 3.5837e-04 - mean_squared_error: 3.5837e-04 - val_loss: 3.5875e-04 - val_mean_squared_error: 3.5875e-04
# Epoch 213/1000
#  - 15s - loss: 3.5777e-04 - mean_squared_error: 3.5777e-04 - val_loss: 4.1406e-04 - val_mean_squared_error: 4.1406e-04
# Epoch 214/1000
#  - 15s - loss: 3.5787e-04 - mean_squared_error: 3.5787e-04 - val_loss: 2.8306e-04 - val_mean_squared_error: 2.8306e-04
# Epoch 215/1000
#  - 16s - loss: 3.5693e-04 - mean_squared_error: 3.5693e-04 - val_loss: 3.5902e-04 - val_mean_squared_error: 3.5902e-04
# Epoch 216/1000
#  - 16s - loss: 3.5622e-04 - mean_squared_error: 3.5622e-04 - val_loss: 3.5300e-04 - val_mean_squared_error: 3.5300e-04
# Epoch 217/1000
#  - 15s - loss: 3.5621e-04 - mean_squared_error: 3.5621e-04 - val_loss: 5.1035e-04 - val_mean_squared_error: 5.1035e-04
# Epoch 218/1000
#  - 15s - loss: 3.5582e-04 - mean_squared_error: 3.5582e-04 - val_loss: 4.5403e-04 - val_mean_squared_error: 4.5403e-04
# Epoch 219/1000
#  - 15s - loss: 3.5504e-04 - mean_squared_error: 3.5504e-04 - val_loss: 3.8610e-04 - val_mean_squared_error: 3.8610e-04
# Epoch 220/1000
#  - 15s - loss: 3.5487e-04 - mean_squared_error: 3.5487e-04 - val_loss: 4.0620e-04 - val_mean_squared_error: 4.0620e-04
# Epoch 221/1000
#  - 15s - loss: 3.5469e-04 - mean_squared_error: 3.5469e-04 - val_loss: 4.8022e-04 - val_mean_squared_error: 4.8022e-04
# Epoch 222/1000
#  - 15s - loss: 3.5373e-04 - mean_squared_error: 3.5373e-04 - val_loss: 4.5502e-04 - val_mean_squared_error: 4.5502e-04
# Epoch 223/1000
#  - 15s - loss: 3.5411e-04 - mean_squared_error: 3.5411e-04 - val_loss: 4.2494e-04 - val_mean_squared_error: 4.2494e-04
# Epoch 224/1000
#  - 17s - loss: 3.5300e-04 - mean_squared_error: 3.5300e-04 - val_loss: 3.9211e-04 - val_mean_squared_error: 3.9211e-04
# Epoch 225/1000
#  - 16s - loss: 3.5271e-04 - mean_squared_error: 3.5271e-04 - val_loss: 4.1668e-04 - val_mean_squared_error: 4.1668e-04
# Epoch 226/1000
#  - 16s - loss: 3.5241e-04 - mean_squared_error: 3.5241e-04 - val_loss: 3.3818e-04 - val_mean_squared_error: 3.3818e-04
# Epoch 227/1000
#  - 15s - loss: 3.5100e-04 - mean_squared_error: 3.5100e-04 - val_loss: 4.3856e-04 - val_mean_squared_error: 4.3856e-04
# Epoch 228/1000
#  - 16s - loss: 3.5198e-04 - mean_squared_error: 3.5198e-04 - val_loss: 2.6374e-04 - val_mean_squared_error: 2.6374e-04
# Epoch 229/1000
#  - 16s - loss: 3.5141e-04 - mean_squared_error: 3.5141e-04 - val_loss: 2.3643e-04 - val_mean_squared_error: 2.3643e-04
# Epoch 230/1000
#  - 16s - loss: 3.5087e-04 - mean_squared_error: 3.5087e-04 - val_loss: 2.8501e-04 - val_mean_squared_error: 2.8501e-04
# Epoch 231/1000
#  - 15s - loss: 3.5031e-04 - mean_squared_error: 3.5031e-04 - val_loss: 3.0161e-04 - val_mean_squared_error: 3.0161e-04
# Epoch 232/1000
#  - 15s - loss: 3.4957e-04 - mean_squared_error: 3.4957e-04 - val_loss: 4.9056e-04 - val_mean_squared_error: 4.9056e-04
# Epoch 233/1000
#  - 16s - loss: 3.4975e-04 - mean_squared_error: 3.4975e-04 - val_loss: 2.5120e-04 - val_mean_squared_error: 2.5120e-04
# Epoch 234/1000
#  - 16s - loss: 3.4900e-04 - mean_squared_error: 3.4900e-04 - val_loss: 2.9227e-04 - val_mean_squared_error: 2.9227e-04
# Epoch 235/1000
#  - 16s - loss: 3.4872e-04 - mean_squared_error: 3.4872e-04 - val_loss: 3.3232e-04 - val_mean_squared_error: 3.3232e-04
# Epoch 236/1000
#  - 15s - loss: 3.4861e-04 - mean_squared_error: 3.4861e-04 - val_loss: 4.7622e-04 - val_mean_squared_error: 4.7622e-04
# Epoch 237/1000
#  - 15s - loss: 3.4738e-04 - mean_squared_error: 3.4738e-04 - val_loss: 5.3054e-04 - val_mean_squared_error: 5.3054e-04
# Epoch 238/1000
#  - 15s - loss: 3.4786e-04 - mean_squared_error: 3.4786e-04 - val_loss: 3.5148e-04 - val_mean_squared_error: 3.5148e-04
# Epoch 239/1000
#  - 16s - loss: 3.4712e-04 - mean_squared_error: 3.4712e-04 - val_loss: 3.1181e-04 - val_mean_squared_error: 3.1181e-04
# Epoch 240/1000
#  - 15s - loss: 3.4681e-04 - mean_squared_error: 3.4681e-04 - val_loss: 3.6832e-04 - val_mean_squared_error: 3.6832e-04
# Epoch 241/1000
#  - 16s - loss: 3.4709e-04 - mean_squared_error: 3.4709e-04 - val_loss: 2.4806e-04 - val_mean_squared_error: 2.4806e-04
# Epoch 242/1000
#  - 15s - loss: 3.4594e-04 - mean_squared_error: 3.4594e-04 - val_loss: 4.0228e-04 - val_mean_squared_error: 4.0228e-04
# Epoch 243/1000
#  - 15s - loss: 3.4508e-04 - mean_squared_error: 3.4508e-04 - val_loss: 3.9253e-04 - val_mean_squared_error: 3.9253e-04
# Epoch 244/1000
#  - 15s - loss: 3.4523e-04 - mean_squared_error: 3.4523e-04 - val_loss: 2.4291e-04 - val_mean_squared_error: 2.4291e-04
# Epoch 245/1000
#  - 15s - loss: 3.4509e-04 - mean_squared_error: 3.4509e-04 - val_loss: 2.9450e-04 - val_mean_squared_error: 2.9450e-04
# Epoch 246/1000
#  - 15s - loss: 3.4408e-04 - mean_squared_error: 3.4408e-04 - val_loss: 2.6983e-04 - val_mean_squared_error: 2.6983e-04
# Epoch 247/1000
#  - 16s - loss: 3.4362e-04 - mean_squared_error: 3.4362e-04 - val_loss: 3.6260e-04 - val_mean_squared_error: 3.6260e-04
# Epoch 248/1000
#  - 16s - loss: 3.4410e-04 - mean_squared_error: 3.4410e-04 - val_loss: 5.6077e-04 - val_mean_squared_error: 5.6077e-04
# Epoch 249/1000
#  - 15s - loss: 3.4309e-04 - mean_squared_error: 3.4309e-04 - val_loss: 4.3114e-04 - val_mean_squared_error: 4.3114e-04
# Epoch 250/1000
#  - 15s - loss: 3.4383e-04 - mean_squared_error: 3.4383e-04 - val_loss: 2.7614e-04 - val_mean_squared_error: 2.7614e-04
# Epoch 251/1000
#  - 15s - loss: 3.4285e-04 - mean_squared_error: 3.4285e-04 - val_loss: 3.6064e-04 - val_mean_squared_error: 3.6064e-04
# Epoch 252/1000
#  - 15s - loss: 3.4200e-04 - mean_squared_error: 3.4200e-04 - val_loss: 3.6028e-04 - val_mean_squared_error: 3.6028e-04
# Epoch 253/1000
#  - 15s - loss: 3.4159e-04 - mean_squared_error: 3.4159e-04 - val_loss: 3.8836e-04 - val_mean_squared_error: 3.8836e-04
# Epoch 254/1000
#  - 15s - loss: 3.4175e-04 - mean_squared_error: 3.4175e-04 - val_loss: 3.8620e-04 - val_mean_squared_error: 3.8620e-04
# Epoch 255/1000
#  - 15s - loss: 3.4095e-04 - mean_squared_error: 3.4095e-04 - val_loss: 3.3773e-04 - val_mean_squared_error: 3.3773e-04
# Epoch 256/1000
#  - 15s - loss: 3.4097e-04 - mean_squared_error: 3.4097e-04 - val_loss: 3.1615e-04 - val_mean_squared_error: 3.1615e-04
# Epoch 257/1000
#  - 15s - loss: 3.4041e-04 - mean_squared_error: 3.4041e-04 - val_loss: 3.3843e-04 - val_mean_squared_error: 3.3843e-04
# Epoch 258/1000
#  - 15s - loss: 3.4039e-04 - mean_squared_error: 3.4039e-04 - val_loss: 3.4386e-04 - val_mean_squared_error: 3.4386e-04
# Epoch 259/1000
#  - 14s - loss: 3.4015e-04 - mean_squared_error: 3.4015e-04 - val_loss: 3.3819e-04 - val_mean_squared_error: 3.3819e-04
# Epoch 260/1000
#  - 15s - loss: 3.3953e-04 - mean_squared_error: 3.3953e-04 - val_loss: 4.2423e-04 - val_mean_squared_error: 4.2423e-04
# Epoch 261/1000
#  - 15s - loss: 3.4005e-04 - mean_squared_error: 3.4005e-04 - val_loss: 2.2233e-04 - val_mean_squared_error: 2.2233e-04
# Epoch 262/1000
#  - 15s - loss: 3.3843e-04 - mean_squared_error: 3.3843e-04 - val_loss: 4.1429e-04 - val_mean_squared_error: 4.1429e-04
# Epoch 263/1000
#  - 15s - loss: 3.3901e-04 - mean_squared_error: 3.3901e-04 - val_loss: 2.6682e-04 - val_mean_squared_error: 2.6682e-04
# Epoch 264/1000
#  - 15s - loss: 3.3884e-04 - mean_squared_error: 3.3884e-04 - val_loss: 3.8096e-04 - val_mean_squared_error: 3.8096e-04
# Epoch 265/1000
#  - 16s - loss: 3.3800e-04 - mean_squared_error: 3.3800e-04 - val_loss: 5.5562e-04 - val_mean_squared_error: 5.5562e-04
# Epoch 266/1000
#  - 16s - loss: 3.3822e-04 - mean_squared_error: 3.3822e-04 - val_loss: 3.0469e-04 - val_mean_squared_error: 3.0469e-04
# Epoch 267/1000
#  - 15s - loss: 3.3732e-04 - mean_squared_error: 3.3732e-04 - val_loss: 2.6619e-04 - val_mean_squared_error: 2.6619e-04
# Epoch 268/1000
#  - 15s - loss: 3.3762e-04 - mean_squared_error: 3.3762e-04 - val_loss: 2.3463e-04 - val_mean_squared_error: 2.3463e-04
# Epoch 269/1000
#  - 14s - loss: 3.3659e-04 - mean_squared_error: 3.3659e-04 - val_loss: 4.3006e-04 - val_mean_squared_error: 4.3006e-04
# Epoch 270/1000
#  - 14s - loss: 3.3673e-04 - mean_squared_error: 3.3673e-04 - val_loss: 5.8837e-04 - val_mean_squared_error: 5.8837e-04
# Epoch 271/1000
#  - 14s - loss: 3.3639e-04 - mean_squared_error: 3.3639e-04 - val_loss: 2.3744e-04 - val_mean_squared_error: 2.3744e-04
# Epoch 272/1000
#  - 15s - loss: 3.3598e-04 - mean_squared_error: 3.3598e-04 - val_loss: 3.5396e-04 - val_mean_squared_error: 3.5396e-04
# Epoch 273/1000
#  - 15s - loss: 3.3552e-04 - mean_squared_error: 3.3552e-04 - val_loss: 2.8007e-04 - val_mean_squared_error: 2.8007e-04
# Epoch 274/1000
#  - 15s - loss: 3.3513e-04 - mean_squared_error: 3.3513e-04 - val_loss: 3.3752e-04 - val_mean_squared_error: 3.3752e-04
# Epoch 275/1000
#  - 15s - loss: 3.3515e-04 - mean_squared_error: 3.3515e-04 - val_loss: 4.7588e-04 - val_mean_squared_error: 4.7588e-04
# Epoch 276/1000
#  - 15s - loss: 3.3482e-04 - mean_squared_error: 3.3482e-04 - val_loss: 3.1385e-04 - val_mean_squared_error: 3.1385e-04
# Epoch 277/1000
#  - 15s - loss: 3.3500e-04 - mean_squared_error: 3.3500e-04 - val_loss: 4.8087e-04 - val_mean_squared_error: 4.8087e-04
# Epoch 278/1000
#  - 15s - loss: 3.3389e-04 - mean_squared_error: 3.3389e-04 - val_loss: 2.9258e-04 - val_mean_squared_error: 2.9258e-04
# Epoch 279/1000
#  - 16s - loss: 3.3442e-04 - mean_squared_error: 3.3442e-04 - val_loss: 2.4493e-04 - val_mean_squared_error: 2.4493e-04
# Epoch 280/1000
#  - 16s - loss: 3.3293e-04 - mean_squared_error: 3.3293e-04 - val_loss: 4.1088e-04 - val_mean_squared_error: 4.1088e-04
# Epoch 281/1000
#  - 15s - loss: 3.3364e-04 - mean_squared_error: 3.3364e-04 - val_loss: 2.7543e-04 - val_mean_squared_error: 2.7543e-04
# Epoch 282/1000
#  - 15s - loss: 3.3279e-04 - mean_squared_error: 3.3279e-04 - val_loss: 3.5534e-04 - val_mean_squared_error: 3.5534e-04
# Epoch 283/1000
#  - 15s - loss: 3.3258e-04 - mean_squared_error: 3.3258e-04 - val_loss: 4.7740e-04 - val_mean_squared_error: 4.7740e-04
# Epoch 284/1000
#  - 15s - loss: 3.3236e-04 - mean_squared_error: 3.3236e-04 - val_loss: 3.2906e-04 - val_mean_squared_error: 3.2906e-04
# Epoch 285/1000
#  - 15s - loss: 3.3221e-04 - mean_squared_error: 3.3221e-04 - val_loss: 2.5418e-04 - val_mean_squared_error: 2.5418e-04
# Epoch 286/1000
#  - 15s - loss: 3.3139e-04 - mean_squared_error: 3.3139e-04 - val_loss: 3.7576e-04 - val_mean_squared_error: 3.7576e-04
# Epoch 287/1000
#  - 15s - loss: 3.3152e-04 - mean_squared_error: 3.3152e-04 - val_loss: 4.0822e-04 - val_mean_squared_error: 4.0822e-04
# Epoch 288/1000
#  - 14s - loss: 3.3104e-04 - mean_squared_error: 3.3104e-04 - val_loss: 5.8001e-04 - val_mean_squared_error: 5.8001e-04
# Epoch 289/1000
#  - 15s - loss: 3.3130e-04 - mean_squared_error: 3.3130e-04 - val_loss: 3.4232e-04 - val_mean_squared_error: 3.4232e-04
# Epoch 290/1000
#  - 15s - loss: 3.3049e-04 - mean_squared_error: 3.3049e-04 - val_loss: 3.2456e-04 - val_mean_squared_error: 3.2456e-04
# Epoch 291/1000
#  - 15s - loss: 3.3083e-04 - mean_squared_error: 3.3083e-04 - val_loss: 2.5482e-04 - val_mean_squared_error: 2.5482e-04
# Epoch 292/1000
#  - 16s - loss: 3.3031e-04 - mean_squared_error: 3.3031e-04 - val_loss: 2.6490e-04 - val_mean_squared_error: 2.6490e-04
# Epoch 293/1000
#  - 15s - loss: 3.2982e-04 - mean_squared_error: 3.2982e-04 - val_loss: 3.0690e-04 - val_mean_squared_error: 3.0690e-04
# Epoch 294/1000
#  - 15s - loss: 3.2998e-04 - mean_squared_error: 3.2998e-04 - val_loss: 3.4934e-04 - val_mean_squared_error: 3.4934e-04
# Epoch 295/1000
#  - 16s - loss: 3.3021e-04 - mean_squared_error: 3.3021e-04 - val_loss: 2.3646e-04 - val_mean_squared_error: 2.3646e-04
# Epoch 296/1000
#  - 16s - loss: 3.2863e-04 - mean_squared_error: 3.2863e-04 - val_loss: 4.8699e-04 - val_mean_squared_error: 4.8699e-04
# Epoch 297/1000
#  - 16s - loss: 3.2947e-04 - mean_squared_error: 3.2947e-04 - val_loss: 3.4854e-04 - val_mean_squared_error: 3.4854e-04
# Epoch 298/1000
#  - 15s - loss: 3.2890e-04 - mean_squared_error: 3.2890e-04 - val_loss: 3.1393e-04 - val_mean_squared_error: 3.1393e-04
# Epoch 299/1000
#  - 15s - loss: 3.2872e-04 - mean_squared_error: 3.2872e-04 - val_loss: 2.5098e-04 - val_mean_squared_error: 2.5098e-04
# Epoch 300/1000
#  - 15s - loss: 3.2847e-04 - mean_squared_error: 3.2847e-04 - val_loss: 3.6966e-04 - val_mean_squared_error: 3.6966e-04
# Epoch 301/1000
#  - 15s - loss: 3.2787e-04 - mean_squared_error: 3.2787e-04 - val_loss: 4.1767e-04 - val_mean_squared_error: 4.1767e-04
# Epoch 302/1000
#  - 15s - loss: 3.2801e-04 - mean_squared_error: 3.2801e-04 - val_loss: 2.5494e-04 - val_mean_squared_error: 2.5494e-04
# Epoch 303/1000
#  - 15s - loss: 3.2747e-04 - mean_squared_error: 3.2747e-04 - val_loss: 2.7795e-04 - val_mean_squared_error: 2.7795e-04
# Epoch 304/1000
#  - 15s - loss: 3.2696e-04 - mean_squared_error: 3.2696e-04 - val_loss: 2.9707e-04 - val_mean_squared_error: 2.9707e-04
# Epoch 305/1000
#  - 15s - loss: 3.2608e-04 - mean_squared_error: 3.2608e-04 - val_loss: 4.5671e-04 - val_mean_squared_error: 4.5671e-04
# Epoch 306/1000
#  - 15s - loss: 3.2624e-04 - mean_squared_error: 3.2624e-04 - val_loss: 3.8113e-04 - val_mean_squared_error: 3.8113e-04
# Epoch 307/1000
#  - 15s - loss: 3.2652e-04 - mean_squared_error: 3.2652e-04 - val_loss: 3.9913e-04 - val_mean_squared_error: 3.9913e-04
# Epoch 308/1000
#  - 15s - loss: 3.2601e-04 - mean_squared_error: 3.2601e-04 - val_loss: 2.4563e-04 - val_mean_squared_error: 2.4563e-04
# Epoch 309/1000
#  - 15s - loss: 3.2646e-04 - mean_squared_error: 3.2646e-04 - val_loss: 2.4048e-04 - val_mean_squared_error: 2.4048e-04
# Epoch 310/1000
#  - 15s - loss: 3.2565e-04 - mean_squared_error: 3.2565e-04 - val_loss: 3.1146e-04 - val_mean_squared_error: 3.1146e-04
# Epoch 311/1000
#  - 15s - loss: 3.2567e-04 - mean_squared_error: 3.2567e-04 - val_loss: 2.8489e-04 - val_mean_squared_error: 2.8489e-04
# Epoch 312/1000
#  - 15s - loss: 3.2500e-04 - mean_squared_error: 3.2500e-04 - val_loss: 3.7061e-04 - val_mean_squared_error: 3.7061e-04
# Epoch 313/1000
#  - 15s - loss: 3.2515e-04 - mean_squared_error: 3.2515e-04 - val_loss: 4.7019e-04 - val_mean_squared_error: 4.7019e-04
# Epoch 314/1000
#  - 15s - loss: 3.2479e-04 - mean_squared_error: 3.2479e-04 - val_loss: 3.5440e-04 - val_mean_squared_error: 3.5440e-04
# Epoch 315/1000
#  - 15s - loss: 3.2445e-04 - mean_squared_error: 3.2445e-04 - val_loss: 4.2276e-04 - val_mean_squared_error: 4.2276e-04
# Epoch 316/1000
#  - 15s - loss: 3.2427e-04 - mean_squared_error: 3.2427e-04 - val_loss: 2.8404e-04 - val_mean_squared_error: 2.8404e-04
# Epoch 317/1000
#  - 15s - loss: 3.2375e-04 - mean_squared_error: 3.2375e-04 - val_loss: 3.0553e-04 - val_mean_squared_error: 3.0553e-04
# Epoch 318/1000
#  - 15s - loss: 3.2334e-04 - mean_squared_error: 3.2334e-04 - val_loss: 3.0545e-04 - val_mean_squared_error: 3.0545e-04
# Epoch 319/1000
#  - 15s - loss: 3.2436e-04 - mean_squared_error: 3.2436e-04 - val_loss: 4.5777e-04 - val_mean_squared_error: 4.5777e-04
# Epoch 320/1000
#  - 15s - loss: 3.2329e-04 - mean_squared_error: 3.2329e-04 - val_loss: 3.4300e-04 - val_mean_squared_error: 3.4300e-04
# Epoch 321/1000
#  - 15s - loss: 3.2336e-04 - mean_squared_error: 3.2336e-04 - val_loss: 4.1406e-04 - val_mean_squared_error: 4.1406e-04
# Epoch 322/1000
#  - 15s - loss: 3.2285e-04 - mean_squared_error: 3.2285e-04 - val_loss: 3.8252e-04 - val_mean_squared_error: 3.8252e-04
# Epoch 323/1000
#  - 15s - loss: 3.2275e-04 - mean_squared_error: 3.2275e-04 - val_loss: 2.5339e-04 - val_mean_squared_error: 2.5339e-04
# Epoch 324/1000
#  - 15s - loss: 3.2222e-04 - mean_squared_error: 3.2222e-04 - val_loss: 4.0071e-04 - val_mean_squared_error: 4.0071e-04
# Epoch 325/1000
#  - 15s - loss: 3.2233e-04 - mean_squared_error: 3.2233e-04 - val_loss: 4.0702e-04 - val_mean_squared_error: 4.0702e-04
# Epoch 326/1000
#  - 15s - loss: 3.2161e-04 - mean_squared_error: 3.2161e-04 - val_loss: 5.0779e-04 - val_mean_squared_error: 5.0779e-04
# Epoch 327/1000
#  - 15s - loss: 3.2202e-04 - mean_squared_error: 3.2202e-04 - val_loss: 2.6503e-04 - val_mean_squared_error: 2.6503e-04
# Epoch 328/1000
#  - 15s - loss: 3.2181e-04 - mean_squared_error: 3.2181e-04 - val_loss: 7.3161e-04 - val_mean_squared_error: 7.3161e-04
# Epoch 329/1000
#  - 15s - loss: 3.2108e-04 - mean_squared_error: 3.2108e-04 - val_loss: 3.1304e-04 - val_mean_squared_error: 3.1304e-04
# Epoch 330/1000
#  - 15s - loss: 3.2143e-04 - mean_squared_error: 3.2143e-04 - val_loss: 4.2291e-04 - val_mean_squared_error: 4.2291e-04
# Epoch 331/1000
#  - 15s - loss: 3.2091e-04 - mean_squared_error: 3.2091e-04 - val_loss: 3.6211e-04 - val_mean_squared_error: 3.6211e-04
# Epoch 332/1000
#  - 15s - loss: 3.2133e-04 - mean_squared_error: 3.2133e-04 - val_loss: 2.6339e-04 - val_mean_squared_error: 2.6339e-04
# Epoch 333/1000
#  - 15s - loss: 3.2046e-04 - mean_squared_error: 3.2046e-04 - val_loss: 3.4712e-04 - val_mean_squared_error: 3.4712e-04
# Epoch 334/1000
#  - 15s - loss: 3.2023e-04 - mean_squared_error: 3.2023e-04 - val_loss: 3.2329e-04 - val_mean_squared_error: 3.2329e-04
# Epoch 335/1000
#  - 15s - loss: 3.2010e-04 - mean_squared_error: 3.2010e-04 - val_loss: 4.1784e-04 - val_mean_squared_error: 4.1784e-04
# Epoch 336/1000
#  - 15s - loss: 3.2035e-04 - mean_squared_error: 3.2035e-04 - val_loss: 3.8263e-04 - val_mean_squared_error: 3.8263e-04
# Epoch 337/1000
#  - 15s - loss: 3.2065e-04 - mean_squared_error: 3.2065e-04 - val_loss: 2.5176e-04 - val_mean_squared_error: 2.5176e-04
# Epoch 338/1000
#  - 15s - loss: 3.1950e-04 - mean_squared_error: 3.1950e-04 - val_loss: 5.0121e-04 - val_mean_squared_error: 5.0121e-04
# Epoch 339/1000
#  - 15s - loss: 3.1910e-04 - mean_squared_error: 3.1910e-04 - val_loss: 4.1726e-04 - val_mean_squared_error: 4.1726e-04
# Epoch 340/1000
#  - 15s - loss: 3.1906e-04 - mean_squared_error: 3.1906e-04 - val_loss: 2.9123e-04 - val_mean_squared_error: 2.9123e-04
# Epoch 341/1000
#  - 15s - loss: 3.1895e-04 - mean_squared_error: 3.1895e-04 - val_loss: 4.0274e-04 - val_mean_squared_error: 4.0274e-04
# Epoch 342/1000
#  - 15s - loss: 3.1836e-04 - mean_squared_error: 3.1836e-04 - val_loss: 4.6324e-04 - val_mean_squared_error: 4.6324e-04
# Epoch 343/1000
#  - 15s - loss: 3.1866e-04 - mean_squared_error: 3.1866e-04 - val_loss: 2.6057e-04 - val_mean_squared_error: 2.6057e-04
# Epoch 344/1000
#  - 15s - loss: 3.1828e-04 - mean_squared_error: 3.1828e-04 - val_loss: 4.1133e-04 - val_mean_squared_error: 4.1133e-04
# Epoch 345/1000
#  - 15s - loss: 3.1808e-04 - mean_squared_error: 3.1808e-04 - val_loss: 2.7551e-04 - val_mean_squared_error: 2.7551e-04
# Epoch 346/1000
#  - 15s - loss: 3.1782e-04 - mean_squared_error: 3.1782e-04 - val_loss: 3.5847e-04 - val_mean_squared_error: 3.5847e-04
# Epoch 347/1000
#  - 15s - loss: 3.1882e-04 - mean_squared_error: 3.1882e-04 - val_loss: 2.5514e-04 - val_mean_squared_error: 2.5514e-04
# Epoch 348/1000
#  - 15s - loss: 3.1733e-04 - mean_squared_error: 3.1733e-04 - val_loss: 3.4155e-04 - val_mean_squared_error: 3.4155e-04
# Epoch 349/1000
#  - 15s - loss: 3.1768e-04 - mean_squared_error: 3.1768e-04 - val_loss: 3.0968e-04 - val_mean_squared_error: 3.0968e-04
# Epoch 350/1000
#  - 15s - loss: 3.1681e-04 - mean_squared_error: 3.1681e-04 - val_loss: 4.8570e-04 - val_mean_squared_error: 4.8570e-04
# Epoch 351/1000
#  - 15s - loss: 3.1670e-04 - mean_squared_error: 3.1670e-04 - val_loss: 5.7280e-04 - val_mean_squared_error: 5.7280e-04
# Epoch 352/1000
#  - 15s - loss: 3.1697e-04 - mean_squared_error: 3.1697e-04 - val_loss: 3.2715e-04 - val_mean_squared_error: 3.2715e-04
# Epoch 353/1000
#  - 15s - loss: 3.1704e-04 - mean_squared_error: 3.1704e-04 - val_loss: 2.3546e-04 - val_mean_squared_error: 2.3546e-04
# Epoch 354/1000
#  - 15s - loss: 3.1606e-04 - mean_squared_error: 3.1606e-04 - val_loss: 3.6621e-04 - val_mean_squared_error: 3.6621e-04
# Epoch 355/1000
#  - 15s - loss: 3.1673e-04 - mean_squared_error: 3.1673e-04 - val_loss: 2.8395e-04 - val_mean_squared_error: 2.8395e-04
# Epoch 356/1000
#  - 15s - loss: 3.1574e-04 - mean_squared_error: 3.1574e-04 - val_loss: 4.0905e-04 - val_mean_squared_error: 4.0905e-04
# Epoch 357/1000
#  - 15s - loss: 3.1617e-04 - mean_squared_error: 3.1617e-04 - val_loss: 2.9036e-04 - val_mean_squared_error: 2.9036e-04
# Epoch 358/1000
#  - 15s - loss: 3.1570e-04 - mean_squared_error: 3.1570e-04 - val_loss: 2.9005e-04 - val_mean_squared_error: 2.9005e-04
# Epoch 359/1000
# ...
# Epoch 462/1000
#  - 15s - loss: 3.0009e-04 - mean_squared_error: 3.0009e-04 - val_loss: 3.1201e-04 - val_mean_squared_error: 3.1201e-04
# Epoch 463/1000
#  - 15s - loss: 2.9910e-04 - mean_squared_error: 2.9910e-04 - val_loss: 3.4960e-04 - val_mean_squared_error: 3.4960e-04
# Epoch 464/1000
#  - 15s - loss: 2.9913e-04 - mean_squared_error: 2.9913e-04 - val_loss: 3.2813e-04 - val_mean_squared_error: 3.2813e-04
# Epoch 465/1000
#  - 15s - loss: 2.9877e-04 - mean_squared_error: 2.9877e-04 - val_loss: 3.1512e-04 - val_mean_squared_error: 3.1512e-04
# Epoch 466/1000
#  - 15s - loss: 2.9916e-04 - mean_squared_error: 2.9916e-04 - val_loss: 2.8036e-04 - val_mean_squared_error: 2.8036e-04
# Epoch 467/1000
#  - 15s - loss: 2.9886e-04 - mean_squared_error: 2.9886e-04 - val_loss: 2.6192e-04 - val_mean_squared_error: 2.6192e-04
# Epoch 468/1000
#  - 15s - loss: 2.9923e-04 - mean_squared_error: 2.9923e-04 - val_loss: 2.3697e-04 - val_mean_squared_error: 2.3697e-04
# Epoch 469/1000
#  - 15s - loss: 2.9824e-04 - mean_squared_error: 2.9824e-04 - val_loss: 3.0930e-04 - val_mean_squared_error: 3.0930e-04
# Epoch 470/1000
#  - 15s - loss: 2.9818e-04 - mean_squared_error: 2.9818e-04 - val_loss: 3.0362e-04 - val_mean_squared_error: 3.0362e-04
# Epoch 471/1000
#  - 15s - loss: 2.9829e-04 - mean_squared_error: 2.9829e-04 - val_loss: 4.0076e-04 - val_mean_squared_error: 4.0076e-04
# Epoch 472/1000
#  - 15s - loss: 2.9862e-04 - mean_squared_error: 2.9862e-04 - val_loss: 3.5902e-04 - val_mean_squared_error: 3.5902e-04
# Epoch 473/1000
#  - 15s - loss: 2.9794e-04 - mean_squared_error: 2.9794e-04 - val_loss: 4.1917e-04 - val_mean_squared_error: 4.1917e-04
# Epoch 474/1000
#  - 15s - loss: 2.9833e-04 - mean_squared_error: 2.9833e-04 - val_loss: 5.3878e-04 - val_mean_squared_error: 5.3878e-04
# Epoch 475/1000
#  - 15s - loss: 2.9790e-04 - mean_squared_error: 2.9790e-04 - val_loss: 3.6660e-04 - val_mean_squared_error: 3.6660e-04
# Epoch 476/1000
#  - 15s - loss: 2.9773e-04 - mean_squared_error: 2.9773e-04 - val_loss: 2.2552e-04 - val_mean_squared_error: 2.2552e-04
# Epoch 477/1000
#  - 15s - loss: 2.9727e-04 - mean_squared_error: 2.9727e-04 - val_loss: 4.0781e-04 - val_mean_squared_error: 4.0781e-04
# Epoch 478/1000
#  - 15s - loss: 2.9724e-04 - mean_squared_error: 2.9724e-04 - val_loss: 5.4133e-04 - val_mean_squared_error: 5.4133e-04
# Epoch 479/1000
#  - 15s - loss: 2.9785e-04 - mean_squared_error: 2.9785e-04 - val_loss: 2.3462e-04 - val_mean_squared_error: 2.3462e-04
# Epoch 480/1000
#  - 15s - loss: 2.9723e-04 - mean_squared_error: 2.9723e-04 - val_loss: 2.6131e-04 - val_mean_squared_error: 2.6131e-04
# Epoch 481/1000
#  - 15s - loss: 2.9717e-04 - mean_squared_error: 2.9717e-04 - val_loss: 3.2834e-04 - val_mean_squared_error: 3.2834e-04
# Epoch 482/1000
#  - 15s - loss: 2.9683e-04 - mean_squared_error: 2.9683e-04 - val_loss: 7.0612e-04 - val_mean_squared_error: 7.0612e-04
# Epoch 483/1000
#  - 15s - loss: 2.9681e-04 - mean_squared_error: 2.9681e-04 - val_loss: 2.6332e-04 - val_mean_squared_error: 2.6332e-04
# Epoch 484/1000
#  - 15s - loss: 2.9721e-04 - mean_squared_error: 2.9721e-04 - val_loss: 2.3688e-04 - val_mean_squared_error: 2.3688e-04
# Epoch 485/1000
#  - 15s - loss: 2.9696e-04 - mean_squared_error: 2.9696e-04 - val_loss: 2.4796e-04 - val_mean_squared_error: 2.4796e-04
# Epoch 486/1000
#  - 15s - loss: 2.9614e-04 - mean_squared_error: 2.9614e-04 - val_loss: 3.1683e-04 - val_mean_squared_error: 3.1683e-04
# Epoch 487/1000
#  - 15s - loss: 2.9624e-04 - mean_squared_error: 2.9624e-04 - val_loss: 2.5395e-04 - val_mean_squared_error: 2.5395e-04
# Epoch 488/1000
#  - 15s - loss: 2.9622e-04 - mean_squared_error: 2.9622e-04 - val_loss: 2.2335e-04 - val_mean_squared_error: 2.2335e-04
# Epoch 489/1000
#  - 15s - loss: 2.9613e-04 - mean_squared_error: 2.9613e-04 - val_loss: 3.1432e-04 - val_mean_squared_error: 3.1432e-04
# Epoch 490/1000
#  - 15s - loss: 2.9589e-04 - mean_squared_error: 2.9589e-04 - val_loss: 2.4924e-04 - val_mean_squared_error: 2.4924e-04
# Epoch 491/1000
#  - 15s - loss: 2.9581e-04 - mean_squared_error: 2.9581e-04 - val_loss: 2.5642e-04 - val_mean_squared_error: 2.5642e-04
# Epoch 492/1000
#  - 15s - loss: 2.9570e-04 - mean_squared_error: 2.9570e-04 - val_loss: 2.7267e-04 - val_mean_squared_error: 2.7267e-04
# Epoch 493/1000
#  - 15s - loss: 2.9585e-04 - mean_squared_error: 2.9585e-04 - val_loss: 5.9571e-04 - val_mean_squared_error: 5.9571e-04
# Epoch 494/1000
#  - 15s - loss: 2.9540e-04 - mean_squared_error: 2.9540e-04 - val_loss: 3.1994e-04 - val_mean_squared_error: 3.1994e-04
# Epoch 495/1000
#  - 15s - loss: 2.9566e-04 - mean_squared_error: 2.9566e-04 - val_loss: 2.1420e-04 - val_mean_squared_error: 2.1420e-04
# Epoch 496/1000
#  - 15s - loss: 2.9468e-04 - mean_squared_error: 2.9468e-04 - val_loss: 3.1282e-04 - val_mean_squared_error: 3.1282e-04
# Epoch 497/1000
#  - 15s - loss: 2.9577e-04 - mean_squared_error: 2.9577e-04 - val_loss: 3.0738e-04 - val_mean_squared_error: 3.0738e-04
# Epoch 498/1000
#  - 15s - loss: 2.9511e-04 - mean_squared_error: 2.9511e-04 - val_loss: 4.1910e-04 - val_mean_squared_error: 4.1910e-04
# Epoch 499/1000
#  - 15s - loss: 2.9471e-04 - mean_squared_error: 2.9471e-04 - val_loss: 3.9286e-04 - val_mean_squared_error: 3.9286e-04
# Epoch 500/1000
#  - 15s - loss: 2.9527e-04 - mean_squared_error: 2.9527e-04 - val_loss: 2.7059e-04 - val_mean_squared_error: 2.7059e-04
# Epoch 501/1000
#  - 15s - loss: 2.9445e-04 - mean_squared_error: 2.9445e-04 - val_loss: 4.1261e-04 - val_mean_squared_error: 4.1261e-04
# Epoch 502/1000
#  - 15s - loss: 2.9413e-04 - mean_squared_error: 2.9413e-04 - val_loss: 3.0217e-04 - val_mean_squared_error: 3.0217e-04
# Epoch 503/1000
#  - 15s - loss: 2.9524e-04 - mean_squared_error: 2.9524e-04 - val_loss: 2.7633e-04 - val_mean_squared_error: 2.7633e-04
# Epoch 504/1000
#  - 15s - loss: 2.9412e-04 - mean_squared_error: 2.9412e-04 - val_loss: 3.3718e-04 - val_mean_squared_error: 3.3718e-04
# Epoch 505/1000
#  - 15s - loss: 2.9436e-04 - mean_squared_error: 2.9436e-04 - val_loss: 2.0951e-04 - val_mean_squared_error: 2.0951e-04
# Epoch 506/1000
#  - 15s - loss: 2.9407e-04 - mean_squared_error: 2.9407e-04 - val_loss: 2.4391e-04 - val_mean_squared_error: 2.4391e-04
# Epoch 507/1000
#  - 15s - loss: 2.9416e-04 - mean_squared_error: 2.9416e-04 - val_loss: 2.8450e-04 - val_mean_squared_error: 2.8450e-04
# Epoch 508/1000
#  - 15s - loss: 2.9345e-04 - mean_squared_error: 2.9345e-04 - val_loss: 2.4773e-04 - val_mean_squared_error: 2.4773e-04
# Epoch 509/1000
#  - 15s - loss: 2.9398e-04 - mean_squared_error: 2.9398e-04 - val_loss: 4.3957e-04 - val_mean_squared_error: 4.3957e-04
# Epoch 510/1000
#  - 15s - loss: 2.9325e-04 - mean_squared_error: 2.9325e-04 - val_loss: 2.3668e-04 - val_mean_squared_error: 2.3668e-04
# Epoch 511/1000
#  - 15s - loss: 2.9370e-04 - mean_squared_error: 2.9370e-04 - val_loss: 2.3743e-04 - val_mean_squared_error: 2.3743e-04
# Epoch 512/1000
#  - 15s - loss: 2.9387e-04 - mean_squared_error: 2.9387e-04 - val_loss: 2.2855e-04 - val_mean_squared_error: 2.2855e-04
# Epoch 513/1000
#  - 15s - loss: 2.9323e-04 - mean_squared_error: 2.9323e-04 - val_loss: 3.7446e-04 - val_mean_squared_error: 3.7446e-04
# Epoch 514/1000
#  - 15s - loss: 2.9352e-04 - mean_squared_error: 2.9352e-04 - val_loss: 2.1848e-04 - val_mean_squared_error: 2.1848e-04
# Epoch 515/1000
#  - 15s - loss: 2.9324e-04 - mean_squared_error: 2.9324e-04 - val_loss: 3.4333e-04 - val_mean_squared_error: 3.4333e-04
# Epoch 516/1000
#  - 15s - loss: 2.9266e-04 - mean_squared_error: 2.9266e-04 - val_loss: 3.4593e-04 - val_mean_squared_error: 3.4593e-04
# Epoch 517/1000
#  - 15s - loss: 2.9321e-04 - mean_squared_error: 2.9321e-04 - val_loss: 2.0585e-04 - val_mean_squared_error: 2.0585e-04
# Epoch 518/1000
#  - 15s - loss: 2.9338e-04 - mean_squared_error: 2.9338e-04 - val_loss: 2.8478e-04 - val_mean_squared_error: 2.8478e-04
# Epoch 519/1000
#  - 15s - loss: 2.9266e-04 - mean_squared_error: 2.9266e-04 - val_loss: 2.1224e-04 - val_mean_squared_error: 2.1224e-04
# Epoch 520/1000
#  - 15s - loss: 2.9223e-04 - mean_squared_error: 2.9223e-04 - val_loss: 2.4459e-04 - val_mean_squared_error: 2.4459e-04
# Epoch 521/1000
#  - 15s - loss: 2.9231e-04 - mean_squared_error: 2.9231e-04 - val_loss: 3.6065e-04 - val_mean_squared_error: 3.6065e-04
# Epoch 522/1000
#  - 15s - loss: 2.9243e-04 - mean_squared_error: 2.9243e-04 - val_loss: 2.5782e-04 - val_mean_squared_error: 2.5782e-04
# Epoch 523/1000
#  - 15s - loss: 2.9215e-04 - mean_squared_error: 2.9215e-04 - val_loss: 2.6540e-04 - val_mean_squared_error: 2.6540e-04
# Epoch 524/1000
#  - 15s - loss: 2.9241e-04 - mean_squared_error: 2.9241e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 525/1000
#  - 15s - loss: 2.9265e-04 - mean_squared_error: 2.9265e-04 - val_loss: 2.2887e-04 - val_mean_squared_error: 2.2887e-04
# Epoch 526/1000
#  - 15s - loss: 2.9210e-04 - mean_squared_error: 2.9210e-04 - val_loss: 2.9295e-04 - val_mean_squared_error: 2.9295e-04
# Epoch 527/1000
#  - 15s - loss: 2.9194e-04 - mean_squared_error: 2.9194e-04 - val_loss: 2.0975e-04 - val_mean_squared_error: 2.0975e-04
# Epoch 528/1000
#  - 15s - loss: 2.9129e-04 - mean_squared_error: 2.9129e-04 - val_loss: 4.9188e-04 - val_mean_squared_error: 4.9188e-04
# Epoch 529/1000
#  - 15s - loss: 2.9207e-04 - mean_squared_error: 2.9207e-04 - val_loss: 3.2190e-04 - val_mean_squared_error: 3.2190e-04
# Epoch 530/1000
#  - 15s - loss: 2.9140e-04 - mean_squared_error: 2.9140e-04 - val_loss: 2.0867e-04 - val_mean_squared_error: 2.0867e-04
# Epoch 531/1000
#  - 15s - loss: 2.9078e-04 - mean_squared_error: 2.9078e-04 - val_loss: 4.6258e-04 - val_mean_squared_error: 4.6258e-04
# Epoch 532/1000
#  - 15s - loss: 2.9127e-04 - mean_squared_error: 2.9127e-04 - val_loss: 6.8111e-04 - val_mean_squared_error: 6.8111e-04
# Epoch 533/1000
#  - 15s - loss: 2.9124e-04 - mean_squared_error: 2.9124e-04 - val_loss: 3.8241e-04 - val_mean_squared_error: 3.8241e-04
# Epoch 534/1000
#  - 15s - loss: 2.9101e-04 - mean_squared_error: 2.9101e-04 - val_loss: 2.1237e-04 - val_mean_squared_error: 2.1237e-04
# Epoch 535/1000
#  - 15s - loss: 2.9097e-04 - mean_squared_error: 2.9097e-04 - val_loss: 4.0717e-04 - val_mean_squared_error: 4.0717e-04
# Epoch 536/1000
#  - 15s - loss: 2.9105e-04 - mean_squared_error: 2.9105e-04 - val_loss: 2.7617e-04 - val_mean_squared_error: 2.7617e-04
# Epoch 537/1000
#  - 15s - loss: 2.9046e-04 - mean_squared_error: 2.9046e-04 - val_loss: 3.1750e-04 - val_mean_squared_error: 3.1750e-04
# Epoch 538/1000
#  - 15s - loss: 2.9130e-04 - mean_squared_error: 2.9130e-04 - val_loss: 2.7803e-04 - val_mean_squared_error: 2.7803e-04
# Epoch 539/1000
#  - 15s - loss: 2.9022e-04 - mean_squared_error: 2.9022e-04 - val_loss: 2.7555e-04 - val_mean_squared_error: 2.7555e-04
# Epoch 540/1000
#  - 15s - loss: 2.9061e-04 - mean_squared_error: 2.9061e-04 - val_loss: 2.1678e-04 - val_mean_squared_error: 2.1678e-04
# Epoch 541/1000
#  - 15s - loss: 2.9022e-04 - mean_squared_error: 2.9022e-04 - val_loss: 2.4727e-04 - val_mean_squared_error: 2.4727e-04
# Epoch 542/1000
#  - 15s - loss: 2.9007e-04 - mean_squared_error: 2.9007e-04 - val_loss: 2.9165e-04 - val_mean_squared_error: 2.9165e-04
# Epoch 543/1000
#  - 15s - loss: 2.9007e-04 - mean_squared_error: 2.9007e-04 - val_loss: 2.9245e-04 - val_mean_squared_error: 2.9245e-04
# Epoch 544/1000
#  - 15s - loss: 2.8985e-04 - mean_squared_error: 2.8985e-04 - val_loss: 3.1957e-04 - val_mean_squared_error: 3.1957e-04
# Epoch 545/1000
#  - 15s - loss: 2.8968e-04 - mean_squared_error: 2.8968e-04 - val_loss: 3.3792e-04 - val_mean_squared_error: 3.3792e-04
# Epoch 546/1000
#  - 15s - loss: 2.9031e-04 - mean_squared_error: 2.9031e-04 - val_loss: 2.5457e-04 - val_mean_squared_error: 2.5457e-04
# Epoch 547/1000
#  - 15s - loss: 2.8944e-04 - mean_squared_error: 2.8944e-04 - val_loss: 2.4324e-04 - val_mean_squared_error: 2.4324e-04
# Epoch 548/1000
#  - 15s - loss: 2.8970e-04 - mean_squared_error: 2.8970e-04 - val_loss: 4.0045e-04 - val_mean_squared_error: 4.0045e-04
# Epoch 549/1000
#  - 15s - loss: 2.9000e-04 - mean_squared_error: 2.9000e-04 - val_loss: 2.2218e-04 - val_mean_squared_error: 2.2218e-04
# Epoch 550/1000
#  - 15s - loss: 2.8911e-04 - mean_squared_error: 2.8911e-04 - val_loss: 2.6095e-04 - val_mean_squared_error: 2.6095e-04
# Epoch 551/1000
#  - 15s - loss: 2.8945e-04 - mean_squared_error: 2.8945e-04 - val_loss: 4.6290e-04 - val_mean_squared_error: 4.6290e-04
# Epoch 552/1000
#  - 15s - loss: 2.8891e-04 - mean_squared_error: 2.8891e-04 - val_loss: 3.3407e-04 - val_mean_squared_error: 3.3407e-04
# Epoch 553/1000
#  - 15s - loss: 2.8899e-04 - mean_squared_error: 2.8899e-04 - val_loss: 3.1282e-04 - val_mean_squared_error: 3.1282e-04
# Epoch 554/1000
#  - 15s - loss: 2.8935e-04 - mean_squared_error: 2.8935e-04 - val_loss: 2.9343e-04 - val_mean_squared_error: 2.9343e-04
# Epoch 555/1000
#  - 15s - loss: 2.8890e-04 - mean_squared_error: 2.8890e-04 - val_loss: 2.0876e-04 - val_mean_squared_error: 2.0876e-04
# Epoch 556/1000
#  - 15s - loss: 2.8962e-04 - mean_squared_error: 2.8962e-04 - val_loss: 2.2180e-04 - val_mean_squared_error: 2.2180e-04
# Epoch 557/1000
#  - 15s - loss: 2.8815e-04 - mean_squared_error: 2.8815e-04 - val_loss: 2.8674e-04 - val_mean_squared_error: 2.8674e-04
# Epoch 558/1000
#  - 15s - loss: 2.8881e-04 - mean_squared_error: 2.8881e-04 - val_loss: 2.4598e-04 - val_mean_squared_error: 2.4598e-04
# Epoch 559/1000
#  - 15s - loss: 2.8826e-04 - mean_squared_error: 2.8826e-04 - val_loss: 3.8258e-04 - val_mean_squared_error: 3.8258e-04
# Epoch 560/1000
#  - 15s - loss: 2.8860e-04 - mean_squared_error: 2.8860e-04 - val_loss: 3.4141e-04 - val_mean_squared_error: 3.4141e-04
# Epoch 561/1000
#  - 15s - loss: 2.8830e-04 - mean_squared_error: 2.8830e-04 - val_loss: 2.5830e-04 - val_mean_squared_error: 2.5830e-04
# Epoch 562/1000
#  - 15s - loss: 2.8861e-04 - mean_squared_error: 2.8861e-04 - val_loss: 3.4358e-04 - val_mean_squared_error: 3.4358e-04
# Epoch 563/1000
#  - 15s - loss: 2.8785e-04 - mean_squared_error: 2.8785e-04 - val_loss: 2.6848e-04 - val_mean_squared_error: 2.6848e-04
# Epoch 564/1000
#  - 15s - loss: 2.8825e-04 - mean_squared_error: 2.8825e-04 - val_loss: 2.3969e-04 - val_mean_squared_error: 2.3969e-04
# Epoch 565/1000
#  - 15s - loss: 2.8819e-04 - mean_squared_error: 2.8819e-04 - val_loss: 2.5859e-04 - val_mean_squared_error: 2.5859e-04
# Epoch 566/1000
#  - 15s - loss: 2.8840e-04 - mean_squared_error: 2.8840e-04 - val_loss: 2.3597e-04 - val_mean_squared_error: 2.3597e-04
# Epoch 567/1000
#  - 15s - loss: 2.8762e-04 - mean_squared_error: 2.8762e-04 - val_loss: 2.7257e-04 - val_mean_squared_error: 2.7257e-04
# Epoch 568/1000
#  - 15s - loss: 2.8774e-04 - mean_squared_error: 2.8774e-04 - val_loss: 3.7069e-04 - val_mean_squared_error: 3.7069e-04
# Epoch 569/1000
#  - 15s - loss: 2.8697e-04 - mean_squared_error: 2.8697e-04 - val_loss: 3.4071e-04 - val_mean_squared_error: 3.4071e-04
# Epoch 570/1000
#  - 15s - loss: 2.8771e-04 - mean_squared_error: 2.8771e-04 - val_loss: 2.0936e-04 - val_mean_squared_error: 2.0936e-04
# Epoch 571/1000
#  - 15s - loss: 2.8724e-04 - mean_squared_error: 2.8724e-04 - val_loss: 2.7021e-04 - val_mean_squared_error: 2.7021e-04
# Epoch 572/1000
#  - 15s - loss: 2.8731e-04 - mean_squared_error: 2.8731e-04 - val_loss: 2.0729e-04 - val_mean_squared_error: 2.0729e-04
# Epoch 573/1000
#  - 15s - loss: 2.8763e-04 - mean_squared_error: 2.8763e-04 - val_loss: 2.4432e-04 - val_mean_squared_error: 2.4432e-04
# Epoch 574/1000
#  - 15s - loss: 2.8666e-04 - mean_squared_error: 2.8666e-04 - val_loss: 3.0746e-04 - val_mean_squared_error: 3.0746e-04
# Epoch 575/1000
#  - 15s - loss: 2.8720e-04 - mean_squared_error: 2.8720e-04 - val_loss: 2.2458e-04 - val_mean_squared_error: 2.2458e-04
# Epoch 576/1000
#  - 15s - loss: 2.8658e-04 - mean_squared_error: 2.8658e-04 - val_loss: 3.2988e-04 - val_mean_squared_error: 3.2988e-04
# Epoch 577/1000
#  - 15s - loss: 2.8705e-04 - mean_squared_error: 2.8705e-04 - val_loss: 3.7895e-04 - val_mean_squared_error: 3.7895e-04
# Epoch 578/1000
#  - 15s - loss: 2.8688e-04 - mean_squared_error: 2.8688e-04 - val_loss: 2.8443e-04 - val_mean_squared_error: 2.8443e-04
# Epoch 579/1000
#  - 15s - loss: 2.8621e-04 - mean_squared_error: 2.8621e-04 - val_loss: 3.2621e-04 - val_mean_squared_error: 3.2621e-04
# Epoch 580/1000
#  - 15s - loss: 2.8664e-04 - mean_squared_error: 2.8664e-04 - val_loss: 2.6155e-04 - val_mean_squared_error: 2.6155e-04
# Epoch 00580: early stopping

# %%
# save history
historyDict["mean_squared_error"].append(history.history["mean_squared_error"][0])
historyDict["val_mean_squared_error"].append(history.history["val_mean_squared_error"][0])

# %%
plt.rcParams.update({'font.size': 18})
plot_model_history(history, saveFig=True)

# %%
# save model
model.save(os.path.join(savedModels,  modelName + '.h5'))

# save weights
wts = model.get_weights().copy()

wtsFile = modelName + '_wts.pkl'
pickle.dump(wts, open(os.path.join(dataOutput, wtsFile), 'wb'))

# save history with same name as model
historyFile = modeltimestamp + '_history.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %%
#  plot error rates on test data

# %%
# predict on test set
Ytest_pred = model.predict(Xtest_scaled)


# make data frames
XtestDF = pd.DataFrame(scalerX.inverse_transform(Xtest_scaled), columns = Xtrain.columns)
YtestDF = pd.DataFrame(Ytest, columns = Ytrain.columns)
YpredDF = pd.DataFrame(scalerY.inverse_transform(Ytest_pred), columns = Ytrain.columns+ "_pred")

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

df_c = pd.concat([YtestDF.reset_index(drop=True), YpredDF], axis=1)
df_c.head()
# Out:
#              Fx            Fy           tau     x_dot_99     y_dot_99  phi_dot_99  theta_dot_99       Fx_pred       Fy_pred      tau_pred  x_dot_99_pred  y_dot_99_pred  phi_dot_99_pred  theta_dot_99_pred
# 0  -5342.432439  14670.842555 -57718.558932  -565.880395 -1308.010371  -76.533684    -84.249086  -6638.659180  14627.717773 -61156.875000    -625.593628   -1263.826904       -75.520416         -82.324577
# 1  -2515.747661   3418.036434 -64775.342625   -20.181017  1293.830310   17.440656      0.822442  -2219.208252   3614.187500 -67643.187500     -36.106522    1250.043213         5.764132          -9.900749
# 2  -6497.950980 -17669.503572 -49237.798014 -1069.335389 -1470.500728  122.742841    113.277258  -8760.392578 -19178.591797 -55382.957031   -1114.325439   -1457.987305       114.504204         103.860733
# 3  24237.433019  -8489.629561  56490.932254  -161.286371  -411.543627   94.390515     94.940620  24848.773438  -8907.293945  58916.347656    -216.947678    -479.516022        99.189331          97.128281
# 4   1782.839206   5791.542006  26503.920442   624.066953    25.616955  -25.183807    -19.802055   2510.315918   3786.080566  31668.394531     672.201965     105.370659       -12.314472          -9.640506

# %%
df_c = df_c.iloc[:1000, :]

# df_c = df_c.replace([np.inf, -np.inf], np.nan)
# df_c = df_c.replace([np.inf, -np.inf], np.nan).dropna()

# %%
"${}$".format(" ")
# Out:
# '$ $'

# %%
import matplotlib.ticker as mtick
class MathTextSciFormatter(mtick.Formatter):
    def __init__(self, fmt="%1.2e"):
        self.fmt = fmt
    def __call__(self, x, pos=None):
        s = self.fmt % x
        decimal_point = '.'
        positive_sign = '+'
        tup = s.split('e')
        significand = tup[0].rstrip(decimal_point)
        sign = tup[1][0].replace(positive_sign, '')
        exponent = tup[1][1:].lstrip('0')
        if exponent:
            exponent = '10^{%s%s}' % (sign, exponent)
        if significand and exponent:
            s =  r'%s{\times}%s' % (significand, exponent)
        else:
            return(" ")
        return "${}$".format(s)

# %%
# make plots
from sklearn.metrics import r2_score
from matplotlib import ticker
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['mathtext.default'] = 'regular'
import matplotlib.ticker as mtick
plt.rcParams.update({'font.size': 18})


fig_col_names = [r'$F_x$', r'$F_y$', r'$\tau$', r'$\dot{x}_f$', r'$\dot{y}_f$', r'$\dot{\phi}_f$', r'$\dot{\theta}_f$']

plt.close("all")
fig, axs = plt.subplots(2,Ytest.shape[1], figsize=np.array([25, 5.5]), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.4, wspace=.9)
# fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel("C")

ylabs = [r'$g·cm/s^2$', "$g·cm/s^2$", "$g·cm^2/s^2$", "$cm/s$", "$cm/s$", "$rad/s$", "$rad/s$"]

# replace lightest colors with white
import matplotlib.colors

cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
#cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

# Plot y = actual, x = predicted
for ii in np.arange(0, df_c.shape[1] //2):
    axs[ii].hexbin(y = df_c.loc[:,YtestDF.columns[ii]],
                   x = df_c.loc[:,YpredDF.columns[ii]], 
                   gridsize = 50, cmap = cmap)
    axs[ii].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[ii].yaxis.set_major_locator(ticker.MaxNLocator(3))

    if(ii == 0):
        axs[ii].set_ylabel("Actual Value\n" + ylabs[ii])
    else:
        axs[ii].set_ylabel(ylabs[ii])

    #axs[ii].set_title(YtestDF.columns[ii])
    axs[ii].set_title(fig_col_names[ii], fontdict = {'verticalalignment': 'bottom'})
    axs[ii].plot(df_c.loc[:,YtestDF.columns[ii]], 
                 df_c.loc[:,YtestDF.columns[ii]], 
                 'grey', linewidth = 1, linestyle  = "--")
    axs[ii].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[ii].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[ii].set_aspect('equal', 'box')

    # annotate with R^2
    axs[ii].text(np.max(df_c.loc[:,YtestDF.columns[ii]])*-0.4, 
                 np.min(df_c.loc[:,YtestDF.columns[ii]])*0.9, 
                 r'$r^2$ =' + 
                 str(np.round((r2_score(df_c.loc[:,YtestDF.columns[ii]],  
                                        df_c.loc[:,YpredDF.columns[ii]])), 3)))
    axs[ii].set_xlim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]])), 
                      np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]]))])
    axs[ii].set_ylim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]])), 
                  np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]]))])

# # residual plots x = predicted, y = actual - predicted
# jj is column in dataset, plotNum is plot position
for jj, plotNum in enumerate(np.arange(Ytest.shape[1], df_c.shape[1])):

    axs[plotNum].hexbin(y = df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]],
                   x = df_c.loc[:,YpredDF.columns[jj]], 
                   gridsize = 50, cmap = cmap) 
    axs[plotNum].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[plotNum].yaxis.set_major_locator(ticker.MaxNLocator(3))  
    
    if jj == 3:
        axs[plotNum].set_xlabel(ylabs[jj] + "\n\n" + "Predicted Value")
    else:
        axs[plotNum].set_xlabel(ylabs[jj] + "\n")
    axs[plotNum].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[plotNum].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))

    if(jj == 0):
        axs[plotNum].set_ylabel("Actual - Predicted\n" + ylabs[jj])
    else:
        axs[plotNum].set_ylabel(ylabs[jj])

    axs[plotNum].hlines(y = 0, xmin = np.min( df_c.loc[:,YpredDF.columns[jj]]), 
                   xmax = np.max( df_c.loc[:,YpredDF.columns[jj]]), 
                   linestyle =  "--", linewidth = 1)
    axs[plotNum].set_ylim([-np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]])), 
                      np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]]- df_c.loc[:,YpredDF.columns[jj]]))])


fig.savefig(os.path.join(figDir, "PredVActual" + modelName + ".pdf"), dpi = 500, bbox_inches='tight')
plt.show()
# plt.close()

# %%
list(enumerate(np.arange(3, 6)))
# Out:
# [(0, 3), (1, 4), (2, 5)]

# %%
list(zip(np.arange(9, 13), np.arange(3, 7)))
# Out:
# [(9, 3), (10, 4), (11, 5), (12, 6)]

# %%
# make plots
from sklearn.metrics import r2_score
from matplotlib import ticker
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['mathtext.default'] = 'regular'
import matplotlib.ticker as mtick
plt.rcParams.update({'font.size': 11})


fig_col_names = [r'$F_x$', r'$F_y$', r'$\tau$', r'$\dot{x}_f$', r'$\dot{y}_f$', r'$\dot{\phi}_f$', r'$\dot{\theta}_f$']

plt.close("all")
fig, axs = plt.subplots(4,4, figsize=np.array([8, 8]), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.5, wspace=.9)
# fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel("C")

ylabs = [r'$g·cm/s^2$', "$g·cm/s^2$", "$g·cm^2/s^2$", "$cm/s$", "$cm/s$", "$rad/s$", "$rad/s$"]

# replace lightest colors with white
import matplotlib.colors

cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

# Plot y = actual, x = predicted
for ii in np.arange(0, 3):
    axs[ii].hexbin(y = df_c.loc[:,YtestDF.columns[ii]],
                   x = df_c.loc[:,YpredDF.columns[ii]], 
                   gridsize = 50, cmap = cmap)
    axs[ii].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[ii].yaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[ii].set_yticklabels(axs[ii].get_yticklabels(), rotation = 45, ha="center",va = "bottom", rotation_mode="anchor")
    axs[ii].yaxis.set_label_coords(-0.5,0.5)
    axs[ii].set_xlabel(ylabs[ii] + "\n")
    axs[ii].xaxis.set_label_coords(0.5,-0.3)

    if(ii == 0):
        axs[ii].set_ylabel("Actual Value\n" + ylabs[ii])
    else:
        axs[ii].set_ylabel(ylabs[ii])

    #axs[ii].set_title(YtestDF.columns[ii])
    axs[ii].set_title(fig_col_names[ii], fontdict = {'verticalalignment': 'bottom'})
    axs[ii].plot(df_c.loc[:,YtestDF.columns[ii]], 
                 df_c.loc[:,YtestDF.columns[ii]], 
                 'grey', linewidth = 1, linestyle  = "--")
    axs[ii].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[ii].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[ii].set_aspect('equal', 'box')

    # annotate with R^2
    axs[ii].text(np.max(df_c.loc[:,YtestDF.columns[ii]])*-0.4, 
                 np.min(df_c.loc[:,YtestDF.columns[ii]])*0.9, 
                 r'$r^2$ =' + 
                 str(np.round((r2_score(df_c.loc[:,YtestDF.columns[ii]],  
                                        df_c.loc[:,YpredDF.columns[ii]])), 3)))
    axs[ii].set_xlim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]])), 
                      np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]]))])
    axs[ii].set_ylim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]])), 
                  np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]]))])

# # residual plots x = predicted, y = actual - predicted
# jj is column in dataset, plotNum is plot position
for jj, plotNum in enumerate(np.arange(4, 7)):

    axs[plotNum].hexbin(y = df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]],
                   x = df_c.loc[:,YpredDF.columns[jj]], 
                   gridsize = 50, cmap = cmap) 
    axs[plotNum].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[plotNum].yaxis.set_major_locator(ticker.MaxNLocator(3))  
    axs[plotNum].set_yticklabels(axs[ii].get_yticklabels(), rotation = 45, ha="center", va = "bottom", rotation_mode="anchor")
    axs[plotNum].yaxis.set_label_coords(-0.4,0.5)
    axs[plotNum].xaxis.set_label_coords(0.5,-0.25)
    
    if jj == 3:
        axs[plotNum].set_xlabel(ylabs[jj] + "\n\n" + "Predicted Value")
    else:
        axs[plotNum].set_xlabel(ylabs[jj] + "\n")
    axs[plotNum].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[plotNum].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))

    if(jj == 0):
        axs[plotNum].set_ylabel("Actual - Predicted\n" + ylabs[jj])
    else:
        axs[plotNum].set_ylabel(ylabs[jj])

    axs[plotNum].hlines(y = 0, xmin = np.min( df_c.loc[:,YpredDF.columns[jj]]), 
                   xmax = np.max( df_c.loc[:,YpredDF.columns[jj]]), 
                   linestyle =  "--", linewidth = 1)
    axs[plotNum].set_ylim([-np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]])), 
                      np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]]- df_c.loc[:,YpredDF.columns[jj]]))])
#####
#### Part 2
#####

# Plot y = actual, x = predicted
for plotnum, dataColNum in zip(np.arange(8,12), np.arange(3, 7)):
    axs[plotnum].hexbin(y = df_c.loc[:,YtestDF.columns[dataColNum]],
                   x = df_c.loc[:,YpredDF.columns[dataColNum]], 
                   gridsize = 50, cmap = cmap)
    axs[plotnum].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[plotnum].yaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[plotnum].set_yticklabels(axs[dataColNum].get_yticklabels(), rotation = 45, ha="center",va = "bottom", rotation_mode="anchor")
    axs[plotnum].yaxis.set_label_coords(-0.5,0.5)
    axs[plotnum].set_xlabel(ylabs[dataColNum] + "\n")
    axs[plotnum].xaxis.set_label_coords(0.5,-0.3)

    if(plotnum == 8):
        axs[plotnum].set_ylabel("Actual Value\n" + ylabs[dataColNum])
    else:
        axs[plotnum].set_ylabel(ylabs[dataColNum])

    #axs[ii].set_title(YtestDF.columns[ii])
    axs[plotnum].set_title(fig_col_names[dataColNum], fontdict = {'verticalalignment': 'bottom'})
    axs[plotnum].plot(df_c.loc[:,YtestDF.columns[dataColNum]], 
                 df_c.loc[:,YtestDF.columns[dataColNum]], 
                 'grey', linewidth = 1, linestyle  = "--")
    axs[plotnum].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[plotnum].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[plotnum].set_aspect('equal', 'box')

    # annotate with R^2
    axs[plotnum].text(np.max(df_c.loc[:,YtestDF.columns[dataColNum]])*-0.4, 
                 np.min(df_c.loc[:,YtestDF.columns[dataColNum]])*0.9, 
                 r'$r^2$ =' + 
                 str(np.round((r2_score(df_c.loc[:,YtestDF.columns[dataColNum]],  
                                        df_c.loc[:,YpredDF.columns[dataColNum]])), 3)))
    axs[plotnum].set_xlim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[dataColNum]])), 
                      np.max(np.abs(df_c.loc[:,YpredDF.columns[dataColNum]]))])
    axs[plotnum].set_ylim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[dataColNum]])), 
                  np.max(np.abs(df_c.loc[:,YpredDF.columns[dataColNum]]))])

# residual plots x = predicted, y = actual - predicted
# jj is column in dataset, plotNum is plot position
# refref Here
for jj, plotNum in zip(np.arange(3, 7), np.arange(12, 16)):

    axs[plotNum].hexbin(y = df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]],
                   x = df_c.loc[:,YpredDF.columns[jj]], 
                   gridsize = 50, cmap = cmap) 
    axs[plotNum].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[plotNum].yaxis.set_major_locator(ticker.MaxNLocator(3))  
    axs[plotNum].set_yticklabels(axs[ii].get_yticklabels(), rotation = 45, ha="center", va = "bottom", rotation_mode="anchor")
    axs[plotNum].yaxis.set_label_coords(-0.4,0.5)
    axs[plotNum].xaxis.set_label_coords(0.5,-0.25)
    
    if jj == 4:
        axs[plotNum].set_xlabel(ylabs[jj] + "\n\n" + "Predicted Value")
    else:
        axs[plotNum].set_xlabel(ylabs[jj] + "\n")
    axs[plotNum].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[plotNum].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))

    if(jj == 3):
        axs[plotNum].set_ylabel("Actual - Predicted\n" + ylabs[jj])
    else:
        axs[plotNum].set_ylabel(ylabs[jj])

    axs[plotNum].hlines(y = 0, xmin = np.min( df_c.loc[:,YpredDF.columns[jj]]), 
                   xmax = np.max( df_c.loc[:,YpredDF.columns[jj]]), 
                   linestyle =  "--", linewidth = 1)
    axs[plotNum].set_ylim([-np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]])), 
                      np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]]- df_c.loc[:,YpredDF.columns[jj]]))])


#fig.savefig(os.path.join(figDir, "PredVActual" + modelName + ".pdf"), dpi = 500, bbox_inches='tight')
plt.show()
# plt.close()

# %%
np.arange(4, 7)
# Out:
# array([4, 5, 6])

# %%
# make plots --- Vertical
from sklearn.metrics import r2_score
from matplotlib import ticker
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['mathtext.default'] = 'regular'
import matplotlib.ticker as mtick
plt.rcParams.update({'font.size': 8})


fig_col_names = [r'$F_x$', r'$F_y$', r'$\tau$', r'$\dot{x}_f$', r'$\dot{y}_f$', r'$\dot{\phi}_f$', r'$\dot{\theta}_f$']

plt.close("all")
fig, axs = plt.subplots(Ytest.shape[1], 2,figsize=np.array([ 3, 22]), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 1.4, wspace=1.5)
# fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel("C")

ylabs = [r'$g·cm/s^2$', "$g·cm/s^2$", "$g·cm^2/s^2$", "$cm/s$", "$cm/s$", "$rad/s$", "$rad/s$"]

# replace lightest colors with white
import matplotlib.colors

cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

# Plot y = actual, x = predicted
for ii, colnum in enumerate(np.arange(0, df_c.shape[1], 2)):
    axs[colnum].hexbin(y = df_c.loc[:,YtestDF.columns[ii]],
                   x = df_c.loc[:,YpredDF.columns[ii]], 
                   gridsize = 50, cmap = cmap)
    axs[colnum].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[colnum].yaxis.set_major_locator(ticker.MaxNLocator(3))

    if(ii == 0):
        axs[colnum].set_title("Actual Value\n")
    
    axs[colnum].set_ylabel(fig_col_names[ii] + "\n" + ylabs[ii])
    axs[colnum].set_xlabel(ylabs[ii])

    #axs[ii].set_title(YtestDF.columns[ii])
#     axs[colnum].set_title(fig_col_names[ii], fontdict = {'verticalalignment': 'bottom'})
    axs[colnum].plot(df_c.loc[:,YtestDF.columns[ii]], 
                 df_c.loc[:,YtestDF.columns[ii]], 
                 'grey', linewidth = 1, linestyle  = "--")
    axs[colnum].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[colnum].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[colnum].set_aspect('equal', 'box')

    # annotate with R^2
    axs[colnum].text(np.max(df_c.loc[:,YtestDF.columns[ii]])*-0.4, 
                 np.min(df_c.loc[:,YtestDF.columns[ii]])*0.9, 
                 r'$r^2$ =' + 
                 str(np.round((r2_score(df_c.loc[:,YtestDF.columns[ii]],  
                                        df_c.loc[:,YpredDF.columns[ii]])), 3)))
    axs[colnum].set_xlim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]])), 
                      np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]]))])
    axs[colnum].set_ylim([-np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]])), 
                  np.max(np.abs(df_c.loc[:,YpredDF.columns[ii]]))])

# # residual plots x = predicted, y = actual - predicted
# jj is column in dataset, plotNum is plot position
for jj, plotNum in enumerate(np.arange(1, df_c.shape[1], 2)):

    axs[plotNum].hexbin(y = df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]],
                   x = df_c.loc[:,YpredDF.columns[jj]], 
                   gridsize = 50, cmap = cmap) 
    axs[plotNum].xaxis.set_major_locator(ticker.MaxNLocator(3))
    axs[plotNum].yaxis.set_major_locator(ticker.MaxNLocator(3))  
    
    if jj == 3:
        axs[plotNum].set_xlabel(ylabs[jj])
    else:
        axs[plotNum].set_xlabel(ylabs[jj])
    axs[plotNum].yaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))
    axs[plotNum].xaxis.set_major_formatter(MathTextSciFormatter("%1.0e"))

    if(jj == 0):
        axs[plotNum].set_title("Actual - Predicted\n")

    axs[plotNum].hlines(y = 0, xmin = np.min( df_c.loc[:,YpredDF.columns[jj]]), 
                   xmax = np.max( df_c.loc[:,YpredDF.columns[jj]]), 
                   linestyle =  "--", linewidth = 1)
    axs[plotNum].set_ylim([-np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]] - df_c.loc[:,YpredDF.columns[jj]])), 
                      np.max(np.abs(df_c.loc[:,YtestDF.columns[jj]]- df_c.loc[:,YpredDF.columns[jj]]))])


#fig.savefig(os.path.join(figDir, "PredVActual" + modelName + ".pdf"), dpi = 500, bbox_inches='tight')
plt.show()
# plt.close()

# %%
# train with pruning
numCuts = 1

wts = model.get_weights()
wtLengths = []
for ii in range(len(wts)):
    wtLengths.append(np.prod(wts[ii].shape))

# %%
# train until I have very good results
# then prune, and retrain until results are close
# change pruning rate as data get closer to 100% removed
def prune_percent_updater(x):
    logit = np.exp(x*8) / (np.exp(x*8) + 1)
    return((logit - 0.5)*2*50)


# cuts a smaller portion as the percent gets closer to 100%
cutPercent = prune_percent_updater(np.linspace(0, 1, 26))

while True:   
   
    for numEpocs in range(100):
        
        MSE_tmp = []

        history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                            verbose = 2, batch_size=2**12, epochs = 1)

        
        # save history
        historyDict["mean_squared_error"].append(history.history["mean_squared_error"][0])
        historyDict["val_mean_squared_error"].append(history.history["val_mean_squared_error"][0])
        
        # local MSE
        MSE_tmp.append(history.history["mean_squared_error"][0])

        # set weights that are close to 0 all the way back to 0, and then retrain for one epoch
        # get nonzero weights
        wts = model.get_weights().copy()

        # set weights close to 0 to 0 (but ignore biases)
        for ii in np.arange(0, len(wts), 1):
            qants = np.percentile(np.reshape(wts[ii], -1), q = (50 - cutPercent[numCuts], 50 + cutPercent[numCuts]), )
            wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0

        # print nonzero weights
        # calculate number of nonzero weights
        nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
        print(nzwts, "of", np.sum(wtLengths), "weights retained")

        # set new weights and calculate new loss
        model.set_weights(wts)
        
        # check the change in mean squared error, and if it's not changing much, then cut out more data
        # calculate slope of loss, based on previous 5 data points
        if numEpocs > 5:
            inputData = historyDict["mean_squared_error"][-5:]

            m = np.shape(inputData)
            X = np.matrix([np.ones(m), np.arange(0, len(inputData))]).T
            y = np.matrix(np.log(inputData)).T

            # Solve for projection matrix
            intercept, slope = np.array(np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)).reshape(-1,)
            print("change in log loss:", slope)
    
            # break if slope has stopped changing or if the overall min has been surpassed
            # in the first training, it will automatically prune after 5 epochs, because the min will be passed
            if (np.abs(slope) < 0.0001) or (history.history["mean_squared_error"][0] < np.min(historyDict["mean_squared_error"][:-1])): 
                print("************************************************ PRUNING ********************************************************")
                print("************************************************ PRUNING ********************************************************")
                print("************************************************ PRUNING ********************************************************")
                model.save(os.path.join(figDir,  modelName + str(datetime.now())[0:-7].replace("-", "_").replace(" ", "__").replace(":", "_") + '_Pruned.h5'))
                break
                       
                    
    ## refref: may want to save weights before each pruning, so I can go back, if I need to
    ## refref: should I be pruning the biases too?
    
    ## keep running tally of min mse, and if we can't get back to the min, then break
#     print("Min MSE for this prune ", np.min(MSE_tmp), "______overall Min MSE ", np.min(historyDict["mean_squared_error"]))
#     if np.min(MSE_tmp) > np.min(historyDict["mean_squared_error"]):
#         print("no more gain by pruning:  STOPPING Pruning")
#         break
    
    numCuts += 1
    if numCuts >= len(cutPercent):
        break

        
        #cutPercent += 0.2
winsound.PlaySound("*", winsound.SND_ALIAS)

# %%
# print sizes of each weight matrix
wtLengths = []
for ii in range(len(wts)):
    wtLengths.append(np.prod(wts[ii].shape))

    
print(np.sum(wtLengths), "total weights")

# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts, "of", np.sum(wtLengths), "weights retained")
    
plot_model_history_fromDict(historyDict, saveFig = True)

# %%
plt.plot(historyDict["mean_squared_error"])
plt.plot(historyDict["val_mean_squared_error"])

# %%
# save model
model.save(os.path.join(savedModels,  modelName + '.h5'))

# save scaler with same name as model
scalerfileX = modelName + '_scalerX.pkl'
pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

scalerfileY = modelName + '_scalerY.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %%
# END

# %%
# check to see if model saved: 
K.clear_session()
from keras.models import load_model
model = load_model(os.path.join(savedModels,  modelName + '.h5'))

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
len(wts[4])

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((20,3)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 100)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 100)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
len(model.get_weights())

# %%
model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (5, 95), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

# %%
ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %% [raw]
# K.clear_session()

# %% [raw]
# # this is the original model
# inputs = Input(shape=(Xtrain_scaled.shape[1],))
# x = Dense(400, activation='tanh')(inputs)
# x = Dense(400, activation='tanh')(x)
# x = Dense(400, activation='tanh')(x)
# x = Dense(16, activation='tanh')(x)
# predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)
#
# # create model
# model = Model(inputs=inputs, outputs=predictions)
# model.compile(loss="mse", optimizer="adam", metrics = ['mse'])
#
# earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=50,
#                           verbose=1, mode='auto', min_delta = 0.001)

# %%
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)

# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (2, 98), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)
model.set_weights(wts)


# start training
history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                    verbose = 2, batch_size=2**14, epochs = 1, 
                    callbacks = [earlystop])

# %%
wts = model.get_weights().copy()

# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (2.5, 97.5), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0

# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)
model.set_weights(wts)

model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining.png"), dpi = 120, bbox_inches='tight')
    plt.show()
    
plot_model_history(history)
print(history.history["loss"][-1])

# %%
# load model that was trained for much longer
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model.h5'))

# %%
model.summary()

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
wts = model.get_weights().copy()
nzwts = [np.nonzero(wts[ii].reshape(-1))[0] for ii in range(len(wts))]

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((20,5)) , facecolor='w', edgecolor='k')
#fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(nzwts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(nzwts[jj].shape))
    axs[jj+1].hist(nzwts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(nzwts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((10,10)) , facecolor='w', edgecolor='k')
#fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
#fig.savefig(os.path.join(figDir, "SmallModelResids.png"), dpi = 120, bbox_inches='tight')

# %%
# trim distribution of weights -- cut out middle 20%
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# show new histogram of weights (excluding the 0's)
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    
    d1 = wts[jj].reshape(-1)
    axs[jj].hist(d1[d1!=0], bins = 30, facecolor = '#d6bddb' )
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))

    d2 = wts[jj+1]
    axs[jj+1].hist(d2[d2!=0], bins = 30, facecolor = '#d6bddb')
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# the validation.split is the last X% of the data
int(0.3*Xtrain_scaled.shape[0])
ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()

# %%
# create dict of hyperparameters


# regularization, num layers, num nodes, learning rate, optimizer, activation function, batch size

from scipy.stats import randint
from scipy.stats import uniform

# Create hyperparameter space
NumHiddenLayers = randint(low = 2, high = 20)#[4, 2, 8]
numUnits  = [2**4, 2**5, 2**6, 2**7, 2**8, 2**9, 2**10]
epochs = [200]
batches1 = [2**12, 2**10, 2**8, 2**14] 
optimizers = ['rmsprop', 'adam']
dropout_rate =  uniform(loc = 0, scale = 0.5) #[0.0, 0.2, 0.5]
weightRegularization = uniform(loc = 0, scale = 0.001) #[0, 0.0001, 0.001, 0.01]
secondToLastUnits = [8, 16, 32, 64]

# Create hyperparameter options
hyperparameters = dict(optimizer=optimizers, 
                        epochs=epochs, 
                        batch_size=batches1,
                        dropout_rate = dropout_rate, 
                        numUnits = numUnits, 
                        NumHiddenLayers = NumHiddenLayers, 
                        weightRegularization = weightRegularization, 
                        secondToLastUnits = secondToLastUnits)
