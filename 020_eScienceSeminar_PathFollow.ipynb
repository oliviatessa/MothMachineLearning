# %% [markdown]
# # Callin Switzer
# ### 30 May 2019
# ### eScience Community Seminar Prep
#
#
# # Make videos of tracking moth

# %% [raw]
# Outline:
# ** show how well moth can follow trajectory with network

# %% [markdown]
# ___

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.ticker import ScalarFormatter
import matplotlib.colors as colors
from  mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

import os
import pandas as pd
import time
from datetime import datetime
import sys
import seaborn as sns
import scipy.io
import subprocess
import winsound
import pickle
import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
print("TensorFlow successfully installed.")
if tf.test.is_built_with_cuda():
    print("The installed version of TensorFlow includes GPU support.")
print(sys.version, "\n")
now = datetime.now()
print("last run on " + str(now))

# define directories
baseDir = os.getcwd()
dataDir = r'D:\MothSimulations\11c-AggressiveManeuver\Qstore\hws_am_con'
figDir = r'D:\Dropbox\AcademiaDropbox\CallinStuff\Presentations\eScience_Community_Seminar_2019'
dataOutput = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput'
savedModels = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels'
randomRawData = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\PythonGeneratedData\TrainingData'
if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
if not os.path.exists(savedModels):
    os.mkdir(savedModels)
# Out:
# C:\Users\calli\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2019-05-30 11:49:16.641143

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers
from keras.models import load_model

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
# define some functions

def format_e(n):
    a = '%E' % n
    return a.split('E')[0].rstrip('0').rstrip('.') + 'E' + a.split('E')[1]


def plot_model_history_fromDict(model_history_dictionary, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history_dictionary['mean_squared_error'])+1),
             model_history_dictionary['mean_squared_error'])
    axs.plot(range(1,len(model_history_dictionary['val_mean_squared_error'])+1),
             model_history_dictionary['val_mean_squared_error'])
    axs.set_title('Model MSE = '+ str(format_e(model_history_dictionary['val_mean_squared_error'][-1])) + "\n" +  str(nzwts) + " non-zero weights")
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history_dictionary['val_mean_squared_error'])+1),
                   len(model_history_dictionary['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    plt.yscale('log') #logarithmic scale for y axis
    if saveFig:
        plt.ylim([0.000001, 0.05])
        fig.savefig(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned_2.png"), dpi = 120, bbox_inches='tight')
        print(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned.png"))
    plt.show()

# %% [markdown]
# # Make training and test set

# %% [raw]
# # concatenate all files (only need to do this once)
# # it takes a few minutes
# all_files = glob.glob(os.path.join(randomRawData, "*.csv"))
# df_from_each_file = (pd.read_csv(f) for f in all_files)
# concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)
#
# # check for duplicates
# concatenated_df.drop_duplicates(inplace=True)
# concatenated_df.shape
#
# print(concatenated_df.shape)
# concatenated_df.tail()
#
# # save to hdf5
# concatenated_df.to_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
# read in data
trainDF = pd.read_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
# refref: check for repeats!

# %%
# double check for repeats!
np.sum(trainDF.iloc[:, [16,17,18]].duplicated()) # 0 means no repeats
# Out:
# 0

# %%
print(trainDF.shape)
trainDF.head()
# Out:
# (9900510, 19)
#     x0         xf          xd0          xdf   y0         yf         yd0  \
# 0  0.0  23.367432  1240.975696  1047.460389  0.0  -2.222497 -321.289498
# 1  0.0 -20.768748 -1149.257088 -1075.409015  0.0  11.106142  365.093207
# 2  0.0 -25.280989 -1496.313673 -1133.713595  0.0   4.318522  244.869357
# 3  0.0  -5.931729  -560.948725   -26.956023  0.0   0.748787   86.858301
# 4  0.0  -9.280447  -214.455052  -539.671502  0.0   6.707153  225.808462
#
#           ydf    theta0    thetaf    thetad0     thetadf      phi0      phif  \
# 0  -38.377027  4.539917  6.334514   5.761704  166.050842  2.909070  4.628560
# 1  697.828947  3.243816  4.921125  16.957561  146.364185  3.308109  4.891662
# 2  748.985152  5.436117 -0.270820   7.760703 -563.122968  5.548527 -0.137526
# 3   45.961219  4.004344  4.826500  -0.067853   72.504068  0.510978  1.423037
# 4  488.013492  6.129205  4.399997 -16.195650 -177.812751  1.609007 -0.231868
#
#        phid0       phidf             F     alpha          tau0
# 0  10.607821  162.092739  29718.210402  3.057406  53852.149654
# 1  22.615302  141.667777  28169.483755  3.504285  66579.923810
# 2   0.328348 -561.725041  42042.954099  1.460073 -13638.356558
# 3  24.197259   77.007517  32817.596791  1.943183 -59677.690610
# 4   9.118306 -183.140660  35120.738164  3.267484  77836.665059

# %%
# rename columns to be consistent with other code
trainDF.rename(columns={"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "xf" : "x_99", "yf" : "y_99", "phif" : "phi_99", "thetaf" : "theta_99", 
                        "xd0" : "x_dot_0", "yd0" : "y_dot_0", "phid0" : "phi_dot_0", "thetad0": "theta_dot_0", 
                        "xdf" : "x_dot_99", "ydf": "y_dot_99", "phidf": "phi_dot_99", "thetadf": "theta_dot_99", 
                        "tau0" : "tau"}, inplace=True)

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

# %%
# make dataset
X = trainDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

# %%
X.head()
# Out:
#       phi_0   theta_0       x_99       y_99    phi_99  theta_99      x_dot_0     y_dot_0  phi_dot_0  theta_dot_0
# 0  2.909070  4.539917  23.367432  -2.222497  4.628560  6.334514  1240.975696 -321.289498  10.607821     5.761704
# 1  3.308109  3.243816 -20.768748  11.106142  4.891662  4.921125 -1149.257088  365.093207  22.615302    16.957561
# 2  5.548527  5.436117 -25.280989   4.318522 -0.137526 -0.270820 -1496.313673  244.869357   0.328348     7.760703
# 3  0.510978  4.004344  -5.931729   0.748787  1.423037  4.826500  -560.948725   86.858301  24.197259    -0.067853
# 4  1.609007  6.129205  -9.280447   6.707153 -0.231868  4.399997  -214.455052  225.808462   9.118306   -16.195650

# %%
Y.head()
# Out:
#              Fx            Fy           tau     x_dot_99    y_dot_99  \
# 0 -29612.961122   2498.912376  53852.149654  1047.460389  -38.377027
# 1 -26336.915345  -9994.333651  66579.923810 -1075.409015  697.828947
# 2   4645.636361  41785.500502 -13638.356558 -1133.713595  748.985152
# 3 -11940.326951  30568.337400 -59677.690610   -26.956023   45.961219
# 4 -34842.795622  -4409.744037  77836.665059  -539.671502  488.013492
#
#    phi_dot_99  theta_dot_99
# 0  162.092739    166.050842
# 1  141.667777    146.364185
# 2 -561.725041   -563.122968
# 3   77.007517     72.504068
# 4 -183.140660   -177.812751

# %%
# test train split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state = 123)

# %%
# scale data 
scalerX = MinMaxScaler([-0.5, 0.5])  
scalerY = MinMaxScaler([-0.5, 0.5])  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xtest_scaled = scalerX.transform(Xtest)
Ytest_scaled = scalerY.transform(Ytest)

# %%
pd.DataFrame(Xtrain_scaled, columns = X.columns).head()
# Out:
#       phi_0   theta_0      x_99      y_99    phi_99  theta_99   x_dot_0  \
# 0 -0.479611  0.002266 -0.318639 -0.229442 -0.094704  0.071486 -0.491811
# 1 -0.453551  0.264615  0.295886  0.197180 -0.188053  0.054898  0.469097
# 2 -0.102133 -0.139825  0.314624  0.345313 -0.234415 -0.252743  0.486725
# 3 -0.025410  0.473391 -0.026110  0.073530  0.050494  0.209861 -0.032577
# 4  0.492691 -0.269698 -0.131405  0.348033  0.118454 -0.135028 -0.191459
#
#     y_dot_0  phi_dot_0  theta_dot_0
# 0 -0.220474   0.168732     0.450440
# 1  0.195148   0.353807    -0.446865
# 2  0.399421   0.036643    -0.265189
# 3 -0.026313  -0.037384    -0.004011
# 4  0.408163  -0.416592    -0.057925

# %%
# save scalers, to be used on test set
scalerfileX = 'scalerX.pkl'
pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

scalerfileY = 'scalerY.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %% [markdown]
# # Keras models

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV

#model.get_config()
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=150, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
K.clear_session()

# %%
# refref: start with small network and then build up
# refref: start with large network and prune

# %%
# create network
def create_network(optimizer = 'rmsprop', 
                    numUnits = [32, 32, 32, 32], 
                    weightRegularization = 0.0, 
                    dropout_rate=0.1):
    
    '''
    Create a feed forward network.  Assumes Xtrain & Ytrain have been created and scaled
    
    Params: 
    optimizer (str): choice of optimizer
    numUnits (list): number of units in each hidden
    weightRegularization (float): between 0 and 1
    dropout_rate (float): between 0 and 1
    
    '''
    K.clear_session()
    inputs = Input(shape=(Xtrain_scaled.shape[1],))    
    
    # add layers
    for ii in np.arange(0, len(numUnits)):
        if ii >= 1: 
            x = Dense(numUnits[ii], activation='tanh', 
                      kernel_regularizer=regularizers.l1(weightRegularization))(x)

        else: 
            x = Dense(numUnits[ii], activation='tanh')(inputs)


        # add dropout
        if dropout_rate > 0: 
            x = Dropout(dropout_rate)(x)
    
    predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

    # create model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(loss="mean_squared_error", optimizer = optimizer, metrics = ['mse'])

    return(model)

# %%
# load pre-trained model

# model = load_model(r"D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels\Opt_rmsprop__Dro_0.0__Num_400_400_400_16__Wei_0.0.h5")

# %%
modelParams = {"optimizer": "rmsprop", 
              "dropout_rate" : 0, 
               "numUnits": [400, 400, 400, 16],
               "weightRegularization": 0
              }



model = create_network(**modelParams)

modelName = ''.join('{}_{}__'.format(key[0:3].capitalize(), val) for  key, val in modelParams.items()).replace("[", "").replace("]", "").replace(", ", "_")[0:-2]+ "_" + str(datetime.now())[0:-7].replace("-", "_").replace(" ", "__").replace(":", "_")
print(modelName)

model.summary()
# Out:
# Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2019_05_30__19_19_39
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               4400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                6416
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 331,735
# Trainable params: 331,735
# Non-trainable params: 0
# _________________________________________________________________

# %%
# show random weight matrices
# show images for matrices

wts = model.get_weights().copy()

plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
fig.subplots_adjust(hspace = -0.7, wspace=0.1, bottom = -0.1 )
axs = axs.ravel("F")


viridis = cm.get_cmap('PRGn', 256)
newcolors = viridis(np.linspace(0, 1, 256))
white = np.array([0.8, 0.8, 0.8, 1])
newcolors[256//2-5:256//2+5, :] = white
newcmp = ListedColormap(newcolors)


for jj, ii in enumerate(np.arange(0, len(wts), 1)):
    
    

    
    if len(wts[ii].shape) < 2: 
        wtsTmp = wts[ii].reshape(1,-1).copy()
    else:
        wtsTmp = wts[ii].copy()
    
    im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    



    
    if np.mod(ii+1, 2) == 0:
        axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 1])
        axs[jj].axes.set_xlim([-1, 413])
        axs[jj].get_xaxis().set_ticks([0, 200, 400])
        
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].tick_params(top = False, labelbottom = True, labeltop = False)
        

    
    if (np.mod(jj, 2) == 0) and (jj != 0):
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])
            
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 413])
        axs[jj].axes.set_xlim([-1, 413])
        #axs[jj].axis('off')
        
        
    if ii == 9:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_xaxis().set_ticks([0])
        axs[jj].axes.set_xlim([-1, 413])
        
    if ii == 0:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        #axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_yaxis().set_ticks([])
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.set_ylim([-1, 32])

    
    #axs[jj].axis('off')

cbaxes = inset_axes(axs[8], width="5%", height="75%", loc= "center") 
cbar = fig.colorbar(im, cax=cbaxes, orientation="vertical", ticks = [-10, -1, 0, 1, 10])    
    
#fig.colorbar(im, orientation="horizontal", pad=0.2)



plt.savefig(os.path.join(figDir, "RandomWeightMatrices" + modelName + ".png"), dpi = 500, bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %%
# train

# %%
# start training
historyDict = {"mean_squared_error": [], 
               "val_mean_squared_error": []}

# %%
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=15, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
# # fit model without regularization
stt = time.time()
history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 1000, verbose = 2, 
                        batch_size=2**14, callbacks = [earlystop], validation_split = 0.3)
winsound.PlaySound("*", winsound.SND_ALIAS)
endd = time.time() - stt
print(endd)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1000
#  - 7s - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 2/1000
#  - 7s - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 3/1000
#  - 7s - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 4/1000
#  - 7s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 5/1000
#  - 7s - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 6/1000
#  - 7s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 7/1000
#  - 7s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 8/1000
#  - 7s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 9/1000
#  - 7s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 10/1000
#  - 7s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 11/1000
#  - 7s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 12/1000
#  - 7s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 13/1000
#  - 7s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 14/1000
#  - 7s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 15/1000
#  - 7s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 16/1000
#  - 7s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 17/1000
#  - 7s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 18/1000
#  - 7s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 19/1000
#  - 7s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 20/1000
#  - 7s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 21/1000
#  - 7s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 22/1000
#  - 7s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 23/1000
#  - 7s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 24/1000
#  - 7s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 25/1000
#  - 7s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 26/1000
#  - 7s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 27/1000
#  - 7s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 28/1000
#  - 7s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 29/1000
#  - 7s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 30/1000
#  - 7s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 31/1000
#  - 7s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 32/1000
#  - 7s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 33/1000
#  - 7s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 34/1000
#  - 7s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 35/1000
#  - 7s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 36/1000
#  - 7s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 37/1000
#  - 7s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 38/1000
#  - 7s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 39/1000
#  - 7s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 40/1000
#  - 7s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 41/1000
#  - 7s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 42/1000
#  - 7s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 43/1000
#  - 7s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 44/1000
#  - 7s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 45/1000
#  - 7s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 46/1000
#  - 7s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 47/1000
#  - 7s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 48/1000
#  - 7s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 49/1000
#  - 7s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 50/1000
#  - 7s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 51/1000
#  - 7s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 52/1000
#  - 7s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 53/1000
#  - 7s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 54/1000
#  - 7s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 55/1000
#  - 7s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 56/1000
#  - 7s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 57/1000
#  - 7s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 58/1000
#  - 7s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 59/1000
#  - 7s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 60/1000
#  - 7s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 61/1000
#  - 7s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 62/1000
#  - 7s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 63/1000
#  - 7s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 64/1000
#  - 7s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 65/1000
#  - 7s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 66/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 67/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 68/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 69/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 70/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 71/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 72/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 73/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 74/1000
#  - 7s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 75/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 76/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 77/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 78/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 79/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 8.9112e-04 - val_mean_squared_error: 8.9112e-04
# Epoch 80/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 81/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 82/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 83/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 84/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 85/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 86/1000
#  - 7s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 87/1000
#  - 7s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.5600e-04 - val_mean_squared_error: 9.5600e-04
# Epoch 88/1000
#  - 7s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 89/1000
#  - 7s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 90/1000
#  - 7s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9
# Epoch 208/1000
#  - 7s - loss: 6.0289e-04 - mean_squared_error: 6.0289e-04 - val_loss: 5.9700e-04 - val_mean_squared_error: 5.9700e-04
# Epoch 209/1000
#  - 7s - loss: 5.9912e-04 - mean_squared_error: 5.9912e-04 - val_loss: 5.5257e-04 - val_mean_squared_error: 5.5257e-04
# Epoch 210/1000
#  - 7s - loss: 5.9911e-04 - mean_squared_error: 5.9911e-04 - val_loss: 5.0865e-04 - val_mean_squared_error: 5.0865e-04
# Epoch 211/1000
#  - 7s - loss: 5.9681e-04 - mean_squared_error: 5.9681e-04 - val_loss: 6.5332e-04 - val_mean_squared_error: 6.5332e-04
# Epoch 212/1000
#  - 7s - loss: 5.9662e-04 - mean_squared_error: 5.9662e-04 - val_loss: 5.1584e-04 - val_mean_squared_error: 5.1584e-04
# Epoch 213/1000
#  - 7s - loss: 5.9377e-04 - mean_squared_error: 5.9377e-04 - val_loss: 6.6627e-04 - val_mean_squared_error: 6.6627e-04
# Epoch 214/1000
#  - 7s - loss: 5.9262e-04 - mean_squared_error: 5.9262e-04 - val_loss: 7.3001e-04 - val_mean_squared_error: 7.3001e-04
# Epoch 215/1000
#  - 7s - loss: 5.9098e-04 - mean_squared_error: 5.9098e-04 - val_loss: 5.1088e-04 - val_mean_squared_error: 5.1088e-04
# Epoch 216/1000
#  - 7s - loss: 5.8926e-04 - mean_squared_error: 5.8926e-04 - val_loss: 6.8819e-04 - val_mean_squared_error: 6.8819e-04
# Epoch 217/1000
#  - 7s - loss: 5.8724e-04 - mean_squared_error: 5.8724e-04 - val_loss: 5.8727e-04 - val_mean_squared_error: 5.8727e-04
# Epoch 218/1000
#  - 7s - loss: 5.8563e-04 - mean_squared_error: 5.8563e-04 - val_loss: 6.4433e-04 - val_mean_squared_error: 6.4433e-04
# Epoch 219/1000
#  - 7s - loss: 5.8434e-04 - mean_squared_error: 5.8434e-04 - val_loss: 5.5177e-04 - val_mean_squared_error: 5.5177e-04
# Epoch 220/1000
#  - 7s - loss: 5.8297e-04 - mean_squared_error: 5.8297e-04 - val_loss: 6.0519e-04 - val_mean_squared_error: 6.0519e-04
# Epoch 221/1000
#  - 7s - loss: 5.8159e-04 - mean_squared_error: 5.8159e-04 - val_loss: 5.4919e-04 - val_mean_squared_error: 5.4919e-04
# Epoch 222/1000
#  - 7s - loss: 5.8101e-04 - mean_squared_error: 5.8101e-04 - val_loss: 5.3762e-04 - val_mean_squared_error: 5.3762e-04
# Epoch 223/1000
#  - 7s - loss: 5.7759e-04 - mean_squared_error: 5.7759e-04 - val_loss: 5.4189e-04 - val_mean_squared_error: 5.4189e-04
# Epoch 224/1000
#  - 7s - loss: 5.7970e-04 - mean_squared_error: 5.7970e-04 - val_loss: 5.4831e-04 - val_mean_squared_error: 5.4831e-04
# Epoch 225/1000
#  - 7s - loss: 5.7281e-04 - mean_squared_error: 5.7281e-04 - val_loss: 5.5976e-04 - val_mean_squared_error: 5.5976e-04
# Epoch 226/1000
# Epoch 905/1000
#  - 7s - loss: 2.6509e-04 - mean_squared_error: 2.6509e-04 - val_loss: 2.9761e-04 - val_mean_squared_error: 2.9761e-04
# Epoch 906/1000
#  - 7s - loss: 2.6205e-04 - mean_squared_error: 2.6205e-04 - val_loss: 2.3432e-04 - val_mean_squared_error: 2.3432e-04
# Epoch 907/1000
#  - 7s - loss: 2.6309e-04 - mean_squared_error: 2.6309e-04 - val_loss: 2.0346e-04 - val_mean_squared_error: 2.0346e-04
# Epoch 908/1000
#  - 7s - loss: 2.6347e-04 - mean_squared_error: 2.6347e-04 - val_loss: 2.2045e-04 - val_mean_squared_error: 2.2045e-04
# Epoch 909/1000
#  - 7s - loss: 2.6249e-04 - mean_squared_error: 2.6249e-04 - val_loss: 2.6226e-04 - val_mean_squared_error: 2.6226e-04
# Epoch 910/1000
#  - 7s - loss: 2.6226e-04 - mean_squared_error: 2.6226e-04 - val_loss: 2.4964e-04 - val_mean_squared_error: 2.4964e-04
# Epoch 911/1000
#  - 7s - loss: 2.6315e-04 - mean_squared_error: 2.6315e-04 - val_loss: 2.1885e-04 - val_mean_squared_error: 2.1885e-04
# Epoch 912/1000
#  - 7s - loss: 2.6361e-04 - mean_squared_error: 2.6361e-04 - val_loss: 1.7113e-04 - val_mean_squared_error: 1.7113e-04
# Epoch 913/1000
#  - 7s - loss: 2.6125e-04 - mean_squared_error: 2.6125e-04 - val_loss: 2.6424e-04 - val_mean_squared_error: 2.6424e-04
# Epoch 00913: early stopping
# 6051.221323490143

# %%
historyDict["mean_squared_error"].extend(history.history["mean_squared_error"][0:])
historyDict["val_mean_squared_error"].extend(history.history["val_mean_squared_error"][0:])

# %%
# refref: save history

# %%
def plot_model_history_fromDict(model_history_dictionary, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history_dictionary['mean_squared_error'])+1),
             model_history_dictionary['mean_squared_error'])
    axs.plot(range(1,len(model_history_dictionary['val_mean_squared_error'])+1),
             model_history_dictionary['val_mean_squared_error'])
    axs.set_title('Model MSE = '+ str(format_e(model_history_dictionary['val_mean_squared_error'][-1])) + "\n" +  str(nzwts) + " non-zero weights")
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history_dictionary['val_mean_squared_error'])+1),
                   len(model_history_dictionary['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    plt.yscale('log') #logarithmic scale for y axis
    if saveFig:
        plt.ylim([0.0001, 0.05])
        fig.savefig(os.path.join(figDir, "ModelTraining_" + modelName + "_NOTpruned_2.png"), dpi = 120, bbox_inches='tight')
        print(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned.png"))
    plt.show()



wts = model.get_weights().copy()



# print sizes of each weight matrix
wtLengths = []
for ii in range(len(wts)):
    wtLengths.append(np.prod(wts[ii].shape))

print(np.sum(wtLengths), "total weights")

# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts, "of", np.sum(wtLengths), "weights retained")
    
plot_model_history_fromDict(historyDict, saveFig = True)
# Out:
# 331735 total weights
# 331735 of 331735 weights retained
# D:\Dropbox\AcademiaDropbox\CallinStuff\Presentations\eScience_Community_Seminar_2019\ModelTraining_Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2019_05_30__19_19_39_pruned.png

# %%
wts = model.get_weights().copy()

# if I need to remake, use this
# wtsPath = "D:\Dropbox\AcademiaDropbox\CallinStuff\Presentations\eScience_Community_Seminar_2019\Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2019_05_30__11_59_54_wts.pkl"
# wts =  pickle.load(open(wtsPath, 'rb'))

plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
fig.subplots_adjust(hspace = -0.7, wspace=0.1, bottom = -0.1 )
axs = axs.ravel("F")


viridis = cm.get_cmap('PRGn', 256)
newcolors = viridis(np.linspace(0, 1, 256))
white = np.array([0.8, 0.8, 0.8, 1])
newcolors[256//2:256//2 + 1, :] = white
newcmp = ListedColormap(newcolors)


for jj, ii in enumerate(np.arange(0, len(wts), 1)):
    
    

    
    if len(wts[ii].shape) < 2: 
        wtsTmp = wts[ii].reshape(1,-1).copy()
    else:
        wtsTmp = wts[ii].copy()
    
    im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    



    
    if np.mod(ii+1, 2) == 0:
        axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 1])
        axs[jj].axes.set_xlim([-1, 413])
        axs[jj].get_xaxis().set_ticks([0, 200, 400])
        
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].tick_params(top = False, labelbottom = True, labeltop = False)
        

    
    if (np.mod(jj, 2) == 0) and (jj != 0):
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])
            
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 413])
        axs[jj].axes.set_xlim([-1, 413])
        #axs[jj].axis('off')
        
        
    if ii == 9:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_xaxis().set_ticks([0])
        axs[jj].axes.set_xlim([-1, 413])
        
    if ii == 0:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        #axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_yaxis().set_ticks([])
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.set_ylim([-1, 32])

    
    #axs[jj].axis('off')

cbaxes = inset_axes(axs[8], width="5%", height="75%", loc= "center") 
cbar = fig.colorbar(im, cax=cbaxes, orientation="vertical", ticks = [-10, -1, 0, 1, 10])    
    
#fig.colorbar(im, orientation="horizontal", pad=0.2)



plt.savefig(os.path.join(figDir, "TrainedWeightMatrices" + modelName + ".png"), dpi = 500, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# # refref: plot predictions on test set and make figures.

# %%
# predict on test set
# apply same transformation to test data
# Xtest_scaled = scalerX.transform(Xtest)
# Ytest_scaled = scalerY.transform(Ytest)


Ytest_pred = model.predict(Xtest_scaled)

# %%
# make dataset
X = trainDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]


# make data frames
XtestDF = pd.DataFrame(scalerX.inverse_transform(Xtest_scaled), columns = X.columns)
YtestDF = pd.DataFrame(scalerY.inverse_transform(Ytest_scaled), columns = Y.columns)
YpredDF = pd.DataFrame(scalerY.inverse_transform(Ytest_pred), columns = Y.columns+ "_pred")

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

df_c = pd.concat([YtestDF.reset_index(drop=True), YpredDF], axis=1)
df_c.head()
# Out:
#              Fx            Fy           tau    x_dot_99     y_dot_99  phi_dot_99  theta_dot_99       Fx_pred       Fy_pred      tau_pred  x_dot_99_pred  y_dot_99_pred  phi_dot_99_pred  theta_dot_99_pred
# 0 -43383.349096   7777.781558 -89149.114709 -289.067470 -1795.196260  191.024411    184.854298 -39568.160156  10624.836914 -82732.929688    -318.989136   -1708.155029       188.036118         181.884445
# 1 -15183.324785 -33332.606636 -67061.833735 -700.930956   494.674624   29.746681     25.086001 -14456.023438 -33143.523438 -66242.468750    -785.343567     539.289795        28.555794          24.200012
# 2 -18573.143652  -5798.048395  60110.993478   80.592187 -1353.445823  -79.225996    -74.887624 -19159.384766  -8496.029297  66678.750000      73.320312   -1323.419922       -82.278786         -77.144814
# 3   3097.636077  13097.481455 -59066.505785  796.970559   633.856580   26.699424     22.407782   1864.951172  11021.346680 -53051.292969     815.212830     615.213135        26.636950          23.231014
# 4  40757.753533   2142.142946  56326.235342    0.179984  1969.065934  232.317284    235.379521  39658.445312   2556.317627  52228.132812    -101.580368    1858.775635       218.292145         221.968185

# %%
#df_c = df_c[0:100000]

# %%
# make plots
from sklearn.metrics import r2_score

plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array([30, 10]) / 1.3, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.2, wspace=0.7)
#fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel()

ylabs = [r"g*cm/$s^2$", r"g*cm/$s^2$", r"g*$cm^2$/$s^2$", "cm/s", "cm/s", "rad/s", "rad/s"]

# replace lightest colors with white
import matplotlib.colors

cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(df_c.shape[1] //2):
    try:
        axs[ii].hexbin(y = df_c.iloc[:,ii],x = df_c.iloc[:,ii + 7], gridsize = 50, cmap = cmap)
        #axs[ii].set_xlabel("Predicted Value\n(unscaled)")
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value\n" + ylabs[ii])
        else:
            axs[ii].set_ylabel(ylabs[ii])
        axs[ii].set_title(df_c.columns[ii])
        axs[ii].plot(df_c.iloc[:,ii], df_c.iloc[:,ii], 'grey', linewidth = 1, linestyle  = "--")
        
        # annotate with R^2
        axs[ii].text(np.max(df_c.iloc[:,ii])*0.1, np.min(df_c.iloc[:,ii])*0.9, r'$r^2$ =' + str(np.round((r2_score(df_c.iloc[:,ii ],  df_c.iloc[:,ii+7])), 3)))
        axs[ii].set_xlim([-np.max(np.abs(df_c.iloc[:,ii+7])), np.max(np.abs(df_c.iloc[:,ii+7]))])
    except:
        pass

# # residual plots x = predicted, y = actual - predicted
for jj in range(df_c.shape[1] //2):
    
    ii = jj + 7
    try:
        axs[ii].hexbin(x = df_c.iloc[:,jj],
                     y = df_c.iloc[:,jj ] - df_c.iloc[:,jj+7], gridsize = (35, 50), cmap = cmap)
        axs[ii].set_xlabel("Predicted Value")

        if(jj == 0):
            axs[ii].set_ylabel("Actual - Predicted\n" + ylabs[jj])
        else:
            axs[ii].set_ylabel(ylabs[jj])
        
        axs[ii].hlines(y = 0, xmin = np.min( df_c.iloc[:,jj+7]), 
                       xmax = np.max( df_c.iloc[:,jj+7]), linestyle =  "--", linewidth = 1)
        axs[ii].set_ylim([-np.max(np.abs(df_c.iloc[:,jj ] - df_c.iloc[:,jj+7])), np.max(np.abs(df_c.iloc[:,jj ] - df_c.iloc[:,jj+7]))])
        
    except:
        pass


fig.savefig(os.path.join(figDir, "PredVActual_" + modelName + ".png"), dpi = 500, bbox_inches='tight')
plt.show()
# plt.close()

# %%
#(y_true, y_pred, sample_weight=None, multioutput=’uniform_average’)

# %%
#  save model
model.save(os.path.join(figDir,  modelName + '_notPruned.h5'))

# save weights
wts = model.get_weights().copy()

wtsFile = modelName + '_wts.pkl'
pickle.dump(wts, open(os.path.join(figDir, wtsFile), 'wb'))

# save history
histName = modelName + '_history.pkl'
pickle.dump(historyDict, open(os.path.join(figDir, histName), 'wb'))

# %%
for jj in range(7):
    print (r2_score(df_c.iloc[:,jj ],  df_c.iloc[:,jj+7]))
# Out:
# 0.9938142640427501
# 0.9922394492016853
# 0.9876010486609776
# 0.9972174213724331
# 0.997349786872206
# 0.9988266849411487
# 0.9988918653206684

# %% [markdown]
# ___

# %% [markdown]
# ## START NEW ITEM: train and trim weights

# %%
# train and trim weights

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               4400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                6416
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 331,735
# Trainable params: 331,735
# Non-trainable params: 0
# _________________________________________________________________

# %%
# read in data
#wts =  pickle.load(open(os.path.join(dataOutput, wtsFile), 'rb'))

# print sizes of each weight matrix
wtLengths = []
for ii in range(len(wts)):
    print(wts[ii].shape)
    wtLengths.append(np.prod(wts[ii].shape))

print(np.sum(wtLengths), "total weights")
# Out:
# (10, 400)
# (400,)
# (400, 400)
# (400,)
# (400, 400)
# (400,)
# (400, 16)
# (16,)
# (16, 7)
# (7,)
# 331735 total weights

# %%
# # start training
# historyDict = {"mean_squared_error": [], 
#                "val_mean_squared_error": []}

# %%
# start pruning
modelName + str(datetime.now())[0:-7].replace("-", "_").replace(" ", "__").replace(":", "_") + '_Pruned.h5'
# Out:
# 'Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2019_05_30__19_19_392019_05_30__21_09_09_Pruned.h5'

# %%
numCuts = 1

# %%
# refref: 
# train until I have very good results
# then prune, and retrain until results are close
# change pruning rate as data get closer to 100% removed
def prune_percent_updater(x):
    logit = np.exp(x*8) / (np.exp(x*8) + 1)
    return((logit - 0.5)*2*50)


# cuts a smaller portion as the percent gets closer to 100%
cutPercent = prune_percent_updater(np.linspace(0, 1, 26))

while True:   
   
    for numEpocs in range(100):
        
        MSE_tmp = []

        history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                            verbose = 2, batch_size=2**14, epochs = 1, 
                            callbacks = [earlystop])
        
        # refref: earlystop doesn't do anything here
        
        # save history
        historyDict["mean_squared_error"].append(history.history["mean_squared_error"][0])
        historyDict["val_mean_squared_error"].append(history.history["val_mean_squared_error"][0])
        
        # local MSE
        MSE_tmp.append(history.history["mean_squared_error"][0])

        # set weights that are close to 0 all the way back to 0, and then retrain for one epoch
        # get nonzero weights
        wts = model.get_weights().copy()

        # set weights close to 0 to 0 (but ignore biases)
        for ii in np.arange(0, len(wts), 1):
            qants = np.percentile(np.reshape(wts[ii], -1), q = (50 - cutPercent[numCuts], 50 + cutPercent[numCuts]), )
            wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0

        # print nonzero weights
        # calculate number of nonzero weights
        nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
        print(nzwts, "of", np.sum(wtLengths), "weights retained")

        # set new weights and calculate new loss
        model.set_weights(wts)
        
        # check the change in mean squared error, and if it's not changing much, then cut out more data
        # calculate slope of loss, based on previous 5 data points
        if numEpocs > 5:
            inputData = historyDict["mean_squared_error"][-5:]

            m = np.shape(inputData)
            X = np.matrix([np.ones(m), np.arange(0, len(inputData))]).T
            y = np.matrix(np.log(inputData)).T

            # Solve for projection matrix
            intercept, slope = np.array(np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)).reshape(-1,)
            print("change in log loss:", slope)
    
            # break if slope has stopped changing or if the overall min has been surpassed
            # in the first training, it will automatically prune after 5 epochs, because the min will be passed
            if (np.abs(slope) < 0.0001) or (history.history["mean_squared_error"][0] < np.min(historyDict["mean_squared_error"][:-1])): 
                print("************************************************ PRUNING ********************************************************")
                print("************************************************ PRUNING ********************************************************")
                print("************************************************ PRUNING ********************************************************")
                model.save(os.path.join(figDir,  modelName + str(datetime.now())[0:-7].replace("-", "_").replace(" ", "__").replace(":", "_") + '_Pruned.h5'))
                break
                       
                    
    ## refref: may want to save weights before each pruning, so I can go back, if I need to
    ## refref: should I be pruning the biases too?
    
    ## keep running tally of min mse, and if we can't get back to the min, then break
#     print("Min MSE for this prune ", np.min(MSE_tmp), "______overall Min MSE ", np.min(historyDict["mean_squared_error"]))
#     if np.min(MSE_tmp) > np.min(historyDict["mean_squared_error"]):
#         print("no more gain by pruning:  STOPPING Pruning")
#         break
    
    numCuts += 1
    if numCuts >= len(cutPercent):
        break

        
        #cutPercent += 0.2
winsound.PlaySound("*", winsound.SND_ALIAS)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.6161e-04 - mean_squared_error: 2.6161e-04 - val_loss: 3.2771e-04 - val_mean_squared_error: 3.2771e-04
# 279104 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.6224e-04 - mean_squared_error: 2.6224e-04 - val_loss: 3.0469e-04 - val_mean_squared_error: 3.0469e-04
# 279104 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.6251e-04 - mean_squared_error: 2.6251e-04 - val_loss: 2.5458e-04 - val_mean_squared_error: 2.5458e-04
# 279104 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.6203e-04 - mean_squared_error: 2.6203e-04 - val_loss: 2.8788e-04 - val_mean_squared_error: 2.8788e-04
# 279104 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.6116e-04 - mean_squared_error: 2.6116e-04 - val_loss: 2.2496e-04 - val_mean_squared_error: 2.2496e-04
# 279104 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.6296e-04 - mean_squared_error: 2.6296e-04 - val_loss: 2.0813e-04 - val_mean_squared_error: 2.0813e-04
# 279104 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.6170e-04 - mean_squared_error: 2.6170e-04 - val_loss: 2.5391e-04 - val_mean_squared_error: 2.5391e-04
# 279104 of 331735 weights retained
# change in log loss: -0.00026365953719231783
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.
of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 3.0576e-04 - mean_squared_error: 3.0576e-04 - val_loss: 2.6802e-04 - val_mean_squared_error: 2.6802e-04
# 47618 of 331735 weights retained
# change in log loss: -0.055479551202174626
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 3.0109e-04 - mean_squared_error: 3.0109e-04 - val_loss: 3.6734e-04 - val_mean_squared_error: 3.6734e-04
# 47618 of 331735 weights retained
# change in log loss: -0.0345375484986985
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.9588e-04 - mean_squared_error: 2.9588e-04 - val_loss: 3.3096e-04 - val_mean_squared_error: 3.3096e-04
# 47618 of 331735 weights retained
# change in log loss: -0.0241605110133285
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.9530e-04 - mean_squared_error: 2.9530e-04 - val_loss: 2.0156e-04 - val_mean_squared_error: 2.0156e-04
# 47618 of 331735 weights retained
# change in log loss: -0.014518464215966587
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.9116e-04 - mean_squared_error: 2.9116e-04 - val_loss: 3.2124e-04 - val_mean_squared_error: 3.2124e-04
# 47618 of 331735 weights retained
# change in log loss: -0.011730216625926992
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.9064e-04 - mean_squared_error: 2.9064e-04 - val_loss: 2.7115e-04 - val_mean_squared_error: 2.7115e-04
# 47618 of 331735 weights retained
# change in log loss: -0.008673884037935675
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8907e-04 - mean_squared_error: 2.8907e-04 - val_loss: 2.5491e-04 - val_mean_squared_error: 2.5491e-04
# 47618 of 331735 weights retained
# change in log loss: -0.006247147583371859
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8555e-04 - mean_squared_error: 2.8555e-04 - val_loss: 2.4509e-04 - val_mean_squared_error: 2.4509e-04
# 47618 of 331735 weights retained
# change in log loss: -0.00743670656957951
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8612e-04 - mean_squared_error: 2.8612e-04 - val_loss: 2.8084e-04 - val_mean_squared_error: 2.8084e-04
# 47618 of 331735 weights retained
# change in log loss: -0.005257723958052685
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8285e-04 - mean_squared_error: 2.8285e-04 - val_loss: 2.9164e-04 - val_mean_squared_error: 2.9164e-04
# 47618 of 331735 weights retained
# change in log loss: -0.006458551051169659
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8398e-04 - mean_squared_error: 2.8398e-04 - val_loss: 2.1774e-04 - val_mean_squared_error: 2.1774e-04
# 47618 of 331735 weights retained
# change in log loss: -0.0045045146169220285
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8271e-04 - mean_squared_error: 2.8271e-04 - val_loss: 2.2901e-04 - val_mean_squared_error: 2.2901e-04
# 47618 of 331735 weights retained
# change in log loss: -0.002749361219379187
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8071e-04 - mean_squared_error: 2.8071e-04 - val_loss: 3.1475e-04 - val_mean_squared_error: 3.1475e-04
# 47618 of 331735 weights retained
# change in log loss: -0.003867515173272107
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.8037e-04 - mean_squared_error: 2.8037e-04 - val_loss: 2.4961e-04 - val_mean_squared_error: 2.4961e-04
# 47618 of 331735 weights retained
# change in log loss: -0.002916874852505469
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.7969e-04 - mean_squared_error: 2.7969e-04 - val_loss: 2.7464e-04 - val_mean_squared_error: 2.7464e-04
# 47618 of 331735 weights retained
# change in log loss: -0.0038738955888839577
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.7903e-04 - mean_squared_error: 2.7903e-04 - val_loss: 2.7576e-04 - val_mean_squared_error: 2.7576e-04
# 47618 of 331735 weights retained
# change in log loss: -0.0029841758470472435
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.7768e-04 - mean_squared_error: 2.7768e-04 - val_loss: 3.5584e-04 - val_mean_squared_error: 3.5584e-04
# 47618 of 331735 weights retained
# change in log loss: -0.0026490374030532227
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.7817e-04 - mean_squared_error: 2.7817e-04 - val_loss: 2.7617e-04 - val_mean_squared_error: 2.7617e-04
# 47618 of 331735 weights retained
# change in log loss: -0.002299367263448815
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 2.
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# 435 of 331735 weights retained
# change in log loss: 0.0007863198377017211
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# 436 of 331735 weights retained
# change in log loss: -0.0006178459560600702
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# 436 of 331735 weights retained
# change in log loss: 0.0009195172453397848
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# 436 of 331735 weights retained
# change in log loss: 0.0012362053128918138
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# 436 of 331735 weights retained
# change in log loss: -0.00018238297605344123
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 436 of 331735 weights retained
# change in log loss: 0.0024550396362282845
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 436 of 331735 weights retained
# change in log loss: 5.256964316302515e-06
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# 318 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# 318 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# 318 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# 318 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# 318 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# 318 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# 317 of 331735 weights retained
# change in log loss: -0.0011210769689222744
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# 318 of 331735 weights retained
# change in log loss: -0.002095612987232265
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# 318 of 331735 weights retained
# change in log loss: 0.0015190733444437887
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# 318 of 331735 weights retained
# change in log loss: 0.002653558629095998
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# 318 of 331735 weights retained
# change in log loss: 0.0063502017926933
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# 318 of 331735 weights retained
# change in log loss: 0.008571118611884643
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 318 of 331735 weights retained
# change in log loss: 0.0041784641586378735
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# 318 of 331735 weights retained
# change in log loss: -0.0038467269135020743
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# 318 of 331735 weights retained
# change in log loss: -0.0035154208219300154
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 318 of 331735 weights retained
# change in log loss: -0.003496869635432498
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# 318 of 331735 weights retained
# change in log loss: -0.00046196994988867424
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# 318 of 331735 weights retained
# change in log loss: -0.00036911396560346255
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# 317 of 331735 weights retained
# change in log loss: -0.0002133409992730595
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 317 of 331735 weights retained
# change in log loss: -0.0018762346372199756
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0244 - val_mean_squared_error: 0.0244
# 318 of 331735 weights retained
# change in log loss: -0.0017182754527167443
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# 318 of 331735 weights retained
# change in log loss: -0.0019659724847919113
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0244 - val_mean_squared_error: 0.0244
# 318 of 331735 weights retained
# change in log loss: -0.0005383011887422073
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# 318 of 331735 weights retained
# change in log loss: 0.00249230852865856
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# 317 of 331735 weights retained
# change in log loss: 0.0007300205745188748
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# 317 of 331735 weights retained
# change in log loss: -0.0016902735294896942
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# 318 of 331735 weights retained
# change in log loss: -0.0002820675396846273
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# 318 of 331735 weights retained
# change in log loss: 0.004814289224934765
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 318 of 331735 weights retained
# change in log loss: 0.0029085792530272325
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# 318 of 331735 weights retained
# change in log loss: -0.0009001386657414567
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# 318 of 331735 weights retained
# change in log loss: -0.002421252119827577
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 318 of 331735 weights retained
# change in log loss: -0.0019462101964292655
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# 318 of 331735 weights retained
# change in log loss: 0.002598401911807602
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# 318 of 331735 weights retained
# change in log loss: 0.005355306526725445
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# 318 of 331735 weights retained
# change in log loss: -0.0004605681906124648
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# 318 of 331735 weights retained
# change in log loss: -0.0004526985593823474
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# 318 of 331735 weights retained
# change in log loss: -0.0009762800346586609
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# 318 of 331735 weights retained
# change in log loss: -0.0027893443691014985
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# 318 of 331735 weights retained
# change in log loss: 0.0006659312449954768
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# 318 of 331735 weights retained
# change in log loss: -0.0006353665810611142
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# 318 of 331735 weights retained
# change in log loss: -0.0007881329098483603
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# 318 of 331735 weights retained
# change in log loss: -8.198545814397384e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# 238 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# 238 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# 237 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# 238 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# 238 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# 237 of 331735 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0304 - val_mean_squared_error: 0.0304
# 238 of 331735 weights retained
# change in log loss: 0.021780857586038205
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.0299 - val_mean_squared_error: 0.0299
# 237 of 331735 weights retained
# change in log loss: 0.03439352932176043
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0298 - val_mean_squared_error: 0.0298
# 237 of 331735 weights retained
# change in log loss: 0.03239116968639544
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 0.0295 - val_mean_squared_error: 0.0295
# 238 of 331735 weights retained
# change in log loss: 0.021424198331015387
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# 238 of 331735 weights retained
# change in log loss: 0.00043959483872946237
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 7s - loss: 0.0323 - mean_squared_error: 0.0323 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# 238 of 331735 weights retained
# change in log loss: -8.375144293226722e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-291-65323b59a2a3> in <module>()
#      85
#      86         #cutPercent += 0.2
# ---> 87 winsound.PlaySound("*", winsound.SND_ALIAS)
#
# RuntimeError: Failed to play sound

# %%
print(numCuts)
(50 - cutPercent[numCuts]) * 2 # percent of original network size that is used the pruned version
# Out:
# 26
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-292-8b3931e61806> in <module>()
#       1 print(numCuts)
# ----> 2 (50 - cutPercent[numCuts]) * 2 # percent of original network size that is used the pruned version
#
# IndexError: index 26 is out of bounds for axis 0 with size 26

# %%
#  save model
model.save(os.path.join(figDir,  modelName + '_Pruned.h5'))

# save weights
wts = model.get_weights().copy()

wtsFile = modelName + '_wts_pruned.pkl'
pickle.dump(wts, open(os.path.join(figDir, wtsFile), 'wb'))

# save history
histName = modelName + '_history_pruned.pkl'
pickle.dump(historyDict, open(os.path.join(figDir, histName), 'wb'))

# %%
# numCuts = 0

# %%
def plot_model_history_fromDict(model_history_dictionary, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history_dictionary['mean_squared_error'])+1),
             model_history_dictionary['mean_squared_error'])
    axs.plot(range(1,len(model_history_dictionary['val_mean_squared_error'])+1),
             model_history_dictionary['val_mean_squared_error'])
    axs.set_title('Model MSE = '+ str(format_e(model_history_dictionary['val_mean_squared_error'][-1])) + "\n" +  str(nzwts) + " non-zero weights")
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history_dictionary['val_mean_squared_error'])+1),
                   len(model_history_dictionary['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    plt.yscale('log') #logarithmic scale for y axis
    if saveFig:
        plt.ylim([0.0001, 0.05])
        fig.savefig(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned.png"), dpi = 120, bbox_inches='tight')
    plt.show()



wts = model.get_weights().copy()



# print sizes of each weight matrix
wtLengths = []
for ii in range(len(wts)):
    wtLengths.append(np.prod(wts[ii].shape))

print(np.sum(wtLengths), "total weights")

# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts, "of", np.sum(wtLengths), "weights retained")
    
plot_model_history_fromDict(historyDict, saveFig = True)
# Out:
# 331735 total weights
# 238 of 331735 weights retained

# %%
str(dictLen).zfill(4)
# Out:
# '0659'

# %%
# make video of training
tmpDir = os.path.join(figDir, "tmpImgs")
if not os.path.exists(tmpDir):
    os.mkdir(tmpDir)
fig, axs = plt.subplots(1,1,figsize=(10,5))
#for dictLen in np.arange(1, len(historyDict["mean_squared_error"])):
for dictLen in range(300):

    # save images
    
    # summarize history for accuracy
    axs.plot(range(1,len(historyDict['mean_squared_error'][dictLen-1:dictLen])+1),
             historyDict['mean_squared_error'][dictLen-1:dictLen])
    axs.plot(range(1,len(historyDict['val_mean_squared_error'][dictLen-1:dictLen])+1),
             historyDict['val_mean_squared_error'][dictLen-1:dictLen])
    axs.set_title('Model MSE = '+ str(format_e(historyDict['val_mean_squared_error'][dictLen])))
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
#     axs.set_xticks(np.arange(1,len(historyDict['val_mean_squared_error'][dictLen-1:dictLen])+1),
#                    len(historyDict['val_mean_squared_error'][dictLen-1:dictLen])//10)
    axs.legend(['train', 'val'], loc='lower left')
    plt.yscale('log') #logarithmic scale for y axis

    plt.ylim([0.0001, 0.05])
    fig.savefig(os.path.join(tmpDir, str(dictLen).zfill(4)+ ".png"), dpi = 120,  pad_inches = 0.5)
    #plt.close()
    
    if np.mod(dictLen, 100) == 0:
        print(dictLen)
# Out:
# 0
# 100
# 200

# %%
# make video of training
tmpDir = os.path.join(figDir, "tmpImgs")
if not os.path.exists(tmpDir):
    os.mkdir(tmpDir)
fig, axs = plt.subplots(1,1,figsize=(10,5))
for dictLen in np.arange(1, len(historyDict["mean_squared_error"])):
#for dictLen in np.arange(1, 100):

    # save images
    
    # summarize history for accuracy
    axs.plot([dictLen -1, dictLen],
             historyDict['mean_squared_error'][dictLen-1:dictLen+1], c= "C0")
    axs.plot([dictLen -1, dictLen],
             historyDict['val_mean_squared_error'][dictLen-1:dictLen+1], c= "C1")
    axs.set_title('Model MSE = '+ str(format_e(historyDict['val_mean_squared_error'][dictLen])))
    axs.set_ylabel('mean squared error')
    axs.set_xlabel('Epoch')
#     axs.set_xticks(np.arange(1,len(historyDict['val_mean_squared_error'][dictLen-1:dictLen])+1),
#                    len(historyDict['val_mean_squared_error'][dictLen-1:dictLen])//10)
    axs.legend(['train', 'val'], loc='lower left')
    plt.yscale('log') #logarithmic scale for y axis

    plt.ylim([0.0001, 0.05])
    fig.savefig(os.path.join(tmpDir, str(dictLen).zfill(4)+ ".png"), dpi = 120,  pad_inches = 0.5)
    #plt.close()
    #plt.show()
    
    if np.mod(dictLen, 100) == 0:
        print(dictLen)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100

# %%
# make into video
os.chdir(tmpDir)

os.system('ffmpeg -start_number 0   -r 50 -i %04d.png -vf "scale=trunc(iw/2)*2:trunc(ih/2)*2" -c:v libx264 -b:v 10000k  -pix_fmt yuv420p -y  0000000_output_epochs.mp4')
# Out:
# 0

# %%
Ytest_pred = model.predict(Xtest_scaled)

# %%
# make data frames
# make dataset
X = trainDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

XtestDF = pd.DataFrame(scalerX.inverse_transform(Xtest_scaled), columns = X.columns)
YtestDF = pd.DataFrame(scalerY.inverse_transform(Ytest_scaled), columns = Y.columns)
YpredDF = pd.DataFrame(scalerY.inverse_transform(Ytest_pred), columns = Y.columns+ "_pred")

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

df_c = pd.concat([YtestDF.reset_index(drop=True), YpredDF], axis=1)
df_c.head()
# Out:
#              Fx            Fy           tau    x_dot_99     y_dot_99  phi_dot_99  theta_dot_99       Fx_pred     Fy_pred    tau_pred  x_dot_99_pred  y_dot_99_pred  phi_dot_99_pred  theta_dot_99_pred
# 0 -43383.349096   7777.781558 -89149.114709 -289.067470 -1795.196260  191.024411    184.854298  -5921.947754 -142.510590 -608.956604    -346.210999       0.707733         3.195872           3.144584
# 1 -15183.324785 -33332.606636 -67061.833735 -700.930956   494.674624   29.746681     25.086001 -16267.968750 -222.267426 -933.026611    -742.263062      19.645536         4.854971           4.791619
# 2 -18573.143652  -5798.048395  60110.993478   80.592187 -1353.445823  -79.225996    -74.887624 -12825.869141 -188.314941 -837.683411      41.247684      12.953908         3.900126           3.841244
# 3   3097.636077  13097.481455 -59066.505785  796.970559   633.856580   26.699424     22.407782  -6494.136230 -132.131226 -651.752563     931.437561       0.975322         2.484330           2.433284
# 4  40757.753533   2142.142946  56326.235342    0.179984  1969.065934  232.317284    235.379521   6570.886719  -43.816021 -221.657883     341.851562     -22.285593         1.062806           1.026232

# %%
len(historyDict["mean_squared_error"])
# Out:
# 1767

# %%
df_c = df_c.iloc[0:10000,:]

# %%
# make plots
from sklearn.metrics import r2_score

plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array([30, 10]) / 1.3, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.2, wspace=0.7)
#fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel()

ylabs = [r"g*cm/$s^2$", r"g*cm/$s^2$", r"g*$cm^2$/$s^2$", "cm/s", "cm/s", "rad/s", "rad/s"]

# replace lightest colors with white
import matplotlib.colors

cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(df_c.shape[1] //2):
    try:
        axs[ii].hexbin(y = df_c.iloc[:,ii],x = df_c.iloc[:,ii + 7], gridsize = 50, cmap = cmap)
        #axs[ii].set_xlabel("Predicted Value\n(unscaled)")
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value\n" + ylabs[ii])
        else:
            axs[ii].set_ylabel(ylabs[ii])
        axs[ii].set_title(df_c.columns[ii])
        axs[ii].plot(df_c.iloc[:,ii], df_c.iloc[:,ii], 'grey', linewidth = 1, linestyle  = "--")
        
        # annotate with R^2
        axs[ii].text(np.max(df_c.iloc[:,ii])*0.1, np.min(df_c.iloc[:,ii])*0.9, r'$r^2$ =' + str(np.round((r2_score(df_c.iloc[:,ii ],  df_c.iloc[:,ii+7])), 3)))
        axs[ii].set_xlim([-np.max(np.abs(df_c.iloc[:,ii+7])), np.max(np.abs(df_c.iloc[:,ii+7]))])
    except:
        pass

# # residual plots x = predicted, y = actual - predicted
for jj in range(df_c.shape[1] //2):
    
    ii = jj + 7
    try:
        axs[ii].hexbin(x = df_c.iloc[:,jj],
                     y = df_c.iloc[:,jj ] - df_c.iloc[:,jj+7], gridsize = (35, 50), cmap = cmap)
        axs[ii].set_xlabel("Predicted Value")

        if(jj == 0):
            axs[ii].set_ylabel("Actual - Predicted\n" + ylabs[jj])
        else:
            axs[ii].set_ylabel(ylabs[jj])
        
        axs[ii].hlines(y = 0, xmin = np.min( df_c.iloc[:,jj+7]), 
                       xmax = np.max( df_c.iloc[:,jj+7]), linestyle =  "--", linewidth = 1)
        axs[ii].set_ylim([-np.max(np.abs(df_c.iloc[:,jj ] - df_c.iloc[:,jj+7])), np.max(np.abs(df_c.iloc[:,jj ] - df_c.iloc[:,jj+7]))])
        
    except:
        pass


fig.savefig(os.path.join(figDir, "PredVActual_" + str(len(historyDict["mean_squared_error"])) +  modelName + ".png"), dpi = 500, bbox_inches='tight')
plt.show()

# %%
wts = model.get_weights().copy()

plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
fig.subplots_adjust(hspace = -0.7, wspace=0.1, bottom = -0.1 )
axs = axs.ravel("F")


viridis = cm.get_cmap('PRGn', 256)
newcolors = viridis(np.linspace(0, 1, 256))
white = np.array([0.8, 0.8, 0.8, 1])
newcolors[256//2:256//2+1, :] = white
newcmp = ListedColormap(newcolors)

for jj, ii in enumerate(np.arange(0, len(wts), 1)):
    
    

    
    if len(wts[ii].shape) < 2: 
        wtsTmp = wts[ii].reshape(1,-1).copy()
    else:
        wtsTmp = wts[ii].copy()
    
    im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    



    
    if np.mod(ii+1, 2) == 0:
        axs[jj].axes.get_yaxis().set_visible(False)
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
fig.subplots_adjust(hspace = -0.7, wspace=0.1, bottom = -0.1 )
axs = axs.ravel("F")


viridis = cm.get_cmap('PRGn', 256)
newcolors = viridis(np.linspace(0, 1, 256))
white = np.array([0.8, 0.8, 0.8, 1])
newcolors[256//2, :] = white
newcmp = ListedColormap(newcolors)


for jj, ii in enumerate(np.arange(0, len(wts), 1)):
    
    

    
    if len(wts[ii].shape) < 2: 
        wtsTmp = wts[ii].reshape(1,-1).copy()
    else:
        wtsTmp = wts[ii].copy()
    
    im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    



    
    if np.mod(ii+1, 2) == 0:
        axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 1])
        axs[jj].axes.set_xlim([-1, 413])
        axs[jj].get_xaxis().set_ticks([0, 200, 400])
        
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].tick_params(top = False, labelbottom = True, labeltop = False)
        

    
    if (np.mod(jj, 2) == 0) and (jj != 0):
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])
            
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 413])
        axs[jj].axes.set_xlim([-1, 413])
        #axs[jj].axis('off')
        
        
    if ii == 9:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_xaxis().set_ticks([0])
        axs[jj].axes.set_xlim([-1, 413])
        
    if ii == 0:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        #axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_yaxis().set_ticks([])
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.set_ylim([-1, 32])

    
    #axs[jj].axis('off')

cbaxes = inset_axes(axs[8], width="5%", height="75%", loc= "center") 
cbar = fig.colorbar(im, cax=cbaxes, orientation="vertical", ticks = [-10, -1, 0, 1, 10])    
    
#fig.colorbar(im, orientation="horizontal", pad=0.2)



plt.savefig(os.path.join(figDir, "Pruned_WeightMatrices" + str(len(historyDict["mean_squared_error"]))  + modelName + ".png"), dpi = 500, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ___

# %% [markdown]
# ## Show example small network

# %%
modelParams = {"optimizer": "rmsprop", 
              "dropout_rate" : 0, 
               "numUnits": [20, 20, 16],
               "weightRegularization": 0
              }



model = create_network(**modelParams)

modelName = ''.join('{}_{}__'.format(key[0:3].capitalize(), val) for  key, val in modelParams.items()).replace("[", "").replace("]", "").replace(", ", "_")[0:-2]+ "_" + str(datetime.now())[0:-7].replace("-", "_").replace(" ", "__").replace(":", "_")
print(modelName)

model.summary()
# Out:
# Opt_rmsprop__Dro_0__Num_20_20_16__Wei_0_2019_06_03__10_55_28
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                336
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 1,095
# Trainable params: 1,095
# Non-trainable params: 0
# _________________________________________________________________

# %%
wts = model.get_weights().copy()

plt.close("all")
fig, axs = plt.subplots(2,4, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
fig.subplots_adjust(hspace = -0.4, wspace=0.1, bottom = -0.1 )
axs = axs.ravel("F")


viridis = cm.get_cmap('PRGn', 256)
newcolors = viridis(np.linspace(0, 1, 256))
white = np.array([0.8, 0.8, 0.8, 1])
newcolors[256//2:256//2 + 1, :] = white
newcmp = ListedColormap(newcolors)


for jj, ii in enumerate(np.arange(0, len(wts), 1)):
    
    if len(wts[ii].shape) < 2: 
        wtsTmp = wts[ii].reshape(1,-1).copy()
    else:
        wtsTmp = wts[ii].copy()
    
    im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))

    if np.mod(ii+1, 2) == 0:
        axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 1])
        axs[jj].axes.set_xlim([-1, 21])
        axs[jj].get_xaxis().set_ticks([0, 10])
        
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].tick_params(top = False, labelbottom = True, labeltop = False)
        
    if (np.mod(jj, 2) == 0) and (jj != 0):
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])   
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")
        axs[jj].axes.set_ylim([-1, 21])
        axs[jj].axes.set_xlim([-1, 21])
              
    if ii == 7:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])
        axs[jj].get_xaxis().set_ticks([0])
        axs[jj].axes.set_xlim([-1, 21])
        
    if ii == 0:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


cbaxes = inset_axes(axs[6], width="5%", height="75%", loc= "center") 
cbar = fig.colorbar(im, cax=cbaxes, orientation="vertical", ticks = [-10, -1, 0, 1, 10])    

plt.savefig(os.path.join(figDir, "RondomWTS_small" + modelName + ".png"), dpi = 500, bbox_inches = 'tight', pad_inches = 0)

# %%
# # fit model without regularization
stt = time.time()
history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 10, verbose = 2, 
                        batch_size=2**14, callbacks = [earlystop], validation_split = 0.3)
winsound.PlaySound("*", winsound.SND_ALIAS)
endd = time.time() - stt
print(endd)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 9s - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 2/10
#  - 8s - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 3/10
#  - 9s - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 4/10
#  - 9s - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 5/10
#  - 9s - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 6/10
#  - 9s - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 7/10
#  - 8s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 8/10
#  - 9s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 9/10
#  - 9s - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 10/10
#  - 9s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# 91.79680347442627

# %%
ctr = 0

# %%
for ii in range(100):
    
        # # fit model without regularization
    stt = time.time()
    history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 10, verbose = 2, 
                            batch_size=2**14, callbacks = [earlystop], validation_split = 0.3)
    winsound.PlaySound("*", winsound.SND_ALIAS)
    endd = time.time() - stt
    print(endd)





    wts = model.get_weights().copy()

    # if I need to remake, use this
    # wtsPath = "D:\Dropbox\AcademiaDropbox\CallinStuff\Presentations\eScience_Community_Seminar_2019\Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2019_05_30__11_59_54_wts.pkl"
    # wts =  pickle.load(open(wtsPath, 'rb'))

    plt.close("all")
    fig, axs = plt.subplots(2,4, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
    fig.subplots_adjust(hspace = -0.4, wspace=0.1, bottom = -0.1 )
    axs = axs.ravel("F")


    PRGn = cm.get_cmap('PRGn', 256)
    newcolors = PRGn(np.linspace(0, 1, 256))
    white = np.array([0.8, 0.8, 0.8, 1])
    newcolors[256//2:256//2 + 1, :] = white
    newcmp = ListedColormap(newcolors)



    for jj, ii in enumerate(np.arange(0, len(wts), 1)):




        if len(wts[ii].shape) < 2: 
            wtsTmp = wts[ii].reshape(1,-1).copy()
        else:
            wtsTmp = wts[ii].copy()

        im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                                  vmin=-3.0, vmax=3.0))





        if np.mod(ii+1, 2) == 0:
            axs[jj].axes.get_yaxis().set_visible(False)
            axs[jj].axes.set_ylim([-1, 1])
            axs[jj].axes.set_xlim([-1, 21])
            axs[jj].get_xaxis().set_ticks([0, 10])

            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].tick_params(top = False, labelbottom = True, labeltop = False)



        if (np.mod(jj, 2) == 0) and (jj != 0):
            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].get_xaxis().set_ticks([])
            axs[jj].get_yaxis().set_ticks([])

            axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


            #axs[jj].axes.get_yaxis().set_visible(False)
            axs[jj].axes.set_ylim([-1, 21])
            axs[jj].axes.set_xlim([-1, 21])
            #axs[jj].axis('off')


        if ii == 7:
            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].get_xaxis().set_ticks([])
            axs[jj].get_yaxis().set_ticks([])


            #axs[jj].axes.get_yaxis().set_visible(False)
            axs[jj].get_xaxis().set_ticks([0])
            axs[jj].axes.set_xlim([-1, 21])

        if ii == 0:
            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].get_xaxis().set_ticks([])

            axs[jj].get_yaxis().set_ticks([])
            axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")

    cbaxes = inset_axes(axs[6], width="5%", height="75%", loc= "center") 
    cbar = fig.colorbar(im, cax=cbaxes, orientation="vertical", ticks = [-10, -1, 0, 1, 10])    

    ctr += 1

    plt.savefig(os.path.join(figDir, "TrainedWts_small_"+ str(ctr) + modelName  + ".png"), dpi = 500, bbox_inches = 'tight', pad_inches = 0)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 9s - loss: 5.6565e-04 - mean_squared_error: 5.6565e-04 - val_loss: 5.7843e-04 - val_mean_squared_error: 5.7843e-04
# Epoch 2/10
#  - 9s - loss: 5.6514e-04 - mean_squared_error: 5.6514e-04 - val_loss: 5.3786e-04 - val_mean_squared_error: 5.3786e-04
# Epoch 3/10
#  - 9s - loss: 5.6342e-04 - mean_squared_error: 5.6342e-04 - val_loss: 5.7195e-04 - val_mean_squared_error: 5.7195e-04
# Epoch 4/10
#  - 9s - loss: 5.6306e-04 - mean_squared_error: 5.6306e-04 - val_loss: 6.0176e-04 - val_mean_squared_error: 6.0176e-04
# Epoch 5/10
#  - 8s - loss: 5.6240e-04 - mean_squared_error: 5.6240e-04 - val_loss: 4.8445e-04 - val_mean_squared_error: 4.8445e-04
# Epoch 6/10
#  - 8s - loss: 5.6029e-04 - mean_squared_error: 5.6029e-04 - val_loss: 5.0134e-04 - val_mean_squared_error: 5.0134e-04
# Epoch 7/10
#  - 8s - loss: 5.5894e-04 - mean_squared_error: 5.5894e-04 - val_loss: 5.6401e-04 - val_mean_squared_error: 5.6401e-04
# Epoch 8/10
#  - 9s - loss: 5.5860e-04 - mean_squared_error: 5.5860e-04 - val_loss: 4.8949e-04 - val_mean_squared_error: 4.8949e-04
# Epoch 9/10
#  - 8s - loss: 5.5725e-04 - mean_squared_error: 5.5725e-04 - val_loss: 5.5277e-04 - val_mean_squared_error: 5.5277e-04
# Epoch 10/10
#  - 8s - loss: 5.5653e-04 - mean_squared_error: 5.5653e-04 - val_loss: 5.1877e-04 - val_mean_squared_error: 5.1877e-04
# 87.83022117614746
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 8s - loss: 5.5522e-04 - mean_squared_error: 5.5522e-04 - val_loss: 5.4207e-04 - val_mean_squared_error: 5.4207e-04
# Epoch 2/10
#  - 8s - loss: 5.5391e-04 - mean_squared_error: 5.5391e-04 - val_loss: 6.4142e-04 - val_mean_squared_error: 6.4142e-04
# Epoch 3/10
#  - 8s - loss: 5.5353e-04 - mean_squared_error: 5.5353e-04 - val_loss: 4.5968e-04 - val_mean_squared_error: 4.5968e-04
# Epoch 4/10
#  - 9s - loss: 5.5149e-04 - mean_squared_error: 5.5149e-04 - val_loss: 5.0383e-04 - val_mean_squared_error: 5.0383e-04
# Epoch 5/10
#  - 10s - loss: 5.4936e-04 - mean_squared_error: 5.4936e-04 - val_loss: 5.8159e-04 - val_mean_squared_error: 5.8159e-04
# Epoch 6/10
#  - 10s - loss: 5.5127e-04 - mean_squared_error: 5.5127e-04 - val_loss: 5.2927e-04 - val_mean_squared_error: 5.2927e-04
# Epoch 7/10
#  - 10s - loss: 5.4899e-04 - mean_squared_error: 5.4899e-04 - val_loss: 5.2936e-04 - val_mean_squared_error: 5.2936e-04
# Epoch 8/10
#  - 9s - loss: 5.4695e-04 - mean_squared_error: 5.4695e-04 - val_loss: 6.4573e-04 - val_mean_squared_error: 6.4573e-04
# Epoch 9/10
#  - 9s - loss: 5.4698e-04 - mean_squared_error: 5.4698e-04 - val_loss: 5.3121e-04 - val_mean_squared_error: 5.3121e-04
# Epoch 10/10
#  - 9s - loss: 5.4453e-04 - mean_squared_error: 5.4453e-04 - val_loss: 5.2659e-04 - val_mean_squared_error: 5.2659e-04
# 93.49140357971191
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 9s - loss: 5.4377e-04 - mean_squared_error: 5.4377e-04 - val_loss: 5.5500e-04 - val_mean_squared_error: 5.5500e-04
# Epoch 2/10
#  - 9s - loss: 5.4307e-04 - mean_squared_error: 5.4307e-04 - val_loss: 5.7418e-04 - val_mean_squared_error: 5.7418e-04
# Epoch 3/10
#  - 9s - loss: 5.4241e-04 - mean_squared_error: 5.4241e-04 - val_loss: 5.2288e-04 - val_mean_squared_error: 5.2288e-04
# Epoch 4/10
#  - 9s - loss: 5.4196e-04 - mean_squared_error: 5.4196e-04 - val_loss: 5.3072e-04 - val_mean_squared_error: 5.3072e-04
# Epoch 5/10
#  - 8s - loss: 5.4139e-04 - mean_squared_error: 5.4139e-04 - val_loss: 6.4077e-04 - val_mean_squared_error: 6.4077e-04
# Epoch 6/10
#  - 8s - loss: 5.4024e-04 - mean_squared_error: 5.4024e-04 - val_loss: 6.2135e-04 - val_mean_squared_error: 6.2135e-04
# Epoch 7/10
#  - 8s - loss: 5.3960e-04 - mean_squared_error: 5.3960e-04 - val_loss: 6.2436e-04 - val_mean_squared_error: 6.2436e-04
# Epoch 8/10
#  - 8s - loss: 5.3932e-04 - mean_squared_error: 5.3932e-04 - val_loss: 5.4404e-04 - val_mean_squared_error: 5.4404e-04
# Epoch 9/10
#  - 8s - loss: 5.3725e-04 - mean_squared_error: 5.3725e-04 - val_loss: 5.1860e-04 - val_mean_squared_error: 5.1860e-04
# Epoch 10/10
#  - 8s - loss: 5.3739e-04 - mean_squared_error: 5.3739e-04 - val_loss: 5.3294e-04 - val_mean_squared_error: 5.3294e-04
# 87.71459150314331
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 8s - loss: 5.3431e-04 - mean_squared_error: 5.3431e-04 - val_loss: 5.4308e-04 - val_mean_squared_error: 5.4308e-04
# Epoch 2/10
#  - 8s - loss: 5.3458e-04 - mean_squared_error: 5.3458e-04 - val_loss: 5.7524e-04 - val_mean_squared_error: 5.7524e-04
# Epoch 3/10
#  - 8s - loss: 5.3289e-04 - mean_squared_error: 5.3289e-04 - val_loss: 4.9030e-04 - val_mean_squared_error: 4.9030e-04
# Epoch 4/10
#  - 8s - loss: 5.3269e-04 - mean_squared_error: 5.3269e-04 - val_loss: 5.5823e-04 - val_mean_squared_error: 5.5823e-04
# Epoch 5/10
#  - 8s - loss: 5.3133e-04 - mean_squared_error: 5.3133e-04 - val_loss: 5.7876e-04 - val_mean_squared_error: 5.7876e-04
# Epoch 6/10
#  - 8s - loss: 5.3062e-04 - mean_squared_error: 5.3062e-04 - val_loss: 5.3307e-04 - val_mean_squared_error: 5.3307e-04
# Epoch 7/10
#  - 8s - loss: 5.2968e-04 - mean_squared_error: 5.2968e-04 - val_loss: 5.2938e-04 - val_mean_squared_error: 5.2938e-04
# Epoch 8/10
#  - 8s - loss: 5.2886e-04 - mean_squared_error: 5.2886e-04 - val_loss: 4.9166e-04 - val_mean_squared_error: 4.9166e-04
# Epoch 9/10
#  - 8s - loss: 5.2643e-04 - mean_squared_error: 5.2643e-04 - val_loss: 5.2609e-04 - val_mean_squared_error: 5.2609e-04
# Epoch 10/10
#  - 8s - loss: 5.2697e-04 - mean_squared_error: 5.2697e-04 - val_loss: 5.6458e-04 - val_mean_squared_error: 5.6458e-04
# 84.8707709312439
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 8s - loss: 5.2595e-04 - mean_squared_error: 5.2595e-04 - val_loss: 4.8820e-04 - val_mean_squared_error: 4.8820e-04
# Epoch 2/10
#  - 8s - loss: 5.2456e-04 - mean_squared_error: 5.2456e-04 - val_loss: 5.2056e-04 - val_mean_squared_error: 5.2056e-04
# Epoch 3/10
#  - 8s - loss: 5.2385e-04 - mean_squared_error: 5.2385e-04 - val_loss: 5.5477e-04 - val_mean_squared_error: 5.5477e-04
# Epoch 4/10
#  - 8s - loss: 5.2286e-04 - mean_squared_error: 5.2286e-04 - val_loss: 5.0514e-04 - val_mean_squared_error: 5.0514e-04
# Epoch 5/10
#  - 8s - loss: 5.2234e-04 - mean_squared_error: 5.2234e-04 - val_loss: 5.1140e-04 - val_mean_squared_error: 5.1140e-04
# Epoch 6/10
#  - 8s - loss: 5.2139e-04 - mean_squared_error: 5.2139e-04 - val_loss: 5.0928e-04 - val_mean_squared_error: 5.0928e-04
# Epoch 7/10
#  - 8s - loss: 5.1955e-04 - mean_squared_error: 5.1955e-04 - val_loss: 4.7363e-04 - val_mean_squared_error: 4.7363e-04
# Epoch 8/10
#  - 8s - loss: 5.1878e-04 - mean_squared_error: 5.1878e-04 - val_loss: 5.0282e-04 - val_mean_squared_error: 5.0282e-04
# Epoch 9/10
#  - 8s - loss: 5.1771e-04 - mean_squared_error: 5.1771e-04 - val_loss: 5.8302e-04 - val_mean_squared_error: 5.8302e-04
# Epoch 10/10
#  - 8s - loss: 5.1747e-04 - mean_squared_error: 5.1747e-04 - val_loss: 4.8937e-04 - val_mean_squared_error: 4.8937e-04
# 84.31927871704102
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 8s - loss: 5.1572e-04 - mean_squared_error: 5.1572e-04 - val_loss: 5.2537e-04 - val_mean_squared_error: 5.2537e-04
# Epoch 2/10
#  - 8s - loss: 5.1619e-04 - mean_squared_error: 5.1619e-04 - val_loss: 5.0446e-04 - val_mean_squared_error: 5.0446e-04
# Epoch 3/10
#  - 8s - loss: 5.1500e-04 - mean_squared_error: 5.1500e-04 - val_loss: 5.2687e-04 - val_mean_squared_error: 5.2687e-04
# Epoch 4/10
#  - 8s - loss: 5.1269e-04 - mean_squared_error: 5.1269e-04 - val_loss: 4.5215e-04 - val_mean_squared_error: 4.5215e-04
# Epoch 5/10
#  - 8s - loss: 5.1252e-04 - mean_squared_error: 5.1252e-04 - val_loss: 5.5217e-04 - val_mean_squared_error: 5.5217e-04
# Epoch 6/10
#  - 8s - loss: 5.1207e-04 - mean_squared_error: 5.1207e-04 - val_loss: 5.4547e-04 - val_mean_squared_error: 5.4547e-04
# Epoch 7/10
#  - 8s - loss: 5.1179e-04 - mean_squared_error: 5.1179e-04 - val_loss: 4.4529e-04 - val_mean_squared_error: 4.4529e-04
# Epoch 8/10
#  - 8s - loss: 5.0964e-04 - mean_squared_error: 5.0964e-04 - val_loss: 5.3596e-04 - val_mean_squared_error: 5.3596e-04
# Epoch 9/10
#  - 8s - loss: 5.0934e-04 - mean_squared_error: 5.0934e-04 - val_loss: 4.8198e-04 - val_mean_squared_error: 4.8198e-04
# Epoch 10/10
#  - 8s - loss: 5.0779e-04 - mean_squared_error: 5.0779e-04 - val_loss: 4.9631e-04 - val_mean_squared_error: 4.9631e-04
# 83.45050692558289
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 8s - loss:
#  - 8s - loss: 3.7667e-04 - mean_squared_error: 3.7667e-04 - val_loss: 3.8693e-04 - val_mean_squared_error: 3.8693e-04
# Epoch 5/10
#  - 8s - loss: 3.7610e-04 - mean_squared_error: 3.7610e-04 - val_loss: 3.7675e-04 - val_mean_squared_error: 3.7675e-04
# Epoch 6/10
#  - 8s - loss: 3.7509e-04 - mean_squared_error: 3.7509e-04 - val_loss: 3.6961e-04 - val_mean_squared_error: 3.6961e-04
# Epoch 7/10
#  - 8s - loss: 3.7488e-04 - mean_squared_error: 3.7488e-04 - val_loss: 3.9298e-04 - val_mean_squared_error: 3.9298e-04
# Epoch 8/10
#  - 8s - loss: 3.7510e-04 - mean_squared_error: 3.7510e-04 - val_loss: 3.5692e-04 - val_mean_squared_error: 3.5692e-04
# Epoch 9/10
#  - 9s - loss: 3.7431e-04 - mean_squared_error: 3.7431e-04 - val_loss: 3.5676e-04 - val_mean_squared_error: 3.5676e-04
# Epoch 10/10
#  - 9s - loss: 3.7425e-04 - mean_squared_error: 3.7425e-04 - val_loss: 4.2027e-04 - val_mean_squared_error: 4.2027e-04
# 84.25396585464478
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 8s - loss: 3.7457e-04 - mean_squared_error: 3.7457e-04 - val_loss: 3.3275e-04 - val_mean_squared_error: 3.3275e-04
# Epoch 2/10
#  - 8s - loss: 3.7454e-04 - mean_squared_error: 3.7454e-04 - val_loss: 4.0591e-04 - val_mean_squared_error: 4.0591e-04
# Epoch 3/10
#  - 8s - loss: 3.7249e-04 - mean_squared_error: 3.7249e-04 - val_loss: 4.1860e-04 - val_mean_squared_error: 4.1860e-04
# Epoch 4/10
#  - 8s - loss: 3.7445e-04 - mean_squared_error: 3.7445e-04 - val_loss: 3.7658e-04 - val_mean_squared_error: 3.7658e-04
# Epoch 5/10
#  - 8s - loss: 3.7289e-04 - mean_squared_error: 3.7289e-04 - val_loss: 3.8585e-04 - val_mean_squared_error: 3.8585e-04
# Epoch 6/10
#  - 8s - loss: 3.7243e-04 - mean_squared_error: 3.7243e-04 - val_loss: 4.0647e-04 - val_mean_squared_error: 4.0647e-04
# Epoch 7/10
#  - 8s - loss: 3.7241e-04 - mean_squared_error: 3.7241e-04 - val_loss: 4.0811e-04 - val_mean_squared_error: 4.0811e-04
# Epoch 8/10
#  - 8s - loss: 3.7171e-04 - mean_squared_error: 3.7171e-04 - val_loss: 3.8775e-04 - val_mean_squared_error: 3.8775e-04
# Epoch 9/10
#  - 8s - loss: 3.7071e-04 - mean_squared_error: 3.7071e-04 - val_loss: 3.4540e-04 - val_mean_squared_error: 3.4540e-04
# Epoch 10/10
#  - 8s - loss: 3.7138e-04 - mean_squared_error: 3.7138e-04 - val_loss: 3.8215e-04 - val_mean_squared_error: 3.8215e-04
# 84.80053567886353
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/10
#  - 10s - loss: 3.7158e-04 - mean_squared_error: 3.7158e-04 - val_loss: 3.9122e-04 - val_mean_squared_error: 3.9122e-04
# Epoch 2/10
#  - 10s - loss: 3.7097e-04 - mean_squared_error: 3.7097e-04 - val_loss: 3.6162e-04 - val_mean_squared_error: 3.6162e-04
# Epoch 3/10
#  - 9s - loss: 3.7132e-04 - mean_squared_error: 3.7132e-04 - val_loss: 3.3275e-04 - val_mean_squared_error: 3.3275e-04
# Epoch 4/10
#  - 8s - loss: 3.6989e-04 - mean_squared_error: 3.6989e-04 - val_loss: 3.4898e-04 - val_mean_squared_error: 3.4898e-04
# Epoch 5/10
#  - 8s - loss: 3.6901e-04 - mean_squared_error: 3.6901e-04 - val_loss: 4.1127e-04 - val_mean_squared_error: 4.1127e-04
# Epoch 6/10
#  - 10s - loss: 3.6922e-04 - mean_squared_error: 3.6922e-04 - val_loss: 3.6273e-04 - val_mean_squared_error: 3.6273e-04
# Epoch 7/10
#  - 9s - loss: 3.6873e-04 - mean_squared_error: 3.6873e-04 - val_loss: 3.4849e-04 - val_mean_squared_error: 3.4849e-04
# Epoch 8/10
#  - 9s - loss: 3.6813e-04 - mean_squared_error: 3.6813e-04 - val_loss: 3.8647e-04 - val_mean_squared_error: 3.8647e-04
# Epoch 9/10

# %%
def saveWeightImages(model):
    
     wts = model.get_weights().copy()

    # if I need to remake, use this
    # wtsPath = "D:\Dropbox\AcademiaDropbox\CallinStuff\Presentations\eScience_Community_Seminar_2019\Opt_rmsprop__Dro_0__Num_400_400_400_16__Wei_0_2019_05_30__11_59_54_wts.pkl"
    # wts =  pickle.load(open(wtsPath, 'rb'))

    plt.close("all")
    fig, axs = plt.subplots(2,4, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
    fig.subplots_adjust(hspace = -0.4, wspace=0.1, bottom = -0.1 )
    axs = axs.ravel("F")


    PRGn = cm.get_cmap('PRGn', 256)
    newcolors = PRGn(np.linspace(0, 1, 256))
    white = np.array([0.8, 0.8, 0.8, 1])
    newcolors[256//2:256//2 + 1, :] = white
    newcmp = ListedColormap(newcolors)



    for jj, ii in enumerate(np.arange(0, len(wts), 1)):




        if len(wts[ii].shape) < 2: 
            wtsTmp = wts[ii].reshape(1,-1).copy()
        else:
            wtsTmp = wts[ii].copy()

        im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                                  vmin=-3.0, vmax=3.0))





        if np.mod(ii+1, 2) == 0:
            axs[jj].axes.get_yaxis().set_visible(False)
            axs[jj].axes.set_ylim([-1, 1])
            axs[jj].axes.set_xlim([-1, 21])
            axs[jj].get_xaxis().set_ticks([0, 10])

            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].tick_params(top = False, labelbottom = True, labeltop = False)



        if (np.mod(jj, 2) == 0) and (jj != 0):
            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].get_xaxis().set_ticks([])
            axs[jj].get_yaxis().set_ticks([])

            axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


            #axs[jj].axes.get_yaxis().set_visible(False)
            axs[jj].axes.set_ylim([-1, 21])
            axs[jj].axes.set_xlim([-1, 21])
            #axs[jj].axis('off')


        if ii == 7:
            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].get_xaxis().set_ticks([])
            axs[jj].get_yaxis().set_ticks([])


            #axs[jj].axes.get_yaxis().set_visible(False)
            axs[jj].get_xaxis().set_ticks([0])
            axs[jj].axes.set_xlim([-1, 21])

        if ii == 0:
            axs[jj].spines['top'].set_visible(False)
            axs[jj].spines['right'].set_visible(False)
            axs[jj].spines['bottom'].set_visible(False)
            axs[jj].spines['left'].set_visible(False)
            axs[jj].get_xaxis().set_ticks([])

            axs[jj].get_yaxis().set_ticks([])
            axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")

    cbaxes = inset_axes(axs[6], width="5%", height="75%", loc= "center") 
    cbar = fig.colorbar(im, cax=cbaxes, orientation="vertical", ticks = [-10, -1, 0, 1, 10])    


    plt.savefig(os.path.join(figDir, "TrainedWts_small_"+ str(ctr) + modelName  + ".png"), dpi = 500, bbox_inches = 'tight', pad_inches = 0)

# %%
wts = model.get_weights().copy()
wtLengths = []
for ii in range(len(wts)):
    print(wts[ii].shape)
    wtLengths.append(np.prod(wts[ii].shape))

print(np.sum(wtLengths), "total weights")

numCuts = 1
# Out:
# (10, 20)
# (20,)
# (20, 20)
# (20,)
# (20, 16)
# (16,)
# (16, 7)
# (7,)
# 1095 total weights

# %%
# refref: 
# train until I have very good results
# then prune, and retrain until results are close
# change pruning rate as data get closer to 100% removed
def prune_percent_updater(x):
    logit = np.exp(x*8) / (np.exp(x*8) + 1)
    return((logit - 0.5)*2*50)


# cuts a smaller portion as the percent gets closer to 100%
cutPercent = prune_percent_updater(np.linspace(0, 1, 26))

while True:   
   
    for numEpocs in range(100):
        
        MSE_tmp = []

        history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                            verbose = 2, batch_size=2**14, epochs = 1, 
                            callbacks = [earlystop])
        
        # refref: earlystop doesn't do anything here
        
        # save history
        historyDict["mean_squared_error"].append(history.history["mean_squared_error"][0])
        historyDict["val_mean_squared_error"].append(history.history["val_mean_squared_error"][0])
        
        # local MSE
        MSE_tmp.append(history.history["mean_squared_error"][0])

        # set weights that are close to 0 all the way back to 0, and then retrain for one epoch
        # get nonzero weights
        wts = model.get_weights().copy()

        # set weights close to 0 to 0 (but ignore biases)
        for ii in np.arange(0, len(wts), 1):
            qants = np.percentile(np.reshape(wts[ii], -1), q = (50 - cutPercent[numCuts], 50 + cutPercent[numCuts]), )
            wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0

        # print nonzero weights
        # calculate number of nonzero weights
        nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
        print(nzwts, "of", np.sum(wtLengths), "weights retained")

        # set new weights and calculate new loss
        model.set_weights(wts)
        
        # check the change in mean squared error, and if it's not changing much, then cut out more data
        # calculate slope of loss, based on previous 5 data points
        if numEpocs > 5:
            inputData = historyDict["mean_squared_error"][-5:]

            m = np.shape(inputData)
            X = np.matrix([np.ones(m), np.arange(0, len(inputData))]).T
            y = np.matrix(np.log(inputData)).T

            # Solve for projection matrix
            intercept, slope = np.array(np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)).reshape(-1,)
            print("change in log loss:", slope)
    
            # break if slope has stopped changing or if the overall min has been surpassed
            # in the first training, it will automatically prune after 5 epochs, because the min will be passed
            if (np.abs(slope) < 0.0001) or (history.history["mean_squared_error"][0] < np.min(historyDict["mean_squared_error"][:-1])): 
                print("************************************************ PRUNING ********************************************************")
                print("************************************************ PRUNING ********************************************************")
                print("************************************************ PRUNING ********************************************************")
                model.save(os.path.join(figDir,  modelName + str(datetime.now())[0:-7].replace("-", "_").replace(" ", "__").replace(":", "_") + '_Pruned.h5'))
                break
                       
                    
    ## refref: may want to save weights before each pruning, so I can go back, if I need to
    ## refref: should I be pruning the biases too?
    
    ## keep running tally of min mse, and if we can't get back to the min, then break
#     print("Min MSE for this prune ", np.min(MSE_tmp), "______overall Min MSE ", np.min(historyDict["mean_squared_error"]))
#     if np.min(MSE_tmp) > np.min(historyDict["mean_squared_error"]):
#         print("no more gain by pruning:  STOPPING Pruning")
#         break
    
    numCuts += 1
    if numCuts >= len(cutPercent):
        break

        
        #cutPercent += 0.2
winsound.PlaySound("*", winsound.SND_ALIAS)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.8171e-04 - mean_squared_error: 4.8171e-04 - val_loss: 4.9801e-04 - val_mean_squared_error: 4.9801e-04
# 612 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.8309e-04 - mean_squared_error: 4.8309e-04 - val_loss: 5.1036e-04 - val_mean_squared_error: 5.1036e-04
# 612 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.8126e-04 - mean_squared_error: 4.8126e-04 - val_loss: 5.0515e-04 - val_mean_squared_error: 5.0515e-04
# 612 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.8070e-04 - mean_squared_error: 4.8070e-04 - val_loss: 4.5811e-04 - val_mean_squared_error: 4.5811e-04
# 612 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.8020e-04 - mean_squared_error: 4.8020e-04 - val_loss: 4.4934e-04 - val_mean_squared_error: 4.4934e-04
# 612 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.8034e-04 - mean_squared_error: 4.8034e-04 - val_loss: 4.9473e-04 - val_mean_squared_error: 4.9473e-04
# 612 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7970e-04 - mean_squared_error: 4.7970e-04 - val_loss: 4.7484e-04 - val_mean_squared_error: 4.7484e-04
# 612 of 1095 weights retained
# change in log loss: -0.0007236086017483601
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7964e-04 - mean_squared_error: 4.7964e-04 - val_loss: 5.2717e-04 - val_mean_squared_error: 5.2717e-04
# 612 of 1095 weights retained
# change in log loss: -0.0005456251764399678
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7643e-04 - mean_squared_error: 4.7643e-04 - val_loss: 4.6064e-04 - val_mean_squared_error: 4.6064e-04
# 612 of 1095 weights retained
# change in log loss: -0.0017226132682044426
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7640e-04 - mean_squared_error: 4.7640e-04 - val_loss: 4.9592e-04 - val_mean_squared_error: 4.9592e-04
# 612 of 1095 weights retained
# change in log loss: -0.002327153464093401
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7531e-04 - mean_squared_error: 4.7531e-04 - val_loss: 4.2957e-04 - val_mean_squared_error: 4.2957e-04
# 612 of 1095 weights retained
# change in log loss: -0.002514510434584949
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7478e-04 - mean_squared_error: 4.7478e-04 - val_loss: 4.8089e-04 - val_mean_squared_error: 4.8089e-04
# 612 of 1095 weights retained
# change in log loss: -0.0022730861907260813
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7359e-04 - mean_squared_error: 4.7359e-04 - val_loss: 4.9938e-04 - val_mean_squared_error: 4.9938e-04
# 612 of 1095 weights retained
# change in log loss: -0.0015363431904120706
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7600e-04 - mean_squared_error: 4.7600e-04 - val_loss: 5.3328e-04 - val_mean_squared_error: 5.3328e-04
# 612 of 1095 weights retained
# change in log loss: -0.0005323716350866814
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7472e-04 - mean_squared_error: 4.7472e-04 - val_loss: 5.3599e-04 - val_mean_squared_error: 5.3599e-04
# 612 of 1095 weights retained
# change in log loss: 6.290059337388243e-06
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 4.7394e-04 - mean_squared_error: 4.7394e-04 - val_loss: 4.6921e-04 - val_mean_squared_error: 4.6921e-04
# 484 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 7.9606e-04 - val_mean_squared_error: 7.9606e-04
# 484 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 5.3341e-04 - val_mean_squared_error: 5.3341e-04
# 484 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 6.9503e-04 - val_mean_squared_error: 6.9503e-04
# 484 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.2471e-04 - val_mean_squared_error: 6.2471e-04
# 484 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 9.5898e-04 - mean_squared_error: 9.5898e-04 - val_loss: 6.0529e-04 - val_mean_squared_error: 6.0529e-04
# 484 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 8.4431e-04 - mean_squared_error: 8.4431e-04 - val_loss: 5.9288e-04 - val_mean_squared_error: 5.9288e-04
# 484 of 1095 weights retained
# change in log loss: -0.22598578535164116
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 7.7283e-04 - mean_squared_error: 7.7283e-04 - val_loss: 5.8048e-04 - val_mean_squared_error: 5.8048e-04
# 484 of 1095 weights retained
# change in log loss: -0.15791019923304095
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 7.1714e-04 - mean_squared_error: 7.1714e-04 - val_loss: 6.1376e-04 - val_mean_squared_error: 6.1376e-04
# 484 of 1095 weights retained
# change in log loss: -0.11451129420092676
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 6.8249e-04 - mean_squared_error: 6.8249e-04 - val_loss: 5.4208e-04 - val_mean_squared_error: 5.4208e-04
# 484 of 1095 weights retained
# change in log loss: -0.08434894191053677
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 6.3580e-04 - mean_squared_error: 6.3580e-04 - val_loss: 5.6237e-04 - val_mean_squared_error: 5.6237e-04
# 484 of 1095 weights retained
# change in log loss: -0.06915855463745757
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 6.1704e-04 - mean_squared_error: 6.1704e-04 - val_loss: 5.4378e-04 - val_mean_squared_error: 5.4378e-04
# 484 of 1095 weights retained
# change in log loss: -0.057063411919231255
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 6.0089e-04 - mean_squared_error: 6.0089e-04 - val_loss: 5.5805e-04 - val_mean_squared_error: 5.5805e-04
# 484 of 1095 weights retained
# change in log loss: -0.04545264506440305
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.8994e-04 - mean_squared_error: 5.8994e-04 - val_loss: 5.5651e-04 - val_mean_squared_error: 5.5651e-04
# 484 of 1095 weights retained
# change in log loss: -0.03479184665093227
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.8106e-04 - mean_squared_error: 5.8106e-04 - val_loss: 5.7694e-04 - val_mean_squared_error: 5.7694e-04
# 484 of 1095 weights retained
# change in log loss: -0.022496578404026524
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.7525e-04 - mean_squared_error: 5.7525e-04 - val_loss: 5.4532e-04 - val_mean_squared_error: 5.4532e-04
# 484 of 1095 weights retained
# change in log loss: -0.017383033337250664
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.6757e-04 - mean_squared_error: 5.6757e-04 - val_loss: 5.1308e-04 - val_mean_squared_error: 5.1308e-04
# 484 of 1095 weights retained
# change in log loss: -0.013931620199175931
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.5907e-04 - mean_squared_error: 5.5907e-04 - val_loss: 4.6449e-04 - val_mean_squared_error: 4.6449e-04
# 484 of 1095 weights retained
# change in log loss: -0.013098916471517619
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.5521e-04 - mean_squared_error: 5.5521e-04 - val_loss: 5.0230e-04 - val_mean_squared_error: 5.0230e-04
# 484 of 1095 weights retained
# change in log loss: -0.011956338772864505
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.4976e-04 - mean_squared_error: 5.4976e-04 - val_loss: 5.2225e-04 - val_mean_squared_error: 5.2225e-04
# 484 of 1095 weights retained
# change in log loss: -0.011266129841099648
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5
of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 9.0603e-04 - mean_squared_error: 9.0603e-04 - val_loss: 5.6455e-04 - val_mean_squared_error: 5.6455e-04
# 376 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 8.3407e-04 - mean_squared_error: 8.3407e-04 - val_loss: 4.6566e-04 - val_mean_squared_error: 4.6566e-04
# 376 of 1095 weights retained
# change in log loss: -0.17986330488455415
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 7.9636e-04 - mean_squared_error: 7.9636e-04 - val_loss: 5.3142e-04 - val_mean_squared_error: 5.3142e-04
# 376 of 1095 weights retained
# change in log loss: -0.10747241620636205
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 7.6584e-04 - mean_squared_error: 7.6584e-04 - val_loss: 4.9984e-04 - val_mean_squared_error: 4.9984e-04
# 376 of 1095 weights retained
# change in log loss: -0.06970043079652766
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 7.4172e-04 - mean_squared_error: 7.4172e-04 - val_loss: 5.2376e-04 - val_mean_squared_error: 5.2376e-04
# 376 of 1095 weights retained
# change in log loss: -0.048555175941701556
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 7.2976e-04 - mean_squared_error: 7.2976e-04 - val_loss: 4.9176e-04 - val_mean_squared_error: 4.9176e-04
# 376 of 1095 weights retained
# change in log loss: -0.03382647715838494
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 7.1696e-04 - mean_squared_error: 7.1696e-04 - val_loss: 5.5784e-04 - val_mean_squared_error: 5.5784e-04
# 376 of 1095 weights retained
# change in log loss: -0.025830945825038976
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 7.0700e-04 - mean_squared_error: 7.0700e-04 - val_loss: 5.8956e-04 - val_mean_squared_error: 5.8956e-04
# 376 of 1095 weights retained
# change in log loss: -0.019385229043014318
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 6.9760e-04 - mean_squared_error: 6.9760e-04 - val_loss: 6.3760e-04 - val_mean_squared_error: 6.3760e-04
# 376 of 1095 weights retained
# change in log loss: -0.015436234081380507
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.9012e-04 - mean_squared_error: 6.9012e-04 - val_loss: 5.4263e-04 - val_mean_squared_error: 5.4263e-04
# 376 of 1095 weights retained
# change in log loss: -0.013909140365486294
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 6.8287e-04 - mean_squared_error: 6.8287e-04 - val_loss: 4.4375e-04 - val_mean_squared_error: 4.4375e-04
# 376 of 1095 weights retained
# change in log loss: -0.012158682796495013
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.7850e-04 - mean_squared_error: 6.7850e-04 - val_loss: 5.0323e-04 - val_mean_squared_error: 5.0323e-04
# 376 of 1095 weights retained
# change in log loss: -0.010360728846495748
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.7116e-04 - mean_squared_error: 6.7116e-04 - val_loss: 5.0519e-04 - val_mean_squared_error: 5.0519e-04
# 376 of 1095 weights retained
# change in log loss: -0.009423968404819183
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.6529e-04 - mean_squared_error: 6.6529e-04 - val_loss: 5.1947e-04 - val_mean_squared_error: 5.1947e-04
# 376 of 1095 weights retained
# change in log loss: -0.009058209978394682
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.6153e-04 - mean_squared_error: 6.6153e-04 - val_loss: 4.8081e-04 - val_mean_squared_error: 4.8081e-04
# 376 of 1095 weights retained
# change in log loss: -0.008315962837274649
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.5576e-04 - mean_squared_error: 6.5576e-04 - val_loss: 5.1336e-04 - val_mean_squared_error: 5.1336e-04
# 376 of 1095 weights retained
# change in log loss: -0.008263345486732243
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.5035e-04 - mean_squared_error: 6.5035e-04 - val_loss: 5.4187e-04 - val_mean_squared_error: 5.4187e-04
# 376 of 1095 weights retained
# change in log loss: -0.007742785732382407
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.4722e-04 - mean_squared_error: 6.4722e-04 - val_loss: 4.9333e-04 - val_mean_squared_error: 4.9333e-04
# 376 of 1095 weights retained
# change in log loss: -0.007213541233140663
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.4361e-04 - mean_squared_error: 6.4361e-04 - val_loss: 5.5128e-04 - val_mean_squared_error: 5.5128e-04
# 376 of 1095 weights retained
# change in log loss: -0.006803260168110725
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.3711e-04 - mean_squared_error: 6.3711e-04 - val_loss: 6.4402e-04 - val_mean_squared_error: 6.4402e-04
# 376 of 1095 weights retained
# change in log loss: -0.0068130772089569636
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.3714e-04 - mean_squared_error: 6.3714e-04 - val_loss: 5.0490e-04 - val_mean_squared_error: 5.0490e-04
# 376 of 1095 weights retained
# change in log loss: -0.005676878710784372
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.3307e-04 - mean_squared_error: 6.3307e-04 - val_loss: 5.2373e-04 - val_mean_squared_error: 5.2373e-04
# 376 of 1095 weights retained
# change in log loss: -0.005429413165778385
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.3187e-04 - mean_squared_error: 6.3187e-04 - val_loss: 4.9999e-04 - val_mean_squared_error: 4.9999e-04
# 376 of 1095 weights retained
# change in log loss: -0.004318670097008814
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.2760e-04 - mean_squared_error: 6.2760e-04 - val_loss: 5.0600e-04 - val_mean_squared_error: 5.0600e-04
# 376 of 1095 weights retained
# change in log loss: -0.0038378746402967234
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.2162e-04 - mean_squared_error: 6.2162e-04 - val_loss: 5.6563e-04 - val_mean_squared_error: 5.6563e-04
# 376 of 1095 weights retained
# change in log loss: -0.005801144854649554
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.2110e-04 - mean_squared_error: 6.2110e-04 - val_loss: 4.6948e-04 - val_mean_squared_error: 4.6948e-04
# 376 of 1095 weights retained
# change in log loss: -0.005453224371601673
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.1805e-04 - mean_squared_error: 6.1805e-04 - val_loss: 5.2220e-04 - val_mean_squared_error: 5.2220e-04
# 376 of 1095 weights retained
# change in log loss: -0.005463178111610567
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.1341e-04 - mean_squared_error: 6.1341e-04 - val_loss: 4.7668e-04 - val_mean_squared_error: 4.7668e-04
# 376 of 1095 weights retained
# change in log loss: -0.005150462316002358
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.1291e-04 - mean_squared_error: 6.1291e-04 - val_loss: 4.8646e-04 - val_mean_squared_error: 4.8646e-04
# 376 of 1095 weights retained
# change in log loss: -0.004068237243378459
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.1197e-04 - mean_squared_error: 6.1197e-04 - val_loss: 4.7456e-04 - val_mean_squared_error: 4.7456e-04
# 376 of 1095 weights retained
# change in log loss: -0.0037973745610953014
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.0495e-04 - mean_squared_error: 6.0495e-04 - val_loss: 5.0427e-04 - val_mean_squared_error: 5.0427e-04
# 376 of 1095 weights retained
# change in log loss: -0.004521240116535985
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 6.0463e-04 - mean_squared_error: 6.0463e-04 - val_loss: 4.9076e-04 - val_mean_squared_error: 4.9076e-04
# 376 of 1095 weights retained
# change in log loss: -0.004191504062920126
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 6.0229e-04 - mean_squared_error: 6.0229e-04 - val_loss: 5.2448e-04 - val_mean_squared_error: 5.2448e-04
# 376 of 1095 weights retained
# change in log loss: -0.004703398898864952
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.9960e-04 - mean_squared_error: 5.9960e-04 - val_loss: 5.9392e-04 - val_mean_squared_error: 5.9392e-04
# 376 of 1095 weights retained
# change in log loss: -0.004524347777387749
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.9665e-04 - mean_squared_error: 5.9665e-04 - val_loss: 3.9747e-04 - val_mean_squared_error: 3.9747e-04
# 376 of 1095 weights retained
# change in log loss: -0.0035978538962717632
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.9636e-04 - mean_squared_error: 5.9636e-04 - val_loss: 5.1785e-04 - val_mean_squared_error: 5.1785e-04
# 376 of 1095 weights retained
# change in log loss: -0.0036958496289349885
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.9430e-04 - mean_squared_error: 5.9430e-04 - val_loss: 4.7384e-04 - val_mean_squared_error: 4.7384e-04
# 376 of 1095 weights retained
# change in log loss: -0.0032130607702736125
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 10s - loss: 5.9041e-04 - mean_squared_error: 5.9041e-04 - val_loss: 4.7174e-04 - val_mean_squared_error: 4.7174e-04
# 376 of 1095 weights retained
# change in log loss: -0.0034818903894804354
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.9000e-04 - mean_squared_error: 5.9000e-04 - val_loss: 5.6294e-04 - val_mean_squared_error: 5.6294e-04
# 376 of 1095 weights retained
# change in log loss: -0.003241151233982942
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.8701e-04 - mean_squared_error: 5.8701e-04 - val_loss: 4.4836e-04 - val_mean_squared_error: 4.4836e-04
# 376 of 1095 weights retained
# change in log loss: -0.0038853119550166237
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.8759e-04 - mean_squared_error: 5.8759e-04 - val_loss: 4.9839e-04 - val_mean_squared_error: 4.9839e-04
# 376 of 1095 weights retained
# change in log loss: -0.002848463626784925
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.8384e-04 - mean_squared_error: 5.8384e-04 - val_loss: 4.8334e-04 - val_mean_squared_error: 4.8334e-04
# 376 of 1095 weights retained
# change in log loss: -0.00264993521068857
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.8223e-04 - mean_squared_error: 5.8223e-04 - val_loss: 4.2424e-04 - val_mean_squared_error: 4.2424e-04
# 376 of 1095 weights retained
# change in log loss: -0.0031933098048850805
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 5.8136e-04 - mean_squared_error: 5.8136e-04 - val_loss: 4.9097e-04 - val_mean_squared_error: 4.9097e-04
# 376 of 1095 weights retained
# change in log loss: -0.002848286986288917
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.7924e-04 - mean_squared_error: 5.7924e-04 - val_loss: 4.4128e-04 - val_mean_squared_error: 4.4128e-04
# 376 of 1095 weights retained
# change in log loss: -0.003288807037551411
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.7813e-04 - mean_squared_error: 5.7813e-04 - val_loss: 5.1058e-04 - val_mean_squared_error: 5.1058e-04
# 376 of 1095 weights retained
# change in log loss: -0.0024813222014361536
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.7587e-04 - mean_squared_error: 5.7587e-04 - val_loss: 4.6209e-04 - val_mean_squared_error: 4.6209e-04
# 376 of 1095 weights retained
# change in log loss: -0.002756121514129184
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.7391e-04 - mean_squared_error: 5.7391e-04 - val_loss: 5.1838e-04 - val_mean_squared_error: 5.1838e-04
# 376 of 1095 weights retained
# change in log loss: -0.003162310995229456
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.7249e-04 - mean_squared_error: 5.7249e-04 - val_loss: 4.5362e-04 - val_mean_squared_error: 4.5362e-04
# 376 of 1095 weights retained
# change in log loss: -0.0030751756260358754
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.7167e-04 - mean_squared_error: 5.7167e-04 - val_loss: 4.8201e-04 - val_mean_squared_error: 4.8201e-04
# 376 of 1095 weights retained
# change in log loss: -0.0028359976547498444
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.6867e-04 - mean_squared_error: 5.6867e-04 - val_loss: 4.2344e-04 - val_mean_squared_error: 4.2344e-04
# 376 of 1095 weights retained
# change in log loss: -0.0029092602017395386
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.6918e-04 - mean_squared_error: 5.6918e-04 - val_loss: 4.5673e-04 - val_mean_squared_error: 4.5673e-04
# 376 of 1095 weights retained
# change in log loss: -0.002326817126071079
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.6541e-04 - mean_squared_error: 5.6541e-04 - val_loss: 4.8637e-04 - val_mean_squared_error: 4.8637e-04
# 376 of 1095 weights retained
# change in log loss: -0.002924131669347352
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.6506e-04 - mean_squared_error: 5.6506e-04 - val_loss: 4.3884e-04 - val_mean_squared_error: 4.3884e-04
# 376 of 1095 weights retained
# change in log loss: -0.002901760430492617
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.6191e-04 - mean_squared_error: 5.6191e-04 - val_loss: 5.1034e-04 - val_mean_squared_error: 5.1034e-04
# 376 of 1095 weights retained
# change in log loss: -0.003116260182630226
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.6308e-04 - mean_squared_error: 5.6308e-04 - val_loss: 4.5773e-04 - val_mean_squared_error: 4.5773e-04
# 376 of 1095 weights retained
# change in log loss: -0.0027761584161214437
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.6198e-04 - mean_squared_error: 5.6198e-04 - val_loss: 5.7593e-04 - val_mean_squared_error: 5.7593e-04
# 376 of 1095 weights retained
# change in log loss: -0.0015698931064793697
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5896e-04 - mean_squared_error: 5.5896e-04 - val_loss: 6.4517e-04 - val_mean_squared_error: 6.4517e-04
# 376 of 1095 weights retained
# change in log loss: -0.002158642889271478
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5851e-04 - mean_squared_error: 5.5851e-04 - val_loss: 4.4009e-04 - val_mean_squared_error: 4.4009e-04
# 376 of 1095 weights retained
# change in log loss: -0.0019512131358578877
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5709e-04 - mean_squared_error: 5.5709e-04 - val_loss: 4.0322e-04 - val_mean_squared_error: 4.0322e-04
# 376 of 1095 weights retained
# change in log loss: -0.0027584055505125438
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5407e-04 - mean_squared_error: 5.5407e-04 - val_loss: 5.7237e-04 - val_mean_squared_error: 5.7237e-04
# 376 of 1095 weights retained
# change in log loss: -0.0031674898349343117
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5397e-04 - mean_squared_error: 5.5397e-04 - val_loss: 4.0819e-04 - val_mean_squared_error: 4.0819e-04
# 376 of 1095 weights retained
# change in log loss: -0.002589006664089233
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5352e-04 - mean_squared_error: 5.5352e-04 - val_loss: 4.4255e-04 - val_mean_squared_error: 4.4255e-04
# 376 of 1095 weights retained
# change in log loss: -0.002354188246451283
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5158e-04 - mean_squared_error: 5.5158e-04 - val_loss: 5.3715e-04 - val_mean_squared_error: 5.3715e-04
# 376 of 1095 weights retained
# change in log loss: -0.0020880901009683317
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5067e-04 - mean_squared_error: 5.5067e-04 - val_loss: 4.9099e-04 - val_mean_squared_error: 4.9099e-04
# 376 of 1095 weights retained
# change in log loss: -0.0016656909309489265
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.5073e-04 - mean_squared_error: 5.5073e-04 - val_loss: 4.1634e-04 - val_mean_squared_error: 4.1634e-04
# 376 of 1095 weights retained
# change in log loss: -0.001691819778300685
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.4661e-04 - mean_squared_error: 5.4661e-04 - val_loss: 5.0681e-04 - val_mean_squared_error: 5.0681e-04
# 376 of 1095 weights retained
# change in log loss: -0.0026673806036880965
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.4379e-04 - mean_squared_error: 5.4379e-04 - val_loss: 4.5105e-04 - val_mean_squared_error: 4.5105e-04
# 376 of 1095 weights retained
# change in log loss: -0.003584154199653744
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.4379e-04 - mean_squared_error: 5.4379e-04 - val_loss: 4.5971e-04 - val_mean_squared_error: 4.5971e-04
# 376 of 1095 weights retained
# change in log loss: -0.0037808068709102027
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.4339e-04 - mean_squared_error: 5.4339e-04 - val_loss: 5.2344e-04 - val_mean_squared_error: 5.2344e-04
# 376 of 1095 weights retained
# change in log loss: -0.003200323094989299
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 5.4160e-04 - mean_squared_error: 5.4160e-04 - val_loss: 4.6657e-04 - val_mean_squared_error: 4.6657e-04
# 376 of 1095 weights retained
# change in log loss: -0.001916128724032573
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
# ...
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 18 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 19 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 20 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 19 of 1095 weights retained
# change in log loss: 7.405591133879952e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 19 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 18 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 19 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 18 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 19 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 18 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 19 of 1095 weights retained
# change in log loss: 9.984546702879182e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 9s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 14 of 1095 weights retained
# change in log loss: -4.5343480703397e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# change in log loss: -3.808300438890022e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# change in log loss: 7.701578008867394e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# change in log loss: 7.133945027537614e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# change in log loss: -0.0002521747681686337
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# change in log loss: 2.0795740018120235e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 13 of 1095 weights retained
# change in log loss: 0.0002893072893055404
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# change in log loss: 0.00021452893075313284
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# change in log loss: 0.00014348470572866923
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# change in log loss: -5.757099783343378e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 13 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 14 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 8s - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0331 - val_mean_squared_error: 0.0331
# 15 of 1095 weights retained
# change in log loss: -2.1058063818024664e-05
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************
# ************************************************ PRUNING ********************************************************

# %%
plt.close("all")
fig, axs = plt.subplots(2,4, figsize=np.array([30, 10])/2, facecolor='w', edgecolor='k', sharex = "none", sharey = "none")
fig.subplots_adjust(hspace = -0.4, wspace=0.1, bottom = -0.1 )
axs = axs.ravel("F")


viridis = cm.get_cmap('viridis', 256)
newcolors = viridis(np.linspace(0, 1, 256))
white = np.array([0.8, 0.8, 0.8, 1])
newcolors[256//2:256//2 + 1, :] = white
newcmp = ListedColormap(newcolors)


for jj, ii in enumerate(np.arange(0, len(wts), 1)):
    
    

    
    if len(wts[ii].shape) < 2: 
        wtsTmp = wts[ii].reshape(1,-1).copy()
    else:
        wtsTmp = wts[ii].copy()
    
    im = axs[jj].matshow(wtsTmp, cmap = newcmp, norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    



    
    if np.mod(ii+1, 2) == 0:
        axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 1])
        axs[jj].axes.set_xlim([-1, 21])
        axs[jj].get_xaxis().set_ticks([0, 10])
        
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].tick_params(top = False, labelbottom = True, labeltop = False)
        

    
    if (np.mod(jj, 2) == 0) and (jj != 0):
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])
            
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].axes.set_ylim([-1, 21])
        axs[jj].axes.set_xlim([-1, 21])
        #axs[jj].axis('off')
        
        
    if ii == 7:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_xaxis().set_ticks([0])
        axs[jj].axes.set_xlim([-1, 21])
        
    if ii == 0:
        axs[jj].spines['top'].set_visible(False)
        axs[jj].spines['right'].set_visible(False)
        axs[jj].spines['bottom'].set_visible(False)
        axs[jj].spines['left'].set_visible(False)
        axs[jj].get_xaxis().set_ticks([])
        #axs[jj].get_yaxis().set_ticks([])


        #axs[jj].axes.get_yaxis().set_visible(False)
        axs[jj].get_yaxis().set_ticks([])
        axs[jj].set_title(str(wtsTmp.shape[0]) + "x" + str(wtsTmp.shape[1]) + " matrix", loc = "left")


        #axs[jj].axes.set_ylim([-1, 32])

    
    #axs[jj].axis('off')

cbaxes = inset_axes(axs[6], width="5%", height="75%", loc= "center") 
cbar = fig.colorbar(im, cax=cbaxes, orientation="vertical", ticks = [-10, -1, 0, 1, 10])    
    
#fig.colorbar(im, orientation="horizontal", pad=0.2)



plt.savefig(os.path.join(figDir, "PrunedWts_small" + modelName + ".png"), dpi = 500, bbox_inches = 'tight', pad_inches = 0)

# %%
# how good can I get without trimming

# %%
# plot matrices

wts = model.get_weights().copy()
for ii in np.arange(0, len(wts), 2):
    plt.matshow(wts[ii], cmap = "PRGn", norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    plt.colorbar()
    plt.show()

# %%
# plot biases

for ii in np.arange(1, len(wts), 2):
    plt.matshow(wts[ii].reshape(1, -1), cmap = "PRGn", norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    plt.colorbar()
    plt.show()

# %%
# refref: save weights and model
model.save(os.path.join(savedModels,  modelName + '_pruned_bias.h5'))

# save weights
wts = model.get_weights().copy()

wtsFile = modelName + '_pruned_wts_bias.pkl'
pickle.dump(wts, open(os.path.join(dataOutput, wtsFile), 'wb'))

# %%
plt.close("all")
fig, axs = plt.subplots(1,5, figsize=(20, 5), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.2)


axs = axs.ravel()

for jj, ii in enumerate(np.arange(0, len(wts), 2)):
    im = axs[jj].matshow(wts[ii], cmap = "PRGn", norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    
    
plt.colorbar(im,ax=axs[jj], orientation = "vertical")
plt.show()

# %%
plt.close("all")
fig, axs = plt.subplots(5,1, figsize=(30, 10), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)


axs = axs.ravel()

for jj, ii in enumerate(np.arange(1, len(wts), 2)):
    im = axs[jj].matshow(wts[ii].reshape(1, -1), cmap = "PRGn", norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    axs[jj].axes.get_yaxis().set_visible(False)

plt.colorbar(im,ax=axs[jj], orientation = "horizontal")
plt.show()

# %%
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=(30, 10), facecolor='w', edgecolor='k', )
fig.subplots_adjust(hspace = 0.1, wspace=0.1)


axs = axs.ravel("F")

for jj, ii in enumerate(np.arange(0, len(wts), 1)):
    
    
    
    if len(wts[ii].shape) < 2: 
        wtsTmp = wts[ii].reshape(1,-1).copy()
    else:
        wtsTmp = wts[ii].copy()
    
    im = axs[jj].matshow(wtsTmp, cmap = "PRGn", norm=colors.SymLogNorm(linthresh=0.01, linscale=0.01,
                                              vmin=-3.0, vmax=3.0))
    if np.mod(ii+1, 2) == 0:
        axs[jj].axes.get_yaxis().set_visible(False)

plt.colorbar(im,ax=axs[jj], orientation = "horizontal")
plt.savefig(os.path.join(figDir, "PrunedWeightMatrices.png"))
plt.show()

# %%
os.path.join(dataOutput, wtsFile)

# %%
# refref: if whole node is basically 0, then remove the node.

# %%
np.std(wts[2].reshape(-1,))

# %%
model = create_network(**modelParams)

history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                        verbose = 2, batch_size=2**14, epochs = 1, 
                        callbacks = [earlystop])

# %%
# check to see if model saved: 
K.clear_session()
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model_400Units_newData.h5'))

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
len(wts[4])

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((20,3)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 100)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 100)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
len(model.get_weights())

# %%
model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (5, 95), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

# %%
ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %% [raw]
# K.clear_session()

# %% [raw]
# # this is the original model
# inputs = Input(shape=(Xtrain_scaled.shape[1],))
# x = Dense(400, activation='tanh')(inputs)
# x = Dense(400, activation='tanh')(x)
# x = Dense(400, activation='tanh')(x)
# x = Dense(16, activation='tanh')(x)
# predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)
#
# # create model
# model = Model(inputs=inputs, outputs=predictions)
# model.compile(loss="mse", optimizer="adam", metrics = ['mse'])
#
# earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=50,
#                           verbose=1, mode='auto', min_delta = 0.001)

# %%
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)

# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (2, 98), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)
model.set_weights(wts)


# start training
history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                    verbose = 2, batch_size=2**14, epochs = 1, 
                    callbacks = [earlystop])

# %%
wts = model.get_weights().copy()

# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (2.5, 97.5), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0

# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)
model.set_weights(wts)

model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining.png"), dpi = 120, bbox_inches='tight')
    plt.show()
    
plot_model_history(history)
print(history.history["loss"][-1])

# %%
# load model that was trained for much longer
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model.h5'))

# %%
model.summary()

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
wts = model.get_weights().copy()
nzwts = [np.nonzero(wts[ii].reshape(-1))[0] for ii in range(len(wts))]

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((20,5)) , facecolor='w', edgecolor='k')
#fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(nzwts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(nzwts[jj].shape))
    axs[jj+1].hist(nzwts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(nzwts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((10,10)) , facecolor='w', edgecolor='k')
#fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
#fig.savefig(os.path.join(figDir, "SmallModelResids.png"), dpi = 120, bbox_inches='tight')

# %%
# trim distribution of weights -- cut out middle 20%
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# show new histogram of weights (excluding the 0's)
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    
    d1 = wts[jj].reshape(-1)
    axs[jj].hist(d1[d1!=0], bins = 30, facecolor = '#d6bddb' )
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))

    d2 = wts[jj+1]
    axs[jj+1].hist(d2[d2!=0], bins = 30, facecolor = '#d6bddb')
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# the validation.split is the last X% of the data
int(0.3*Xtrain_scaled.shape[0])
ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()

# %%
# create dict of hyperparameters


# regularization, num layers, num nodes, learning rate, optimizer, activation function, batch size

from scipy.stats import randint
from scipy.stats import uniform

# Create hyperparameter space
NumHiddenLayers = randint(low = 2, high = 20)#[4, 2, 8]
numUnits  = [2**4, 2**5, 2**6, 2**7, 2**8, 2**9, 2**10]
epochs = [200]
batches1 = [2**12, 2**10, 2**8, 2**14] 
optimizers = ['rmsprop', 'adam']
dropout_rate =  uniform(loc = 0, scale = 0.5) #[0.0, 0.2, 0.5]
weightRegularization = uniform(loc = 0, scale = 0.001) #[0, 0.0001, 0.001, 0.01]
secondToLastUnits = [8, 16, 32, 64]

# Create hyperparameter options
hyperparameters = dict(optimizer=optimizers, 
                        epochs=epochs, 
                        batch_size=batches1,
                        dropout_rate = dropout_rate, 
                        numUnits = numUnits, 
                        NumHiddenLayers = NumHiddenLayers, 
                        weightRegularization = weightRegularization, 
                        secondToLastUnits = secondToLastUnits)

# %%
# refref: 
# train until I have very good results
# then prune, and retrain until results are close
# change pruning rate as data get closer to 100% removed
cutPercent = 49.7
for numCuts in range(3):
    for numEpocs in range(100):

        history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                            verbose = 2, batch_size=2**14, epochs = 1, 
                            callbacks = [earlystop])
        # save history
        historyDict["mean_squared_error"].append(history.history["mean_squared_error"][0])
        historyDict["val_mean_squared_error"].append(history.history["val_mean_squared_error"][0])

        # set weights that are close to 0 all the way back to 0, and then retrain for one epoch
        # get nonzero weights
        wts = model.get_weights().copy()

        # set weights close to 0 to 0 (but ignore biases)
        for ii in np.arange(0, len(wts), 2):
            qants = np.percentile(np.reshape(wts[ii], -1), q = (50 - cutPercent, 50 + cutPercent), )
            wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0

        # print nonzero weights
        # calculate number of nonzero weights
        nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
        print(nzwts, "of", np.sum(wtLengths), "weights retained")

        # set new weights and calculate new loss
        model.set_weights(wts)
        #cutPercent += 0.2
winsound.PlaySound("*", winsound.SND_ALIAS)
