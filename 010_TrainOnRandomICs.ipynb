# %% [markdown]
# # Callin Switzer
# ### 12 Dec 2018
# ___
# ### - Train Dense, Feedforward Neural Network with Keras
# ### - Use data that was generated in Python

# %% [markdown]
# ___

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.ticker import ScalarFormatter
import os
import pandas as pd
import time
from datetime import datetime
import sys
import seaborn as sns
import scipy.io
import subprocess
import winsound
import pickle
import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
print("TensorFlow successfully installed.")
if tf.test.is_built_with_cuda():
    print("The installed version of TensorFlow includes GPU support.")
print(sys.version, "\n")
now = datetime.now()
print("last run on " + str(now))

# define directories
baseDir = os.getcwd()
dataDir = r'D:\MothSimulations\11c-AggressiveManeuver\Qstore\hws_am_con'
figDir = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\Figs'
dataOutput = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput'
savedModels = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels'
randomRawData = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\PythonGeneratedData\TrainingData'
if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
if not os.path.exists(savedModels):
    os.mkdir(savedModels)
# Out:
# C:\Users\calli\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2019-04-05 08:35:39.666933

# %% [markdown]
# # Make training and test set

# %% [raw]
# # concatenate all files (only need to do this once)
# # it takes a few minutes
# all_files = glob.glob(os.path.join(randomRawData, "*.csv"))
# df_from_each_file = (pd.read_csv(f) for f in all_files)
# concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)
#
# # check for duplicates
# concatenated_df.drop_duplicates(inplace=True)
# concatenated_df.shape
#
# print(concatenated_df.shape)
# concatenated_df.tail()
#
# # save to hdf5
# concatenated_df.to_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
# read in data
trainDF = pd.read_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
print(trainDF.shape)
trainDF.head()
# Out:
# (9900510, 19)
#     x0         xf          xd0          xdf   y0         yf         yd0  \
# 0  0.0  23.367432  1240.975696  1047.460389  0.0  -2.222497 -321.289498
# 1  0.0 -20.768748 -1149.257088 -1075.409015  0.0  11.106142  365.093207
# 2  0.0 -25.280989 -1496.313673 -1133.713595  0.0   4.318522  244.869357
# 3  0.0  -5.931729  -560.948725   -26.956023  0.0   0.748787   86.858301
# 4  0.0  -9.280447  -214.455052  -539.671502  0.0   6.707153  225.808462
#
#           ydf    theta0    thetaf    thetad0     thetadf      phi0      phif  \
# 0  -38.377027  4.539917  6.334514   5.761704  166.050842  2.909070  4.628560
# 1  697.828947  3.243816  4.921125  16.957561  146.364185  3.308109  4.891662
# 2  748.985152  5.436117 -0.270820   7.760703 -563.122968  5.548527 -0.137526
# 3   45.961219  4.004344  4.826500  -0.067853   72.504068  0.510978  1.423037
# 4  488.013492  6.129205  4.399997 -16.195650 -177.812751  1.609007 -0.231868
#
#        phid0       phidf             F     alpha          tau0
# 0  10.607821  162.092739  29718.210402  3.057406  53852.149654
# 1  22.615302  141.667777  28169.483755  3.504285  66579.923810
# 2   0.328348 -561.725041  42042.954099  1.460073 -13638.356558
# 3  24.197259   77.007517  32817.596791  1.943183 -59677.690610
# 4   9.118306 -183.140660  35120.738164  3.267484  77836.665059

# %%
# rename columns to be consistent with other code
trainDF.rename(columns={"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "xf" : "x_99", "yf" : "y_99", "phif" : "phi_99", "thetaf" : "theta_99", 
                        "xd0" : "x_dot_0", "yd0" : "y_dot_0", "phid0" : "phi_dot_0", "thetad0": "theta_dot_0", 
                        "xdf" : "x_dot_99", "ydf": "y_dot_99", "phidf": "phi_dot_99", "thetadf": "theta_dot_99", 
                        "tau0" : "tau"}, inplace=True)

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

# %%
# make dataset
X = trainDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

# %%
X.head()
# Out:
#       phi_0   theta_0       x_99       y_99    phi_99  theta_99      x_dot_0  \
# 0  2.909070  4.539917  23.367432  -2.222497  4.628560  6.334514  1240.975696
# 1  3.308109  3.243816 -20.768748  11.106142  4.891662  4.921125 -1149.257088
# 2  5.548527  5.436117 -25.280989   4.318522 -0.137526 -0.270820 -1496.313673
# 3  0.510978  4.004344  -5.931729   0.748787  1.423037  4.826500  -560.948725
# 4  1.609007  6.129205  -9.280447   6.707153 -0.231868  4.399997  -214.455052
#
#       y_dot_0  phi_dot_0  theta_dot_0
# 0 -321.289498  10.607821     5.761704
# 1  365.093207  22.615302    16.957561
# 2  244.869357   0.328348     7.760703
# 3   86.858301  24.197259    -0.067853
# 4  225.808462   9.118306   -16.195650

# %%
Y.head()
# Out:
#              Fx            Fy           tau     x_dot_99    y_dot_99  \
# 0 -29612.961122   2498.912376  53852.149654  1047.460389  -38.377027
# 1 -26336.915345  -9994.333651  66579.923810 -1075.409015  697.828947
# 2   4645.636361  41785.500502 -13638.356558 -1133.713595  748.985152
# 3 -11940.326951  30568.337400 -59677.690610   -26.956023   45.961219
# 4 -34842.795622  -4409.744037  77836.665059  -539.671502  488.013492
#
#    phi_dot_99  theta_dot_99
# 0  162.092739    166.050842
# 1  141.667777    146.364185
# 2 -561.725041   -563.122968
# 3   77.007517     72.504068
# 4 -183.140660   -177.812751

# %%
# test train split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state = 123)

# %% [raw]
# # scale data
# scalerX = StandardScaler()
# scalerY = StandardScaler()
#
# # Don't cheat - fit only on training data
# scalerX.fit(Xtrain)
# scalerY.fit(Ytrain)
#
# Xtrain_scaled = scalerX.transform(Xtrain)
# Ytrain_scaled = scalerY.transform(Ytrain)
#
# # apply same transformation to test data
# Xtest_scaled = scalerX.transform(Xtest)
# Ytest_scaled = scalerY.transform(Ytest)

# %%
# scale data 
scalerX = MinMaxScaler([-0.5, 0.5])  
scalerY = MinMaxScaler([-0.5, 0.5])  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xtest_scaled = scalerX.transform(Xtest)
Ytest_scaled = scalerY.transform(Ytest)

# %%
pd.DataFrame(Xtrain_scaled, columns = X.columns).head()
# Out:
#       phi_0   theta_0      x_99      y_99    phi_99  theta_99   x_dot_0  \
# 0 -0.479611  0.002266 -0.318639 -0.229442 -0.094704  0.071486 -0.491811
# 1 -0.453551  0.264615  0.295886  0.197180 -0.188053  0.054898  0.469097
# 2 -0.102133 -0.139825  0.314624  0.345313 -0.234415 -0.252743  0.486725
# 3 -0.025410  0.473391 -0.026110  0.073530  0.050494  0.209861 -0.032577
# 4  0.492691 -0.269698 -0.131405  0.348033  0.118454 -0.135028 -0.191459
#
#     y_dot_0  phi_dot_0  theta_dot_0
# 0 -0.220474   0.168732     0.450440
# 1  0.195148   0.353807    -0.446865
# 2  0.399421   0.036643    -0.265189
# 3 -0.026313  -0.037384    -0.004011
# 4  0.408163  -0.416592    -0.057925

# %%
# save scalers, to be used on test set
scalerfileX = 'scalerX.pkl'
pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

scalerfileY = 'scalerY.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %% [markdown]
# # Keras models

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
K.clear_session()

# %%
# create network
def create_network(optimizer = 'rmsprop', dropout_rate=0.1, 
                  numUnits = 400, 
                  NumHiddenLayers = 3, 
                  weightRegularization = 0.0, 
                  secondToLastUnits = 16):
    K.clear_session()
    
    inputs = Input(shape=(Xtrain_scaled.shape[1],))
    x = Dense(numUnits, activation='tanh')(inputs)
    x = Dropout(dropout_rate)(x)
    
    for ii in np.arange(1, NumHiddenLayers + 1):
        x = Dense(numUnits, activation='tanh', 
                  kernel_regularizer=regularizers.l1(weightRegularization))(x)
        x = Dropout(dropout_rate)(x)
    
    x = Dense(secondToLastUnits, activation='tanh')(x)
    predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

    # create model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(loss="mean_squared_error", optimizer = optimizer, metrics = ['mse'])

    return(model)

# %% [raw]
# # create dict of hyperparameters
#
#
# # regularization, num layers, num nodes, learning rate, optimizer, activation function, batch size
#
# from scipy.stats import randint
# from scipy.stats import uniform
#
# # Create hyperparameter space
# NumHiddenLayers = randint(low = 2, high = 20)#[4, 2, 8]
# numUnits  = [2**4, 2**5, 2**6, 2**7, 2**8, 2**9, 2**10]
# epochs = [200]
# batches1 = [2**12, 2**10, 2**8, 2**14]
# optimizers = ['rmsprop', 'adam']
# dropout_rate =  uniform(loc = 0, scale = 0.5) #[0.0, 0.2, 0.5]
# weightRegularization = uniform(loc = 0, scale = 0.001) #[0, 0.0001, 0.001, 0.01]
# secondToLastUnits = [8, 16, 32, 64]
#
# # Create hyperparameter options
# hyperparameters = dict(optimizer=optimizers,
#                         epochs=epochs,
#                         batch_size=batches1,
#                         dropout_rate = dropout_rate,
#                         numUnits = numUnits,
#                         NumHiddenLayers = NumHiddenLayers,
#                         weightRegularization = weightRegularization,
#                         secondToLastUnits = secondToLastUnits)

# %%
Xtrain_scaled_small = Xtrain_scaled[0:8000, :]
Ytrain_scaled_small = Ytrain_scaled[0:8000, :]

# %%
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=20, 
                          verbose=1, mode='auto', min_delta = 0.0001)

model = KerasRegressor(build_fn=create_network, verbose=0)
fit_params = dict(callbacks=[earlystop])

# %%
K.clear_session()

# %% [raw]
# model = create_network(optimizer = bestParams["optimizer"],
#                         dropout_rate=bestParams["dropout_rate"],
#                         numUnits = bestParams["numUnits"],
#                         NumHiddenLayers = bestParams["NumHiddenLayers"],
#                         weightRegularization = bestParams["weightRegularization"],
#                         secondToLastUnits = bestParams['secondToLastUnits'],
#                         batch_size = bestParams['batch_size'])

# %% [markdown]
# model = create_network(optimizer = "rmsprop",
#                         dropout_rate=0.0,
#                         numUnits = 512,
#                         NumHiddenLayers = 1,
#                         weightRegularization = 0,
#                         secondToLastUnits = 32)

# %%
model = create_network(optimizer = "rmsprop", 
                        dropout_rate=0.0, 
                        numUnits = 800, 
                        NumHiddenLayers = 2, 
                        weightRegularization = 0, 
                        secondToLastUnits = 16)

# %% [raw]
# K.clear_session()
# from keras.models import load_model
# model = load_model(os.path.join(savedModels, 'my_model_400Units.h5'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 800)               8800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 800)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 800)               640800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 800)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 800)               640800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 800)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                12816
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 1,303,335
# Trainable params: 1,303,335
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.get_config()
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=150, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
stt = time.time()
history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 1500, verbose = 2, 
                        batch_size =2**14, callbacks = [earlystop], validation_split = 0.3)
# history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 1500, verbose = 2, 
#                         batch_size =512, callbacks = [earlystop], validation_split = 0.3)
# Probably play Windows default sound, if any is registered (because
# "*" probably isn't the registered name of any sound).
winsound.PlaySound("*", winsound.SND_ALIAS)
endd = time.time() - stt
print(endd)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1500
#  - 11s - loss: 3.9558e-04 - mean_squared_error: 3.9558e-04 - val_loss: 3.6349e-04 - val_mean_squared_error: 3.6349e-04
# Epoch 2/1500
#  - 11s - loss: 4.0153e-04 - mean_squared_error: 4.0153e-04 - val_loss: 3.7015e-04 - val_mean_squared_error: 3.7015e-04
# Epoch 3/1500
#  - 11s - loss: 3.8231e-04 - mean_squared_error: 3.8231e-04 - val_loss: 3.5434e-04 - val_mean_squared_error: 3.5434e-04
# Epoch 4/1500
#  - 11s - loss: 4.0487e-04 - mean_squared_error: 4.0487e-04 - val_loss: 4.2409e-04 - val_mean_squared_error: 4.2409e-04
# Epoch 5/1500
#  - 11s - loss: 3.8941e-04 - mean_squared_error: 3.8941e-04 - val_loss: 2.7875e-04 - val_mean_squared_error: 2.7875e-04
# Epoch 6/1500
#  - 11s - loss: 3.8104e-04 - mean_squared_error: 3.8104e-04 - val_loss: 3.1539e-04 - val_mean_squared_error: 3.1539e-04
# Epoch 7/1500
#  - 11s - loss: 3.8143e-04 - mean_squared_error: 3.8143e-04 - val_loss: 3.6104e-04 - val_mean_squared_error: 3.6104e-04
# Epoch 8/1500
#  - 11s - loss: 3.8279e-04 - mean_squared_error: 3.8279e-04 - val_loss: 2.7818e-04 - val_mean_squared_error: 2.7818e-04
# Epoch 9/1500
#  - 11s - loss: 3.8410e-04 - mean_squared_error: 3.8410e-04 - val_loss: 2.0024e-04 - val_mean_squared_error: 2.0024e-04
# Epoch 10/1500
#  - 11s - loss: 3.8518e-04 - mean_squared_error: 3.8518e-04 - val_loss: 4.0458e-04 - val_mean_squared_error: 4.0458e-04
# Epoch 11/1500
#  - 11s - loss: 3.8021e-04 - mean_squared_error: 3.8021e-04 - val_loss: 3.4955e-04 - val_mean_squared_error: 3.4955e-04
# Epoch 12/1500
#  - 11s - loss: 3.7930e-04 - mean_squared_error: 3.7930e-04 - val_loss: 3.5115e-04 - val_mean_squared_error: 3.5115e-04
# Epoch 13/1500
#  - 11s - loss: 4.0421e-04 - mean_squared_error: 4.0421e-04 - val_loss: 2.2183e-04 - val_mean_squared_error: 2.2183e-04
# Epoch 14/1500
#  - 11s - loss: 3.9931e-04 - mean_squared_error: 3.9931e-04 - val_loss: 3.8620e-04 - val_mean_squared_error: 3.8620e-04
# Epoch 15/1500
#  - 11s - loss: 3.8049e-04 - mean_squared_error: 3.8049e-04 - val_loss: 3.0963e-04 - val_mean_squared_error: 3.0963e-04
# Epoch 16/1500
#  - 11s - loss: 3.9659e-04 - mean_squared_error: 3.9659e-04 - val_loss: 3.9428e-04 - val_mean_squared_error: 3.9428e-04
# Epoch 17/1500
#  - 11s - loss: 3.9879e-04 - mean_squared_error: 3.9879e-04 - val_loss: 2.5129e-04 - val_mean_squared_error: 2.5129e-04
# Epoch 18/1500
#  - 11s - loss: 4.0021e-04 - mean_squared_error: 4.0021e-04 - val_loss: 2.9845e-04 - val_mean_squared_error: 2.9845e-04
# Epoch 19/1500
#  - 11s - loss: 3.9654e-04 - mean_squared_error: 3.9654e-04 - val_loss: 2.9456e-04 - val_mean_squared_error: 2.9456e-04
# Epoch 20/1500
#  - 11s - loss: 3.8418e-04 - mean_squared_error: 3.8418e-04 - val_loss: 3.6296e-04 - val_mean_squared_error: 3.6296e-04
# Epoch 21/1500
#  - 11s - loss: 3.8382e-04 - mean_squared_error: 3.8382e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 22/1500
#  - 11s - loss: 3.7968e-04 - mean_squared_error: 3.7968e-04 - val_loss: 2.5536e-04 - val_mean_squared_error: 2.5536e-04
# Epoch 23/1500
#  - 12s - loss: 3.8612e-04 - mean_squared_error: 3.8612e-04 - val_loss: 2.8485e-04 - val_mean_squared_error: 2.8485e-04
# Epoch 24/1500
#  - 11s - loss: 3.8689e-04 - mean_squared_error: 3.8689e-04 - val_loss: 3.9399e-04 - val_mean_squared_error: 3.9399e-04
# Epoch 25/1500
#  - 11s - loss: 3.8094e-04 - mean_squared_error: 3.8094e-04 - val_loss: 3.5803e-04 - val_mean_squared_error: 3.5803e-04
# Epoch 26/1500
#  - 11s - loss: 3.8307e-04 - mean_squared_error: 3.8307e-04 - val_loss: 7.6081e-04 - val_mean_squared_error: 7.6081e-04
# Epoch 27/1500
#  - 11s - loss: 3.8298e-04 - mean_squared_error: 3.8298e-04 - val_loss: 2.1942e-04 - val_mean_squared_error: 2.1942e-04
# Epoch 28/1500
#  - 11s - loss: 3.8648e-04 - mean_squared_error: 3.8648e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 29/1500
#  - 11s - loss: 3.8967e-04 - mean_squared_error: 3.8967e-04 - val_loss: 3.3243e-04 - val_mean_squared_error: 3.3243e-04
# Epoch 30/1500
#  - 11s - loss: 3.7662e-04 - mean_squared_error: 3.7662e-04 - val_loss: 2.6670e-04 - val_mean_squared_error: 2.6670e-04
# Epoch 31/1500
#  - 11s - loss: 3.9351e-04 - mean_squared_error: 3.9351e-04 - val_loss: 4.1779e-04 - val_mean_squared_error: 4.1779e-04
# Epoch 32/1500
#  - 11s - loss: 3.8987e-04 - mean_squared_error: 3.8987e-04 - val_loss: 2.8663e-04 - val_mean_squared_error: 2.8663e-04
# Epoch 33/1500
#  - 11s - loss: 3.8610e-04 - mean_squared_error: 3.8610e-04 - val_loss: 3.5871e-04 - val_mean_squared_error: 3.5871e-04
# Epoch 34/1500
#  - 11s - loss: 3.9847e-04 - mean_squared_error: 3.9847e-04 - val_loss: 3.1209e-04 - val_mean_squared_error: 3.1209e-04
# Epoch 35/1500
#  - 11s - loss: 3.8299e-04 - mean_squared_error: 3.8299e-04 - val_loss: 3.3822e-04 - val_mean_squared_error: 3.3822e-04
# Epoch 36/1500
#  - 11s - loss: 3.7322e-04 - mean_squared_error: 3.7322e-04 - val_loss: 5.1128e-04 - val_mean_squared_error: 5.1128e-04
# Epoch 37/1500
#  - 11s - loss: 3.7948e-04 - mean_squared_error: 3.7948e-04 - val_loss: 3.7454e-04 - val_mean_squared_error: 3.7454e-04
# Epoch 38/1500
#  - 11s - loss: 3.9444e-04 - mean_squared_error: 3.9444e-04 - val_loss: 2.8826e-04 - val_mean_squared_error: 2.8826e-04
# Epoch 39/1500
#  - 11s - loss: 3.8446e-04 - mean_squared_error: 3.8446e-04 - val_loss: 3.0593e-04 - val_mean_squared_error: 3.0593e-04
# Epoch 40/1500
#  - 11s - loss: 3.8579e-04 - mean_squared_error: 3.8579e-04 - val_loss: 3.6413e-04 - val_mean_squared_error: 3.6413e-04
# Epoch 41/1500
#  - 11s - loss: 3.8871e-04 - mean_squared_error: 3.8871e-04 - val_loss: 4.4214e-04 - val_mean_squared_error: 4.4214e-04
# Epoch 42/1500
#  - 11s - loss: 3.7446e-04 - mean_squared_error: 3.7446e-04 - val_loss: 2.6848e-04 - val_mean_squared_error: 2.6848e-04
# Epoch 43/1500
#  - 11s - loss: 4.0357e-04 - mean_squared_error: 4.0357e-04 - val_loss: 3.0053e-04 - val_mean_squared_error: 3.0053e-04
# Epoch 44/1500
#  - 11s - loss: 3.7422e-04 - mean_squared_error: 3.7422e-04 - val_loss: 4.6653e-04 - val_mean_squared_error: 4.6653e-04
# Epoch 45/1500
#  - 11s - loss: 4.0542e-04 - mean_squared_error: 4.0542e-04 - val_loss: 3.6897e-04 - val_mean_squared_error: 3.6897e-04
# Epoch 46/1500
#  - 11s - loss: 3.9160e-04 - mean_squared_error: 3.9160e-04 - val_loss: 5.2519e-04 - val_mean_squared_error: 5.2519e-04
# Epoch 47/1500
#  - 11s - loss: 3.8417e-04 - mean_squared_error: 3.8417e-04 - val_loss: 3.6047e-04 - val_mean_squared_error: 3.6047e-04
# Epoch 48/1500
#  - 11s - loss: 3.6954e-04 - mean_squared_error: 3.6954e-04 - val_loss: 4.5421e-04 - val_mean_squared_error: 4.5421e-04
# Epoch 49/1500
#  - 11s - loss: 3.8937e-04 - mean_squared_error: 3.8937e-04 - val_loss: 3.4840e-04 - val_mean_squared_error: 3.4840e-04
# Epoch 50/1500
#  - 11s - loss: 3.9238e-04 - mean_squared_error: 3.9238e-04 - val_loss: 2.3953e-04 - val_mean_squared_error: 2.3953e-04
# Epoch 51/1500
#  - 11s - loss: 3.8087e-04 - mean_squared_error: 3.8087e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 52/1500
#  - 11s - loss: 3.7787e-04 - mean_squared_error: 3.7787e-04 - val_loss: 2.5233e-04 - val_mean_squared_error: 2.5233e-04
# Epoch 53/1500
#  - 11s - loss: 3.7305e-04 - mean_squared_error: 3.7305e-04 - val_loss: 2.6189e-04 - val_mean_squared_error: 2.6189e-04
# Epoch 54/1500
#  - 11s - loss: 4.0158e-04 - mean_squared_error: 4.0158e-04 - val_loss: 3.0038e-04 - val_mean_squared_error: 3.0038e-04
# Epoch 55/1500
#  - 11s - loss: 3.7301e-04 - mean_squared_error: 3.7301e-04 - val_loss: 2.1141e-04 - val_mean_squared_error: 2.1141e-04
# Epoch 56/1500
#  - 11s - loss: 3.7650e-04 - mean_squared_error: 3.7650e-04 - val_loss: 3.5183e-04 - val_mean_squared_error: 3.5183e-04
# Epoch 57/1500
#  - 11s - loss: 3.9700e-04 - mean_squared_error: 3.9700e-04 - val_loss: 2.1397e-04 - val_mean_squared_error: 2.1397e-04
# Epoch 58/1500
#  - 11s - loss: 3.6731e-04 - mean_squared_error: 3.6731e-04 - val_loss: 3.2294e-04 - val_mean_squared_error: 3.2294e-04
# Epoch 59/1500
#  - 11s - loss: 3.8140e-04 - mean_squared_error: 3.8140e-04 - val_loss: 3.1155e-04 - val_mean_squared_error: 3.1155e-04
# Epoch 60/1500
#  - 11s - loss: 3.9473e-04 - mean_squared_error: 3.9473e-04 - val_loss: 3.4858e-04 - val_mean_squared_error: 3.4858e-04
# Epoch 61/1500
#  - 11s - loss: 3.8672e-04 - mean_squared_error: 3.8672e-04 - val_loss: 1.6704e-04 - val_mean_squared_error: 1.6704e-04
# Epoch 62/1500
#  - 11s - loss: 3.7848e-04 - mean_squared_error: 3.7848e-04 - val_loss: 3.5345e-04 - val_mean_squared_error: 3.5345e-04
# Epoch 63/1500
#  - 11s - loss: 3.7926e-04 - mean_squared_error: 3.7926e-04 - val_loss: 2.0480e-04 - val_mean_squared_error: 2.0480e-04
# Epoch 64/1500
#  - 11s - loss: 3.6909e-04 - mean_squared_error: 3.6909e-04 - val_loss: 2.6340e-04 - val_mean_squared_error: 2.6340e-04
# Epoch 65/1500
#  - 11s - loss: 3.9982e-04 - mean_squared_error: 3.9982e-04 - val_loss: 4.1839e-04 - val_mean_squared_error: 4.1839e-04
# Epoch 66/1500
#  - 11s - loss: 3.8459e-04 - mean_squared_error: 3.8459e-04 - val_loss: 3.2842e-04 - val_mean_squared_error: 3.2842e-04
# Epoch 67/1500
#  - 11s - loss: 3.7941e-04 - mean_squared_error: 3.7941e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 68/1500
#  - 11s - loss: 3.7531e-04 - mean_squared_error: 3.7531e-04 - val_loss: 3.1926e-04 - val_mean_squared_error: 3.1926e-04
# Epoch 69/1500
#  - 11s - loss: 3.8262e-04 - mean_squared_error: 3.8262e-04 - val_loss: 3.7510e-04 - val_mean_squared_error: 3.7510e-04
# Epoch 70/1500
#  - 11s - loss: 3.7697e-04 - mean_squared_error: 3.7697e-04 - val_loss: 2.3002e-04 - val_mean_squared_error: 2.3002e-04
# Epoch 71/1500
#  - 11s - loss: 3.6674e-04 - mean_squared_error: 3.6674e-04 - val_loss: 3.4499e-04 - val_mean_squared_error: 3.4499e-04
# Epoch 72/1500
#  - 11s - loss: 3.8406e-04 - mean_squared_error: 3.8406e-04 - val_loss: 2.1029e-04 - val_mean_squared_error: 2.1029e-04
# Epoch 73/1500
#  - 11s - loss: 3.8677e-04 - mean_squared_error: 3.8677e-04 - val_loss: 1.9561e-04 - val_mean_squared_error: 1.9561e-04
# Epoch 74/1500
#  - 11s - loss: 3.6995e-04 - mean_squared_error: 3.6995e-04 - val_loss: 3.7110e-04 - val_mean_squared_error: 3.7110e-04
# Epoch 75/1500
#  - 11s - loss: 3.7016e-04 - mean_squared_error: 3.7016e-04 - val_loss: 3.0686e-04 - val_mean_squared_error: 3.0686e-04
# Epoch 76/1500
#  - 11s - loss: 3.8076e-04 - mean_squared_error: 3.8076e-04 - val_loss: 3.4214e-04 - val_mean_squared_error: 3.4214e-04
# Epoch 77/1500
#  - 11s - loss: 3.6568e-04 - mean_squared_error: 3.6568e-04 - val_loss: 2.3540e-04 - val_mean_squared_error: 2.3540e-04
# Epoch 78/1500
#  - 11s - loss: 3.7065e-04 - mean_squared_error: 3.7065e-04 - val_loss: 8.5033e-04 - val_mean_squared_error: 8.5033e-04
# Epoch 79/1500
#  - 11s - loss: 3.7970e-04 - mean_squared_error: 3.7970e-04 - val_loss: 2.4238e-04 - val_mean_squared_error: 2.4238e-04
# Epoch 80/1500
#  - 11s - loss: 3.6736e-04 - mean_squared_error: 3.6736e-04 - val_loss: 2.1344e-04 - val_mean_squared_error: 2.1344e-04
# Epoch 81/1500
#  - 11s - loss: 3.7547e-04 - mean_squared_error: 3.7547e-04 - val_loss: 2.8451e-04 - val_mean_squared_error: 2.8451e-04
# Epoch 82/1500
#  - 11s - loss: 3.8129e-04 - mean_squared_error: 3.8129e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 83/1500
#  - 11s - loss: 3.7794e-04 - mean_squared_error: 3.7794e-04 - val_loss: 4.7267e-04 - val_mean_squared_error: 4.7267e-04
# Epoch 84/1500
#  - 11s - loss: 3.7288e-04 - mean_squared_error: 3.7288e-04 - val_loss: 1.8860e-04 - val_mean_squared_error: 1.8860e-04
# Epoch 85/1500
#  - 11s - loss: 3.6782e-04 - mean_squared_error: 3.6782e-04 - val_loss: 2.7415e-04 - val_mean_squared_error: 2.7415e-04
# Epoch 86/1500
#  - 11s - loss: 3.7052e-04 - mean_squared_error: 3.7052e-04 - val_loss: 4.0188e-04 - val_mean_squared_error: 4.0188e-04
# Epoch 87/1500
#  - 11s - loss: 3.6644e-04 - mean_squared_error: 3.6644e-04 - val_loss: 3.2791e-04 - val_mean_squared_error: 3.2791e-04
# Epoch 88/1500
#  - 11s - loss: 3.6825e-04 - mean_squared_error: 3.6825e-04 - val_loss: 7.7264e-04 - val_mean_squared_error: 7.7264e-04
# Epoch 89/1500
#  - 11s - loss: 3.7954e-04 - mean_squared_error: 3.7954e-04 - val_loss: 2.9038e-04 - val_mean_squared_error: 2.9038e-04
# Epoch 90/1500
#  - 11s - loss: 3.6444e-04 - mean_squared_error: 3.6444e-04 - val_loss: 4.2370e-04 - val_mean_squared_error: 4.2370e-04
# Epoch 91/1500
#  - 11s - loss: 3.6559e-04 - mean_squared_error: 3.6559e-04 - val_loss: 2.4793e-04 - val_mean_squared_error: 2.4793e-04
# Epoch 92/1500
#  - 11s - loss: 3.7458e-04 - mean_squared_error: 3.7458e-04 - val_loss: 2.0351e-04 - val_mean_squared_error: 2.0351e-04
# Epoch 93/1500
#  - 11s - loss: 3.6010e-04 - mean_squared_error: 3.6010e-04 - val_loss: 3.2593e-04 - val_mean_squared_error: 3.2593e-04
# Epoch 94/1500
#  - 11s - loss: 3.8267e-04 - mean_squared_error: 3.8267e-04 - val_loss: 1.4858e-04 - val_mean_squared_error: 1.4858e-04
# Epoch 95/1500
#  - 11s - loss: 3.6748e-04 - mean_squared_error: 3.6748e-04 - val_loss: 2.9139e-04 - val_mean_squared_error: 2.9139e-04
# Epoch 96/1500
#  - 11s - loss: 3.7417e-04 - mean_squared_error: 3.7417e-04 - val_loss: 2.3139e-04 - val_mean_squared_error: 2.3139e-04
# Epoch 97/1500
#  - 11s - loss: 3.8030e-04 - mean_squared_error: 3.8030e-04 - val_loss: 2.9561e-04 - val_mean_squared_error: 2.9561e-04
# Epoch 98/1500
#  - 11s - loss: 3.6342e-04 - mean_squared_error: 3.6342e-04 - val_loss: 3.8308e-04 - val_mean_squared_error: 3.8308e-04
# Epoch 99/1500
#  - 11s - loss: 3.6345e-04 - mean_squared_error: 3.6345e-04 - val_loss: 2.5254e-04 - val_mean_squared_error: 2.5254e-04
# Epoch 100/1500
#  - 11s - loss: 3.7371e-04 - mean_squared_error: 3.7371e-04 - val_loss: 2.7069e-04 - val_mean_squared_error: 2.7069e-04
# Epoch 101/1500
#  - 11s - loss: 3.6031e-04 - mean_squared_error: 3.6031e-04 - val_loss: 2.8957e-04 - val_mean_squared_error: 2.8957e-04
# Epoch 102/1500
#  - 11s - loss: 3.6739e-04 - mean_squared_error: 3.6739e-04 - val_loss: 3.1777e-04 - val_mean_squared_error: 3.1777e-04
# Epoch 103/1500
#  - 11s - loss: 3.7768e-04 - mean_squared_error: 3.7768e-04 - val_loss: 3.7716e-04 - val_mean_squared_error: 3.7716e-04
# Epoch 104/1500
#  - 11s - loss: 3.6848e-04 - mean_squared_error: 3.6848e-04 - val_loss: 3.2529e-04 - val_mean_squared_error: 3.2529e-04
# Epoch 105/1500
#  - 11s - loss: 3.6705e-04 - mean_squared_error: 3.6705e-04 - val_loss: 3.1730e-04 - val_mean_squared_error: 3.1730e-04
# Epoch 106/1500
#  - 11s - loss: 3.7621e-04 - mean_squared_error: 3.7621e-04 - val_loss: 3.6930e-04 - val_mean_squared_error: 3.6930e-04
# Epoch 107/1500
#  - 11s - loss: 3.7404e-04 - mean_squared_error: 3.7404e-04 - val_loss: 1.9995e-04 - val_mean_squared_error: 1.9995e-04
# Epoch 108/1500
#  - 11s - loss: 3.5975e-04 - mean_squared_error: 3.5975e-04 - val_loss: 3.2142e-04 - val_mean_squared_error: 3.2142e-04
# Epoch 109/1500
#  - 11s - loss: 3.8385e-04 - mean_squared_error: 3.8385e-04 - val_loss: 2.5593e-04 - val_mean_squared_error: 2.5593e-04
# Epoch 110/1500
#  - 11s - loss: 3.8194e-04 - mean_squared_error: 3.8194e-04 - val_loss: 1.4728e-04 - val_mean_squared_error: 1.4728e-04
# Epoch 111/1500
#  - 11s - loss: 3.7484e-04 - mean_squared_error: 3.7484e-04 - val_loss: 1.8054e-04 - val_mean_squared_error: 1.8054e-04
# Epoch 112/1500
#  - 11s - loss: 3.5585e-04 - mean_squared_error: 3.5585e-04 - val_loss: 5.2649e-04 - val_mean_squared_error: 5.2649e-04
# Epoch 113/1500
#  - 11s - loss: 3.8068e-04 - mean_squared_error: 3.8068e-04 - val_loss: 3.6109e-04 - val_mean_squared_error: 3.6109e-04
# Epoch 114/1500
#  - 11s - loss: 3.6377e-04 - mean_squared_error: 3.6377e-04 - val_loss: 4.1106e-04 - val_mean_squared_error: 4.1106e-04
# Epoch 115/1500
#  - 11s - loss: 3.6202e-04 - mean_squared_error: 3.6202e-04 - val_loss: 3.6879e-04 - val_mean_squared_error: 3.6879e-04
# Epoch 116/1500
#  - 11s - loss: 3.6156e-04 - mean_squared_error: 3.6156e-04 - val_loss: 3.3343e-04 - val_mean_squared_error: 3.3343e-04
# Epoch 117/1500
#  - 11s - loss: 3.6634e-04 - mean_squared_error: 3.6634e-04 - val_loss: 5.7203e-04 - val_mean_squared_error: 5.7203e-04
# Epoch 118/1500
#  - 11s - loss: 3.5861e-04 - mean_squared_error: 3.5861e-04 - val_loss: 2.8146e-04 - val_mean_squared_error: 2.8146e-04
# Epoch 119/1500
#  - 11s - loss: 3.6626e-04 - mean_squared_error: 3.6626e-04 - val_loss: 7.4358e-04 - val_mean_squared_error: 7.4358e-04
# Epoch 120/1500
#  - 11s - loss: 3.8038e-04 - mean_squared_error: 3.8038e-04 - val_loss: 2.1799e-04 - val_mean_squared_error: 2.1799e-04
# Epoch 121/1500
#  - 11s - loss: 3.6867e-04 - mean_squared_error: 3.6867e-04 - val_loss: 3.8113e-04 - val_mean_squared_error: 3.8113e-04
# Epoch 122/1500
#  - 11s - loss: 3.7890e-04 - mean_squared_error: 3.7890e-04 - val_loss: 2.2707e-04 - val_mean_squared_error: 2.2707e-04
# Epoch 123/1500
#  - 11s - loss: 3.7212e-04 - mean_squared_error: 3.7212e-04 - val_loss: 3.3863e-04 - val_mean_squared_error: 3.3863e-04
# Epoch 124/1500
#  - 11s - loss: 3.7477e-04 - mean_squared_error: 3.7477e-04 - val_loss: 2.5246e-04 - val_mean_squared_error: 2.5246e-04
# Epoch 125/1500
#  - 11s - loss: 3.6219e-04 - mean_squared_error: 3.6219e-04 - val_loss: 3.9225e-04 - val_mean_squared_error: 3.9225e-04
# Epoch 126/1500
#  - 11s - loss: 3.6386e-04 - mean_squared_error: 3.6386e-04 - val_loss: 3.9133e-04 - val_mean_squared_error: 3.9133e-04
# Epoch 127/1500
#  - 11s - loss: 3.6878e-04 - mean_squared_error: 3.6878e-04 - val_loss: 3.1737e-04 - val_mean_squared_error: 3.1737e-04
# Epoch 128/1500
#  - 11s - loss: 3.6489e-04 - mean_squared_error: 3.6489e-04 - val_loss: 3.0084e-04 - val_mean_squared_error: 3.0084e-04
# Epoch 129/1500
#  - 11s - loss: 3.6761e-04 - mean_squared_error: 3.6761e-04 - val_loss: 1.8659e-04 - val_mean_squared_error: 1.8659e-04
# Epoch 130/1500
#  - 11s - loss: 3.7306e-04 - mean_squared_error: 3.7306e-04 - val_loss: 3.2131e-04 - val_mean_squared_error: 3.2131e-04
# Epoch 131/1500
#  - 11s - loss: 3.5826e-04 - mean_squared_error: 3.5826e-04 - val_loss: 3.3680e-04 - val_mean_squared_error: 3.3680e-04
# Epoch 132/1500
#  - 11s - loss: 3.6178e-04 - mean_squared_error: 3.6178e-04 - val_loss: 3.6002e-04 - val_mean_squared_error: 3.6002e-04
# Epoch 133/1500
#  - 11s - loss: 3.6257e-04 - mean_squared_error: 3.6257e-04 - val_loss: 2.7916e-04 - val_mean_squared_error: 2.7916e-04
# Epoch 134/1500
#  - 11s - loss: 3.6092e-04 - mean_squared_error: 3.6092e-04 - val_loss: 3.7051e-04 - val_mean_squared_error: 3.7051e-04
# Epoch 135/1500
#  - 11s - loss: 3.7709e-04 - mean_squared_error: 3.7709e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 136/1500
#  - 11s - loss: 3.7441e-04 - mean_squared_error: 3.7441e-04 - val_loss: 2.6166e-04 - val_mean_squared_error: 2.6166e-04
# Epoch 137/1500
#  - 11s - loss: 3.6915e-04 - mean_squared_error: 3.6915e-04 - val_loss: 2.4296e-04 - val_mean_squared_error: 2.4296e-04
# Epoch 138/1500
#  - 11s - loss: 3.6767e-04 - mean_squared_error: 3.6767e-04 - val_loss: 4.6980e-04 - val_mean_squared_error: 4.6980e-04
# Epoch 139/1500
#  - 11s - loss: 3.5962e-04 - mean_squared_error: 3.5962e-04 - val_loss: 3.0876e-04 - val_mean_squared_error: 3.0876e-04
# Epoch 140/1500
#  - 11s - loss: 3.7977e-04 - mean_squared_error: 3.7977e-04 - val_loss: 3.3428e-04 - val_mean_squared_error: 3.3428e-04
# Epoch 141/1500
#  - 11s - loss: 3.6662e-04 - mean_squared_error: 3.6662e-04 - val_loss: 2.1429e-04 - val_mean_squared_error: 2.1429e-04
# Epoch 142/1500
#  - 11s - loss: 3.6225e-04 - mean_squared_error: 3.6225e-04 - val_loss: 2.2540e-04 - val_mean_squared_error: 2.2540e-04
# Epoch 143/1500
#  - 11s - loss: 3.7848e-04 - mean_squared_error: 3.7848e-04 - val_loss: 2.7327e-04 - val_mean_squared_error: 2.7327e-04
# Epoch 144/1500
#  - 11s - loss: 3.6203e-04 - mean_squared_error: 3.6203e-04 - val_loss: 2.9395e-04 - val_mean_squared_error: 2.9395e-04
# Epoch 145/1500
#  - 11s - loss: 3.6616e-04 - mean_squared_error: 3.6616e-04 - val_loss: 2.5862e-04 - val_mean_squared_error: 2.5862e-04
# Epoch 146/1500
#  - 11s - loss: 3.6279e-04 - mean_squared_error: 3.6279e-04 - val_loss: 2.8367e-04 - val_mean_squared_error: 2.8367e-04
# Epoch 147/1500
#  - 11s - loss: 3.5631e-04 - mean_squared_error: 3.5631e-04 - val_loss: 4.4027e-04 - val_mean_squared_error: 4.4027e-04
# Epoch 148/1500
#  - 11s - loss: 3.8865e-04 - mean_squared_error: 3.8865e-04 - val_loss: 3.2645e-04 - val_mean_squared_error: 3.2645e-04
# Epoch 149/1500
#  - 11s - loss: 3.5432e-04 - mean_squared_error: 3.5432e-04 - val_loss: 7.0232e-04 - val_mean_squared_error: 7.0232e-04
# Epoch 150/1500
#  - 11s - loss: 3.5972e-04 - mean_squared_error: 3.5972e-04 - val_loss: 8.6299e-04 - val_mean_squared_error: 8.6299e-04
# Epoch 151/1500
#  - 11s - loss: 3.6061e-04 - mean_squared_error: 3.6061e-04 - val_loss: 3.0586e-04 - val_mean_squared_error: 3.0586e-04
# Epoch 152/1500
#  - 11s - loss: 3.6224e-04 - mean_squared_error: 3.6224e-04 - val_loss: 2.6166e-04 - val_mean_squared_error: 2.6166e-04
# Epoch 153/1500
#  - 11s - loss: 3.6069e-04 - mean_squared_error: 3.6069e-04 - val_loss: 2.8233e-04 - val_mean_squared_error: 2.8233e-04
# Epoch 154/1500
#  - 11s - loss: 3.6604e-04 - mean_squared_error: 3.6604e-04 - val_loss: 1.7106e-04 - val_mean_squared_error: 1.7106e-04
# Epoch 155/1500
#  - 11s - loss: 3.6140e-04 - mean_squared_error: 3.6140e-04 - val_loss: 2.8989e-04 - val_mean_squared_error: 2.8989e-04
# Epoch 156/1500
#  - 11s - loss: 3.7783e-04 - mean_squared_error: 3.7783e-04 - val_loss: 4.0109e-04 - val_mean_squared_error: 4.0109e-04
# Epoch 157/1500
#  - 11s - loss: 3.5024e-04 - mean_squared_error: 3.5024e-04 - val_loss: 3.3602e-04 - val_mean_squared_error: 3.3602e-04
# Epoch 158/1500
#  - 11s - loss: 3.8309e-04 - mean_squared_error: 3.8309e-04 - val_loss: 3.6414e-04 - val_mean_squared_error: 3.6414e-04
# Epoch 159/1500
#  - 11s - loss: 3.5896e-04 - mean_squared_error: 3.5896e-04 - val_loss: 3.8707e-04 - val_mean_squared_error: 3.8707e-04
# Epoch 160/1500
#  - 11s - loss: 3.8378e-04 - mean_squared_error: 3.8378e-04 - val_loss: 2.8374e-04 - val_mean_squared_error: 2.8374e-04
# Epoch 161/1500
#  - 11s - loss: 3.5946e-04 - mean_squared_error: 3.5946e-04 - val_loss: 3.1426e-04 - val_mean_squared_error: 3.1426e-04
# Epoch 162/1500
#  - 11s - loss: 3.7174e-04 - mean_squared_error: 3.7174e-04 - val_loss: 5.7018e-04 - val_mean_squared_error: 5.7018e-04
# Epoch 163/1500
#  - 11s - loss: 3.5834e-04 - mean_squared_error: 3.5834e-04 - val_loss: 3.5726e-04 - val_mean_squared_error: 3.5726e-04
# Epoch 164/1500
#  - 11s - loss: 3.5777e-04 - mean_squared_error: 3.5777e-04 - val_loss: 2.9376e-04 - val_mean_squared_error: 2.9376e-04
# Epoch 165/1500
#  - 11s - loss: 3.5750e-04 - mean_squared_error: 3.5750e-04 - val_loss: 3.0232e-04 - val_mean_squared_error: 3.0232e-04
# Epoch 166/1500
#  - 11s - loss: 3.5972e-04 - mean_squared_error: 3.5972e-04 - val_loss: 2.1720e-04 - val_mean_squared_error: 2.1720e-04
# Epoch 167/1500
#  - 11s - loss: 3.5860e-04 - mean_squared_error: 3.5860e-04 - val_loss: 2.5619e-04 - val_mean_squared_error: 2.5619e-04
# Epoch 168/1500
#  - 11s - loss: 3.5013e-04 - mean_squared_error: 3.5013e-04 - val_loss: 3.0797e-04 - val_mean_squared_error: 3.0797e-04
# Epoch 169/1500
#  - 11s - loss: 3.6551e-04 - mean_squared_error: 3.6551e-04 - val_loss: 5.0206e-04 - val_mean_squared_error: 5.0206e-04
# Epoch 170/1500
#  - 11s - loss: 3.6123e-04 - mean_squared_error: 3.6123e-04 - val_loss: 3.5151e-04 - val_mean_squared_error: 3.5151e-04
# Epoch 171/1500
#  - 11s - loss: 3.5685e-04 - mean_squared_error: 3.5685e-04 - val_loss: 2.5206e-04 - val_mean_squared_error: 2.5206e-04
# Epoch 172/1500
#  - 11s - loss: 3.6590e-04 - mean_squared_error: 3.6590e-04 - val_loss: 2.5392e-04 - val_mean_squared_error: 2.5392e-04
# Epoch 173/1500
#  - 11s - loss: 3.5659e-04 - mean_squared_error: 3.5659e-04 - val_loss: 2.3779e-04 - val_mean_squared_error: 2.3779e-04
# Epoch 174/1500
#  - 11s - loss: 3.6478e-04 - mean_squared_error: 3.6478e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 175/1500
#  - 11s - loss: 3.6862e-04 - mean_squared_error: 3.6862e-04 - val_loss: 3.3028e-04 - val_mean_squared_error: 3.3028e-04
# Epoch 176/1500
#  - 11s - loss: 3.7501e-04 - mean_squared_error: 3.7501e-04 - val_loss: 3.3743e-04 - val_mean_squared_error: 3.3743e-04
# Epoch 177/1500
#  - 11s - loss: 3.5300e-04 - mean_squared_error: 3.5300e-04 - val_loss: 2.7048e-04 - val_mean_squared_error: 2.7048e-04
# Epoch 178/1500
#  - 11s - loss: 3.6592e-04 - mean_squared_error: 3.6592e-04 - val_loss: 2.6592e-04 - val_mean_squared_error: 2.6592e-04
# Epoch 179/1500
#  - 11s - loss: 3.6470e-04 - mean_squared_error: 3.6470e-04 - val_loss: 1.9212e-04 - val_mean_squared_error: 1.9212e-04
# Epoch 180/1500
#  - 11s - loss: 3.4938e-04 - mean_squared_error: 3.4938e-04 - val_loss: 3.5449e-04 - val_mean_squared_error: 3.5449e-04
# Epoch 181/1500
#  - 11s - loss: 3.5934e-04 - mean_squared_error: 3.5934e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 182/1500
#  - 11s - loss: 3.6900e-04 - mean_squared_error: 3.6900e-04 - val_loss: 3.1738e-04 - val_mean_squared_error: 3.1738e-04
# Epoch 183/1500
#  - 11s - loss: 3.5628e-04 - mean_squared_error: 3.5628e-04 - val_loss: 2.5359e-04 - val_mean_squared_error: 2.5359e-04
# Epoch 184/1500
#  - 11s - loss: 3.5160e-04 - mean_squared_error: 3.5160e-04 - val_loss: 2.8052e-04 - val_mean_squared_error: 2.8052e-04
# Epoch 185/1500
#  - 11s - loss: 3.5598e-04 - mean_squared_error: 3.5598e-04 - val_loss: 2.6033e-04 - val_mean_squared_error: 2.6033e-04
# Epoch 186/1500
#  - 11s - loss: 3.4998e-04 - mean_squared_error: 3.4998e-04 - val_loss: 2.5543e-04 - val_mean_squared_error: 2.5543e-04
# Epoch 187/1500
#  - 11s - loss: 3.5221e-04 - mean_squared_error: 3.5221e-04 - val_loss: 3.4948e-04 - val_mean_squared_error: 3.4948e-04
# Epoch 188/1500
#  - 11s - loss: 3.6442e-04 - mean_squared_error: 3.6442e-04 - val_loss: 2.5437e-04 - val_mean_squared_error: 2.5437e-04
# Epoch 189/1500
#  - 11s - loss: 3.5411e-04 - mean_squared_error: 3.5411e-04 - val_loss: 3.8962e-04 - val_mean_squared_error: 3.8962e-04
# Epoch 190/1500
#  - 11s - loss: 3.6136e-04 - mean_squared_error: 3.6136e-04 - val_loss: 4.3958e-04 - val_mean_squared_error: 4.3958e-04
# Epoch 191/1500
#  - 11s - loss: 3.5013e-04 - mean_squared_error: 3.5013e-04 - val_loss: 2.4690e-04 - val_mean_squared_error: 2.4690e-04
# Epoch 192/1500
#  - 11s - loss: 3.6277e-04 - mean_squared_error: 3.6277e-04 - val_loss: 2.3999e-04 - val_mean_squared_error: 2.3999e-04
# Epoch 193/1500
#  - 11s - loss: 3.6408e-04 - mean_squared_error: 3.6408e-04 - val_loss: 2.1600e-04 - val_mean_squared_error: 2.1600e-04
# Epoch 194/1500
#  - 11s - loss: 3.5933e-04 - mean_squared_error: 3.5933e-04 - val_loss: 4.2926e-04 - val_mean_squared_error: 4.2926e-04
# Epoch 195/1500
#  - 11s - loss: 3.5819e-04 - mean_squared_error: 3.5819e-04 - val_loss: 9.8225e-04 - val_mean_squared_error: 9.8225e-04
# Epoch 196/1500
#  - 11s - loss: 3.6733e-04 - mean_squared_error: 3.6733e-04 - val_loss: 2.1312e-04 - val_mean_squared_error: 2.1312e-04
# Epoch 197/1500
#  - 11s - loss: 3.7395e-04 - mean_squared_error: 3.7395e-04 - val_loss: 2.8188e-04 - val_mean_squared_error: 2.8188e-04
# Epoch 198/1500
#  - 11s - loss: 3.6486e-04 - mean_squared_error: 3.6486e-04 - val_loss: 2.4471e-04 - val_mean_squared_error: 2.4471e-04
# Epoch 199/1500
#  - 11s - loss: 3.5485e-04 - mean_squared_error: 3.5485e-04 - val_loss: 2.9781e-04 - val_mean_squared_error: 2.9781e-04
# Epoch 200/1500
#  - 11s - loss: 3.5612e-04 - mean_squared_error: 3.5612e-04 - val_loss: 4.3475e-04 - val_mean_squared_error: 4.3475e-04
# Epoch 201/1500
#  - 11s - loss: 3.4657e-04 - mean_squared_error: 3.4657e-04 - val_loss: 2.5545e-04 - val_mean_squared_error: 2.5545e-04
# Epoch 202/1500
#  - 11s - loss: 3.5975e-04 - mean_squared_error: 3.5975e-04 - val_loss: 2.1919e-04 - val_mean_squared_error: 2.1919e-04
# Epoch 203/1500
#  - 11s - loss: 3.6707e-04 - mean_squared_error: 3.6707e-04 - val_loss: 5.4961e-04 - val_mean_squared_error: 5.4961e-04
# Epoch 204/1500
#  - 11s - loss: 3.5620e-04 - mean_squared_error: 3.5620e-04 - val_loss: 3.3639e-04 - val_mean_squared_error: 3.3639e-04
# Epoch 205/1500
#  - 11s - loss: 3.4695e-04 - mean_squared_error: 3.4695e-04 - val_loss: 3.3149e-04 - val_mean_squared_error: 3.3149e-04
# Epoch 206/1500
#  - 11s - loss: 3.5859e-04 - mean_squared_error: 3.5859e-04 - val_loss: 3.0842e-04 - val_mean_squared_error: 3.0842e-04
# Epoch 207/1500
#  - 11s - loss: 3.4936e-04 - mean_squared_error: 3.4936e-04 - val_loss: 3.1244e-04 - val_mean_squared_error: 3.1244e-04
# Epoch 208/1500
#  - 11s - loss: 3.7469e-04 - mean_squared_error: 3.7469e-04 - val_loss: 4.9516e-04 - val_mean_squared_error: 4.9516e-04
# Epoch 209/1500
#  - 11s - loss: 3.4638e-04 - mean_squared_error: 3.4638e-04 - val_loss: 3.3372e-04 - val_mean_squared_error: 3.3372e-04
# Epoch 210/1500
#  - 11s - loss: 3.6146e-04 - mean_squared_error: 3.6146e-04 - val_loss: 2.7476e-04 - val_mean_squared_error: 2.7476e-04
# Epoch 211/1500
#  - 11s - loss: 3.4713e-04 - mean_squared_error: 3.4713e-04 - val_loss: 3.0004e-04 - val_mean_squared_error: 3.0004e-04
# Epoch 212/1500
#  - 11s - loss: 3.4926e-04 - mean_squared_error: 3.4926e-04 - val_loss: 2.9810e-04 - val_mean_squared_error: 2.9810e-04
# Epoch 213/1500
#  - 11s - loss: 3.4865e-04 - mean_squared_error: 3.4865e-04 - val_loss: 6.9759e-04 - val_mean_squared_error: 6.9759e-04
# Epoch 214/1500
#  - 11s - loss: 3.6153e-04 - mean_squared_error: 3.6153e-04 - val_loss: 3.6877e-04 - val_mean_squared_error: 3.6877e-04
# Epoch 215/1500
#  - 11s - loss: 3.6680e-04 - mean_squared_error: 3.6680e-04 - val_loss: 1.8847e-04 - val_mean_squared_error: 1.8847e-04
# Epoch 216/1500
#  - 11s - loss: 3.4853e-04 - mean_squared_error: 3.4853e-04 - val_loss: 3.3697e-04 - val_mean_squared_error: 3.3697e-04
# Epoch 217/1500
#  - 11s - loss: 3.6003e-04 - mean_squared_error: 3.6003e-04 - val_loss: 4.4204e-04 - val_mean_squared_error: 4.4204e-04
# Epoch 218/1500
#  - 11s - loss: 3.5186e-04 - mean_squared_error: 3.5186e-04 - val_loss: 2.5611e-04 - val_mean_squared_error: 2.5611e-04
# Epoch 219/1500
#  - 11s - loss: 3.5713e-04 - mean_squared_error: 3.5713e-04 - val_loss: 2.4448e-04 - val_mean_squared_error: 2.4448e-04
# Epoch 220/1500
#  - 11s - loss: 3.5242e-04 - mean_squared_error: 3.5242e-04 - val_loss: 2.0273e-04 - val_mean_squared_error: 2.0273e-04
# Epoch 221/1500
#  - 11s - loss: 3.4466e-04 - mean_squared_error: 3.4466e-04 - val_loss: 2.8496e-04 - val_mean_squared_error: 2.8496e-04
# Epoch 222/1500
#  - 11s - loss: 3.6934e-04 - mean_squared_error: 3.6934e-04 - val_loss: 3.0908e-04 - val_mean_squared_error: 3.0908e-04
# Epoch 223/1500
#  - 11s - loss: 3.6032e-04 - mean_squared_error: 3.6032e-04 - val_loss: 2.6344e-04 - val_mean_squared_error: 2.6344e-04
# Epoch 224/1500
#  - 11s - loss: 3.5746e-04 - mean_squared_error: 3.5746e-04 - val_loss: 9.4576e-04 - val_mean_squared_error: 9.4576e-04
# Epoch 225/1500
#  - 11s - loss: 3.4178e-04 - mean_squared_error: 3.4178e-04 - val_loss: 3.3309e-04 - val_mean_squared_error: 3.3309e-04
# Epoch 226/1500
#  - 11s - loss: 3.6591e-04 - mean_squared_error: 3.6591e-04 - val_loss: 3.4220e-04 - val_mean_squared_error: 3.4220e-04
# Epoch 227/1500
#  - 11s - loss: 3.5458e-04 - mean_squared_error: 3.5458e-04 - val_loss: 2.6144e-04 - val_mean_squared_error: 2.6144e-04
# Epoch 228/1500
#  - 11s - loss: 3.5733e-04 - mean_squared_error: 3.5733e-04 - val_loss: 3.3483e-04 - val_mean_squared_error: 3.3483e-04
# Epoch 229/1500
#  - 11s - loss: 3.6283e-04 - mean_squared_error: 3.6283e-04 - val_loss: 4.9799e-04 - val_mean_squared_error: 4.9799e-04
# Epoch 230/1500
#  - 11s - loss: 3.5593e-04 - mean_squared_error: 3.5593e-04 - val_loss: 3.3586e-04 - val_mean_squared_error: 3.3586e-04
# Epoch 231/1500
#  - 11s - loss: 3.4598e-04 - mean_squared_error: 3.4598e-04 - val_loss: 2.6244e-04 - val_mean_squared_error: 2.6244e-04
# Epoch 232/1500
#  - 11s - loss: 3.5696e-04 - mean_squared_error: 3.5696e-04 - val_loss: 2.5037e-04 - val_mean_squared_error: 2.5037e-04
# Epoch 233/1500
#  - 11s - loss: 3.7491e-04 - mean_squared_error: 3.7491e-04 - val_loss: 2.4910e-04 - val_mean_squared_error: 2.4910e-04
# Epoch 234/1500
#  - 11s - loss: 3.4693e-04 - mean_squared_error: 3.4693e-04 - val_loss: 4.3094e-04 - val_mean_squared_error: 4.3094e-04
# Epoch 235/1500
#  - 11s - loss: 3.4934e-04 - mean_squared_error: 3.4934e-04 - val_loss: 2.9368e-04 - val_mean_squared_error: 2.9368e-04
# Epoch 236/1500
#  - 11s - loss: 3.5991e-04 - mean_squared_error: 3.5991e-04 - val_loss: 3.0573e-04 - val_mean_squared_error: 3.0573e-04
# Epoch 237/1500
#  - 11s - loss: 3.5775e-04 - mean_squared_error: 3.5775e-04 - val_loss: 3.0949e-04 - val_mean_squared_error: 3.0949e-04
# Epoch 238/1500
#  - 11s - loss: 3.4309e-04 - mean_squared_error: 3.4309e-04 - val_loss: 3.2026e-04 - val_mean_squared_error: 3.2026e-04
# Epoch 239/1500
#  - 11s - loss: 3.4467e-04 - mean_squared_error: 3.4467e-04 - val_loss: 2.0397e-04 - val_mean_squared_error: 2.0397e-04
# Epoch 240/1500
#  - 11s - loss: 3.4384e-04 - mean_squared_error: 3.4384e-04 - val_loss: 2.7785e-04 - val_mean_squared_error: 2.7785e-04
# Epoch 241/1500
#  - 11s - loss: 3.5617e-04 - mean_squared_error: 3.5617e-04 - val_loss: 2.6567e-04 - val_mean_squared_error: 2.6567e-04
# Epoch 242/1500
#  - 11s - loss: 3.6063e-04 - mean_squared_error: 3.6063e-04 - val_loss: 3.6127e-04 - val_mean_squared_error: 3.6127e-04
# Epoch 243/1500
#  - 11s - loss: 3.5166e-04 - mean_squared_error: 3.5166e-04 - val_loss: 2.5030e-04 - val_mean_squared_error: 2.5030e-04
# Epoch 244/1500
#  - 11s - loss: 3.4968e-04 - mean_squared_error: 3.4968e-04 - val_loss: 3.3620e-04 - val_mean_squared_error: 3.3620e-04
# Epoch 245/1500
#  - 11s - loss: 3.6397e-04 - mean_squared_error: 3.6397e-04 - val_loss: 5.2037e-04 - val_mean_squared_error: 5.2037e-04
# Epoch 246/1500
#  - 11s - loss: 3.4421e-04 - mean_squared_error: 3.4421e-04 - val_loss: 9.8028e-04 - val_mean_squared_error: 9.8028e-04
# Epoch 247/1500
#  - 11s - loss: 3.5002e-04 - mean_squared_error: 3.5002e-04 - val_loss: 2.4175e-04 - val_mean_squared_error: 2.4175e-04
# Epoch 248/1500
#  - 11s - loss: 3.5148e-04 - mean_squared_error: 3.5148e-04 - val_loss: 2.2061e-04 - val_mean_squared_error: 2.2061e-04
# Epoch 249/1500
#  - 11s - loss: 3.6166e-04 - mean_squared_error: 3.6166e-04 - val_loss: 2.8672e-04 - val_mean_squared_error: 2.8672e-04
# Epoch 250/1500
#  - 11s - loss: 3.7211e-04 - mean_squared_error: 3.7211e-04 - val_loss: 3.0547e-04 - val_mean_squared_error: 3.0547e-04
# Epoch 251/1500
#  - 11s - loss: 3.4321e-04 - mean_squared_error: 3.4321e-04 - val_loss: 5.4992e-04 - val_mean_squared_error: 5.4992e-04
# Epoch 252/1500
#  - 11s - loss: 3.5315e-04 - mean_squared_error: 3.5315e-04 - val_loss: 8.4147e-04 - val_mean_squared_error: 8.4147e-04
# Epoch 253/1500
#  - 11s - loss: 3.7055e-04 - mean_squared_error: 3.7055e-04 - val_loss: 3.4275e-04 - val_mean_squared_error: 3.4275e-04
# Epoch 254/1500
#  - 11s - loss: 3.4306e-04 - mean_squared_error: 3.4306e-04 - val_loss: 1.9908e-04 - val_mean_squared_error: 1.9908e-04
# Epoch 255/1500
#  - 11s - loss: 3.4209e-04 - mean_squared_error: 3.4209e-04 - val_loss: 3.7547e-04 - val_mean_squared_error: 3.7547e-04
# Epoch 256/1500
#  - 11s - loss: 3.5752e-04 - mean_squared_error: 3.5752e-04 - val_loss: 3.3647e-04 - val_mean_squared_error: 3.3647e-04
# Epoch 257/1500
#  - 11s - loss: 3.4245e-04 - mean_squared_error: 3.4245e-04 - val_loss: 2.9805e-04 - val_mean_squared_error: 2.9805e-04
# Epoch 258/1500
#  - 11s - loss: 3.5673e-04 - mean_squared_error: 3.5673e-04 - val_loss: 2.3648e-04 - val_mean_squared_error: 2.3648e-04
# Epoch 259/1500
#  - 11s - loss: 3.5549e-04 - mean_squared_error: 3.5549e-04 - val_loss: 3.0439e-04 - val_mean_squared_error: 3.0439e-04
# Epoch 260/1500
#  - 11s - loss: 3.4705e-04 - mean_squared_error: 3.4705e-04 - val_loss: 2.3712e-04 - val_mean_squared_error: 2.3712e-04
# Epoch 00260: early stopping
# 2866.430097579956

# %%
history.history['val_loss'][-1]# MSE for final epoch testing
# not sure why it's different from MSE vs. loss????  answer : I think loss incorporates regularization.
# Out:
# 0.00023712440852708026

# %%
history.history['val_mean_squared_error'][-1] # it is the same when there is no regularization
# Out:
# 0.0006754225494877889

# %%
history.history['loss'][-1]# MSE for final epoch training

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_2343Params.png"), dpi = 120, bbox_inches='tight')
    plt.yscale('log') #logarithmic scale for y axis
    plt.show()
    
plot_model_history(history, saveFig=True)

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_2343Params.png"), dpi = 120, bbox_inches='tight')
    plt.yscale('log') #logarithmic scale for y axis
    plt.show()
    
plot_model_history(history, saveFig=True)

# %%
# save model
model.save(os.path.join(savedModels, 'my_model_400Units_newData.h5'))

# %%
print("hello")

# %%
savedModels

# %%
# check to see if model saved: 
K.clear_session()
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model_512Units.h5'))

# %%
model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
K.clear_session()

# %%
# this is the original model
inputs = Input(shape=(Xtrain_scaled.shape[1],))
x = Dense(400, activation='tanh')(inputs)
x = Dense(400, activation='tanh')(x)
x = Dense(400, activation='tanh')(x)
x = Dense(16, activation='tanh')(x)
predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

# create model
model = Model(inputs=inputs, outputs=predictions)
model.compile(loss="mse", optimizer="adam", metrics = ['mse'])

earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=50, 
                          verbose=1, mode='auto', min_delta = 0.001)

# %%
# start training
history = model.fit(Xtrain_scaled_small, Ytrain_scaled_small, validation_split = 0.3, 
                    verbose = 2, batch_size=2**14, epochs = 200, 
                    callbacks = [earlystop])

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining.png"), dpi = 120, bbox_inches='tight')
    plt.show()
    
plot_model_history(history)
print(history.history["loss"][-1])

# %%
# load model that was trained for much longer
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model.h5'))

# %%
model.summary()

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
#fig.savefig(os.path.join(figDir, "SmallModelResids.png"), dpi = 120, bbox_inches='tight')

# %%
# trim distribution of weights -- cut out middle 20%
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# show new histogram of weights (excluding the 0's)
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    
    d1 = wts[jj].reshape(-1)
    axs[jj].hist(d1[d1!=0], bins = 30, facecolor = '#d6bddb' )
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))

    d2 = wts[jj+1]
    axs[jj+1].hist(d2[d2!=0], bins = 30, facecolor = '#d6bddb')
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# the validation.split is the last X% of the data
int(0.3*Xtrain_scaled.shape[0])
ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
