# %% [markdown]
# # Callin Switzer
# ### 12 Dec 2018
# ___
# ### - Train Dense, Feedforward Neural Network with Keras
# ### - Use data that was generated in Python

# %% [markdown]
# ___

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.ticker import ScalarFormatter
import os
import pandas as pd
import time
from datetime import datetime
import sys
import seaborn as sns
import scipy.io
import subprocess
import winsound
import pickle
import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
print("TensorFlow successfully installed.")
if tf.test.is_built_with_cuda():
    print("The installed version of TensorFlow includes GPU support.")
print(sys.version, "\n")
now = datetime.now()
print("last run on " + str(now))

# define directories
baseDir = os.getcwd()
dataDir = r'D:\MothSimulations\11c-AggressiveManeuver\Qstore\hws_am_con'
figDir = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\Figs'
dataOutput = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput'
savedModels = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels'
randomRawData = r'D:/Dropbox/AcademiaDropbox/mothMachineLearning_dataAndFigs/PythonGeneratedData'

if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
if not os.path.exists(savedModels):
    os.mkdir(savedModels)
# Out:
# C:\Users\calli\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2019-01-02 10:16:17.205773

# %% [markdown]
# # Make training and test set

# %% [raw]
# # concatenate all files (only need to do this once)
# # it takes a few minutes
# all_files = glob.glob(os.path.join(randomRawData, "*.csv"))
# df_from_each_file = (pd.read_csv(f) for f in all_files)
# concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)
#
# # check for duplicates
# concatenated_df.drop_duplicates(inplace=True)
# concatenated_df.shape
#
# print(concatenated_df.shape)
# concatenated_df.tail()
#
# # save to hdf5
# concatenated_df.to_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
# read in data
trainDF = pd.read_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
print(trainDF.shape)
trainDF.head()
# Out:
# (7462000, 19)
#     x0         xf          xd0          xdf   y0         yf          yd0  \
# 0  0.0  -7.035508  -697.247264     2.719425  0.0  19.824180   811.561430
# 1  0.0 -29.489352 -1290.991013 -1688.231411  0.0  18.867234   855.348518
# 2  0.0  -2.440546   -70.458577  -137.437918  0.0  19.766663  1324.589034
# 3  0.0  34.219806  1451.393666  2014.859116  0.0   5.165661   338.703701
# 4  0.0  10.856104   582.112877   484.748980  0.0  16.965309  1223.016439
#
#            ydf    theta0    thetaf    thetad0    thetadf      phi0      phif  \
# 0  1163.639628  0.727497  0.398168 -18.408509  -9.431580  0.963598  0.695186
# 1  1047.116531  5.987413  5.811625   1.917497  -4.169280  5.450164  5.281295
# 2   670.841128  0.925517  1.251490   2.034755  25.437157  1.044752  1.379735
# 3   283.398971  0.452417  1.291192  22.989042  60.873470  0.657641  1.519135
# 4   497.612869  4.358034  4.225693   5.143906  -0.574363  0.917873  0.789616
#
#        phid0      phidf             F     alpha          tau0
# 0 -23.604126  -6.300335  41869.951735  6.189162 -42870.300882
# 1 -17.899335  -3.772698  24371.507813  3.030945  -4887.820763
# 2  10.145966  25.881689  33630.852318  3.477308  -6650.955604
# 3  23.710338  62.057183  29256.479246  5.343446 -16237.130412
# 4 -19.404342  -0.322180  37489.211937  0.292085  -1822.430608

# %%
# rename columns to be consistent with other code
trainDF.rename(columns={"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "xf" : "x_99", "yf" : "y_99", "phif" : "phi_99", "thetaf" : "theta_99", 
                        "xd0" : "x_dot_0", "yd0" : "y_dot_0", "phid0" : "phi_dot_0", "thetad0": "theta_dot_0", 
                        "xdf" : "x_dot_99", "ydf": "y_dot_99", "phidf": "phi_dot_99", "thetadf": "theta_dot_99", 
                        "tau0" : "tau"}, inplace=True)

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

# %%
# make dataset
X = trainDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

# %%
X.head()
# Out:
#       phi_0   theta_0       x_99       y_99    phi_99  theta_99      x_dot_0  \
# 0  0.963598  0.727497  -7.035508  19.824180  0.695186  0.398168  -697.247264
# 1  5.450164  5.987413 -29.489352  18.867234  5.281295  5.811625 -1290.991013
# 2  1.044752  0.925517  -2.440546  19.766663  1.379735  1.251490   -70.458577
# 3  0.657641  0.452417  34.219806   5.165661  1.519135  1.291192  1451.393666
# 4  0.917873  4.358034  10.856104  16.965309  0.789616  4.225693   582.112877
#
#        y_dot_0  phi_dot_0  theta_dot_0
# 0   811.561430 -23.604126   -18.408509
# 1   855.348518 -17.899335     1.917497
# 2  1324.589034  10.145966     2.034755
# 3   338.703701  23.710338    22.989042
# 4  1223.016439 -19.404342     5.143906

# %%
Y.head()
# Out:
#              Fx            Fy           tau     x_dot_99     y_dot_99  \
# 0  41685.015668  -3930.944804 -42870.300882     2.719425  1163.639628
# 1 -24222.469881   2691.160711  -4887.820763 -1688.231411  1047.116531
# 2 -31753.405961 -11079.505290  -6650.955604  -137.437918   670.841128
# 3  17261.284888 -23621.803951 -16237.130412  2014.859116   283.398971
# 4  35901.376464  10795.007161  -1822.430608   484.748980   497.612869
#
#    phi_dot_99  theta_dot_99
# 0   -6.300335     -9.431580
# 1   -3.772698     -4.169280
# 2   25.881689     25.437157
# 3   62.057183     60.873470
# 4   -0.322180     -0.574363

# %%
# test train split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state = 123)

# %% [raw]
# # scale data
# scalerX = StandardScaler()
# scalerY = StandardScaler()
#
# # Don't cheat - fit only on training data
# scalerX.fit(Xtrain)
# scalerY.fit(Ytrain)
#
# Xtrain_scaled = scalerX.transform(Xtrain)
# Ytrain_scaled = scalerY.transform(Ytrain)
#
# # apply same transformation to test data
# Xtest_scaled = scalerX.transform(Xtest)
# Ytest_scaled = scalerY.transform(Ytest)

# %%
# scale data 
scalerX = MinMaxScaler([-0.5, 0.5])  
scalerY = MinMaxScaler([-0.5, 0.5])  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xtest_scaled = scalerX.transform(Xtest)
Ytest_scaled = scalerY.transform(Ytest)

# %%
pd.DataFrame(Xtrain_scaled, columns = X.columns).head()
# Out:
#       phi_0   theta_0      x_99      y_99    phi_99  theta_99   x_dot_0  \
# 0  0.333050  0.472721  0.257654  0.241138  0.340124  0.444330  0.391954
# 1  0.131236 -0.038044  0.279058  0.042443  0.153993  0.014989  0.322572
# 2 -0.452973  0.424556 -0.241723 -0.203956 -0.371019  0.263256 -0.377804
# 3 -0.115643 -0.411061 -0.147184 -0.243873 -0.069119 -0.277453 -0.170099
# 4 -0.077187 -0.246431 -0.274887 -0.024286 -0.030600 -0.154275 -0.295966
#
#     y_dot_0  phi_dot_0  theta_dot_0
# 0  0.386508   0.460140     0.180975
# 1 -0.044537   0.139473     0.295138
# 2 -0.307068   0.007166    -0.313487
# 3 -0.345410   0.116342     0.408037
# 4 -0.021396   0.402270     0.483048

# %%
# save scalers, to be used on test set
scalerfileX = 'scalerX.pkl'
pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

scalerfileY = 'scalerY.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %% [markdown]
# # Keras models

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
K.clear_session()

# %%
# create network
def create_network(optimizer = 'rmsprop', dropout_rate=0.1, 
                  numUnits = 400, 
                  NumHiddenLayers = 3, 
                  weightRegularization = 0.0, 
                  secondToLastUnits = 16):
    K.clear_session()
    
    inputs = Input(shape=(Xtrain_scaled.shape[1],))
    x = Dense(numUnits, activation='tanh')(inputs)
    x = Dropout(dropout_rate)(x)
    
    for ii in np.arange(1, NumHiddenLayers + 1):
        x = Dense(numUnits, activation='tanh', 
                  kernel_regularizer=regularizers.l1(weightRegularization))(x)
        x = Dropout(dropout_rate)(x)
    
    x = Dense(secondToLastUnits, activation='tanh')(x)
    predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

    # create model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(loss="mean_squared_error", optimizer = optimizer, metrics = ['mse'])

    return(model)

# %% [raw]
# # create dict of hyperparameters
#
#
# # regularization, num layers, num nodes, learning rate, optimizer, activation function, batch size
#
# from scipy.stats import randint
# from scipy.stats import uniform
#
# # Create hyperparameter space
# NumHiddenLayers = randint(low = 2, high = 20)#[4, 2, 8]
# numUnits  = [2**4, 2**5, 2**6, 2**7, 2**8, 2**9, 2**10]
# epochs = [200]
# batches1 = [2**12, 2**10, 2**8, 2**14]
# optimizers = ['rmsprop', 'adam']
# dropout_rate =  uniform(loc = 0, scale = 0.5) #[0.0, 0.2, 0.5]
# weightRegularization = uniform(loc = 0, scale = 0.001) #[0, 0.0001, 0.001, 0.01]
# secondToLastUnits = [8, 16, 32, 64]
#
# # Create hyperparameter options
# hyperparameters = dict(optimizer=optimizers,
#                         epochs=epochs,
#                         batch_size=batches1,
#                         dropout_rate = dropout_rate,
#                         numUnits = numUnits,
#                         NumHiddenLayers = NumHiddenLayers,
#                         weightRegularization = weightRegularization,
#                         secondToLastUnits = secondToLastUnits)

# %%
Xtrain_scaled_small = Xtrain_scaled[0:8000, :]
Ytrain_scaled_small = Ytrain_scaled[0:8000, :]

# %%
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=20, 
                          verbose=1, mode='auto', min_delta = 0.0001)

model = KerasRegressor(build_fn=create_network, verbose=0)
fit_params = dict(callbacks=[earlystop])

# %%
K.clear_session()

# %% [raw]
# model = create_network(optimizer = bestParams["optimizer"],
#                         dropout_rate=bestParams["dropout_rate"],
#                         numUnits = bestParams["numUnits"],
#                         NumHiddenLayers = bestParams["NumHiddenLayers"],
#                         weightRegularization = bestParams["weightRegularization"],
#                         secondToLastUnits = bestParams['secondToLastUnits'],
#                         batch_size = bestParams['batch_size'])

# %% [markdown]
# model = create_network(optimizer = "rmsprop",
#                         dropout_rate=0.0,
#                         numUnits = 512,
#                         NumHiddenLayers = 1,
#                         weightRegularization = 0,
#                         secondToLastUnits = 32)

# %%
model = create_network(optimizer = "rmsprop", 
                        dropout_rate=0.0, 
                        numUnits = 400, 
                        NumHiddenLayers = 2, 
                        weightRegularization = 0, 
                        secondToLastUnits = 16)

# %% [raw]
# K.clear_session()
# from keras.models import load_model
# model = load_model(os.path.join(savedModels, 'my_model_400Units.h5'))

# %% [raw]
# model.summary()

# %%
#model.get_config()
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=150, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
stt = time.time()
history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 1500, verbose = 2, 
                        batch_size =2**14, callbacks = [earlystop], validation_split = 0.3)
# Probably play Windows default sound, if any is registered (because
# "*" probably isn't the registered name of any sound).
winsound.PlaySound("*", winsound.SND_ALIAS)
endd = time.time() - stt
print(endd)
# Out:
# Train on 4178719 samples, validate on 1790881 samples
# Epoch 1/1500
#  - 7s - loss: 0.0264 - mean_squared_error: 0.0264 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 2/1500
#  - 5s - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 3/1500
#  - 5s - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 4/1500
#  - 5s - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 5/1500
#  - 5s - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 6/1500
#  - 5s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 7/1500
#  - 5s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 8/1500
#  - 5s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 9/1500
#  - 5s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 10/1500
#  - 5s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 11/1500
#  - 5s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 12/1500
#  - 5s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 13/1500
#  - 5s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 14/1500
#  - 5s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 15/1500
#  - 5s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 16/1500
#  - 5s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 17/1500
#  - 5s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 18/1500
#  - 5s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 19/1500
#  - 5s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 20/1500
#  - 5s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 21/1500
#  - 5s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 22/1500
#  - 5s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 23/1500
#  - 5s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 24/1500
#  - 5s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 25/1500
#  - 5s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 26/1500
#  - 5s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 27/1500
#  - 5s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 28/1500
#  - 5s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 29/1500
#  - 5s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 30/1500
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 31/1500
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 32/1500
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 33/1500
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 34/1500
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 35/1500
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 36/1500
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 37/1500
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 38/1500
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 39/1500
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 40/1500
#  - 5s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 41/1500
#  - 5s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 42/1500
#  - 5s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 43/1500
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 44/1500
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 45/1500
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 46/1500
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 47/1500
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 48/1500
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 49/1500
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 50/1500
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 51/1500
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 52/1500
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 53/1500
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 54/1500
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 55/1500
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 56/1500
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 8.9774e-04 - val_mean_squared_error: 8.9774e-04
# Epoch 57/1500
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 58/1500
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 9.4485e-04 - val_mean_squared_error: 9.4485e-04
# Epoch 59/1500
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 60/1500
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 61/1500
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 62/1500
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 63/1500
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 9.5270e-04 - val_mean_squared_error: 9.5270e-04
# Epoch 64/1500
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 65/1500
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 66/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 67/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 68/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 69/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 70/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.5855e-04 - val_mean_squared_error: 9.5855e-04
# Epoch 71/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 72/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 73/1500
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.2001e-04 - val_mean_squared_error: 9.2001e-04
# Epoch 74/1500
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 75/1500
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 7.3164e-04 - val_mean_squared_error: 7.3164e-04
# Epoch 76/1500
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.8420e-04 - val_mean_squared_error: 9.8420e-04
# Epoch 77/1500
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 78/1500
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 79/1500
#  - 5s - loss: 9.9392e-04 - mean_squared_error: 9.9392e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 80/1500
#  - 5s - loss: 9.8385e-04 - mean_squared_error: 9.8385e-04 - val_loss: 8.4164e-04 - val_mean_squared_error: 8.4164e-04
# Epoch 81/1500
#  - 5s - loss: 9.7445e-04 - mean_squared_error: 9.7445e-04 - val_loss: 8.9559e-04 - val_mean_squared_error: 8.9559e-04
# Epoch 82/1500
#  - 5s - loss: 9.6449e-04 - mean_squared_error: 9.6449e-04 - val_loss: 8.0326e-04 - val_mean_squared_error: 8.0326e-04
# Epoch 83/1500
#  - 5s - loss: 9.5157e-04 - mean_squared_error: 9.5157e-04 - val_loss: 8.8752e-04 - val_mean_squared_error: 8.8752e-04
# Epoch 84/1500
#  - 5s - loss: 9.5733e-04 - mean_squared_error: 9.5733e-04 - val_loss: 9.3466e-04 - val_mean_squared_error: 9.3466e-04
# Epoch 85/1500
#  - 5s - loss: 9.4110e-04 - mean_squared_error: 9.4110e-04 - val_loss: 8.9103e-04 - val_mean_squared_error: 8.9103e-04
# Epoch 86/1500
#  - 5s - loss: 9.3260e-04 - mean_squared_error: 9.3260e-04 - val_loss: 9.9106e-04 - val_mean_squared_error: 9.9106e-04
# Epoch 87/1500
#  - 5s - loss: 9.3097e-04 - mean_squared_error: 9.3097e-04 - val_loss: 9.8030e-04 - val_mean_squared_error: 9.8030e-04
# Epoch 88/1500
#  - 5s - loss: 9.2114e-04 - mean_squared_error: 9.2114e-04 - val_loss: 7.8370e-04 - val_mean_squared_error: 7.8370e-04
# Epoch 89/1500
#  - 5s - loss: 9.0879e-04 - mean_squared_error: 9.0879e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 90/1500
#  - 5s - loss: 9.0399e-04 - mean_squared_error: 9.0399e-04 - val_loss: 9.4834e-04 - val_mean_squared_error: 9.4834e-04
# Epoch 91/1500
#  - 5s - loss: 8.9488e-04 - mean_squared_error: 8.9488e-04 - val_loss: 6.4651e-04 - val_mean_squared_error: 6.4651e-04
# Epoch 92/1500
#  - 5s - loss: 8.9092e-04 - mean_squared_error: 8.9092e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 93/1500
#  - 5s - loss: 8.8471e-04 - mean_squared_error: 8.8471e-04 - val_loss: 9.5017e-04 - val_mean_squared_error: 9.5017e-04
# Epoch 94/1500
#  - 5s - loss: 8.7580e-04 - mean_squared_error: 8.7580e-04 - val_loss: 9.7534e-04 - val_mean_squared_error: 9.7534e-04
# Epoch 95/1500
#  - 5s - loss: 8.6949e-04 - mean_squared_error: 8.6949e-04 - val_loss: 6.9824e-04 - val_mean_squared_error: 6.9824e-04
# Epoch 96/1500
#  - 5s - loss: 8.6293e-04 - mean_squared_error: 8.6293e-04 - val_loss: 9.4078e-04 - val_mean_squared_error: 9.4078e-04
# Epoch 97/1500
#  - 5s - loss: 8.5950e-04 - mean_squared_error: 8.5950e-04 - val_loss: 8.8036e-04 - val_mean_squared_error: 8.8036e-04
# Epoch 98/1500
#  - 5s - loss: 8.4667e-04 - mean_squared_error: 8.4667e-04 - val_loss: 7.3666e-04 - val_mean_squared_error: 7.3666e-04
# Epoch 99/1500
#  - 5s - loss: 8.4286e-04 - mean_squared_error: 8.4286e-04 - val_loss: 9.9804e-04 - val_mean_squared_error: 9.9804e-04
# Epoch 100/1500
#  - 5s - loss: 8.3015e-04 - mean_squared_error: 8.3015e-04 - val_loss: 8.8897e-04 - val_mean_squared_error: 8.8897e-04
# Epoch 101/1500
#  - 5s - loss: 8.3206e-04 - mean_squared_error: 8.3206e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 102/1500
#  - 5s - loss: 8.2506e-04 - mean_squared_error: 8.2506e-04 - val_loss: 8.4553e-04 - val_mean_squared_error: 8.4553e-04
# Epoch 103/1500
#  - 5s - loss: 8.1855e-04 - mean_squared_error: 8.1855e-04 - val_loss: 7.3458e-04 - val_mean_squared_error: 7.3458e-04
# Epoch 104/1500
#  - 5s - loss: 8.1688e-04 - mean_squared_error: 8.1688e-04 - val_loss: 8.5877e-04 - val_mean_squared_error: 8.5877e-04
# Epoch 105/1500
#  - 5s - loss: 8.1104e-04 - mean_squared_error: 8.1104e-04 - val_loss: 6.5688e-04 - val_mean_squared_error: 6.5688e-04
# Epoch 106/1500
#  - 5s - loss: 8.0346e-04 - mean_squared_error: 8.0346e-04 - val_loss: 6.5782e-04 - val_mean_squared_error: 6.5782e-04
# Epoch 107/1500
#  - 5s - loss: 7.9884e-04 - mean_squared_error: 7.9884e-04 - val_loss: 8.8783e-04 - val_mean_squared_error: 8.8783e-04
# Epoch 108/1500
#  - 5s - loss: 7.9312e-04 - mean_squared_error: 7.9312e-04 - val_loss: 6.7086e-04 - val_mean_squared_error: 6.7086e-04
# Epoch 109/1500
#  - 5s - loss: 7.8351e-04 - mean_squared_error: 7.8351e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch
# Epoch 148/1500
#  - 5s - loss: 6.3662e-04 - mean_squared_error: 6.3662e-04 - val_loss: 5.7725e-04 - val_mean_squared_error: 5.7725e-04
# Epoch 149/1500
#  - 5s - loss: 6.3099e-04 - mean_squared_error: 6.3099e-04 - val_loss: 5.3774e-04 - val_mean_squared_error: 5.3774e-04
# Epoch 150/1500
#  - 5s - loss: 6.3350e-04 - mean_squared_error: 6.3350e-04 - val_loss: 7.4971e-04 - val_mean_squared_error: 7.4971e-04
# Epoch 151/1500
#  - 5s - loss: 6.3083e-04 - mean_squared_error: 6.3083e-04 - val_loss: 7.0144e-04 - val_mean_squared_error: 7.0144e-04
# Epoch 152/1500
#  - 5s - loss: 6.2816e-04 - mean_squared_error: 6.2816e-04 - val_loss: 8.5952e-04 - val_mean_squared_error: 8.5952e-04
# Epoch 153/1500
#  - 5s - loss: 6.2374e-04 - mean_squared_error: 6.2374e-04 - val_loss: 6.4421e-04 - val_mean_squared_error: 6.4421e-04
# Epoch 154/1500
#  - 5s - loss: 6.2315e-04 - mean_squared_error: 6.2315e-04 - val_loss: 5.2787e-04 - val_mean_squared_error: 5.2787e-04
# Epoch 155/1500
#  - 5s - loss: 6.1849e-04 - mean_squared_error: 6.1849e-04 - val_loss: 5.5671e-04 - val_mean_squared_error: 5.5671e-04
# Epoch 156/1500
#  - 5s - loss: 6.1652e-04 - mean_squared_error: 6.1652e-04 - val_loss: 4.5062e-04 - val_mean_squared_error: 4.5062e-04
# Epoch 157/1500
#  - 5s - loss: 6.1270e-04 - mean_squared_error: 6.1270e-04 - val_loss: 5.7970e-04 - val_mean_squared_error: 5.7970e-04
# Epoch 158/1500
#  - 5s - loss: 6.1323e-04 - mean_squared_error: 6.1323e-04 - val_loss: 6.4862e-04 - val_mean_squared_error: 6.4862e-04
# Epoch 159/1500
#  - 5s - loss: 6.0572e-04 - mean_squared_error: 6.0572e-04 - val_loss: 6.4065e-04 - val_mean_squared_error: 6.4065e-04
# Epoch 160/1500
#  - 5s - loss: 6.0721e-04 - mean_squared_error: 6.0721e-04 - val_loss: 5.6365e-04 - val_mean_squared_error: 5.6365e-04
# Epoch 161/1500
#  - 5s - loss: 6.0653e-04 - mean_squared_error: 6.0653e-04 - val_loss: 7.1535e-04 - val_mean_squared_error: 7.1535e-04
# Epoch 162/1500
#  - 5s - loss: 6.0163e-04 - mean_squared_error: 6.0163e-04 - val_loss: 5.5058e-04 - val_mean_squared_error: 5.5058e-04
# Epoch 163/1500
#  - 5s - loss: 6.0090e-04 - mean_squared_error: 6.0090e-04 - val_loss: 5.2259e-04 - val_mean_squared_error: 5.2259e-04
# Epoch 164/1500
#  - 5s - loss: 5.9352e-04 - mean_squared_error: 5.9352e-04 - val_loss: 7.3985e-04 - val_mean_squared_error: 7.3985e-04
# Epoch 165/1500
#  - 5s - loss: 5.9533e-04 - mean_squared_error: 5.9533e-04 - val_loss: 6.0501e-04 - val_mean_squared_error: 6.0501e-04
# Epoch 166/1500
#  - 5s - loss: 5.9151e-04 - mean_squared_error: 5.9151e-04 - val_loss: 4.8720e-04 - val_mean_squared_error: 4.8720e-04
# Epoch 167/1500
#  - 5s - loss: 5.9056e-04 - mean_squared_error: 5.9056e-04 - val_loss: 5.6070e-04 - val_mean_squared_error: 5.6070e-04
# Epoch 168/1500
#  - 5s - loss: 5.8607e-04 - mean_squared_error: 5.8607e-04 - val_loss: 7.1243e-04 - val_mean_squared_error: 7.1243e-04
# Epoch 169/1500
#  - 6s - loss: 5.8247e-04 - mean_squared_error: 5.8247e-04 - val_loss: 6.1986e-04 - val_mean_squared_error: 6.1986e-04
# Epoch 170/1500
#  - 5s - loss: 5.8524e-04 - mean_squared_error: 5.8524e-04 - val_loss: 5.2617e-04 - val_mean_squared_error: 5.2617e-04
# Epoch 171/1500
#  - 5s - loss: 5.8120e-04 - mean_squared_error: 5.8120e-04 - val_loss: 5.0156e-04 - val_mean_squared_error: 5.0156e-04
# Epoch 172/1500
#  - 5s - loss: 5.7827e-04 - mean_squared_error: 5.7827e-04 - val_loss: 5.8975e-04 - val_mean_squared_error: 5.8975e-04
# Epoch 173/1500
#  - 5s - loss: 5.7380e-04 - mean_squared_error: 5.7380e-04 - val_loss: 6.0182e-04 - val_mean_squared_error: 6.0182e-04
# Epoch 174/1500
#  - 5s - loss: 5.7408e-04 - mean_squared_error: 5.7408e-04 - val_loss: 3.9545e-04 - val_mean_squared_error: 3.9545e-04
# Epoch 175/1500
#  - 5s - loss: 5.7120e-04 - mean_squared_error: 5.7120e-04 - val_loss: 7.9779e-04 - val_mean_squared_error: 7.9779e-04
# Epoch 176/1500
#  - 5s - loss: 5.6341e-04 - mean_squared_error: 5.6341e-04 - val_loss: 5.6768e-04 - val_mean_squared_error: 5.6768e-04
# Epoch 177/1500
#  - 5s - loss: 5.7262e-04 - mean_squared_error: 5.7262e-04 - val_loss: 6.4621e-04 - val_mean_squared_error: 6.4621e-04
# Epoch 178/1500
#  - 5s - loss: 5.6460e-04 - mean_squared_error: 5.6460e-04 - val_loss: 6.4356e-04 - val_mean_squared_error: 6.4356e-04
# Epoch 179/1500
#  - 5s - loss: 5.6265e-04 - mean_squared_error: 5.6265e-04 - val_loss: 5.4517e-04 - val_mean_squared_error: 5.4517e-04
# Epoch 180/1500
#  - 5s - loss: 5.6192e-04 - mean_squared_error: 5.6192e-04 - val_loss: 5.7980e-04 - val_mean_squared_error: 5.7980e-04
# Epoch 181/1500
#  - 5s - loss: 5.5950e-04 - mean_squared_error: 5.5950e-04 - val_loss: 5.9129e-04 - val_mean_squared_error: 5.9129e-04
# Epoch 182/1500
#  - 5s - loss: 5.5691e-04 - mean_squared_error: 5.5691e-04 - val_loss: 6.1160e-04 - val_mean_squared_error: 6.1160e-04
# Epoch 183/1500
#  - 5s - loss: 5.5393e-04 - mean_squared_error: 5.5393e-04 - val_loss: 7.5027e-04 - val_mean_squared_error: 7.5027e-04
# Epoch 184/1500
#  - 5s - loss: 5.5460e-04 - mean_squared_error: 5.5460e-04 - val_loss: 5.2993e-04 - val_mean_squared_error: 5.2993e-04
# Epoch 969/1500
#  - 5s - loss: 2.1943e-04 - mean_squared_error: 2.1943e-04 - val_loss: 2.9091e-04 - val_mean_squared_error: 2.9091e-04
# Epoch 970/1500
#  - 5s - loss: 2.1981e-04 - mean_squared_error: 2.1981e-04 - val_loss: 1.4884e-04 - val_mean_squared_error: 1.4884e-04
# Epoch 971/1500
#  - 5s - loss: 2.1856e-04 - mean_squared_error: 2.1856e-04 - val_loss: 1.6100e-04 - val_mean_squared_error: 1.6100e-04
# Epoch 972/1500
#  - 5s - loss: 2.1866e-04 - mean_squared_error: 2.1866e-04 - val_loss: 2.4840e-04 - val_mean_squared_error: 2.4840e-04
# Epoch 973/1500
#  - 6s - loss: 2.1927e-04 - mean_squared_error: 2.1927e-04 - val_loss: 1.9311e-04 - val_mean_squared_error: 1.9311e-04
# Epoch 974/1500
#  - 6s - loss: 2.1868e-04 - mean_squared_error: 2.1868e-04 - val_loss: 3.2391e-04 - val_mean_squared_error: 3.2391e-04
# Epoch 975/1500
#  - 6s - loss: 2.1935e-04 - mean_squared_error: 2.1935e-04 - val_loss: 1.5933e-04 - val_mean_squared_error: 1.5933e-04
# Epoch 976/1500
#  - 6s - loss: 2.1689e-04 - mean_squared_error: 2.1689e-04 - val_loss: 3.3119e-04 - val_mean_squared_error: 3.3119e-04
# Epoch 977/1500
#  - 6s - loss: 2.1888e-04 - mean_squared_error: 2.1888e-04 - val_loss: 1.7780e-04 - val_mean_squared_error: 1.7780e-04
# Epoch 978/1500
#  - 6s - loss: 2.1834e-04 - mean_squared_error: 2.1834e-04 - val_loss: 2.1947e-04 - val_mean_squared_error: 2.1947e-04
# Epoch 979/1500
#  - 6s - loss: 2.1850e-04 - mean_squared_error: 2.1850e-04 - val_loss: 2.7355e-04 - val_mean_squared_error: 2.7355e-04
# Epoch 980/1500
#  - 6s - loss: 2.1837e-04 - mean_squared_error: 2.1837e-04 - val_loss: 1.7745e-04 - val_mean_squared_error: 1.7745e-04
# Epoch 981/1500
#  - 5s - loss: 2.1672e-04 - mean_squared_error: 2.1672e-04 - val_loss: 2.7146e-04 - val_mean_squared_error: 2.7146e-04
# Epoch 982/1500
#  - 6s - loss: 2.1724e-04 - mean_squared_error: 2.1724e-04 - val_loss: 2.4058e-04 - val_mean_squared_error: 2.4058e-04
# Epoch 983/1500
#  - 6s - loss: 2.1930e-04 - mean_squared_error: 2.1930e-04 - val_loss: 2.7599e-04 - val_mean_squared_error: 2.7599e-04
# Epoch 984/1500
#  - 6s - loss: 2.1656e-04 - mean_squared_error: 2.1656e-04 - val_loss: 2.1848e-04 - val_mean_squared_error: 2.1848e-04
# Epoch 985/1500
#  - 6s - loss: 2.1743e-04 - mean_squared_error: 2.1743e-04 - val_loss: 1.9779e-04 - val_mean_squared_error: 1.9779e-04
# Epoch 986/1500
#  - 5s - loss: 2.1678e-04 - mean_squared_error: 2.1678e-04 - val_loss: 1.9800e-04 - val_mean_squared_error: 1.9800e-04
# Epoch 987/1500
#  - 6s - loss: 2.1945e-04 - mean_squared_error: 2.1945e-04 - val_loss: 1.5024e-04 - val_mean_squared_error: 1.5024e-04
# Epoch 988/1500
#  - 6s - loss: 2.1528e-04 - mean_squared_error: 2.1528e-04 - val_loss: 2.7570e-04 - val_mean_squared_error: 2.7570e-04
# Epoch 989/1500
#  - 5s - loss: 2.1666e-04 - mean_squared_error: 2.1666e-04 - val_loss: 2.3501e-04 - val_mean_squared_error: 2.3501e-04
# Epoch 990/1500
#  - 6s - loss: 2.1700e-04 - mean_squared_error: 2.1700e-04 - val_loss: 1.5170e-04 - val_mean_squared_error: 1.5170e-04
# Epoch 991/1500
#  - 6s - loss: 2.1872e-04 - mean_squared_error: 2.1872e-04 - val_loss: 2.3410e-04 - val_mean_squared_error: 2.3410e-04
# Epoch 992/1500
#  - 6s - loss: 2.1622e-04 - mean_squared_error: 2.1622e-04 - val_loss: 1.7442e-04 - val_mean_squared_error: 1.7442e-04
# Epoch 993/1500
#  - 5s - loss: 2.1553e-04 - mean_squared_error: 2.1553e-04 - val_loss: 2.2020e-04 - val_mean_squared_error: 2.2020e-04
# Epoch 994/1500
#  - 6s - loss: 2.1618e-04 - mean_squared_error: 2.1618e-04 - val_loss: 1.9332e-04 - val_mean_squared_error: 1.9332e-04
# Epoch 00994: early stopping
# 5395.661008834839

# %%
history.history['val_loss'][-1]# MSE for final epoch testing
# not sure why it's different from MSE vs. loss????  answer : I think loss incorporates regularization.
# Out:
# 0.0001933241371599077

# %%
history.history['val_mean_squared_error'][-1] # it is the same when there is no regularization
# Out:
# 0.0001933241371599077

# %%
history.history['loss'][-1]# MSE for final epoch training
# Out:
# 0.00021617992878949753

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_2343Params.png"), dpi = 120, bbox_inches='tight')
    plt.yscale('log') #logarithmic scale for y axis
    plt.show()
    
plot_model_history(history, saveFig=True)

# %%
# save model
model.save(os.path.join(savedModels, 'my_model_400Units_noZeros.h5'))

# %%
print("hello")
# Out:
# hello

# %%
savedModels
# Out:
# 'D:\\Dropbox\\AcademiaDropbox\\mothMachineLearning_dataAndFigs\\savedModels'

# %%
# check to see if model saved: 
K.clear_session()
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model_512Units.h5'))

# %%
model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
K.clear_session()

# %%
# this is the original model
inputs = Input(shape=(Xtrain_scaled.shape[1],))
x = Dense(400, activation='tanh')(inputs)
x = Dense(400, activation='tanh')(x)
x = Dense(400, activation='tanh')(x)
x = Dense(16, activation='tanh')(x)
predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

# create model
model = Model(inputs=inputs, outputs=predictions)
model.compile(loss="mse", optimizer="adam", metrics = ['mse'])

earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=50, 
                          verbose=1, mode='auto', min_delta = 0.001)

# %%
# start training
history = model.fit(Xtrain_scaled_small, Ytrain_scaled_small, validation_split = 0.3, 
                    verbose = 2, batch_size=2**14, epochs = 200, 
                    callbacks = [earlystop])

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining.png"), dpi = 120, bbox_inches='tight')
    plt.show()
    
plot_model_history(history)
print(history.history["loss"][-1])

# %%
# load model that was trained for much longer
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model.h5'))

# %%
model.summary()

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
#fig.savefig(os.path.join(figDir, "SmallModelResids.png"), dpi = 120, bbox_inches='tight')

# %%
# trim distribution of weights -- cut out middle 20%
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# show new histogram of weights (excluding the 0's)
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    
    d1 = wts[jj].reshape(-1)
    axs[jj].hist(d1[d1!=0], bins = 30, facecolor = '#d6bddb' )
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))

    d2 = wts[jj+1]
    axs[jj+1].hist(d2[d2!=0], bins = 30, facecolor = '#d6bddb')
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# the validation.split is the last X% of the data
int(0.3*Xtrain_scaled.shape[0])
ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
