# %% [markdown]
# # Callin Switzer
# ### 12 Dec 2018
# ___
# ### - Train Dense, Feedforward Neural Network with Keras
# ### - Use data that was generated in Python

# %% [markdown]
# ___

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.ticker import ScalarFormatter
import os
import pandas as pd
import time
from datetime import datetime
import sys
import seaborn as sns
import scipy.io
import subprocess
import winsound
import pickle
import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
print("TensorFlow successfully installed.")
if tf.test.is_built_with_cuda():
    print("The installed version of TensorFlow includes GPU support.")
print(sys.version, "\n")
now = datetime.now()
print("last run on " + str(now))

# define directories
baseDir = os.getcwd()
dataDir = r'D:\MothSimulations\11c-AggressiveManeuver\Qstore\hws_am_con'
figDir = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\Figs'
dataOutput = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput'
savedModels = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels'
randomRawData = r'D:/Dropbox/AcademiaDropbox/mothMachineLearning_dataAndFigs/PythonGeneratedData'

if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
if not os.path.exists(savedModels):
    os.mkdir(savedModels)
# Out:
# C:\Users\calli\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2019-01-01 07:21:40.257899

# %% [markdown]
# # Make training and test set

# %% [raw]
# # concatenate all files (only need to do this once)
# # it takes a few minutes
# all_files = glob.glob(os.path.join(randomRawData, "*.csv"))
# df_from_each_file = (pd.read_csv(f) for f in all_files)
# concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)
#
# # check for duplicates
# concatenated_df.drop_duplicates(inplace=True)
# concatenated_df.shape
#
# print(concatenated_df.shape)
# concatenated_df.tail()
#
# # save to hdf5
# concatenated_df.to_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
# read in data
trainDF = pd.read_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
print(trainDF.shape)
trainDF.head()
# Out:
# (7462000, 19)
#     x0         xf          xd0          xdf   y0         yf          yd0  \
# 0  0.0  -7.035508  -697.247264     2.719425  0.0  19.824180   811.561430
# 1  0.0 -29.489352 -1290.991013 -1688.231411  0.0  18.867234   855.348518
# 2  0.0  -2.440546   -70.458577  -137.437918  0.0  19.766663  1324.589034
# 3  0.0  34.219806  1451.393666  2014.859116  0.0   5.165661   338.703701
# 4  0.0  10.856104   582.112877   484.748980  0.0  16.965309  1223.016439
#
#            ydf    theta0    thetaf    thetad0    thetadf      phi0      phif  \
# 0  1163.639628  0.727497  0.398168 -18.408509  -9.431580  0.963598  0.695186
# 1  1047.116531  5.987413  5.811625   1.917497  -4.169280  5.450164  5.281295
# 2   670.841128  0.925517  1.251490   2.034755  25.437157  1.044752  1.379735
# 3   283.398971  0.452417  1.291192  22.989042  60.873470  0.657641  1.519135
# 4   497.612869  4.358034  4.225693   5.143906  -0.574363  0.917873  0.789616
#
#        phid0      phidf             F     alpha          tau0
# 0 -23.604126  -6.300335  41869.951735  6.189162 -42870.300882
# 1 -17.899335  -3.772698  24371.507813  3.030945  -4887.820763
# 2  10.145966  25.881689  33630.852318  3.477308  -6650.955604
# 3  23.710338  62.057183  29256.479246  5.343446 -16237.130412
# 4 -19.404342  -0.322180  37489.211937  0.292085  -1822.430608

# %%
# rename columns to be consistent with other code
trainDF.rename(columns={"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "xf" : "x_99", "yf" : "y_99", "phif" : "phi_99", "thetaf" : "theta_99", 
                        "xd0" : "x_dot_0", "yd0" : "y_dot_0", "phid0" : "phi_dot_0", "thetad0": "theta_dot_0", 
                        "xdf" : "x_dot_99", "ydf": "y_dot_99", "phidf": "phi_dot_99", "thetadf": "theta_dot_99", 
                        "tau0" : "tau"}, inplace=True)

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

# %%
# make dataset
X = trainDF.loc[:, ["x_0", "y_0", "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

# %%
X.head()
# Out:
#    x_0  y_0     phi_0   theta_0       x_99       y_99    phi_99  theta_99  \
# 0  0.0  0.0  0.963598  0.727497  -7.035508  19.824180  0.695186  0.398168
# 1  0.0  0.0  5.450164  5.987413 -29.489352  18.867234  5.281295  5.811625
# 2  0.0  0.0  1.044752  0.925517  -2.440546  19.766663  1.379735  1.251490
# 3  0.0  0.0  0.657641  0.452417  34.219806   5.165661  1.519135  1.291192
# 4  0.0  0.0  0.917873  4.358034  10.856104  16.965309  0.789616  4.225693
#
#        x_dot_0      y_dot_0  phi_dot_0  theta_dot_0
# 0  -697.247264   811.561430 -23.604126   -18.408509
# 1 -1290.991013   855.348518 -17.899335     1.917497
# 2   -70.458577  1324.589034  10.145966     2.034755
# 3  1451.393666   338.703701  23.710338    22.989042
# 4   582.112877  1223.016439 -19.404342     5.143906

# %%
Y.head()
# Out:
#              Fx            Fy           tau     x_dot_99     y_dot_99  \
# 0  41685.015668  -3930.944804 -42870.300882     2.719425  1163.639628
# 1 -24222.469881   2691.160711  -4887.820763 -1688.231411  1047.116531
# 2 -31753.405961 -11079.505290  -6650.955604  -137.437918   670.841128
# 3  17261.284888 -23621.803951 -16237.130412  2014.859116   283.398971
# 4  35901.376464  10795.007161  -1822.430608   484.748980   497.612869
#
#    phi_dot_99  theta_dot_99
# 0   -6.300335     -9.431580
# 1   -3.772698     -4.169280
# 2   25.881689     25.437157
# 3   62.057183     60.873470
# 4   -0.322180     -0.574363

# %%
# test train split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state = 123)

# %% [raw]
# # scale data
# scalerX = StandardScaler()
# scalerY = StandardScaler()
#
# # Don't cheat - fit only on training data
# scalerX.fit(Xtrain)
# scalerY.fit(Ytrain)
#
# Xtrain_scaled = scalerX.transform(Xtrain)
# Ytrain_scaled = scalerY.transform(Ytrain)
#
# # apply same transformation to test data
# Xtest_scaled = scalerX.transform(Xtest)
# Ytest_scaled = scalerY.transform(Ytest)

# %%
# scale data 
scalerX = MinMaxScaler([-0.5, 0.5])  
scalerY = MinMaxScaler([-0.5, 0.5])  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xtest_scaled = scalerX.transform(Xtest)
Ytest_scaled = scalerY.transform(Ytest)

# %%
# save scalers, to be used on test set
scalerfileX = 'scalerX.pkl'
pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

scalerfileY = 'scalerY.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %% [markdown]
# # Keras models

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
K.clear_session()

# %%
# create network
def create_network(optimizer = 'rmsprop', dropout_rate=0.1, 
                  numUnits = 400, 
                  NumHiddenLayers = 3, 
                  weightRegularization = 0.0, 
                  secondToLastUnits = 16):
    K.clear_session()
    
    inputs = Input(shape=(Xtrain_scaled.shape[1],))
    x = Dense(numUnits, activation='tanh')(inputs)
    x = Dropout(dropout_rate)(x)
    
    for ii in np.arange(1, NumHiddenLayers + 1):
        x = Dense(numUnits, activation='tanh', 
                  kernel_regularizer=regularizers.l1(weightRegularization))(x)
        x = Dropout(dropout_rate)(x)
    
    x = Dense(secondToLastUnits, activation='tanh')(x)
    predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

    # create model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(loss="mean_squared_error", optimizer = optimizer, metrics = ['mse'])

    return(model)

# %% [raw]
# # create dict of hyperparameters
#
#
# # regularization, num layers, num nodes, learning rate, optimizer, activation function, batch size
#
# from scipy.stats import randint
# from scipy.stats import uniform
#
# # Create hyperparameter space
# NumHiddenLayers = randint(low = 2, high = 20)#[4, 2, 8]
# numUnits  = [2**4, 2**5, 2**6, 2**7, 2**8, 2**9, 2**10]
# epochs = [200]
# batches1 = [2**12, 2**10, 2**8, 2**14]
# optimizers = ['rmsprop', 'adam']
# dropout_rate =  uniform(loc = 0, scale = 0.5) #[0.0, 0.2, 0.5]
# weightRegularization = uniform(loc = 0, scale = 0.001) #[0, 0.0001, 0.001, 0.01]
# secondToLastUnits = [8, 16, 32, 64]
#
# # Create hyperparameter options
# hyperparameters = dict(optimizer=optimizers,
#                         epochs=epochs,
#                         batch_size=batches1,
#                         dropout_rate = dropout_rate,
#                         numUnits = numUnits,
#                         NumHiddenLayers = NumHiddenLayers,
#                         weightRegularization = weightRegularization,
#                         secondToLastUnits = secondToLastUnits)

# %%
Xtrain_scaled_small = Xtrain_scaled[0:8000, :]
Ytrain_scaled_small = Ytrain_scaled[0:8000, :]

# %%
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=20, 
                          verbose=1, mode='auto', min_delta = 0.0001)

model = KerasRegressor(build_fn=create_network, verbose=0)
fit_params = dict(callbacks=[earlystop])

# %%
K.clear_session()

# %% [raw]
# model = create_network(optimizer = bestParams["optimizer"],
#                         dropout_rate=bestParams["dropout_rate"],
#                         numUnits = bestParams["numUnits"],
#                         NumHiddenLayers = bestParams["NumHiddenLayers"],
#                         weightRegularization = bestParams["weightRegularization"],
#                         secondToLastUnits = bestParams['secondToLastUnits'],
#                         batch_size = bestParams['batch_size'])

# %% [markdown]
# model = create_network(optimizer = "rmsprop",
#                         dropout_rate=0.0,
#                         numUnits = 512,
#                         NumHiddenLayers = 1,
#                         weightRegularization = 0,
#                         secondToLastUnits = 32)

# %%
model = create_network(optimizer = "rmsprop", 
                        dropout_rate=0.0, 
                        numUnits = 400, 
                        NumHiddenLayers = 2, 
                        weightRegularization = 0, 
                        secondToLastUnits = 16)

# %%
K.clear_session()
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model_400Units.h5'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 12)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               5200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                6416
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 332,535
# Trainable params: 332,535
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.get_config()
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=150, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
stt = time.time()
history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 1500, verbose = 2, 
                        batch_size =2**14, callbacks = [earlystop], validation_split = 0.3)
# Probably play Windows default sound, if any is registered (because
# "*" probably isn't the registered name of any sound).
winsound.PlaySound("*", winsound.SND_ALIAS)
endd = time.time() - stt
print(endd)
# Out:
# Train on 4178719 samples, validate on 1790881 samples
# Epoch 1/1500
#  - 5s - loss: 3.6081e-04 - mean_squared_error: 3.6081e-04 - val_loss: 3.8843e-04 - val_mean_squared_error: 3.8843e-04
# Epoch 2/1500
#  - 5s - loss: 3.6575e-04 - mean_squared_error: 3.6575e-04 - val_loss: 2.8493e-04 - val_mean_squared_error: 2.8493e-04
# Epoch 3/1500
#  - 5s - loss: 3.5785e-04 - mean_squared_error: 3.5785e-04 - val_loss: 4.5049e-04 - val_mean_squared_error: 4.5049e-04
# Epoch 4/1500
#  - 5s - loss: 3.6036e-04 - mean_squared_error: 3.6036e-04 - val_loss: 3.7376e-04 - val_mean_squared_error: 3.7376e-04
# Epoch 5/1500
#  - 5s - loss: 3.6091e-04 - mean_squared_error: 3.6091e-04 - val_loss: 3.3336e-04 - val_mean_squared_error: 3.3336e-04
# Epoch 6/1500
#  - 5s - loss: 3.6339e-04 - mean_squared_error: 3.6339e-04 - val_loss: 2.7965e-04 - val_mean_squared_error: 2.7965e-04
# Epoch 7/1500
#  - 5s - loss: 3.5823e-04 - mean_squared_error: 3.5823e-04 - val_loss: 3.0651e-04 - val_mean_squared_error: 3.0651e-04
# Epoch 8/1500
#  - 5s - loss: 3.5819e-04 - mean_squared_error: 3.5819e-04 - val_loss: 4.4953e-04 - val_mean_squared_error: 4.4953e-04
# Epoch 9/1500
#  - 5s - loss: 3.6055e-04 - mean_squared_error: 3.6055e-04 - val_loss: 5.5884e-04 - val_mean_squared_error: 5.5884e-04
# Epoch 10/1500
#  - 5s - loss: 3.5805e-04 - mean_squared_error: 3.5805e-04 - val_loss: 5.6603e-04 - val_mean_squared_error: 5.6603e-04
# Epoch 11/1500
#  - 5s - loss: 3.5727e-04 - mean_squared_error: 3.5727e-04 - val_loss: 3.2820e-04 - val_mean_squared_error: 3.2820e-04
# Epoch 12/1500
#  - 5s - loss: 3.5632e-04 - mean_squared_error: 3.5632e-04 - val_loss: 3.8795e-04 - val_mean_squared_error: 3.8795e-04
# Epoch 13/1500
#  - 5s - loss: 3.5760e-04 - mean_squared_error: 3.5760e-04 - val_loss: 3.7290e-04 - val_mean_squared_error: 3.7290e-04
# Epoch 14/1500
#  - 5s - loss: 3.5611e-04 - mean_squared_error: 3.5611e-04 - val_loss: 4.0568e-04 - val_mean_squared_error: 4.0568e-04
# Epoch 15/1500
#  - 5s - loss: 3.5725e-04 - mean_squared_error: 3.5725e-04 - val_loss: 2.9432e-04 - val_mean_squared_error: 2.9432e-04
# Epoch 16/1500
#  - 5s - loss: 3.5596e-04 - mean_squared_error: 3.5596e-04 - val_loss: 2.0660e-04 - val_mean_squared_error: 2.0660e-04
# Epoch 17/1500
#  - 5s - loss: 3.5317e-04 - mean_squared_error: 3.5317e-04 - val_loss: 4.4020e-04 - val_mean_squared_error: 4.4020e-04
# Epoch 18/1500
#  - 5s - loss: 3.5458e-04 - mean_squared_error: 3.5458e-04 - val_loss: 3.0506e-04 - val_mean_squared_error: 3.0506e-04
# Epoch 19/1500
#  - 5s - loss: 3.4750e-04 - mean_squared_error: 3.4750e-04 - val_loss: 2.3886e-04 - val_mean_squared_error: 2.3886e-04
# Epoch 39/1500
#  - 5s - loss: 3.4576e-04 - mean_squared_error: 3.4576e-04 - val_loss: 3.1827e-04 - val_mean_squared_error: 3.1827e-04
# Epoch 40/1500
#  - 5s - loss: 3.4531e-04 - mean_squared_error: 3.4531e-04 - val_loss: 3.4594e-04 - val_mean_squared_error: 3.4594e-04
# Epoch 41/1500
#  - 5s - loss: 3.4510e-04 - mean_squared_error: 3.4510e-04 - val_loss: 3.7156e-04 - val_mean_squared_error: 3.7156e-04
# Epoch 42/1500
#  - 5s - loss: 3.4436e-04 - mean_squared_error: 3.4436e-04 - val_loss: 3.5286e-04 - val_mean_squared_error: 3.5286e-04
# Epoch 43/1500
#  - 5s - loss: 3.4474e-04 - mean_squared_error: 3.4474e-04 - val_loss: 3.4810e-04 - val_mean_squared_error: 3.4810e-04
# Epoch 44/1500
#  - 5s - loss: 3.4310e-04 - mean_squared_error: 3.4310e-04 - val_loss: 3.3931e-04 - val_mean_squared_error: 3.3931e-04
# Epoch 45/1500
#  - 5s - loss: 3.4325e-04 - mean_squared_error: 3.4325e-04 - val_loss: 3.9785e-04 - val_mean_squared_error: 3.9785e-04
# Epoch 46/1500
#  - 5s - loss: 3.4160e-04 - mean_squared_error: 3.4160e-04 - val_loss: 4.1357e-04 - val_mean_squared_error: 4.1357e-04
# Epoch 47/1500
#  - 5s - loss: 3.4314e-04 - mean_squared_error: 3.4314e-04 - val_loss: 3.6286e-04 - val_mean_squared_error: 3.6286e-04
# Epoch 48/1500
#  - 5s - loss: 3.4419e-04 - mean_squared_error: 3.4419e-04 - val_loss: 2.9677e-04 - val_mean_squared_error: 2.9677e-04
# Epoch 49/1500
#  - 5s - loss: 3.4105e-04 - mean_squared_error: 3.4105e-04 - val_loss: 4.0282e-04 - val_mean_squared_error: 4.0282e-04
# Epoch 50/1500
#  - 5s - loss: 3.4050e-04 - mean_squared_error: 3.4050e-04 - val_loss: 4.6222e-04 - val_mean_squared_error: 4.6222e-04
# Epoch 51/1500
#  - 5s - loss: 3.4022e-04 - mean_squared_error: 3.4022e-04 - val_loss: 3.3789e-04 - val_mean_squared_error: 3.3789e-04
# Epoch 52/1500
#  - 5s - loss: 3.4110e-04 - mean_squared_error: 3.4110e-04 - val_loss: 3.0509e-04 - val_mean_squared_error: 3.0509e-04
# Epoch 53/1500
#  - 5s - loss: 3.4254e-04 - mean_squared_error: 3.4254e-04 - val_loss: 3.3119e-04 - val_mean_squared_error: 3.3119e-04
# Epoch 54/1500
#  - 5s - loss: 3.3741e-04 - mean_squared_error: 3.3741e-04 - val_loss: 6.2433e-04 - val_mean_squared_error: 6.2433e-04
# Epoch 55/1500
#  - 5s - loss: 3.3986e-04 - mean_squared_error: 3.3986e-04 - val_loss: 2.8077e-04 - val_mean_squared_error: 2.8077e-04
# Epoch 56/1500
#  - 5s - loss: 3.3956e-04 - mean_squared_error: 3.3956e-04 - val_loss: 3.0282e-04 - val_mean_squared_error: 3.0282e-04
# Epoch 57/1500
#  - 5s - loss: 3.4208e-04 - mean_squared_error: 3.4208e-04 - val_loss: 2.0975e-04 - val_mean_squared_error: 2.0975e-04
# Epoch 58/1500
#  - 5s - loss: 3.3620e-04 - mean_squared_error: 3.3620e-04 - val_loss: 4.6191e-04 - val_mean_squared_error: 4.6191e-04
# Epoch 59/1500
#  - 5s - loss: 3.3654e-04 - mean_squared_error: 3.3654e-04 - val_loss: 3.4109e-04 - val_mean_squared_error: 3.4109e-04
# Epoch 60/1500
#  - 5s - loss: 3.3433e-04 - mean_squared_error: 3.3433e-04 - val_loss: 3.1305e-04 - val_mean_squared_error: 3.1305e-04
# Epoch 61/1500
#  - 5s - loss: 3.3688e-04 - mean_squared_error: 3.3688e-04 - val_loss: 4.0570e-04 - val_mean_squared_error: 4.0570e-04
# Epoch 62/1500
#  - 5s - loss: 3.3831e-04 - mean_squared_error: 3.3831e-04 - val_loss: 2.7686e-04 - val_mean_squared_error: 2.7686e-04
# Epoch 63/1500
#  - 5s - loss: 3.3687e-04 - mean_squared_error: 3.3687e-04 - val_loss: 3.5129e-04 - val_mean_squared_error: 3.5129e-04
# Epoch 64/1500
#  - 5s - loss: 3.3434e-04 - mean_squared_error: 3.3434e-04 - val_loss: 2.3612e-04 - val_mean_squared_error: 2.3612e-04
# Epoch 65/1500
#  - 5s - loss: 3.3671e-04 - mean_squared_error: 3.3671e-04 - val_loss: 2.6943e-04 - val_mean_squared_error: 2.6943e-04
# Epoch 66/1500
#  - 5s - loss: 3.3400e-04 - mean_squared_error: 3.3400e-04 - val_loss: 3.0245e-04 - val_mean_squared_error: 3.0245e-04
# Epoch 67/1500
#  - 5s - loss: 3.3392e-04 - mean_squared_error: 3.3392e-04 - val_loss: 3.5709e-04 - val_mean_squared_error: 3.5709e-04
# Epoch 68/1500
#  - 5s - loss: 3.3438e-04 - mean_squared_error: 3.3438e-04 - val_loss: 4.4480e-04 - val_mean_squared_error: 4.4480e-04
# Epoch 69/1500
#  - 5s - loss: 3.3523e-04 - mean_squared_error: 3.3523e-04 - val_loss: 3.1681e-04 - val_mean_squared_error: 3.1681e-04
# Epoch 70/1500
#  - 5s - loss: 3.3407e-04 - mean_squared_error: 3.3407e-04 - val_loss: 4.1402e-04 - val_mean_squared_error: 4.1402e-04
# Epoch 71/1500
#  - 5s - loss: 3.3274e-04 - mean_squared_error: 3.3274e-04 - val_loss: 3.2077e-04 - val_mean_squared_error: 3.2077e-04
# Epoch 72/1500
#  - 5s - loss: 3.3191e-04 - mean_squared_error: 3.3191e-04 - val_loss: 3.5084e-04 - val_mean_squared_error: 3.5084e-04
# Epoch 73/1500
#  - 5s - loss: 3.3556e-04 - mean_squared_error: 3.3556e-04 - val_loss: 2.8139e-04 - val_mean_squared_error: 2.8139e-04
# Epoch 74/1500
#  - 5s - loss: 3.3134e-04 - mean_squared_error: 3.3134e-04 - val_loss: 5.4578e-04 - val_mean_squared_error: 5.4578e-04
# Epoch 75/1500
#  - 5s - loss: 3.2818e-04 - mean_squared_error: 3.2818e-04 - val_loss: 3.1452e-04 - val_mean_squared_error: 3.1452e-04
# Epoch 76/1500
#  - 5s - loss: 3.3478e-04 - mean_squared_error: 3.3478e-04 - val_loss: 2.9823e-04 - val_mean_squared_error: 2.9823e-04
# Epoch 77/1500
#  - 5s - loss: 3.2992e-04 - mean_squared_error: 3.2992e-04 - val_loss: 3.8081e-04 - val_mean_squared_error: 3.8081e-04
# Epoch 78/1500
#  - 5s - loss: 3.3045e-04 - mean_squared_error: 3.3045e-04 - val_loss: 2.5568e-04 - val_mean_squared_error: 2.5568e-04
# Epoch 79/1500
#  - 5s - loss: 3.2972e-04 - mean_squared_error: 3.2972e-04 - val_loss: 4.7828e-04 - val_mean_squared_error: 4.7828e-04
# Epoch 80/1500
#  - 5s - loss: 3.2966e-04 - mean_squared_error: 3.2966e-04 - val_loss: 4.4966e-04 - val_mean_squared_error: 4.4966e-04
# Epoch 81/1500
#  - 5s - loss: 3.3078e-04 - mean_squared_error: 3.3078e-04 - val_loss: 2.3554e-04 - val_mean_squared_error: 2.3554e-04
# Epoch 82/1500
#  - 5s - loss: 3.2852e-04 - mean_squared_error: 3.2852e-04 - val_loss: 3.1154e-04 - val_mean_squared_error: 3.1154e-04
# Epoch 83/1500
#  - 5s - loss: 3.2910e-04 - mean_squared_error: 3.2910e-04 - val_loss: 3.5740e-04 - val_mean_squared_error: 3.5740e-04
# Epoch 84/1500
#  - 5s - loss: 3.2922e-04 - mean_squared_error: 3.2922e-04 - val_loss: 3.3389e-04 - val_mean_squared_error: 3.3389e-04
# Epoch 85/1500
#  - 5s - loss: 3.2938e-04 - mean_squared_error: 3.2938e-04 - val_loss: 2.7780e-04 - val_mean_squared_error: 2.7780e-04
# Epoch 86/1500
#  - 5s - loss: 3.2435e-04 - mean_squared_error: 3.2435e-04 - val_loss: 3.3166e-04 - val_mean_squared_error: 3.3166e-04
# Epoch 87/1500
#  - 5s - loss: 3.2672e-04 - mean_squared_error: 3.2672e-04 - val_loss: 3.8505e-04 - val_mean_squared_error: 3.8505e-04
# Epoch 88/1500
#  - 5s - loss: 3.2614e-04 - mean_squared_error: 3.2614e-04 - val_loss: 2.9277e-04 - val_mean_squared_error: 2.9277e-04
# Epoch 89/1500
#  - 5s - loss: 3.2497e-04 - mean_squared_error: 3.2497e-04 - val_loss: 4.1887e-04 - val_mean_squared_error: 4.1887e-04
# Epoch 90/1500
#  - 5s - loss: 3.2457e-04 - mean_squared_error: 3.2457e-04 - val_loss: 3.4840e-04 - val_mean_squared_error: 3.4840e-04
# Epoch 91/1500
#  - 5s - loss: 3.2460e-04 - mean_squared_error: 3.2460e-04 - val_loss: 4.0283e-04 - val_mean_squared_error: 4.0283e-04
# Epoch 92/1500
#  - 5s - loss: 3.2631e-04 - mean_squared_error: 3.2631e-04 - val_loss: 2.4034e-04 - val_mean_squared_error: 2.4034e-04
# Epoch 93/1500
#  - 5s - loss: 3.2532e-04 - mean_squared_error: 3.2532e-04 - val_loss: 2.6320e-04 - val_mean_squared_error: 2.6320e-04
# Epoch 94/1500
#  - 5s - loss: 2.8845e-04 - mean_squared_error: 2.8845e-04 - val_loss: 2.6307e-04 - val_mean_squared_error: 2.6307e-04
# Epoch 227/1500
#  - 5s - loss: 2.9090e-04 - mean_squared_error: 2.9090e-04 - val_loss: 2.6051e-04 - val_mean_squared_error: 2.6051e-04
# Epoch 228/1500
#  - 5s - loss: 2.8866e-04 - mean_squared_error: 2.8866e-04 - val_loss: 2.9851e-04 - val_mean_squared_error: 2.9851e-04
# Epoch 229/1500
#  - 5s - loss: 2.9132e-04 - mean_squared_error: 2.9132e-04 - val_loss: 4.2982e-04 - val_mean_squared_error: 4.2982e-04
# Epoch 230/1500
#  - 5s - loss: 2.8543e-04 - mean_squared_error: 2.8543e-04 - val_loss: 3.5599e-04 - val_mean_squared_error: 3.5599e-04
# Epoch 231/1500
#  - 5s - loss: 2.8796e-04 - mean_squared_error: 2.8796e-04 - val_loss: 2.5136e-04 - val_mean_squared_error: 2.5136e-04
# Epoch 232/1500
#  - 5s - loss: 2.8538e-04 - mean_squared_error: 2.8538e-04 - val_loss: 3.0099e-04 - val_mean_squared_error: 3.0099e-04
# Epoch 233/1500
#  - 5s - loss: 2.8808e-04 - mean_squared_error: 2.8808e-04 - val_loss: 3.2638e-04 - val_mean_squared_error: 3.2638e-04
# Epoch 234/1500
#  - 5s - loss: 2.9020e-04 - mean_squared_error: 2.9020e-04 - val_loss: 2.0331e-04 - val_mean_squared_error: 2.0331e-04
# Epoch 235/1500
#  - 5s - loss: 2.8668e-04 - mean_squared_error: 2.8668e-04 - val_loss: 2.9430e-04 - val_mean_squared_error: 2.9430e-04
# Epoch 236/1500
#  - 5s - loss: 2.9083e-04 - mean_squared_error: 2.9083e-04 - val_loss: 1.7847e-04 - val_mean_squared_error: 1.7847e-04
# Epoch 237/1500
#  - 5s - loss: 2.8484e-04 - mean_squared_error: 2.8484e-04 - val_loss: 3.4982e-04 - val_mean_squared_error: 3.4982e-04
# Epoch 238/1500
#  - 5s - loss: 2.8705e-04 - mean_squared_error: 2.8705e-04 - val_loss: 2.2100e-04 - val_mean_squared_error: 2.2100e-04
# Epoch 239/1500
#  - 5s - loss: 2.8739e-04 - mean_squared_error: 2.8739e-04 - val_loss: 2.3085e-04 - val_mean_squared_error: 2.3085e-04
# Epoch 240/1500
#  - 5s - loss: 2.8856e-04 - mean_squared_error: 2.8856e-04 - val_loss: 3.7000e-04 - val_mean_squared_error: 3.7000e-04
# Epoch 241/1500
#  - 5s - loss: 2.8434e-04 - mean_squared_error: 2.8434e-04 - val_loss: 2.7770e-04 - val_mean_squared_error: 2.7770e-04
# Epoch 242/1500
#  - 5s - loss: 2.8490e-04 - mean_squared_error: 2.8490e-04 - val_loss: 3.0527e-04 - val_mean_squared_error: 3.0527e-04
# Epoch 243/1500
#  - 5s - loss: 2.8575e-04 - mean_squared_error: 2.8575e-04 - val_loss: 4.6532e-04 - val_mean_squared_error: 4.6532e-04
# Epoch 244/1500
#  - 5s - loss: 2.8473e-04 - mean_squared_error: 2.8473e-04 - val_loss: 2.0408e-04 - val_mean_squared_error: 2.0408e-04
# Epoch 245/1500
#  - 5s - loss: 2.8656e-04 - mean_squared_error: 2.8656e-04 - val_loss: 3.5797e-04 - val_mean_squared_error: 3.5797e-04
# Epoch 246/1500
#  - 5s - loss: 2.8497e-04 - mean_squared_error: 2.8497e-04 - val_loss: 3.3824e-04 - val_mean_squared_error: 3.3824e-04
# Epoch 247/1500
#  - 5s - loss: 2.8662e-04 - mean_squared_error: 2.8662e-04 - val_loss: 3.7133e-04 - val_mean_squared_error: 3.7133e-04
# Epoch 248/1500
#  - 5s - loss: 2.8130e-04 - mean_squared_error: 2.8130e-04 - val_loss: 2.2745e-04 - val_mean_squared_error: 2.2745e-04
# Epoch 249/1500
#  - 5s - loss: 2.8571e-04 - mean_squared_error: 2.8571e-04 - val_loss: 2.3230e-04 - val_mean_squared_error: 2.3230e-04
# Epoch 250/1500
#  - 5s - loss: 2.8621e-04 - mean_squared_error: 2.8621e-04 - val_loss: 2.2735e-04 - val_mean_squared_error: 2.2735e-04
# Epoch 251/1500
#  - 5s - loss: 2.8277e-04 - mean_squared_error: 2.8277e-04 - val_loss: 3.2873e-04 - val_mean_squared_error: 3.2873e-04
# Epoch 252/1500
#  - 5s - loss: 2.8521e-04 - mean_squared_error: 2.8521e-04 - val_loss: 1.8701e-04 - val_mean_squared_error: 1.8701e-04
# Epoch 253/1500
#  - 5s - loss: 2.8287e-04 - mean_squared_error: 2.8287e-04 - val_loss: 3.1358e-04 - val_mean_squared_error: 3.1358e-04
# Epoch 254/1500
#  - 5s - loss: 2.8500e-04 - mean_squared_error: 2.8500e-04 - val_loss: 2.1537e-04 - val_mean_squared_error: 2.1537e-04
# Epoch 255/1500
#  - 5s - loss: 2.8048e-04 - mean_squared_error: 2.8048e-04 - val_loss: 5.1913e-04 - val_mean_squared_error: 5.1913e-04
# Epoch 256/1500
#  - 5s - loss: 2.8426e-04 - mean_squared_error: 2.8426e-04 - val_loss: 2.6323e-04 - val_mean_squared_error: 2.6323e-04
# Epoch 257/1500
#  - 5s - loss: 2.8248e-04 - mean_squared_error: 2.8248e-04 - val_loss: 4.9555e-04 - val_mean_squared_error: 4.9555e-04
# Epoch 258/1500
#  - 5s - loss: 2.8063e-04 - mean_squared_error: 2.8063e-04 - val_loss: 2.3740e-04 - val_mean_squared_error: 2.3740e-04
# Epoch 259/1500
#  - 5s - loss: 2.8295e-04 - mean_squared_error: 2.8295e-04 - val_loss: 2.6062e-04 - val_mean_squared_error: 2.6062e-04
# Epoch 260/1500
#  - 5s - loss: 2.8316e-04 - mean_squared_error: 2.8316e-04 - val_loss: 2.1681e-04 - val_mean_squared_error: 2.1681e-04
# Epoch 261/1500
#  - 5s - loss: 2.8111e-04 - mean_squared_error: 2.8111e-04 - val_loss: 4.6981e-04 - val_mean_squared_error: 4.6981e-04
# Epoch 262/1500
#  - 5s - loss: 2.8694e-04 - mean_squared_error: 2.8694e-04 - val_loss: 2.3261e-04 - val_mean_squared_error: 2.3261e-04
# Epoch 263/1500
#  - 5s - loss: 2.7864e-04 - mean_squared_error: 2.7864e-04 - val_loss: 3.5365e-04 - val_mean_squared_error: 3.5365e-04
# Epoch 264/1500
#  - 5s - loss: 2.8020e-04 - mean_squared_error: 2.8020e-04 - val_loss: 3.1077e-04 - val_mean_squared_error: 3.1077e-04
# Epoch 265/1500
#  - 5s - loss: 2.8392e-04 - mean_squared_error: 2.8392e-04 - val_loss: 2.4304e-04 - val_mean_squared_error: 2.4304e-04
# Epoch 266/1500
#  - 5s - loss: 2.7769e-04 - mean_squared_error: 2.7769e-04 - val_loss: 2.7934e-04 - val_mean_squared_error: 2.7934e-04
# Epoch 267/1500
#  - 5s - loss: 2.8076e-04 - mean_squared_error: 2.8076e-04 - val_loss: 3.1955e-04 - val_mean_squared_error: 3.1955e-04
# Epoch 268/1500
#  - 5s - loss: 2.7881e-04 - mean_squared_error: 2.7881e-04 - val_loss: 4.1200e-04 - val_mean_squared_error: 4.1200e-04
# Epoch 269/1500
#  - 5s - loss: 2.8366e-04 - mean_squared_error: 2.8366e-04 - val_loss: 2.4775e-04 - val_mean_squared_error: 2.4775e-04
# Epoch 270/1500
#  - 5s - loss: 2.7840e-04 - mean_squared_error: 2.7840e-04 - val_loss: 3.7936e-04 - val_mean_squared_error: 3.7936e-04
# Epoch 271/1500
#  - 5s - loss: 2.8279e-04 - mean_squared_error: 2.8279e-04 - val_loss: 2.1136e-04 - val_mean_squared_error: 2.1136e-04
# Epoch 272/1500
#  - 5s - loss: 2.7788e-04 - mean_squared_error: 2.7788e-04 - val_loss: 2.7185e-04 - val_mean_squared_error: 2.7185e-04
# Epoch 273/1500
#  - 5s - loss: 2.8092e-04 - mean_squared_error: 2.8092e-04 - val_loss: 2.5937e-04 - val_mean_squared_error: 2.5937e-04
# Epoch 274/1500
#  - 5s - loss: 2.7694e-04 - mean_squared_error: 2.7694e-04 - val_loss: 2.5022e-04 - val_mean_squared_error: 2.5022e-04
# Epoch 275/1500
#  - 5s - loss: 2.7873e-04 - mean_squared_error: 2.7873e-04 - val_loss: 2.3897e-04 - val_mean_squared_error: 2.3897e-04
# Epoch 276/1500
#  - 5s - loss: 2.7855e-04 - mean_squared_error: 2.7855e-04 - val_loss: 3.7080e-04 - val_mean_squared_error: 3.7080e-04
# Epoch 277/1500
#  - 5s - loss: 2.7995e-04 - mean_squared_error: 2.7995e-04 - val_loss: 4.1876e-04 - val_mean_squared_error: 4.1876e-04
# Epoch 278/1500
#  - 5s - loss: 2.7818e-04 - mean_squared_error: 2.7818e-04 - val_loss: 2.2143e-04 - val_mean_squared_error: 2.2143e-04
# Epoch 279/1500
#  - 5s - loss: 2.7950e-04 - mean_squared_error: 2.7950e-04 - val_loss: 1.6300e-04 - val_mean_squared_error: 1.6300e-04
# Epoch 280/1500
#  - 5s - loss: 2.7620e-04 - mean_squared_error: 2.7620e-04 - val_loss: 2.5017e-04 - val_mean_squared_error: 2.5017e-04
# Epoch 281/1500
#  - 5s - loss: 2.7705e-04 - mean_squared_error: 2.7705e-04 - val_loss: 4.8522e-04 - val_mean_squared_error: 4.8522e-04
# Epoch 282/1500
#  - 5s - loss: 2.8063e-04 - mean_squared_error: 2.8063e-04 - val_loss: 1.5022e-04 - val_mean_squared_error: 1.5022e-04
# Epoch 283/1500
#  - 5s - loss: 2.7411e-04 - mean_squared_error: 2.7411e-04 - val_loss: 4.6456e-04 - val_mean_squared_error: 4.6456e-04
# Epoch 284/1500
#  - 5s - loss: 2.7752e-04 - mean_squared_error: 2.7752e-04 - val_loss: 3.6477e-04 - val_mean_squared_error: 3.6477e-04
# Epoch 285/1500
#  - 5s - loss: 2.7558e-04 - mean_squared_error: 2.7558e-04 - val_loss: 2.2880e-04 - val_mean_squared_error: 2.2880e-04
# Epoch 286/1500
#  - 5s - loss: 2.7691e-04 - mean_squared_error: 2.7691e-04 - val_loss: 2.6558e-04 - val_mean_squared_error: 2.6558e-04
# Epoch 287/1500
#  - 5s - loss: 2.7854e-04 - mean_squared_error: 2.7854e-04 - val_loss: 2.5347e-04 - val_mean_squared_error: 2.5347e-04
# Epoch 288/1500
#  - 5s - loss: 2.7549e-04 - mean_squared_error: 2.7549e-04 - val_loss: 1.5981e-04 - val_mean_squared_error: 1.5981e-04
# Epoch 289/1500
#  - 5s - loss: 2.7605e-04 - mean_squared_error: 2.7605e-04 - val_loss: 2.5847e-04 - val_mean_squared_error: 2.5847e-04
# Epoch 290/1500
#  - 5s - loss: 2.7379e-04 - mean_squared_error: 2.7379e-04 - val_loss: 2.9913e-04 - val_mean_squared_error: 2.9913e-04
# Epoch 291/1500
#  - 5s - loss: 2.7684e-04 - mean_squared_error: 2.7684e-04 - val_loss: 3.5376e-04 - val_mean_squared_error: 3.5376e-04
# Epoch 292/1500
#  - 5s - loss: 2.7754e-04 - mean_squared_error: 2.7754e-04 - val_loss: 2.6883e-04 - val_mean_squared_error: 2.6883e-04
# Epoch 293/1500
#  - 5s - loss: 2.7390e-04 - mean_squared_error: 2.7390e-04 - val_loss: 1.7224e-04 - val_mean_squared_error: 1.7224e-04
# Epoch 294/1500
#  - 5s - loss: 2.7589e-04 - mean_squared_error: 2.7589e-04 - val_loss: 2.5369e-04 - val_mean_squared_error: 2.5369e-04
# Epoch 295/1500
#  - 5s - loss: 2.7425e-04 - mean_squared_error: 2.7425e-04 - val_loss: 2.8255e-04 - val_mean_squared_error: 2.8255e-04
# Epoch 296/1500
#  - 5s - loss: 2.7569e-04 - mean_squared_error: 2.7569e-04 - val_loss: 2.6413e-04 - val_mean_squared_error: 2.6413e-04
# Epoch 297/1500
#  - 5s - loss: 2.7408e-04 - mean_squared_error: 2.7408e-04 - val_loss: 3.0844e-04 - val_mean_squared_error: 3.0844e-04
# Epoch 298/1500
#  - 5s - loss: 2.7456e-04 - mean_squared_error: 2.7456e-04 - val_loss: 3.0535e-04 - val_mean_squared_error: 3.0535e-04
# Epoch 299/1500
#  - 5s - loss: 2.7614e-04 - mean_squared_error: 2.7614e-04 - val_loss: 3.2132e-04 - val_mean_squared_error: 3.2132e-04
# Epoch 300/1500
#  - 5s - loss: 2.7469e-04 - mean_squared_error: 2.7469e-04 - val_loss: 3.0878e-04 - val_mean_squared_error: 3.0878e-04
# Epoch 301/1500
#  - 5s - loss: 2.7402e-04 - mean_squared_error: 2.7402e-04 - val_loss: 2.5503e-04 - val_mean_squared_error: 2.5503e-04
# Epoch 302/1500
#  - 5s - loss: 2.7251e-04 - mean_squared_error: 2.7251e-04 - val_loss: 2.1568e-04 - val_mean_squared_error: 2.1568e-04
# Epoch 303/1500
#  - 5s - loss: 2.7411e-04 - mean_squared_error: 2.7411e-04 - val_loss: 2.5890e-04 - val_mean_squared_error: 2.5890e-04
# Epoch 304/1500
#  - 5s - loss: 2.7346e-04 - mean_squared_error: 2.7346e-04 - val_loss: 2.9399e-04 - val_mean_squared_error: 2.9399e-04
# Epoch 305/1500
#  - 5s - loss: 2.7305e-04 - mean_squared_error: 2.7305e-04 - val_loss: 3.3042e-04 - val_mean_squared_error: 3.3042e-04
# Epoch 306/1500
#  - 5s - loss: 2.7224e-04 - mean_squared_error: 2.7224e-04 - val_loss: 2.3446e-04 - val_mean_squared_error: 2.3446e-04
# Epoch 307/1500
#  - 5s - loss: 2.7195e-04 - mean_squared_error: 2.7195e-04 - val_loss: 3.9256e-04 - val_mean_squared_error: 3.9256e-04
# Epoch 00307: early stopping
# 1550.6605095863342

# %%
history.history['val_loss'][-1]# MSE for final epoch testing
# not sure why it's different from MSE vs. loss????  answer : I think loss incorporates regularization.
# Out:
# 0.00039255854550724776

# %%
history.history['val_mean_squared_error'][-1] # it is the same when there is no regularization
# Out:
# 0.00039255854550724776

# %%
history.history['loss'][-1]# MSE for final epoch training
# Out:
# 0.00027195196356233516

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_2343Params.png"), dpi = 120, bbox_inches='tight')
    plt.yscale('log') #logarithmic scale for y axis
    plt.show()
    
plot_model_history(history, saveFig=True)

# %%
# save model
model.save(os.path.join(savedModels, 'my_model_400Units.h5'))

# %%
print("hello")

# %%
savedModels

# %%
# check to see if model saved: 
K.clear_session()
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model_512Units.h5'))

# %%
model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
K.clear_session()

# %%
# this is the original model
inputs = Input(shape=(Xtrain_scaled.shape[1],))
x = Dense(400, activation='tanh')(inputs)
x = Dense(400, activation='tanh')(x)
x = Dense(400, activation='tanh')(x)
x = Dense(16, activation='tanh')(x)
predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

# create model
model = Model(inputs=inputs, outputs=predictions)
model.compile(loss="mse", optimizer="adam", metrics = ['mse'])

earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=50, 
                          verbose=1, mode='auto', min_delta = 0.001)

# %%
# start training
history = model.fit(Xtrain_scaled_small, Ytrain_scaled_small, validation_split = 0.3, 
                    verbose = 2, batch_size=2**14, epochs = 200, 
                    callbacks = [earlystop])

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining.png"), dpi = 120, bbox_inches='tight')
    plt.show()
    
plot_model_history(history)
print(history.history["loss"][-1])

# %%
# load model that was trained for much longer
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model.h5'))

# %%
model.summary()

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
#fig.savefig(os.path.join(figDir, "SmallModelResids.png"), dpi = 120, bbox_inches='tight')

# %%
# trim distribution of weights -- cut out middle 20%
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# show new histogram of weights (excluding the 0's)
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    
    d1 = wts[jj].reshape(-1)
    axs[jj].hist(d1[d1!=0], bins = 30, facecolor = '#d6bddb' )
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))

    d2 = wts[jj+1]
    axs[jj+1].hist(d2[d2!=0], bins = 30, facecolor = '#d6bddb')
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# the validation.split is the last X% of the data
int(0.3*Xtrain_scaled.shape[0])
ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
