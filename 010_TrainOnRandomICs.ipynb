# %% [markdown]
# # Callin Switzer
# ### 12 Dec 2018 -- Initial commit
# ___
# ### - Train Dense, Feedforward Neural Network with Keras
# ### - Use data that was generated in Python

# %% [markdown]
# ___

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from matplotlib.ticker import ScalarFormatter
import os
import pandas as pd
import time
from datetime import datetime
import sys
import seaborn as sns
import scipy.io
import subprocess
import winsound
import pickle
import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
print("TensorFlow successfully installed.")
if tf.test.is_built_with_cuda():
    print("The installed version of TensorFlow includes GPU support.")
print(sys.version, "\n")
now = datetime.now()
print("last run on " + str(now))

# define directories
baseDir = os.getcwd()
dataDir = r'D:\MothSimulations\11c-AggressiveManeuver\Qstore\hws_am_con'
figDir = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\Figs'
dataOutput = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\DataOutput'
savedModels = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\savedModels'
randomRawData = r'D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\PythonGeneratedData\TrainingData'
if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
if not os.path.exists(savedModels):
    os.mkdir(savedModels)
# Out:
# C:\Users\calli\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2019-05-13 16:03:02.265153

# %%
# import
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.models import Model
from keras import regularizers

# Keras callcacks
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import keras.backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Make training and test set

# %% [raw]
# # concatenate all files (only need to do this once)
# # it takes a few minutes
# all_files = glob.glob(os.path.join(randomRawData, "*.csv"))
# df_from_each_file = (pd.read_csv(f) for f in all_files)
# concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)
#
# # check for duplicates
# concatenated_df.drop_duplicates(inplace=True)
# concatenated_df.shape
#
# print(concatenated_df.shape)
# concatenated_df.tail()
#
# # save to hdf5
# concatenated_df.to_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
# read in data
trainDF = pd.read_hdf(os.path.join(dataOutput, "concatenatedRandomICs.h5"), key = "data")

# %%
# refref: check for repeats!

# %%
# double check for repeats!
np.sum(trainDF.iloc[:, [16,17,18]].duplicated()) # 0 means no repeats
# Out:
# 0

# %%
print(trainDF.shape)
trainDF.head()
# Out:
# (9900510, 19)
#     x0         xf          xd0          xdf   y0         yf         yd0  \
# 0  0.0  23.367432  1240.975696  1047.460389  0.0  -2.222497 -321.289498
# 1  0.0 -20.768748 -1149.257088 -1075.409015  0.0  11.106142  365.093207
# 2  0.0 -25.280989 -1496.313673 -1133.713595  0.0   4.318522  244.869357
# 3  0.0  -5.931729  -560.948725   -26.956023  0.0   0.748787   86.858301
# 4  0.0  -9.280447  -214.455052  -539.671502  0.0   6.707153  225.808462
#
#           ydf    theta0    thetaf    thetad0     thetadf      phi0      phif  \
# 0  -38.377027  4.539917  6.334514   5.761704  166.050842  2.909070  4.628560
# 1  697.828947  3.243816  4.921125  16.957561  146.364185  3.308109  4.891662
# 2  748.985152  5.436117 -0.270820   7.760703 -563.122968  5.548527 -0.137526
# 3   45.961219  4.004344  4.826500  -0.067853   72.504068  0.510978  1.423037
# 4  488.013492  6.129205  4.399997 -16.195650 -177.812751  1.609007 -0.231868
#
#        phid0       phidf             F     alpha          tau0
# 0  10.607821  162.092739  29718.210402  3.057406  53852.149654
# 1  22.615302  141.667777  28169.483755  3.504285  66579.923810
# 2   0.328348 -561.725041  42042.954099  1.460073 -13638.356558
# 3  24.197259   77.007517  32817.596791  1.943183 -59677.690610
# 4   9.118306 -183.140660  35120.738164  3.267484  77836.665059

# %%
# rename columns to be consistent with other code
trainDF.rename(columns={"x0" : "x_0", "y0" : "y_0", "phi0" : "phi_0", "theta0" : "theta_0", 
                        "xf" : "x_99", "yf" : "y_99", "phif" : "phi_99", "thetaf" : "theta_99", 
                        "xd0" : "x_dot_0", "yd0" : "y_dot_0", "phid0" : "phi_dot_0", "thetad0": "theta_dot_0", 
                        "xdf" : "x_dot_99", "ydf": "y_dot_99", "phidf": "phi_dot_99", "thetadf": "theta_dot_99", 
                        "tau0" : "tau"}, inplace=True)

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

# %%
# make dataset
X = trainDF.loc[:, [ "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99", 
                   "x_dot_0", "y_dot_0", "phi_dot_0", "theta_dot_0"]]

Y = trainDF.loc[:, ["Fx", "Fy", "tau", "x_dot_99", "y_dot_99", 
                    "phi_dot_99", "theta_dot_99"] ]

# %%
X.head()
# Out:
#       phi_0   theta_0       x_99       y_99    phi_99  theta_99      x_dot_0  \
# 0  2.909070  4.539917  23.367432  -2.222497  4.628560  6.334514  1240.975696
# 1  3.308109  3.243816 -20.768748  11.106142  4.891662  4.921125 -1149.257088
# 2  5.548527  5.436117 -25.280989   4.318522 -0.137526 -0.270820 -1496.313673
# 3  0.510978  4.004344  -5.931729   0.748787  1.423037  4.826500  -560.948725
# 4  1.609007  6.129205  -9.280447   6.707153 -0.231868  4.399997  -214.455052
#
#       y_dot_0  phi_dot_0  theta_dot_0
# 0 -321.289498  10.607821     5.761704
# 1  365.093207  22.615302    16.957561
# 2  244.869357   0.328348     7.760703
# 3   86.858301  24.197259    -0.067853
# 4  225.808462   9.118306   -16.195650

# %%
Y.head()
# Out:
#              Fx            Fy           tau     x_dot_99    y_dot_99  \
# 0 -29612.961122   2498.912376  53852.149654  1047.460389  -38.377027
# 1 -26336.915345  -9994.333651  66579.923810 -1075.409015  697.828947
# 2   4645.636361  41785.500502 -13638.356558 -1133.713595  748.985152
# 3 -11940.326951  30568.337400 -59677.690610   -26.956023   45.961219
# 4 -34842.795622  -4409.744037  77836.665059  -539.671502  488.013492
#
#    phi_dot_99  theta_dot_99
# 0  162.092739    166.050842
# 1  141.667777    146.364185
# 2 -561.725041   -563.122968
# 3   77.007517     72.504068
# 4 -183.140660   -177.812751

# %%
# test train split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.2, random_state = 123)

# %% [raw]
# # scale data
# scalerX = StandardScaler()
# scalerY = StandardScaler()
#
# # Don't cheat - fit only on training data
# scalerX.fit(Xtrain)
# scalerY.fit(Ytrain)
#
# Xtrain_scaled = scalerX.transform(Xtrain)
# Ytrain_scaled = scalerY.transform(Ytrain)
#
# # apply same transformation to test data
# Xtest_scaled = scalerX.transform(Xtest)
# Ytest_scaled = scalerY.transform(Ytest)

# %%
# scale data 
scalerX = MinMaxScaler([-0.5, 0.5])  
scalerY = MinMaxScaler([-0.5, 0.5])  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xtest_scaled = scalerX.transform(Xtest)
Ytest_scaled = scalerY.transform(Ytest)

# %%
pd.DataFrame(Xtrain_scaled, columns = X.columns).head()
# Out:
#       phi_0   theta_0      x_99      y_99    phi_99  theta_99   x_dot_0  \
# 0 -0.479611  0.002266 -0.318639 -0.229442 -0.094704  0.071486 -0.491811
# 1 -0.453551  0.264615  0.295886  0.197180 -0.188053  0.054898  0.469097
# 2 -0.102133 -0.139825  0.314624  0.345313 -0.234415 -0.252743  0.486725
# 3 -0.025410  0.473391 -0.026110  0.073530  0.050494  0.209861 -0.032577
# 4  0.492691 -0.269698 -0.131405  0.348033  0.118454 -0.135028 -0.191459
#
#     y_dot_0  phi_dot_0  theta_dot_0
# 0 -0.220474   0.168732     0.450440
# 1  0.195148   0.353807    -0.446865
# 2  0.399421   0.036643    -0.265189
# 3 -0.026313  -0.037384    -0.004011
# 4  0.408163  -0.416592    -0.057925

# %%
# save scalers, to be used on test set
scalerfileX = 'scalerX.pkl'
pickle.dump(scalerX, open(os.path.join(dataOutput, scalerfileX), 'wb'))

scalerfileY = 'scalerY.pkl'
pickle.dump(scalerY, open(os.path.join(dataOutput, scalerfileY), 'wb'))

# %% [markdown]
# # Keras models

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
K.clear_session()

# %%
# refref: start with small network and then build up

# %%
# create network
def create_network(optimizer = 'rmsprop', 
                    numUnits = [400, 16], 
                    weightRegularization = 0.0, 
                    dropout_rate=0.1):
    
    '''
    Create a feed forward network.  Assumes Xtrain & Ytrain have been created and scaled
    
    Params: 
    optimizer (str): choice of optimizer
    numUnits (list): number of units in each hidden
    weightRegularization (float): between 0 and 1
    dropout_rate (float): between 0 and 1
    
    '''
    K.clear_session()
    inputs = Input(shape=(Xtrain_scaled.shape[1],))    
    
    # add layers
    for ii in np.arange(0, len(numUnits)):
        if ii >= 1: 
            x = Dense(numUnits[ii], activation='tanh', 
                      kernel_regularizer=regularizers.l1(weightRegularization))(x)

        else: 
            x = Dense(numUnits[ii], activation='tanh')(inputs)


        # add dropout
        if dropout_rate > 0: 
            x = Dropout(dropout_rate)(x)
    
    predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

    # create model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(loss="mean_squared_error", optimizer = optimizer, metrics = ['mse'])

    return(model)

# %%
model = create_network(optimizer = "rmsprop", 
                        dropout_rate=0.0, 
                        numUnits = [400, 400, 400, 16], 
                        weightRegularization = 0)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               4400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                6416
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 331,735
# Trainable params: 331,735
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelParams = {"optimizer": "rmsprop", 
              "dropout_rate" : 0.0, 
               "numUnits": [400, 400, 400, 16],
               "weightRegularization": 0.0
              }


model = create_network(**modelParams)

modelName = ''.join('{}_{}__'.format(key[0:3].capitalize(), val) for  key, val in modelParams.items()).replace("[", "").replace("]", "").replace(", ", "_")[0:-2]
print(modelName)

model.summary()
# Out:
# Opt_rmsprop__Dro_0.0__Num_400_400_400_16__Wei_0.0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               4400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                6416
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 331,735
# Trainable params: 331,735
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.get_config()
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=15, 
                          verbose=1, mode='auto', min_delta = 0.000001)

# %%
# fit model without regularization
stt = time.time()
history = model.fit(Xtrain_scaled, Ytrain_scaled, epochs = 150, verbose = 2, 
                        batch_size=2**14, callbacks = [earlystop], validation_split = 0.3)
winsound.PlaySound("*", winsound.SND_ALIAS)
endd = time.time() - stt
print(endd)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/150
#  - 5s - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 2/150
#  - 5s - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 3/150
#  - 4s - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 4/150
#  - 5s - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 5/150
#  - 5s - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 6/150
#  - 5s - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 7/150
#  - 5s - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 8/150
#  - 5s - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 9/150
#  - 5s - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 10/150
#  - 5s - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 11/150
#  - 5s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 12/150
#  - 5s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 13/150
#  - 4s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 14/150
#  - 4s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 15/150
#  - 4s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 16/150
#  - 4s - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 17/150
#  - 5s - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 18/150
#  - 5s - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 19/150
#  - 5s - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 20/150
#  - 5s - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 21/150
#  - 5s - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 22/150
#  - 5s - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 23/150
#  - 4s - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
# Epoch 24/150
#  - 5s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 25/150
#  - 5s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 26/150
#  - 5s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 27/150
#  - 5s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 28/150
#  - 5s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 29/150
#  - 5s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 30/150
#  - 5s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 31/150
#  - 5s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 32/150
#  - 5s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 33/150
#  - 5s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 34/150
#  - 5s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 35/150
#  - 5s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 36/150
#  - 5s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 37/150
#  - 5s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 38/150
#  - 5s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 39/150
#  - 5s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 40/150
#  - 5s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 41/150
#  - 5s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 42/150
#  - 5s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 43/150
#  - 5s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 44/150
#  - 5s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 45/150
#  - 5s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 46/150
#  - 4s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 47/150
#  - 5s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 48/150
#  - 5s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 49/150
#  - 5s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 50/150
#  - 5s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 51/150
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 52/150
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 53/150
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 54/150
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 55/150
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 56/150
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 57/150
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 58/150
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 59/150
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 60/150
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 61/150
#  - 5s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 62/150
#  - 5s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 63/150
#  - 5s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 64/150
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 65/150
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 66/150
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 67/150
#  - 5s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 68/150
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 69/150
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 70/150
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 71/150
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 72/150
#  - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 73/150
#  - 4s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 74/150
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 75/150
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 76/150
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 77/150
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 78/150
#  - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 79/150
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 80/150
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 81/150
#  - 4s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 82/150
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 83/150
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 84/150
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 85/150
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 86/150
#  - 5s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 87/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 88/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 89/150
#  - 4s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 90/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 91/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 92/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 93/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 94/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 95/150
#  - 4s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.1907e-04 - val_mean_squared_error: 9.1907e-04
# Epoch 96/150
#  - 5s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.9770e-04 - val_mean_squared_error: 9.9770e-04
# Epoch 97/150
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 98/150
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 8.9241e-04 - val_mean_squared_error: 8.9241e-04
# Epoch 99/150
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.2864e-04 - val_mean_squared_error: 9.2864e-04
# Epoch 100/150
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.4209e-04 - val_mean_squared_error: 9.4209e-04
# Epoch 101/150
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 8.2991e-04 - val_mean_squared_error: 8.2991e-04
# Epoch 102/150
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 8.8986e-04 - val_mean_squared_error: 8.8986e-04
# Epoch 103/150
#  - 5s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.7986e-04 - val_mean_squared_error: 9.7986e-04
# Epoch 104/150
#  - 5s - loss: 9.9676e-04 - mean_squared_error: 9.9676e-04 - val_loss: 8.6403e-04 - val_mean_squared_error: 8.6403e-04
# Epoch 105/150
#  - 5s - loss: 9.8893e-04 - mean_squared_error: 9.8893e-04 - val_loss: 9.9967e-04 - val_mean_squared_error: 9.9967e-04
# Epoch 106/150
#  - 5s - loss: 9.8462e-04 - mean_squared_error: 9.8462e-04 - val_loss: 9.4600e-04 - val_mean_squared_error: 9.4600e-04
# Epoch 107/150
#  - 5s - loss: 9.7638e-04 - mean_squared_error: 9.7638e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 108/150
#  - 5s - loss: 9.7245e-04 - mean_squared_error: 9.7245e-04 - val_loss: 7.8586e-04 - val_mean_squared_error: 7.8586e-04
# Epoch 109/150
#  - 5s - loss: 9.6330e-04 - mean_squared_error: 9.6330e-04 - val_loss: 8.9575e-04 - val_mean_squared_error: 8.9575e-04
# Epoch 110/150
#  - 5s - loss: 9.6009e-04 - mean_squared_error: 9.6009e-04 - val_loss: 9.0558e-04 - val_mean_squared_error: 9.0558e-04
# Epoch 111/150
#  - 4s - loss: 9.5124e-04 - mean_squared_error: 9.5124e-04 - val_loss: 9.3347e-04 - val_mean_squared_error: 9.3347e-04
# Epoch 112/150
#  - 5s - loss: 9.4804e-04 - mean_squared_error: 9.4804e-04 - val_loss: 9.5998e-04 - val_mean_squared_error: 9.5998e-04
# Epoch 113/150
#  - 5s - loss: 9.4377e-04 - mean_squared_error: 9.4377e-04 - val_loss: 8.7622e-04 - val_mean_squared_error: 8.7622e-04
# Epoch 114/150
#  - 4s - loss: 9.3530e-04 - mean_squared_error: 9.3530e-04 - val_loss: 9.1845e-04 - val_mean_squared_error: 9.1845e-04
# Epoch 115/150
#  - 4s - loss: 9.2939e-04 - mean_squared_error: 9.2939e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 116/150
#  - 5s - loss: 9.2643e-04 - mean_squared_error: 9.2643e-04 - val_loss: 7.8488e-04 - val_mean_squared_error: 7.8488e-04
# Epoch 117/150
#  - 5s - loss: 9.1944e-04 - mean_squared_error: 9.1944e-04 - val_loss: 8.6102e-04 - val_mean_squared_error: 8.6102e-04
# Epoch 118/150
#  - 5s - loss: 9.1474e-04 - mean_squared_error: 9.1474e-04 - val_loss: 8.6743e-04 - val_mean_squared_error: 8.6743e-04
# Epoch 119/150
#  - 4s - loss: 9.0980e-04 - mean_squared_error: 9.0980e-04 - val_loss: 9.3346e-04 - val_mean_squared_error: 9.3346e-04
# Epoch 120/150
#  - 5s - loss: 9.0499e-04 - mean_squared_error: 9.0499e-04 - val_loss: 9.0204e-04 - val_mean_squared_error: 9.0204e-04
# Epoch 121/150
#  - 5s - loss: 9.0046e-04 - mean_squared_error: 9.0046e-04 - val_loss: 8.1097e-04 - val_mean_squared_error: 8.1097e-04
# Epoch 122/150
#  - 5s - loss: 8.9355e-04 - mean_squared_error: 8.9355e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 123/150
#  - 4s - loss: 8.8934e-04 - mean_squared_error: 8.8934e-04 - val_loss: 9.7416e-04 - val_mean_squared_error: 9.7416e-04
# Epoch 00123: early stopping
# 566.2011976242065

# %%
history.history['val_loss'][-1]# MSE for final epoch testing
# why are val MSE vs. loss different????  answer : I think loss incorporates regularization.
# Out:
# 0.0009741578262365548

# %%
history.history['val_mean_squared_error'][-1] # it is the same when there is no regularization
# Out:
# 0.0009741578262365548

# %%
history.history['loss'][-1]# MSE for final epoch training
# Out:
# 0.0008893398097671787

# %%
def format_e(n):
    a = '%E' % n
    return a.split('E')[0].rstrip('0').rstrip('.') + 'E' + a.split('E')[1]

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE = '+ str(format_e(model_history.history['val_mean_squared_error'][-1])))
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    plt.yscale('log') #logarithmic scale for y axis
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_" + modelName + ".png"), dpi = 120, bbox_inches='tight')
    
    plt.show()
    
plot_model_history(history, saveFig=True)

# %%
# save model
model.save(os.path.join(savedModels,  modelName + '.h5'))

# %%
# save weights
wts = model.get_weights().copy()

wtsFile = modelName + '_wts.pkl'
pickle.dump(wts, open(os.path.join(dataOutput, wtsFile), 'wb'))

# %%
# read file back in 
wt2 = pickle.load(open(os.path.join(dataOutput, wtsFile), 'rb'))

# %%
# END
os.path.join(dataOutput, wtsFile)
# Out:
# 'D:\\Dropbox\\AcademiaDropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Opt_rmsprop__Dro_0.0__Num_20_20_16__Wei_0_wts.pkl'

# %% [markdown]
# ___

# %%
## START NEW ITEM: train and trim weights

# %%
# train and trim weights

# %%
modelParams = {"optimizer": "rmsprop", 
              "dropout_rate" : 0.0, 
               "numUnits": [20, 20, 16],
               "weightRegularization": 0
              }


model = create_network(**modelParams)

modelName = ''.join('{}_{}__'.format(key[0:3].capitalize(), val) for  key, val in modelParams.items()).replace("[", "").replace("]", "").replace(", ", "_")[0:-2]
print(modelName)

model.summary()
# Out:
# Opt_rmsprop__Dro_0.0__Num_20_20_16__Wei_0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                336
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 1,095
# Trainable params: 1,095
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_to_wts_file = os.path.join(dataOutput, wtsFile)
path_to_wts_file
# Out:
# 'D:\\Dropbox\\AcademiaDropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Opt_rmsprop__Dro_0.0__Num_20_20_16__Wei_0_wts.pkl'

# %%
# read in data
import pickle
import numpy as np

wts =  pickle.load(open("path_to_wts_file", 'rb'))

# print sizes of each weight matrix
wtLengths = []
for ii in range(len(wts)):
    print(wts[ii].shape)
    wtLengths.append(np.prod(wts[ii].shape))

print(np.sum(wtLengths), "total weights")
# Out:
# (10, 20)
# (20,)
# (20, 20)
# (20,)
# (20, 16)
# (16,)
# (16, 7)
# (7,)
# 1095 total weights

# %%
# print sizes of each weight matrix
wtLengths = []

wts = model.get_weights().copy()

for ii in range(len(wts)):
    print(wts[ii].shape)
    wtLengths.append(np.prod(wts[ii].shape))
print(np.sum(wtLengths), "total weights")

# %%
# start training
historyDict = {"mean_squared_error": [], 
               "val_mean_squared_error": []}

# %%
for numEpocs in range(40):

    history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                        verbose = 2, batch_size=2**14, epochs = 1, 
                        callbacks = [earlystop])
    # save history
    historyDict["mean_squared_error"].append(history.history["mean_squared_error"][0])
    historyDict["val_mean_squared_error"].append(history.history["val_mean_squared_error"][0])
    
    # set weights that are close to 0 all the way back to 0, and then retrain for one epoch
    # get nonzero weights
    wts = model.get_weights().copy()
    
    # set weights close to 0 to 0 (but ignore biases)
    for ii in np.arange(0, len(wts), 2):
        qants = np.percentile(np.reshape(wts[ii], -1), q = (15, 85), )
        wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
        
    # print nonzero weights
    # calculate number of nonzero weights
    nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
    print(nzwts, "of", np.sum(wtLengths), "weights retained")

    # set new weights and calculate new loss
    model.set_weights(wts)
# Out:
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 5s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# 373 of 1095 weights retained
# Train on 5544285 samples, validate on 2376123 samples
# Epoch 1/1
#  - 4s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# 373 of 1095 weights retained

# %%
def plot_model_history_fromDict(model_history_dictionary, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history_dictionary['mean_squared_error'])+1),
             model_history_dictionary['mean_squared_error'])
    axs.plot(range(1,len(model_history_dictionary['val_mean_squared_error'])+1),
             model_history_dictionary['val_mean_squared_error'])
    axs.set_title('Model MSE = '+ str(format_e(model_history_dictionary['val_mean_squared_error'][-1])) + "\n" +  str(nzwts) + " non-zero weights")
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history_dictionary['val_mean_squared_error'])+1),
                   len(model_history_dictionary['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    plt.yscale('log') #logarithmic scale for y axis
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned.png"), dpi = 120, bbox_inches='tight')
        print(os.path.join(figDir, "ModelTraining_" + modelName + "_pruned.png"))
    plt.show()
    
plot_model_history_fromDict(historyDict, saveFig = True)
# Out:
# D:\Dropbox\AcademiaDropbox\mothMachineLearning_dataAndFigs\Figs\ModelTraining_Opt_rmsprop__Dro_0.0__Num_20_20_16__Wei_0_pruned.png

# %%
# how good can I get without trimming

# %%
# plot matrices
wts = model.get_weights().copy()
for ii in np.arange(0, len(wts), 2):
    plt.matshow(wts[ii], cmap = "PRGn")
    plt.colorbar()
    plt.show()

# %%
# refref: save weights and model
model.save(os.path.join(savedModels,  modelName + '_pruned.h5'))

# save weights
wts = model.get_weights().copy()

wtsFile = modelName + '_pruned_wts.pkl'
pickle.dump(wts, open(os.path.join(dataOutput, wtsFile), 'wb'))

# %%
# refref: if whole node is basically 0, then remove the node.
# Out:
# (array([ 1.,  2., 11., 28., 66., 96., 66., 41.,  6.,  3.]),
#  array([-1.63204086, -1.33877281, -1.04550476, -0.75223671, -0.45896866,
#         -0.16570061,  0.12756743,  0.42083548,  0.71410353,  1.00737158,
#          1.30063963]),
#  <a list of 10 Patch objects>)

# %%
np.std(wts[2].reshape(-1,))
# Out:
# 0.2601679

# %%
model = create_network(**modelParams)

history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                        verbose = 2, batch_size=2**14, epochs = 1, 
                        callbacks = [earlystop])

# %%
# check to see if model saved: 
K.clear_session()
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model_400Units_newData.h5'))

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
len(wts[4])

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((20,3)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 100)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 100)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
len(model.get_weights())

# %%
model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (5, 95), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

# %%
ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %% [raw]
# K.clear_session()

# %% [raw]
# # this is the original model
# inputs = Input(shape=(Xtrain_scaled.shape[1],))
# x = Dense(400, activation='tanh')(inputs)
# x = Dense(400, activation='tanh')(x)
# x = Dense(400, activation='tanh')(x)
# x = Dense(16, activation='tanh')(x)
# predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)
#
# # create model
# model = Model(inputs=inputs, outputs=predictions)
# model.compile(loss="mse", optimizer="adam", metrics = ['mse'])
#
# earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=50,
#                           verbose=1, mode='auto', min_delta = 0.001)

# %%
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)

# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (2, 98), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)
model.set_weights(wts)


# start training
history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                    verbose = 2, batch_size=2**14, epochs = 1, 
                    callbacks = [earlystop])

# %%
wts = model.get_weights().copy()

# trim weights
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (2.5, 97.5), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0

# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
print(nzwts)
model.set_weights(wts)

model.evaluate(Xtest_scaled, Ytest_scaled)

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining.png"), dpi = 120, bbox_inches='tight')
    plt.show()
    
plot_model_history(history)
print(history.history["loss"][-1])

# %%
# load model that was trained for much longer
from keras.models import load_model
model = load_model(os.path.join(savedModels, 'my_model.h5'))

# %%
model.summary()

# %%
# get nonzero weights
wts = model.get_weights().copy()
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.05*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
wts = model.get_weights().copy()
nzwts = [np.nonzero(wts[ii].reshape(-1))[0] for ii in range(len(wts))]

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((20,5)) , facecolor='w', edgecolor='k')
#fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(nzwts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(nzwts[jj].shape))
    axs[jj+1].hist(nzwts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(nzwts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,8, figsize=np.array((10,10)) , facecolor='w', edgecolor='k')
#fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    axs[jj].hist(wts[jj].reshape(-1), bins = 30)
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))
    axs[jj+1].hist(wts[jj+1], bins = 30)
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()
#fig.savefig(os.path.join(figDir, "SmallModelResids.png"), dpi = 120, bbox_inches='tight')

# %%
# trim distribution of weights -- cut out middle 20%
for ii in np.arange(0, 7):
    qants = np.percentile(np.reshape(wts[ii], -1), q = (40, 60), )
    wts[ii][(wts[ii] > qants[0]) & (wts[ii] < qants[1])] = 0
    
# calculate number of nonzero weights
nzwts = np.sum([np.nonzero(wts[ii].reshape(-1))[0].shape[0] for ii in range(len(wts))])
nzwts

# %%
# show new histogram of weights (excluding the 0's)
# show weights histograms
plt.close("all")
fig, axs = plt.subplots(2,5, figsize=np.array((15, 6)) , facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.3, wspace=0.3)
axs = axs.ravel(order = "F")

for ii in range(int(len(wts) / 2)):  
    jj= int(2*ii)
    
    d1 = wts[jj].reshape(-1)
    axs[jj].hist(d1[d1!=0], bins = 30, facecolor = '#d6bddb' )
    axs[jj].set_xlabel("Layer " + str(int(jj/2)) + " weights" + ", shape = " + str(wts[jj].shape))

    d2 = wts[jj+1]
    axs[jj+1].hist(d2[d2!=0], bins = 30, facecolor = '#d6bddb')
    axs[jj+1].set_xlabel("Layer " + str(int(jj/2)) + " biases" + ", shape = " + str(wts[jj+1].shape))

plt.tight_layout()
plt.show()

# %%
# the validation.split is the last X% of the data
int(0.3*Xtrain_scaled.shape[0])
ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# set new weights and calculate new loss
model.set_weights(wts)

ValLoss = model.evaluate(Xtrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :], 
                         Ytrain_scaled[-int(0.3*Xtrain_scaled.shape[0]):, :])
print(ValLoss[0])

# %%
# predict on test set
nnpreds = model.predict(Xtest_scaled[ :])

# rescale
nnpreds_unscaled = scalerY.inverse_transform(nnpreds)

# show residuals
# combine residual and regular plots
plt.close("all")
fig, axs = plt.subplots(2,7, figsize=np.array((30, 8)) / 1.7, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.5)
axs = axs.ravel()

# replace lightest colors with white
import matplotlib.colors
cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(len(Y.columns)):
    
    try:
        axs[ii].hexbin(y = Ytest.iloc[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[ii].ticklabel_format(style='sci',  axis='y', scilimits=(3,4))
        axs[ii].axes.xaxis.set_ticklabels([])
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value")
        axs[ii].set_title(nms2[ii])
        axs[ii].plot(Ytest.iloc[0:1000,ii], Ytest.iloc[0:1000,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

for ii in range(len(Y.columns)):
    jj = ii + len(Y.columns)
    
    try:
        axs[jj].hexbin(y = Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii],x = nnpreds_unscaled[:,ii], gridsize = 150, cmap = cmap)
        axs[jj].set_xlabel("Predicted Value")
        axs[jj].xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        axs[jj].yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
        mmin = np.min(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        mmax = np.max(Ytest.iloc[:,ii] - nnpreds_unscaled[:,ii])
        
        upper = np.max([np.abs(mmin), np.abs(mmax)])
        axs[jj].set_ylim(-upper, upper)

        if(ii == 0):
            axs[jj].set_ylabel("Actual - Predicted")
        axs[jj].hlines(y = 0, xmin = np.min(nnpreds_unscaled[:,ii]), 
                       xmax = np.max(nnpreds_unscaled[:,ii]), linestyle =  "--", linewidth = 1)
    except:
        pass
plt.tight_layout()

# %%
# create dict of hyperparameters


# regularization, num layers, num nodes, learning rate, optimizer, activation function, batch size

from scipy.stats import randint
from scipy.stats import uniform

# Create hyperparameter space
NumHiddenLayers = randint(low = 2, high = 20)#[4, 2, 8]
numUnits  = [2**4, 2**5, 2**6, 2**7, 2**8, 2**9, 2**10]
epochs = [200]
batches1 = [2**12, 2**10, 2**8, 2**14] 
optimizers = ['rmsprop', 'adam']
dropout_rate =  uniform(loc = 0, scale = 0.5) #[0.0, 0.2, 0.5]
weightRegularization = uniform(loc = 0, scale = 0.001) #[0, 0.0001, 0.001, 0.01]
secondToLastUnits = [8, 16, 32, 64]

# Create hyperparameter options
hyperparameters = dict(optimizer=optimizers, 
                        epochs=epochs, 
                        batch_size=batches1,
                        dropout_rate = dropout_rate, 
                        numUnits = numUnits, 
                        NumHiddenLayers = NumHiddenLayers, 
                        weightRegularization = weightRegularization, 
                        secondToLastUnits = secondToLastUnits)
